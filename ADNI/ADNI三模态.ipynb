# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#生物标志物 ad 90*48   no 349*58
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'normal_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'ad_nii_KG/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NC_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #151
print(count_no) #211
print(count_mci) #475
# Out:
# 151
# 211
# 475

# %%
# 基础替换字典
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0', 'ind':'3', 'ans':'4'}

# 隔离诊断标签的列索引提取规则
# EHR (14维): age(2), gender(3), education(4), hispanic(5), race(6) + his_系列(57-65)
ehr_cols = [2, 3, 4, 5, 6] + list(range(57, 66))
# BIO (39维): apoe(7) + mmse/cdr(20-22) + gds/moca(66, 67) + trail/npiq/faq等(24-56)
bio_cols = [7, 20, 21, 22, 66, 67] + list(range(24, 57))

# 统一且安全的预处理函数
def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        extracted_row = [row[idx] for idx in target_cols]
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                if math.isnan(val):
                    val = np.nan
            except ValueError:
                val = np.nan
            numerical_row.append(val)
        processed_data.append(numerical_row)
    return np.array(processed_data, dtype=float)

# 1. 提取 BIO 数组 (39 维特征)
ad_array = preprocess_data(data_ad, replace_dict, bio_cols)

normal_array = preprocess_data(data_normal, replace_dict, bio_cols)
mci_array = preprocess_data(data_mci, replace_dict, bio_cols)
print('ad.BIO--->', ad_array.shape)
print('normal.BIO--->', normal_array.shape)
print('mci.BIO--->', mci_array.shape)
# Out:
# ad.BIO---> (151, 39)
# normal.BIO---> (211, 39)
# mci.BIO---> (475, 39)

# %%
#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # 推荐：引入激活函数库

# 1. 转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 2. 定义网络层 
# 关键修复：输入维度改为 39（BIO 特征维度）
# 关键优化：使用不同的变量名 (fc1, fc2, fc3) 防止层被覆盖
fc1 = nn.Linear(39, 32)
fc2 = nn.Linear(32, 16)
fc3 = nn.Linear(16, 1)

# 3. 前向传播
# 注意：多层网络通常需要在层与层之间加激活函数(如 ReLU)，否则它数学上等价于单层网络。
# 为了保持代码运行，这里先按你的逻辑写，如果需要增加非线性能力，请取消注释 relu 行。

# 第一层
ad_tensor = fc1(ad_tensor)
# ad_tensor = F.relu(ad_tensor) 
normal_tensor = fc1(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc1(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第二层
ad_tensor = fc2(ad_tensor)
# ad_tensor = F.relu(ad_tensor)
normal_tensor = fc2(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc2(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第三层 (输出层)
ad_tensor = fc3(ad_tensor)
normal_tensor = fc3(normal_tensor)
mci_tensor = fc3(mci_tensor)

# 4. 打印结果
print('AD_tensor shape:', ad_tensor.shape)      # 预期: (151, 1)
print('Normal_tensor shape:', normal_tensor.shape) # 预期: (211, 1)
print('MCI_tensor shape:', mci_tensor.shape)    # 预期: (475, 1)
# Out:
# AD_tensor shape: torch.Size([151, 1])
# Normal_tensor shape: torch.Size([211, 1])
# MCI_tensor shape: torch.Size([475, 1])

# %%
# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict, ehr_cols)
normal_data = preprocess_data(data_normal, replace_dict, ehr_cols)
mci_data = preprocess_data(data_mci, replace_dict, ehr_cols)

categorical_indices = [1, 2, 3, 4]  # gender, education, hispanic, race
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(14, 16)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(16, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])

# %%
#医学图像
nii = CNN_3D(num_class=1)
nii = nii.to(device)
all_ad = 'ad_nii_KG/'
all_normal = 'normal_nii_kg/'
all_mci = 'NC_nii_kg/'

# 打印原始 NIfTI tensor 形状，确保 MRI 提取的 nii.shape 可见

def print_raw_nii_shape(folder, label):
    dataset = NiiDataset(folder)
    if len(dataset) == 0:
        print(f'{label} raw nii tensor shape---> empty dataset')
        return
    print(f'{label} raw nii tensor shape--->', dataset[0].shape)

print_raw_nii_shape(all_ad, 'ad')
print_raw_nii_shape(all_normal, 'normal')
print_raw_nii_shape(all_mci, 'mci')

dataset = NiiDataset(all_ad)
batch_size = 16
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_normal)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_mci)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)
# Out:
# ad raw nii tensor shape---> torch.Size([1, 64, 64, 64])
# normal raw nii tensor shape---> torch.Size([1, 64, 64, 64])
# mci raw nii tensor shape---> torch.Size([1, 64, 64, 64])

# %%
print('ad.BIO--->', ad_tensor.shape)
print('normal.BIO--->', normal_tensor.shape)
print('mci.BIO--->', mci_tensor.shape)
print('ad.EHR--->', ad_EHR.shape)
print('normal.EHR--->', normal_EHR.shape)
print('mci.EHR--->', mci_EHR.shape)
print('ad nii shape--->', ad_output.shape)
print('normal nii shape--->', normal_output.shape)
print('mci nii shape--->', mci_output.shape)
# Out:
# ad.BIO---> torch.Size([151, 1])
# normal.BIO---> torch.Size([211, 1])
# mci.BIO---> torch.Size([475, 1])
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])
# ad nii shape---> torch.Size([151, 1])
# normal nii shape---> torch.Size([211, 1])
# mci nii shape---> torch.Size([475, 1])

# %%
ad_EHR = ad_EHR.cpu()
ad_tensor = ad_tensor.cpu()
mci_EHR = mci_EHR.cpu()
mci_tensor = mci_tensor.cpu()
normal_EHR = normal_EHR.cpu()
normal_tensor = normal_tensor.cpu()
ad_output = ad_output.cpu()
mci_output = mci_output.cpu()
normal_output = normal_output.cpu()

X_ad = torch.cat([ad_EHR, ad_output, ad_tensor], dim=1)
X_mci = torch.cat([mci_EHR, mci_output, mci_tensor], dim=1)
X_normal = torch.cat([normal_EHR, normal_output, normal_tensor], dim=1)
y_ad = torch.ones(len(X_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(X_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(X_normal)) * 0  # Nc 类别标签为 0
# 拼接特征和标签
X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()

# 数据划分
X_train, X_test, y_train, y_test = train_test_split(X.detach().numpy(), y.numpy(),
                                                    test_size=0.25,
                                                    stratify=y.numpy(),
                                                    random_state=34)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                  test_size=0.25,
                                                  stratify=y_train,
                                                  random_state=34)

# %%
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.FloatTensor(y_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.FloatTensor(y_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.FloatTensor(y_test).to(device)

# 创建 TensorDataset
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        labels = labels.long()
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        # 获取预测概率
        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc

# %%
def evaluate(model, loader):
    model.eval()
    all_probs = []
    all_labels = []
    total_loss = 0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.long()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            # 获取预测概率
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
    test_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, test_auc

# %%
train_losses = []
train_aucs = []
test_losses = []
test_aucs = []
model = MultiModalTransformer().to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-5, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()    
for epoch in range(201):
    train_loss, train_auc = train_epoch(model, train_loader)
    test_loss, test_auc = evaluate(model, test_loader)
        
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    print(f"Epoch {epoch:03d} | "
            f"Train Loss: {train_loss:.4f} | Train AUC: {train_auc:.4f} | "
            f"Test Loss: {test_loss:.4f} | Test AUC: {test_auc:.4f}")
# Out:
# Epoch 000 | Train Loss: 1.0895 | Train AUC: 0.5402 | Test Loss: 1.0870 | Test AUC: 0.5337
# Epoch 001 | Train Loss: 1.0902 | Train AUC: 0.5448 | Test Loss: 1.0859 | Test AUC: 0.5594
# Epoch 002 | Train Loss: 1.0843 | Train AUC: 0.5405 | Test Loss: 1.0948 | Test AUC: 0.5463
# Epoch 003 | Train Loss: 1.0755 | Train AUC: 0.5398 | Test Loss: 1.0941 | Test AUC: 0.5492
# Epoch 004 | Train Loss: 1.0814 | Train AUC: 0.5375 | Test Loss: 1.0931 | Test AUC: 0.5587
# Epoch 005 | Train Loss: 1.0709 | Train AUC: 0.5677 | Test Loss: 1.0857 | Test AUC: 0.5758
# Epoch 006 | Train Loss: 1.0511 | Train AUC: 0.5909 | Test Loss: 1.0852 | Test AUC: 0.5806
# Epoch 007 | Train Loss: 1.0588 | Train AUC: 0.5532 | Test Loss: 1.0864 | Test AUC: 0.5745
# Epoch 008 | Train Loss: 1.0552 | Train AUC: 0.5941 | Test Loss: 1.0770 | Test AUC: 0.6254
# Epoch 009 | Train Loss: 1.0611 | Train AUC: 0.5623 | Test Loss: 1.0796 | Test AUC: 0.6406
# Epoch 010 | Train Loss: 1.0448 | Train AUC: 0.6109 | Test Loss: 1.0700 | Test AUC: 0.6468
# Epoch 011 | Train Loss: 1.0393 | Train AUC: 0.6116 | Test Loss: 1.0669 | Test AUC: 0.6490
# Epoch 012 | Train Loss: 1.0437 | Train AUC: 0.5787 | Test Loss: 1.0602 | Test AUC: 0.6601
# Epoch 013 | Train Loss: 1.0323 | Train AUC: 0.6211 | Test Loss: 1.0626 | Test AUC: 0.6570
# Epoch 014 | Train Loss: 1.0249 | Train AUC: 0.6417 | Test Loss: 1.0763 | Test AUC: 0.6539
# Epoch 015 | Train Loss: 1.0288 | Train AUC: 0.6019 | Test Loss: 1.0596 | Test AUC: 0.6603
# Epoch 016 | Train Loss: 1.0329 | Train AUC: 0.5833 | Test Loss: 1.0658 | Test AUC: 0.6559
# Epoch 017 | Train Loss: 1.0174 | Train AUC: 0.6098 | Test Loss: 1.0576 | Test AUC: 0.6550
# Epoch 018 | Train Loss: 1.0119 | Train AUC: 0.6296 | Test Loss: 1.0537 | Test AUC: 0.6580
# Epoch 019 | Train Loss: 1.0202 | Train AUC: 0.6110 | Test Loss: 1.0648 | Test AUC: 0.6515
# Epoch 020 | Train Loss: 1.0187 | Train AUC: 0.5970 | Test Loss: 1.0613 | Test AUC: 0.6537
# Epoch 021 | Train Loss: 1.0007 | Train AUC: 0.6320 | Test Loss: 1.0524 | Test AUC: 0.6557
# Epoch 022 | Train Loss: 1.0285 | Train AUC: 0.6115 | Test Loss: 1.0557 | Test AUC: 0.6525
# Epoch 023 | Train Loss: 1.0117 | Train AUC: 0.6194 | Test Loss: 1.0513 | Test AUC: 0.6524
# Epoch 024 | Train Loss: 1.0126 | Train AUC: 0.6256 | Test Loss: 1.0431 | Test AUC: 0.6556
# Epoch 025 | Train Loss: 0.9946 | Train AUC: 0.6289 | Test Loss: 1.0514 | Test AUC: 0.6545
# Epoch 026 | Train Loss: 1.0189 | Train AUC: 0.6332 | Test Loss: 1.0532 | Test AUC: 0.6460
# Epoch 027 | Train Loss: 1.0032 | Train AUC: 0.6251 | Test Loss: 1.0513 | Test AUC: 0.6430
# Epoch 028 | Train Loss: 0.9913 | Train AUC: 0.6457 | Test Loss: 1.0361 | Test AUC: 0.6528
# Epoch 029 | Train Loss: 0.9980 | Train AUC: 0.6578 | Test Loss: 1.0462 | Test AUC: 0.6456
# Epoch 030 | Train Loss: 0.9941 | Train AUC: 0.6576 | Test Loss: 1.0313 | Test AUC: 0.6455
# Epoch 031 | Train Loss: 0.9913 | Train AUC: 0.6534 | Test Loss: 1.0303 | Test AUC: 0.6491
# Epoch 032 | Train Loss: 0.9851 | Train AUC: 0.6743 | Test Loss: 1.0311 | Test AUC: 0.6455
# Epoch 033 | Train Loss: 0.9895 | Train AUC: 0.6709 | Test Loss: 1.0277 | Test AUC: 0.6446
# Epoch 034 | Train Loss: 0.9892 | Train AUC: 0.6275 | Test Loss: 1.0275 | Test AUC: 0.6446
# Epoch 035 | Train Loss: 0.9835 | Train AUC: 0.6441 | Test Loss: 1.0239 | Test AUC: 0.6482
# Epoch 036 | Train Loss: 0.9858 | Train AUC: 0.6427 | Test Loss: 1.0281 | Test AUC: 0.6465
# Epoch 037 | Train Loss: 0.9742 | Train AUC: 0.6640 | Test Loss: 1.0236 | Test AUC: 0.6479
# Epoch 038 | Train Loss: 0.9784 | Train AUC: 0.6640 | Test Loss: 1.0287 | Test AUC: 0.6411
# Epoch 039 | Train Loss: 0.9885 | Train AUC: 0.6441 | Test Loss: 1.0283 | Test AUC: 0.6373
# Epoch 040 | Train Loss: 0.9771 | Train AUC: 0.6576 | Test Loss: 1.0209 | Test AUC: 0.6420
# Epoch 041 | Train Loss: 0.9960 | Train AUC: 0.6310 | Test Loss: 1.0215 | Test AUC: 0.6432
# Epoch 042 | Train Loss: 0.9700 | Train AUC: 0.6636 | Test Loss: 1.0263 | Test AUC: 0.6453
# Epoch 043 | Train Loss: 0.9749 | Train AUC: 0.6571 | Test Loss: 1.0197 | Test AUC: 0.6426
# Epoch 044 | Train Loss: 0.9888 | Train AUC: 0.6457 | Test Loss: 1.0165 | Test AUC: 0.6484
# Epoch 045 | Train Loss: 0.9685 | Train AUC: 0.6728 | Test Loss: 1.0200 | Test AUC: 0.6424
# Epoch 046 | Train Loss: 0.9766 | Train AUC: 0.6591 | Test Loss: 1.0183 | Test AUC: 0.6458
# Epoch 047 | Train Loss: 0.9651 | Train AUC: 0.6661 | Test Loss: 1.0198 | Test AUC: 0.6461
# Epoch 048 | Train Loss: 0.9700 | Train AUC: 0.6503 | Test Loss: 1.0238 | Test AUC: 0.6439
# Epoch 049 | Train Loss: 0.9758 | Train AUC: 0.6518 | Test Loss: 1.0093 | Test AUC: 0.6428
# Epoch 050 | Train Loss: 0.9658 | Train AUC: 0.6496 | Test Loss: 1.0175 | Test AUC: 0.6399
# Epoch 051 | Train Loss: 0.9643 | Train AUC: 0.6649 | Test Loss: 1.0149 | Test AUC: 0.6410
# Epoch 052 | Train Loss: 0.9649 | Train AUC: 0.6572 | Test Loss: 1.0116 | Test AUC: 0.6394
# Epoch 053 | Train Loss: 0.9525 | Train AUC: 0.6571 | Test Loss: 1.0093 | Test AUC: 0.6403
# Epoch 054 | Train Loss: 0.9637 | Train AUC: 0.6590 | Test Loss: 1.0034 | Test AUC: 0.6474
# Epoch 055 | Train Loss: 0.9629 | Train AUC: 0.6561 | Test Loss: 1.0083 | Test AUC: 0.6475
# Epoch 056 | Train Loss: 0.9605 | Train AUC: 0.6793 | Test Loss: 1.0044 | Test AUC: 0.6410
# Epoch 057 | Train Loss: 0.9466 | Train AUC: 0.6754 | Test Loss: 1.0053 | Test AUC: 0.6520
# Epoch 058 | Train Loss: 0.9635 | Train AUC: 0.6603 | Test Loss: 0.9954 | Test AUC: 0.6479
# Epoch 059 | Train Loss: 0.9570 | Train AUC: 0.6787 | Test Loss: 0.9959 | Test AUC: 0.6537
# Epoch 060 | Train Loss: 0.9447 | Train AUC: 0.7010 | Test Loss: 1.0025 | Test AUC: 0.6566
# Epoch 061 | Train Loss: 0.9590 | Train AUC: 0.6776 | Test Loss: 0.9963 | Test AUC: 0.6582
# Epoch 062 | Train Loss: 0.9544 | Train AUC: 0.6463 | Test Loss: 0.9922 | Test AUC: 0.6591
# Epoch 063 | Train Loss: 0.9603 | Train AUC: 0.6627 | Test Loss: 1.0056 | Test AUC: 0.6593
# Epoch 064 | Train Loss: 0.9500 | Train AUC: 0.6905 | Test Loss: 0.9996 | Test AUC: 0.6569
# Epoch 065 | Train Loss: 0.9576 | Train AUC: 0.6521 | Test Loss: 0.9998 | Test AUC: 0.6565
# Epoch 066 | Train Loss: 0.9385 | Train AUC: 0.6842 | Test Loss: 0.9925 | Test AUC: 0.6547
# Epoch 067 | Train Loss: 0.9436 | Train AUC: 0.6760 | Test Loss: 0.9956 | Test AUC: 0.6544
# Epoch 068 | Train Loss: 0.9630 | Train AUC: 0.6639 | Test Loss: 0.9907 | Test AUC: 0.6587
# Epoch 069 | Train Loss: 0.9379 | Train AUC: 0.6720 | Test Loss: 0.9912 | Test AUC: 0.6468
# Epoch 070 | Train Loss: 0.9499 | Train AUC: 0.6627 | Test Loss: 0.9841 | Test AUC: 0.6562
# Epoch 071 | Train Loss: 0.9473 | Train AUC: 0.6742 | Test Loss: 0.9843 | Test AUC: 0.6565
# Epoch 072 | Train Loss: 0.9414 | Train AUC: 0.6565 | Test Loss: 0.9878 | Test AUC: 0.6554
# Epoch 073 | Train Loss: 0.9343 | Train AUC: 0.6931 | Test Loss: 0.9848 | Test AUC: 0.6506
# Epoch 074 | Train Loss: 0.9359 | Train AUC: 0.6866 | Test Loss: 0.9868 | Test AUC: 0.6543
# Epoch 075 | Train Loss: 0.9304 | Train AUC: 0.6867 | Test Loss: 0.9869 | Test AUC: 0.6529
# Epoch 076 | Train Loss: 0.9345 | Train AUC: 0.6696 | Test Loss: 0.9788 | Test AUC: 0.6535
# Epoch 077 | Train Loss: 0.9398 | Train AUC: 0.6637 | Test Loss: 0.9836 | Test AUC: 0.6543
# Epoch 078 | Train Loss: 0.9363 | Train AUC: 0.6608 | Test Loss: 0.9790 | Test AUC: 0.6473
# Epoch 079 | Train Loss: 0.9398 | Train AUC: 0.6686 | Test Loss: 0.9800 | Test AUC: 0.6520
# Epoch 080 | Train Loss: 0.9359 | Train AUC: 0.6622 | Test Loss: 0.9802 | Test AUC: 0.6531
# Epoch 081 | Train Loss: 0.9512 | Train AUC: 0.6536 | Test Loss: 0.9901 | Test AUC: 0.6478
# Epoch 082 | Train Loss: 0.9462 | Train AUC: 0.6586 | Test Loss: 0.9814 | Test AUC: 0.6527
# Epoch 083 | Train Loss: 0.9357 | Train AUC: 0.6719 | Test Loss: 0.9813 | Test AUC: 0.6434
# Epoch 084 | Train Loss: 0.9319 | Train AUC: 0.6757 | Test Loss: 0.9818 | Test AUC: 0.6478
# Epoch 085 | Train Loss: 0.9307 | Train AUC: 0.6764 | Test Loss: 0.9825 | Test AUC: 0.6477
# Epoch 086 | Train Loss: 0.9404 | Train AUC: 0.6708 | Test Loss: 0.9829 | Test AUC: 0.6500
# Epoch 087 | Train Loss: 0.9492 | Train AUC: 0.6698 | Test Loss: 0.9847 | Test AUC: 0.6441
# Epoch 088 | Train Loss: 0.9485 | Train AUC: 0.6425 | Test Loss: 0.9822 | Test AUC: 0.6487
# Epoch 089 | Train Loss: 0.9281 | Train AUC: 0.6813 | Test Loss: 0.9810 | Test AUC: 0.6522
# Epoch 090 | Train Loss: 0.9329 | Train AUC: 0.6653 | Test Loss: 0.9810 | Test AUC: 0.6496
# Epoch 091 | Train Loss: 0.9127 | Train AUC: 0.6934 | Test Loss: 0.9840 | Test AUC: 0.6512
# Epoch 092 | Train Loss: 0.9293 | Train AUC: 0.6867 | Test Loss: 0.9738 | Test AUC: 0.6494
# Epoch 093 | Train Loss: 0.9258 | Train AUC: 0.6959 | Test Loss: 0.9800 | Test AUC: 0.6528
# Epoch 094 | Train Loss: 0.9407 | Train AUC: 0.6540 | Test Loss: 0.9810 | Test AUC: 0.6592
# Epoch 095 | Train Loss: 0.9171 | Train AUC: 0.7046 | Test Loss: 0.9776 | Test AUC: 0.6525
# Epoch 096 | Train Loss: 0.9339 | Train AUC: 0.6814 | Test Loss: 0.9726 | Test AUC: 0.6610
# Epoch 097 | Train Loss: 0.9110 | Train AUC: 0.6952 | Test Loss: 0.9768 | Test AUC: 0.6641
# Epoch 098 | Train Loss: 0.9177 | Train AUC: 0.6962 | Test Loss: 0.9667 | Test AUC: 0.6586
# Epoch 099 | Train Loss: 0.9181 | Train AUC: 0.6890 | Test Loss: 0.9791 | Test AUC: 0.6550
# Epoch 100 | Train Loss: 0.9223 | Train AUC: 0.6848 | Test Loss: 0.9756 | Test AUC: 0.6550
# Epoch 101 | Train Loss: 0.9125 | Train AUC: 0.6992 | Test Loss: 0.9685 | Test AUC: 0.6587
# Epoch 102 | Train Loss: 0.9363 | Train AUC: 0.6779 | Test Loss: 0.9648 | Test AUC: 0.6583
# Epoch 103 | Train Loss: 0.9228 | Train AUC: 0.6811 | Test Loss: 0.9693 | Test AUC: 0.6618
# Epoch 104 | Train Loss: 0.9207 | Train AUC: 0.6651 | Test Loss: 0.9697 | Test AUC: 0.6624
# Epoch 105 | Train Loss: 0.9144 | Train AUC: 0.7100 | Test Loss: 0.9634 | Test AUC: 0.6596
# Epoch 106 | Train Loss: 0.9353 | Train AUC: 0.6591 | Test Loss: 0.9648 | Test AUC: 0.6609
# Epoch 107 | Train Loss: 0.9164 | Train AUC: 0.6760 | Test Loss: 0.9674 | Test AUC: 0.6557
# Epoch 108 | Train Loss: 0.9327 | Train AUC: 0.6777 | Test Loss: 0.9591 | Test AUC: 0.6587
# Epoch 109 | Train Loss: 0.9059 | Train AUC: 0.7047 | Test Loss: 0.9576 | Test AUC: 0.6639
# Epoch 110 | Train Loss: 0.9215 | Train AUC: 0.6688 | Test Loss: 0.9678 | Test AUC: 0.6597
# Epoch 111 | Train Loss: 0.9274 | Train AUC: 0.6731 | Test Loss: 0.9617 | Test AUC: 0.6626
# Epoch 112 | Train Loss: 0.9242 | Train AUC: 0.6888 | Test Loss: 0.9552 | Test AUC: 0.6661
# Epoch 113 | Train Loss: 0.9195 | Train AUC: 0.6724 | Test Loss: 0.9581 | Test AUC: 0.6559
# Epoch 114 | Train Loss: 0.9160 | Train AUC: 0.6785 | Test Loss: 0.9585 | Test AUC: 0.6612
# Epoch 115 | Train Loss: 0.9210 | Train AUC: 0.6992 | Test Loss: 0.9555 | Test AUC: 0.6612
# Epoch 116 | Train Loss: 0.9118 | Train AUC: 0.7013 | Test Loss: 0.9641 | Test AUC: 0.6641
# Epoch 117 | Train Loss: 0.9277 | Train AUC: 0.6591 | Test Loss: 0.9593 | Test AUC: 0.6517
# Epoch 118 | Train Loss: 0.9196 | Train AUC: 0.6936 | Test Loss: 0.9693 | Test AUC: 0.6511
# Epoch 119 | Train Loss: 0.9240 | Train AUC: 0.6680 | Test Loss: 0.9556 | Test AUC: 0.6684
# Epoch 120 | Train Loss: 0.9135 | Train AUC: 0.6928 | Test Loss: 0.9679 | Test AUC: 0.6686
# Epoch 121 | Train Loss: 0.9297 | Train AUC: 0.6628 | Test Loss: 0.9578 | Test AUC: 0.6569
# Epoch 122 | Train Loss: 0.9319 | Train AUC: 0.6691 | Test Loss: 0.9531 | Test AUC: 0.6659
# Epoch 123 | Train Loss: 0.9179 | Train AUC: 0.6971 | Test Loss: 0.9559 | Test AUC: 0.6664
# Epoch 124 | Train Loss: 0.9087 | Train AUC: 0.6871 | Test Loss: 0.9542 | Test AUC: 0.6669
# Epoch 125 | Train Loss: 0.9243 | Train AUC: 0.6766 | Test Loss: 0.9538 | Test AUC: 0.6647
# Epoch 126 | Train Loss: 0.8981 | Train AUC: 0.7039 | Test Loss: 0.9538 | Test AUC: 0.6662
# Epoch 127 | Train Loss: 0.9018 | Train AUC: 0.6978 | Test Loss: 0.9555 | Test AUC: 0.6662
# Epoch 128 | Train Loss: 0.9110 | Train AUC: 0.6799 | Test Loss: 0.9497 | Test AUC: 0.6633
# Epoch 129 | Train Loss: 0.9020 | Train AUC: 0.6852 | Test Loss: 0.9441 | Test AUC: 0.6625
# Epoch 130 | Train Loss: 0.9090 | Train AUC: 0.6907 | Test Loss: 0.9521 | Test AUC: 0.6674
# Epoch 131 | Train Loss: 0.9176 | Train AUC: 0.6715 | Test Loss: 0.9535 | Test AUC: 0.6632
# Epoch 132 | Train Loss: 0.9015 | Train AUC: 0.6788 | Test Loss: 0.9583 | Test AUC: 0.6649
# Epoch 133 | Train Loss: 0.9085 | Train AUC: 0.6855 | Test Loss: 0.9451 | Test AUC: 0.6631
# Epoch 134 | Train Loss: 0.9223 | Train AUC: 0.6940 | Test Loss: 0.9488 | Test AUC: 0.6608
# Epoch 135 | Train Loss: 0.9004 | Train AUC: 0.6992 | Test Loss: 0.9493 | Test AUC: 0.6674
# Epoch 136 | Train Loss: 0.9005 | Train AUC: 0.6832 | Test Loss: 0.9438 | Test AUC: 0.6655
# Epoch 137 | Train Loss: 0.9015 | Train AUC: 0.6874 | Test Loss: 0.9480 | Test AUC: 0.6645
# Epoch 138 | Train Loss: 0.9053 | Train AUC: 0.6780 | Test Loss: 0.9481 | Test AUC: 0.6631
# Epoch 139 | Train Loss: 0.9109 | Train AUC: 0.6793 | Test Loss: 0.9463 | Test AUC: 0.6637
# Epoch 140 | Train Loss: 0.9119 | Train AUC: 0.7041 | Test Loss: 0.9482 | Test AUC: 0.6647
# Epoch 141 | Train Loss: 0.9062 | Train AUC: 0.6888 | Test Loss: 0.9472 | Test AUC: 0.6658
# Epoch 142 | Train Loss: 0.9073 | Train AUC: 0.6861 | Test Loss: 0.9495 | Test AUC: 0.6645
# Epoch 143 | Train Loss: 0.9028 | Train AUC: 0.7045 | Test Loss: 0.9488 | Test AUC: 0.6570
# Epoch 144 | Train Loss: 0.9073 | Train AUC: 0.6841 | Test Loss: 0.9504 | Test AUC: 0.6635
# Epoch 145 | Train Loss: 0.9126 | Train AUC: 0.6734 | Test Loss: 0.9534 | Test AUC: 0.6556
# Epoch 146 | Train Loss: 0.9108 | Train AUC: 0.6686 | Test Loss: 0.9471 | Test AUC: 0.6589
# Epoch 147 | Train Loss: 0.9216 | Train AUC: 0.6663 | Test Loss: 0.9510 | Test AUC: 0.6593
# Epoch 148 | Train Loss: 0.9192 | Train AUC: 0.6725 | Test Loss: 0.9437 | Test AUC: 0.6596
# Epoch 149 | Train Loss: 0.8921 | Train AUC: 0.6799 | Test Loss: 0.9415 | Test AUC: 0.6631
# Epoch 150 | Train Loss: 0.9030 | Train AUC: 0.6927 | Test Loss: 0.9437 | Test AUC: 0.6627
# Epoch 151 | Train Loss: 0.9123 | Train AUC: 0.6756 | Test Loss: 0.9471 | Test AUC: 0.6587
# Epoch 152 | Train Loss: 0.9233 | Train AUC: 0.6592 | Test Loss: 0.9393 | Test AUC: 0.6611
# Epoch 153 | Train Loss: 0.9104 | Train AUC: 0.6788 | Test Loss: 0.9422 | Test AUC: 0.6629
# Epoch 154 | Train Loss: 0.9207 | Train AUC: 0.6668 | Test Loss: 0.9469 | Test AUC: 0.6626
# Epoch 155 | Train Loss: 0.8952 | Train AUC: 0.6906 | Test Loss: 0.9436 | Test AUC: 0.6617
# Epoch 156 | Train Loss: 0.8934 | Train AUC: 0.6906 | Test Loss: 0.9488 | Test AUC: 0.6686
# Epoch 157 | Train Loss: 0.9169 | Train AUC: 0.6722 | Test Loss: 0.9469 | Test AUC: 0.6661
# Epoch 158 | Train Loss: 0.9111 | Train AUC: 0.6770 | Test Loss: 0.9473 | Test AUC: 0.6655
# Epoch 159 | Train Loss: 0.9159 | Train AUC: 0.6688 | Test Loss: 0.9406 | Test AUC: 0.6638
# Epoch 160 | Train Loss: 0.9091 | Train AUC: 0.6949 | Test Loss: 0.9424 | Test AUC: 0.6614
# Epoch 161 | Train Loss: 0.8954 | Train AUC: 0.7046 | Test Loss: 0.9381 | Test AUC: 0.6645
# Epoch 162 | Train Loss: 0.9008 | Train AUC: 0.6864 | Test Loss: 0.9451 | Test AUC: 0.6640
# Epoch 163 | Train Loss: 0.8952 | Train AUC: 0.6970 | Test Loss: 0.9472 | Test AUC: 0.6651
# Epoch 164 | Train Loss: 0.9181 | Train AUC: 0.6874 | Test Loss: 0.9394 | Test AUC: 0.6619
# Epoch 165 | Train Loss: 0.9110 | Train AUC: 0.6750 | Test Loss: 0.9396 | Test AUC: 0.6632
# Epoch 166 | Train Loss: 0.9045 | Train AUC: 0.6873 | Test Loss: 0.9347 | Test AUC: 0.6647
# Epoch 167 | Train Loss: 0.9143 | Train AUC: 0.6718 | Test Loss: 0.9373 | Test AUC: 0.6586
# Epoch 168 | Train Loss: 0.9121 | Train AUC: 0.6810 | Test Loss: 0.9451 | Test AUC: 0.6671
# Epoch 169 | Train Loss: 0.8848 | Train AUC: 0.7111 | Test Loss: 0.9389 | Test AUC: 0.6642
# Epoch 170 | Train Loss: 0.8969 | Train AUC: 0.6759 | Test Loss: 0.9457 | Test AUC: 0.6667
# Epoch 171 | Train Loss: 0.9051 | Train AUC: 0.6803 | Test Loss: 0.9421 | Test AUC: 0.6642
# Epoch 172 | Train Loss: 0.9162 | Train AUC: 0.6783 | Test Loss: 0.9409 | Test AUC: 0.6609
# Epoch 173 | Train Loss: 0.9197 | Train AUC: 0.6813 | Test Loss: 0.9449 | Test AUC: 0.6664
# Epoch 174 | Train Loss: 0.9033 | Train AUC: 0.6848 | Test Loss: 0.9387 | Test AUC: 0.6634
# Epoch 175 | Train Loss: 0.9106 | Train AUC: 0.6903 | Test Loss: 0.9373 | Test AUC: 0.6594
# Epoch 176 | Train Loss: 0.8912 | Train AUC: 0.6928 | Test Loss: 0.9408 | Test AUC: 0.6632
# Epoch 177 | Train Loss: 0.9039 | Train AUC: 0.6915 | Test Loss: 0.9404 | Test AUC: 0.6627
# Epoch 178 | Train Loss: 0.9157 | Train AUC: 0.6640 | Test Loss: 0.9316 | Test AUC: 0.6583
# Epoch 179 | Train Loss: 0.8959 | Train AUC: 0.6950 | Test Loss: 0.9376 | Test AUC: 0.6627
# Epoch 180 | Train Loss: 0.9016 | Train AUC: 0.6913 | Test Loss: 0.9384 | Test AUC: 0.6646
# Epoch 181 | Train Loss: 0.8811 | Train AUC: 0.7012 | Test Loss: 0.9329 | Test AUC: 0.6634
# Epoch 182 | Train Loss: 0.9166 | Train AUC: 0.6866 | Test Loss: 0.9326 | Test AUC: 0.6639
# Epoch 183 | Train Loss: 0.8878 | Train AUC: 0.7032 | Test Loss: 0.9326 | Test AUC: 0.6584
# Epoch 184 | Train Loss: 0.8857 | Train AUC: 0.6945 | Test Loss: 0.9379 | Test AUC: 0.6621
# Epoch 185 | Train Loss: 0.8881 | Train AUC: 0.7111 | Test Loss: 0.9358 | Test AUC: 0.6628
# Epoch 186 | Train Loss: 0.9115 | Train AUC: 0.6836 | Test Loss: 0.9376 | Test AUC: 0.6573
# Epoch 187 | Train Loss: 0.8918 | Train AUC: 0.6840 | Test Loss: 0.9389 | Test AUC: 0.6579
# Epoch 188 | Train Loss: 0.8944 | Train AUC: 0.6853 | Test Loss: 0.9365 | Test AUC: 0.6570
# Epoch 189 | Train Loss: 0.8997 | Train AUC: 0.6868 | Test Loss: 0.9378 | Test AUC: 0.6495
# Epoch 190 | Train Loss: 0.8889 | Train AUC: 0.6908 | Test Loss: 0.9440 | Test AUC: 0.6509
# Epoch 191 | Train Loss: 0.8951 | Train AUC: 0.6814 | Test Loss: 0.9325 | Test AUC: 0.6501
# Epoch 192 | Train Loss: 0.8902 | Train AUC: 0.6933 | Test Loss: 0.9329 | Test AUC: 0.6524
# Epoch 193 | Train Loss: 0.8889 | Train AUC: 0.6936 | Test Loss: 0.9331 | Test AUC: 0.6495
# Epoch 194 | Train Loss: 0.8923 | Train AUC: 0.6753 | Test Loss: 0.9326 | Test AUC: 0.6465
# Epoch 195 | Train Loss: 0.8868 | Train AUC: 0.7005 | Test Loss: 0.9340 | Test AUC: 0.6582
# Epoch 196 | Train Loss: 0.9138 | Train AUC: 0.6741 | Test Loss: 0.9378 | Test AUC: 0.6600
# Epoch 197 | Train Loss: 0.8810 | Train AUC: 0.7157 | Test Loss: 0.9384 | Test AUC: 0.6547
# Epoch 198 | Train Loss: 0.8999 | Train AUC: 0.7003 | Test Loss: 0.9311 | Test AUC: 0.6534
# Epoch 199 | Train Loss: 0.8952 | Train AUC: 0.7098 | Test Loss: 0.9352 | Test AUC: 0.6515
# Epoch 200 | Train Loss: 0.9127 | Train AUC: 0.6793 | Test Loss: 0.9367 | Test AUC: 0.6547

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
# 获取预测类别
preds = np.argmax(all_probs, axis=1)
# 计算指标
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro') 
recall = recall_score(all_labels, preds, average='macro')       
f1 = f1_score(all_labels, preds, average='macro')               
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')  
print("\n=== Final Test Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Test Metrics ===
# Accuracy:  0.5872
# Precision: 0.3759
# Recall:    0.4328
# F1 Score:  0.3897
# AUC-ROC:   0.6965
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("Train and Test AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("Train and Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
def evaluate_model():
    model.eval()
    all_preds, all_probs, all_labels = [], [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.softmax(outputs, dim=1)
            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    all_probs = np.array(all_probs)
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=['NC', 'MCI', 'AD']))
    print("Confusion Matrix:")
    print(confusion_matrix(all_labels, all_preds))
    auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')  # 使用 'ovr' 或 'ovo'
    print(f"AUC Score (Ovr): {auc:.4f}")

evaluate_model()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           NC       0.00      0.00      0.00        40
#          MCI       0.58      0.84      0.69        89
#           AD       0.39      0.39      0.39        28
#
#     accuracy                           0.55       157
#    macro avg       0.32      0.41      0.36       157
# weighted avg       0.40      0.55      0.46       157
#
# Confusion Matrix:
# [[ 0 37  3]
#  [ 0 75 14]
#  [ 0 17 11]]
# AUC Score (Ovr): 0.6825
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
