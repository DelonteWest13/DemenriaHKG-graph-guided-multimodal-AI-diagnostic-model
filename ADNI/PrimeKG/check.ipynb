# %%
import glob
import pandas as pd

csv_files = glob.glob('*.csv')

for filename in csv_files:
    print(f"📄 文件名: {filename}")
    try:
        # 只读取前 2 行 (nrows=1 读取数据行，header默认是第一行)
        # 注意：pd.read_csv 默认把第一行当做表头，nrows=1 会读入表头 + 1行数据
        df = pd.read_csv(filename, nrows=1)
        
        # 打印表头（列名）
        print(f"   第一行 (列名): {list(df.columns)}")
        
        # 打印第一行数据 (如果文件不为空)
        if not df.empty:
            print(f"   第二行 (数值): {df.iloc[0].tolist()}")
            
    except Exception as e:
        print(f"   读取出错: {e}")
    print("-" * 40)
# Out:
# 📄 文件名: AD.csv
#    第一行 (列名): ['path', 'filename', 'age', 'gender', 'education', 'hispanic', 'race', 'apoe', 'NC', 'MCI', 'DE', 'COG', 'AD', 'PD', 'FTD', 'VD', 'DLB', 'PDD', 'ADD', 'OTHER', 'mmse', 'cdr', 'cdrSum', 'Tesla', 'trailA', 'trailB', 'lm_imm', 'lm_del', 'boston', 'animal', 'vege', 'digitB', 'digitBL', 'digitF', 'digitFL', 'npiq_DEL', 'npiq_HALL', 'npiq_AGIT', 'npiq_DEPD', 'npiq_ANX', 'npiq_ELAT', 'npiq_APA', 'npiq_DISN', 'npiq_IRR', 'npiq_MOT', 'npiq_NITE', 'npiq_APP', 'faq_BILLS', 'faq_TAXES', 'faq_SHOPPING', 'faq_GAMES', 'faq_STOVE', 'faq_MEALPREP', 'faq_EVENTS', 'faq_PAYATTN', 'faq_REMDATES', 'faq_TRAVEL', 'his_CVHATT', 'his_PSYCDIS', 'his_Alcohol', 'his_SMOKYRS', 'his_PACKSPER', 'his_NACCFAM', 'his_CBSTROKE', 'his_HYPERTEN', 'his_DEPOTHR', 'gds', 'moca']
#    第二行 (数值): ['C:\\Users\\86137\\ClinicRoom\\ADNI\\ad_nii_KG/', 'ADNI_109_S_1157_MR_MPR__GradWarp__B1_Correction__N3__Scaled_Br_20070808201650854_S24711_I66158.nii', np.float64(nan), 'female', np.int64(-4), np.int64(-4), np.float64(nan), np.float64(1.0), np.int64(0), np.int64(0), np.int64(1), np.int64(2), np.int64(1), np.float64(0.0), np.float64(nan), np.int64(0), np.float64(nan), np.int64(0), np.float64(1.0), np.float64(nan), np.int64(9), np.float64(2.0), np.float64(13.0), np.float64(1.5), np.float64(76.0), np.float64(180.0), np.int64(6), np.int64(4), np.float64(13.0), np.float64(8.0), np.float64(7.0), np.float64(3.0), np.float64(4.0), np.float64(7.0), np.float64(6.0), np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(1.0), np.float64(1.0), np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(0.0), np.float64(1.0), np.float64(1.0), np.float64(1.0), np.float64(0.0), np.float64(5.0), np.float64(4.0), np.float64(2.0), np.float64(0.0), np.float64(0.0), np.float64(5.0), np.float64(5.0), np.float64(5.0), np.float64(5.0), np.int64(1), np.int64(0), np.int64(0), np.float64(nan), np.float64(nan), np.int64(1), np.int64(0), np.int64(1), np.float64(0.0), np.int64(7), np.float64(nan)]
# ----------------------------------------
# 📄 文件名: kg.csv
#    第一行 (列名): ['relation', 'display_relation', 'x_index', 'x_id', 'x_type', 'x_name', 'x_source', 'y_index', 'y_id', 'y_type', 'y_name', 'y_source']
#    第二行 (数值): ['protein_protein', 'ppi', np.int64(0), np.int64(9796), 'gene/protein', 'PHYHIP', 'NCBI', np.int64(8889), np.int64(56992), 'gene/protein', 'KIF15', 'NCBI']
# ----------------------------------------
# 📄 文件名: mci.csv
#    第一行 (列名): ['path', 'filename', 'age', 'gender', 'education', 'hispanic', 'race', 'apoe', 'NC', 'MCI', 'DE', 'COG', 'AD', 'PD', 'FTD', 'VD', 'DLB', 'PDD', 'ADD', 'OTHER', 'mmse', 'cdr', 'cdrSum', 'Tesla', 'trailA', 'trailB', 'lm_imm', 'lm_del', 'boston', 'animal', 'vege', 'digitB', 'digitBL', 'digitF', 'digitFL', 'npiq_DEL', 'npiq_HALL', 'npiq_AGIT', 'npiq_DEPD', 'npiq_ANX', 'npiq_ELAT', 'npiq_APA', 'npiq_DISN', 'npiq_IRR', 'npiq_MOT', 'npiq_NITE', 'npiq_APP', 'faq_BILLS', 'faq_TAXES', 'faq_SHOPPING', 'faq_GAMES', 'faq_STOVE', 'faq_MEALPREP', 'faq_EVENTS', 'faq_PAYATTN', 'faq_REMDATES', 'faq_TRAVEL', 'his_CVHATT', 'his_PSYCDIS', 'his_Alcohol', 'his_SMOKYRS', 'his_PACKSPER', 'his_NACCFAM', 'his_CBSTROKE', 'his_HYPERTEN', 'his_DEPOTHR', 'gds', 'moca']
#    第二行 (数值): ['C:\\Users\\86137\\ClinicRoom\\ADNI\\mci_nii_KG/', 'ADNI_136_S_0873_MR_MPR__GradWarp__N3__Scaled_Br_20080307185908451_S19616_I96178.nii', np.float64(78.0), 'female', np.int64(14), np.int64(2), 'whi', np.float64(1.0), np.int64(0), np.int64(1), np.int64(0), np.int64(1), np.int64(0), np.float64(0.0), np.float64(0.0), np.int64(0), np.float64(0.0), np.int64(0), np.float64(nan), np.float64(0.0), np.int64(21), np.float64(1.0), np.float64(6.0), np.float64(1.5), np.float64(43.0), np.float64(259.0), np.int64(3), np.int64(0), np.float64(25.0), np.float64(9.0), np.float64(13.0), np.float64(5.0), np.float64(4.0), np.float64(7.0), np.float64(6.0), np.float64(0.0), np.float64(0.0), np.float64(2.0), np.float64(2.0), np.float64(2.0), np.float64(0.0), np.float64(2.0), np.float64(2.0), np.float64(2.0), np.float64(0.0), np.float64(0.0), np.float64(2.0), np.float64(2.0), np.float64(2.0), np.float64(0.0), np.float64(2.0), np.float64(3.0), np.float64(3.0), np.float64(3.0), np.float64(3.0), np.float64(4.0), np.float64(4.0), np.int64(0), np.int64(1), np.int64(0), np.float64(nan), np.float64(nan), np.int64(1), np.int64(0), np.int64(0), np.float64(0.0), np.int64(2), np.float64(nan)]
# ----------------------------------------
# 📄 文件名: normal.csv
#    第一行 (列名): ['path', 'filename', 'age', 'gender', 'education', 'hispanic', 'race', 'apoe', 'NC', 'MCI', 'DE', 'COG', 'AD', 'PD', 'FTD', 'VD', 'DLB', 'PDD', 'ADD', 'OTHER', 'mmse', 'cdr', 'cdrSum', 'Tesla', 'trailA', 'trailB', 'lm_imm', 'lm_del', 'boston', 'animal', 'vege', 'digitB', 'digitBL', 'digitF', 'digitFL', 'npiq_DEL', 'npiq_HALL', 'npiq_AGIT', 'npiq_DEPD', 'npiq_ANX', 'npiq_ELAT', 'npiq_APA', 'npiq_DISN', 'npiq_IRR', 'npiq_MOT', 'npiq_NITE', 'npiq_APP', 'faq_BILLS', 'faq_TAXES', 'faq_SHOPPING', 'faq_GAMES', 'faq_STOVE', 'faq_MEALPREP', 'faq_EVENTS', 'faq_PAYATTN', 'faq_REMDATES', 'faq_TRAVEL', 'his_CVHATT', 'his_PSYCDIS', 'his_Alcohol', 'his_SMOKYRS', 'his_PACKSPER', 'his_NACCFAM', 'his_CBSTROKE', 'his_HYPERTEN', 'his_DEPOTHR', 'gds', 'moca']
#    第二行 (数值): ['C:\\Users\\86137\\ClinicRoom\\ADNI\\normal_nii_kg/', 'ADNI_100_S_0015_MR_MPR____N3_Br_20061213152255416_S8834_I33043.nii', np.float64(81.0), 'male', np.int64(18), np.int64(2), 'whi', np.float64(1.0), np.int64(1), np.int64(0), np.int64(0), np.int64(0), np.int64(0), np.float64(0.0), np.float64(0.0), np.int64(0), np.float64(0.0), np.int64(0), np.float64(nan), np.float64(0.0), np.int64(30), np.float64(0.0), np.float64(0.0), np.float64(3.0), np.float64(27.0), np.float64(49.0), np.int64(17), np.int64(14), np.float64(30.0), np.float64(25.0), np.float64(12.0), np.float64(10.0), np.float64(7.0), np.float64(10.0), np.float64(7.0), np.float64(0.0), np.float64(0.0), np.float64(2.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(1.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.int64(0), np.int64(0), np.int64(0), np.float64(nan), np.float64(nan), np.int64(1), np.int64(0), np.int64(0), np.float64(0.0), np.int64(0), np.float64(nan)]
# ----------------------------------------
