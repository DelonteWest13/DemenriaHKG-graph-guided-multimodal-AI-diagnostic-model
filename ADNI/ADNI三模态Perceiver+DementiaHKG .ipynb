# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,PerceiverAttentionBlock,KGMultiModalPerceiver
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
#生物标志物 ad 90*48   no 349*58
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'normal_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'ad_nii_KG/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NC_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #151
print(count_no) #211
print(count_mci) #475

# %%
# 基础替换字典
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','ind':'3','ans':'4'}

# 隔离诊断标签的列索引提取规则
# EHR (14维): age(2), gender(3), education(4), hispanic(5), race(6) + his_系列(57-65)
ehr_cols = [2, 3, 4, 5, 6, 57, 58, 59, 60, 61, 62, 63, 64, 65] 
# BIO (39维): apoe(7) + mmse/cdr(20-22) + gds/moca(66, 67) + trail/npiq/faq等(24-56)
bio_cols = [7, 20, 21, 22, 66, 67] + list(range(24, 57))

# 统一且安全的预处理函数
# 统一且安全的预处理函数
def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        # 仅提取安全的特征列
        extracted_row = [row[idx] for idx in target_cols]
        # 字典映射替换
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                # 拦截 NaN，保留为 np.nan 供后续专门的 Imputer 处理
                if math.isnan(val):
                    val = np.nan
            except ValueError:
                val = np.nan 
            numerical_row.append(val)
            
        processed_data.append(numerical_row)
    return np.array(processed_data)

# 加权算值函数 (保留你的原始定义)
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
# 1. 提取 BIO 数组 (真实的 39 维特征)
ad_array = preprocess_data(data_ad, replace_dict, bio_cols)
normal_array = preprocess_data(data_normal, replace_dict, bio_cols)
mci_array = preprocess_data(data_mci, replace_dict, bio_cols)

# 2. 直接转换数据为 Tensor (无需外部线性层)
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 3. 打印结果 (预期输出类似: torch.Size([151, 39]))
print('AD_tensor shape:', ad_tensor.shape)      
print('Normal_tensor shape:', normal_tensor.shape) 
print('MCI_tensor shape:', mci_tensor.shape)

# %%
# 1. 提取脱敏后的 EHR 数组 (内部已通过 replace_dict 转换为数值)
ad_data = preprocess_data(data_ad, replace_dict, ehr_cols)
normal_data = preprocess_data(data_normal, replace_dict, ehr_cols)
mci_data = preprocess_data(data_mci, replace_dict, ehr_cols)

# 2. 直接转换为 Tensor (无需外部线性层)
ad_EHR = torch.from_numpy(ad_data).float()
normal_EHR = torch.from_numpy(normal_data).float()
mci_EHR = torch.from_numpy(mci_data).float()

# 3. 打印结果 (预期输出类似: torch.Size([151, 14]))
print('ad.EHR--->', ad_EHR.shape)
print('normal.EHR--->', normal_EHR.shape)
print('mci.EHR--->', mci_EHR.shape)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import torch
from torch.utils.data import DataLoader

# 1. 实例化模型，将输出维度设为64，以严格匹配 Transformer 的 img_dim=64
nii = CNN_3D(num_class=64)
nii = nii.to(device)
nii.eval() # 开启评估模式，冻结网络行为

def extract_mri_features(folder_path, batch_size=16):
    dataset = NiiDataset(folder_path)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    all_outputs = []
    
    # 2. 极其重要：关闭梯度计算，大幅节省显存并加快提取速度
    with torch.no_grad():
        for batch_idx, batch_data in enumerate(dataloader):
            batch_data = batch_data.to(device)
            output = nii(batch_data)
            # 提取后立即转回 CPU，防止 GPU 显存堆积
            all_outputs.append(output.cpu())
            
    return torch.cat(all_outputs, dim=0)

all_ad = 'ad_nii_KG/'
all_normal = 'normal_nii_kg/'
all_mci = 'NC_nii_kg/'

# 3. 模块化调用
ad_output = extract_mri_features(all_ad)
print('ad nii shape--->', ad_output.shape)

normal_output = extract_mri_features(all_normal)
print('normal nii shape--->', normal_output.shape)

mci_output = extract_mri_features(all_mci)
print('mci nii shape--->', mci_output.shape)
# Out:
# ad nii shape---> torch.Size([151, 64])
# normal nii shape---> torch.Size([211, 64])
# mci nii shape---> torch.Size([475, 64])

# %%
import numpy as np
import torch
import pandas as pd
import json

# 保持你的路径配置不变
ENTITY_EMB_NPY = "ADNI-DementiaHKG-Embeddings.npy"
ENTITY2ID_FILE = "ADNI-DementiaHKG-Entity2ID.json"
PATIENT_QUERY_DICT = "ADNI-DementiaHKG-Entities.json"

with open(ENTITY2ID_FILE, 'r', encoding='utf-8') as f:
    entity2id = json.load(f)

with open(PATIENT_QUERY_DICT, 'r', encoding='utf-8') as f:
    patient_entities = json.load(f)

emb = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
embed_dim = emb.shape[1] 
max_seq_len = 35 

def get_patient_embedding_seq(filename: str):
    filename = str(filename).strip()
    patient_data = patient_entities.get(filename, {})
    active_nodes = patient_data.get("input_nodes", [])
    
    vecs = []
    pad_masks = []
    
    # 构造固定长度为35的序列与对应的布尔掩码
    for i in range(max_seq_len):
        if i < len(active_nodes):
            node = active_nodes[i]
            if node != "[PAD]" and node in entity2id:
                vecs.append(emb[entity2id[node]])
                pad_masks.append(False) 
            else:
                vecs.append(torch.zeros(embed_dim))
                pad_masks.append(True) 
        else:
            vecs.append(torch.zeros(embed_dim))
            pad_masks.append(True)
            
    # 返回知识序列矩阵和用于PyTorch注意力的掩码
    return torch.stack(vecs), torch.tensor(pad_masks, dtype=torch.bool)

def process_and_verify_seq(df, cohort_name):
    seq_tensors = []
    mask_tensors = []
    valid_count = 0
    
    for _, r in df.iterrows():
        seq_tensor, mask_tensor = get_patient_embedding_seq(r['filename'])
        seq_tensors.append(seq_tensor)
        mask_tensors.append(mask_tensor)
        
        # 验证是否包含至少一个有效节点（掩码中存在False）
        if not torch.all(mask_tensor):
            valid_count += 1
            
    stacked_seq = torch.stack(seq_tensors)
    stacked_mask = torch.stack(mask_tensors)
    
    print(f"[{cohort_name}] 总样本数: {len(df)} | 成功注入KG先验序列的样本数: {valid_count}")
    return stacked_seq, stacked_mask

# 执行数据提取
print("开始提取完整知识序列与注意力掩码...")
ad_transe_seq, ad_transe_mask = process_and_verify_seq(pd.read_csv('AD.csv'), "AD")
mci_transe_seq, mci_transe_mask = process_and_verify_seq(pd.read_csv('mci.csv'), "MCI")
nc_transe_seq, nc_transe_mask = process_and_verify_seq(pd.read_csv('normal.csv'), "NC")

print("最终生成的知识序列 Shapes:", ad_transe_seq.shape, mci_transe_seq.shape, nc_transe_seq.shape)
print("最终生成的掩码张量 Shapes:", ad_transe_mask.shape, mci_transe_mask.shape, nc_transe_mask.shape)
# Out:
# 开始提取完整知识序列与注意力掩码...
# [AD] 总样本数: 151 | 成功注入KG先验序列的样本数: 151
# [MCI] 总样本数: 475 | 成功注入KG先验序列的样本数: 474
# [NC] 总样本数: 211 | 成功注入KG先验序列的样本数: 196
# 最终生成的知识序列 Shapes: torch.Size([151, 35, 128]) torch.Size([475, 35, 128]) torch.Size([211, 35, 128])
# 最终生成的掩码张量 Shapes: torch.Size([151, 35]) torch.Size([475, 35]) torch.Size([211, 35])

# %%
# 第一步：合并原有的多模态特征 (EHR + IMG + BIO)
features_ad = torch.cat([ad_EHR, ad_output.cpu(), ad_tensor], dim=1)
features_mci = torch.cat([mci_EHR, mci_output.cpu(), mci_tensor], dim=1)
features_normal = torch.cat([normal_EHR, normal_output.cpu(), normal_tensor], dim=1)

# 第二步：沿着批次维度(dim=0)纵向合并所有样本的特征
features = torch.cat([features_ad, features_mci, features_normal], dim=0).float()

# 第三步：纵向合并上一步提取的所有样本的知识序列矩阵
kg_seq = torch.cat([ad_transe_seq, mci_transe_seq, nc_transe_seq], dim=0).float()

# 第四步：纵向合并对应的知识掩码矩阵
kg_mask = torch.cat([ad_transe_mask, mci_transe_mask, nc_transe_mask], dim=0).bool()

# 第五步：生成类别标签
y_ad = torch.ones(len(features_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(features_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(features_normal)) * 0  # NC 类别标签为 0

# 分类任务的标签通常建议使用 long 类型
y = torch.cat([y_ad, y_mci, y_normal], dim=0).long() 

print("多模态特征 (features) 维度:", features.shape)
print("知识序列 (kg_seq) 维度:", kg_seq.shape)
print("注意力掩码 (kg_mask) 维度:", kg_mask.shape)
print("标签 (y) 维度:", y.shape)
# Out:
# 多模态特征 (features) 维度: torch.Size([837, 117])
# 知识序列 (kg_seq) 维度: torch.Size([837, 35, 128])
# 注意力掩码 (kg_mask) 维度: torch.Size([837, 35])
# 标签 (y) 维度: torch.Size([837])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.impute import SimpleImputer
import torch



# 1. 正常的划分数据集：同时切分特征(features), 图谱序列(kg_seq), 掩码(kg_mask) 和 标签(y)
# ★★★ 修复 NaN 报错的核心代码：防止全填充序列导致 Attention Softmax 除零崩溃 ★★★
# 找到那些掩码一整行全为 True 的样本（完全没有图谱节点的健康人）
all_padded_idx = kg_mask.all(dim=1)
# 强行把这些样本的第0个位置的掩码设为 False，使其能够去关注一个全零的 Padding 向量
kg_mask[all_padded_idx, 0] = False

X_train, X_test, seq_train, seq_test, mask_train, mask_test, y_train, y_test = train_test_split(
    features.detach().numpy(), 
    kg_seq.detach().numpy(), 
    kg_mask.detach().numpy(), 
    y.numpy(),
    test_size=0.20,
    stratify=y.numpy(),
    random_state=32
)


X_train, X_val, seq_train, seq_val, mask_train, mask_val, y_train, y_val = train_test_split(
    X_train, seq_train, mask_train, y_train,
    test_size=0.20,
    stratify=y_train,
    random_state=30
)

# ----------------- 缺失值填充与归一化模块 -----------------
# 2. 初始化填充器和标准化器
imputer = SimpleImputer(strategy='median')
scaler = StandardScaler()

# 3. 仅在训练集的“多模态特征(X)”上进行 fit_transform，严防数据泄露。图谱序列和掩码无需处理。
X_train = imputer.fit_transform(X_train)
X_train = scaler.fit_transform(X_train)

# 4. 在验证集和测试集上仅进行 transform
X_val = imputer.transform(X_val)
X_val = scaler.transform(X_val)

X_test = imputer.transform(X_test)
X_test = scaler.transform(X_test)
# ----------------------------------------------------

# 5. 转为 Tensor 并构建 DataLoader
X_train_tensor = torch.FloatTensor(X_train).to(device)
seq_train_tensor = torch.FloatTensor(seq_train).to(device)
mask_train_tensor = torch.BoolTensor(mask_train).to(device) # 注意掩码用 BoolTensor
y_train_tensor = torch.LongTensor(y_train).to(device)  

X_val_tensor = torch.FloatTensor(X_val).to(device)
seq_val_tensor = torch.FloatTensor(seq_val).to(device)
mask_val_tensor = torch.BoolTensor(mask_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
seq_test_tensor = torch.FloatTensor(seq_test).to(device)
mask_test_tensor = torch.BoolTensor(mask_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)

# 将 4 个张量打包进入 Dataset
train_dataset = TensorDataset(X_train_tensor, seq_train_tensor, mask_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, seq_val_tensor, mask_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, seq_test_tensor, mask_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
import numpy as np
from sklearn.metrics import roc_auc_score, f1_score, recall_score, precision_score

def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    # 修改点：解包 4 个变量
    for inputs, kg_seq, kg_mask, labels in loader:
        inputs = inputs.to(device)
        kg_seq = kg_seq.to(device)
        kg_mask = kg_mask.to(device)
        labels = labels.to(device).long()
        
        optimizer.zero_grad()
        # 修改点：将特征、知识序列、掩码传入模型
        outputs = model(inputs, kg_seq, kg_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        # 修改点：解包 4 个变量
        for inputs, kg_seq, kg_mask, labels in loader:
            inputs = inputs.to(device)
            kg_seq = kg_seq.to(device)
            kg_mask = kg_mask.to(device)
            labels = labels.to(device).long()
            
            # 修改点：将特征、知识序列、掩码传入模型
            outputs = model(inputs, kg_seq, kg_mask)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
import torch.optim as optim
import torch.nn as nn

embed_dim        = 128
transe_embed_dim = 128           
num_epochs       = 200
batch_size       = 32
learning_rate    = 1e-5
weight_decay     = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 初始化模型 
model = KGMultiModalPerceiver(
    ehr_dim=14, 
    img_dim=64, 
    bio_dim=39, 
    embed_dim=128,           # 映射后的统一特征维度
    latent_dim_low=32,       # 底层融合和图谱精炼的潜变量序列长度（对应你原先想设定的 num_latents）
    latent_dim_high=16,      # 高阶融合的潜变量序列长度（实现进一步的信息压缩）
    num_heads=4,             # 注意力头数
    transe_embed_dim=128     # KG 嵌入维度
).to(device)

criterion  = nn.CrossEntropyLoss()
optimizer  = optim.Adam(model.parameters(),
                        lr=learning_rate,
                        weight_decay=weight_decay)

train_losses  = []; train_aucs  = []; train_f1s  = []
train_recalls = []; train_precisions = []
test_losses   = []; test_aucs   = []; test_f1s   = []
test_recalls  = []; test_precisions  = []

for epoch in range(num_epochs):
    tr_loss, tr_auc, tr_f1, tr_rec, tr_prec = train_epoch(
        model, train_loader, optimizer, criterion, device)
    
    # 原代码这里写的是 validate_epoch 却传入了 test_loader，我保留你的原逻辑
    te_loss, te_auc, te_f1, te_rec, te_prec = validate_epoch(
        model, test_loader,  criterion, device)

    train_losses.append(tr_loss);    test_losses.append(te_loss)
    train_aucs.append(tr_auc);       test_aucs.append(te_auc)
    train_f1s.append(tr_f1);         test_f1s.append(te_f1)
    train_recalls.append(tr_rec);    test_recalls.append(te_rec)
    train_precisions.append(tr_prec);test_precisions.append(te_prec)

    print(f"Epoch {epoch+1}/{num_epochs} | "
          f"Train Loss {tr_loss:.4f}  AUC {tr_auc:.4f} | "
          f"Test Loss {te_loss:.4f}   AUC {te_auc:.4f}")
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 1/200 | Train Loss 1.1577  AUC 0.5005 | Test Loss 1.1080   AUC 0.5870
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 2/200 | Train Loss 1.1693  AUC 0.4767 | Test Loss 1.1103   AUC 0.6143
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 3/200 | Train Loss 1.1571  AUC 0.5041 | Test Loss 1.1154   AUC 0.5971
# Epoch 4/200 | Train Loss 1.1333  AUC 0.5344 | Test Loss 1.1242   AUC 0.5762
# Epoch 5/200 | Train Loss 1.1518  AUC 0.5196 | Test Loss 1.1093   AUC 0.6295
# Epoch 6/200 | Train Loss 1.1266  AUC 0.5304 | Test Loss 1.1267   AUC 0.6339
# Epoch 7/200 | Train Loss 1.1366  AUC 0.5121 | Test Loss 1.1111   AUC 0.6325
# Epoch 8/200 | Train Loss 1.1223  AUC 0.5483 | Test Loss 1.1108   AUC 0.6861
# Epoch 9/200 | Train Loss 1.1160  AUC 0.5554 | Test Loss 1.1091   AUC 0.7133
# Epoch 10/200 | Train Loss 1.1359  AUC 0.5108 | Test Loss 1.1152   AUC 0.7134
# Epoch 11/200 | Train Loss 1.1247  AUC 0.5240 | Test Loss 1.1031   AUC 0.7426
# Epoch 12/200 | Train Loss 1.1011  AUC 0.5605 | Test Loss 1.1175   AUC 0.7071
# Epoch 13/200 | Train Loss 1.0776  AUC 0.5973 | Test Loss 1.1093   AUC 0.7270
# Epoch 14/200 | Train Loss 1.0633  AUC 0.6051 | Test Loss 1.1052   AUC 0.7319
# Epoch 15/200 | Train Loss 1.0784  AUC 0.6027 | Test Loss 1.1100   AUC 0.7477
# Epoch 16/200 | Train Loss 1.0426  AUC 0.6320 | Test Loss 1.1019   AUC 0.7549
# Epoch 17/200 | Train Loss 1.0791  AUC 0.5738 | Test Loss 1.0930   AUC 0.7612
# Epoch 18/200 | Train Loss 1.0290  AUC 0.6422 | Test Loss 1.1092   AUC 0.7678
# Epoch 19/200 | Train Loss 1.0363  AUC 0.6388 | Test Loss 1.0805   AUC 0.7705
# Epoch 20/200 | Train Loss 1.0297  AUC 0.6387 | Test Loss 1.0723   AUC 0.7811
# Epoch 21/200 | Train Loss 1.0186  AUC 0.6648 | Test Loss 1.0650   AUC 0.7884
# Epoch 22/200 | Train Loss 1.0102  AUC 0.6750 | Test Loss 1.0519   AUC 0.7984
# Epoch 23/200 | Train Loss 0.9939  AUC 0.6897 | Test Loss 1.0327   AUC 0.7983
# Epoch 24/200 | Train Loss 0.9778  AUC 0.7026 | Test Loss 1.0195   AUC 0.8034
# Epoch 25/200 | Train Loss 0.9737  AUC 0.7125 | Test Loss 1.0031   AUC 0.8059
# Epoch 26/200 | Train Loss 0.9344  AUC 0.7538 | Test Loss 0.9848   AUC 0.8149
# Epoch 27/200 | Train Loss 0.9363  AUC 0.7517 | Test Loss 0.9966   AUC 0.8183
# Epoch 28/200 | Train Loss 0.9194  AUC 0.7589 | Test Loss 0.9854   AUC 0.8142
# Epoch 29/200 | Train Loss 0.9093  AUC 0.7632 | Test Loss 0.9544   AUC 0.8205
# Epoch 30/200 | Train Loss 0.8949  AUC 0.7813 | Test Loss 0.9304   AUC 0.8297
# Epoch 31/200 | Train Loss 0.8675  AUC 0.8013 | Test Loss 0.9226   AUC 0.8357
# Epoch 32/200 | Train Loss 0.8698  AUC 0.8012 | Test Loss 0.8942   AUC 0.8405
# Epoch 33/200 | Train Loss 0.8575  AUC 0.8033 | Test Loss 0.9026   AUC 0.8439
# Epoch 34/200 | Train Loss 0.8265  AUC 0.8182 | Test Loss 0.8772   AUC 0.8517
# Epoch 35/200 | Train Loss 0.8419  AUC 0.8182 | Test Loss 0.8536   AUC 0.8560
# Epoch 36/200 | Train Loss 0.8555  AUC 0.7998 | Test Loss 0.8505   AUC 0.8569
# Epoch 37/200 | Train Loss 0.8264  AUC 0.8167 | Test Loss 0.8508   AUC 0.8585
# Epoch 38/200 | Train Loss 0.7857  AUC 0.8462 | Test Loss 0.8218   AUC 0.8691
# Epoch 39/200 | Train Loss 0.8021  AUC 0.8382 | Test Loss 0.8186   AUC 0.8679
# Epoch 40/200 | Train Loss 0.7889  AUC 0.8451 | Test Loss 0.7992   AUC 0.8759
# Epoch 41/200 | Train Loss 0.7934  AUC 0.8280 | Test Loss 0.8040   AUC 0.8737
# Epoch 42/200 | Train Loss 0.7489  AUC 0.8562 | Test Loss 0.8004   AUC 0.8778
# Epoch 43/200 | Train Loss 0.7643  AUC 0.8554 | Test Loss 0.7869   AUC 0.8768
# Epoch 44/200 | Train Loss 0.7392  AUC 0.8605 | Test Loss 0.7630   AUC 0.8814
# Epoch 45/200 | Train Loss 0.7560  AUC 0.8497 | Test Loss 0.7603   AUC 0.8840
# Epoch 46/200 | Train Loss 0.7597  AUC 0.8459 | Test Loss 0.7558   AUC 0.8864
# Epoch 47/200 | Train Loss 0.7591  AUC 0.8457 | Test Loss 0.7611   AUC 0.8879
# Epoch 48/200 | Train Loss 0.7407  AUC 0.8595 | Test Loss 0.7608   AUC 0.8881
# Epoch 49/200 | Train Loss 0.7245  AUC 0.8674 | Test Loss 0.7573   AUC 0.8892
# Epoch 50/200 | Train Loss 0.7358  AUC 0.8532 | Test Loss 0.7297   AUC 0.8908
# Epoch 51/200 | Train Loss 0.7134  AUC 0.8741 | Test Loss 0.7236   AUC 0.8904
# Epoch 52/200 | Train Loss 0.6939  AUC 0.8844 | Test Loss 0.7225   AUC 0.8945
# Epoch 53/200 | Train Loss 0.7102  AUC 0.8723 | Test Loss 0.7372   AUC 0.8933
# Epoch 54/200 | Train Loss 0.6894  AUC 0.8831 | Test Loss 0.7213   AUC 0.8975
# Epoch 55/200 | Train Loss 0.6796  AUC 0.8865 | Test Loss 0.7135   AUC 0.8957
# Epoch 56/200 | Train Loss 0.6812  AUC 0.8856 | Test Loss 0.7167   AUC 0.8975
# Epoch 57/200 | Train Loss 0.6715  AUC 0.8877 | Test Loss 0.7051   AUC 0.8970
# Epoch 58/200 | Train Loss 0.6772  AUC 0.8863 | Test Loss 0.7014   AUC 0.8978
# Epoch 59/200 | Train Loss 0.6892  AUC 0.8786 | Test Loss 0.7026   AUC 0.9021
# Epoch 60/200 | Train Loss 0.6824  AUC 0.8850 | Test Loss 0.6976   AUC 0.9003
# Epoch 61/200 | Train Loss 0.6626  AUC 0.8885 | Test Loss 0.7001   AUC 0.8993
# Epoch 62/200 | Train Loss 0.6801  AUC 0.8754 | Test Loss 0.6872   AUC 0.9008
# Epoch 63/200 | Train Loss 0.6583  AUC 0.8908 | Test Loss 0.6946   AUC 0.9025
# Epoch 64/200 | Train Loss 0.6704  AUC 0.8777 | Test Loss 0.6880   AUC 0.9042
# Epoch 65/200 | Train Loss 0.6608  AUC 0.8880 | Test Loss 0.6870   AUC 0.9034
# Epoch 66/200 | Train Loss 0.6485  AUC 0.8893 | Test Loss 0.6917   AUC 0.9046
# Epoch 67/200 | Train Loss 0.6428  AUC 0.8977 | Test Loss 0.6775   AUC 0.9065
# Epoch 68/200 | Train Loss 0.6493  AUC 0.8846 | Test Loss 0.6852   AUC 0.9080
# Epoch 69/200 | Train Loss 0.6302  AUC 0.9049 | Test Loss 0.6687   AUC 0.9081
# Epoch 70/200 | Train Loss 0.6156  AUC 0.9094 | Test Loss 0.6497   AUC 0.9085
# Epoch 71/200 | Train Loss 0.6265  AUC 0.8999 | Test Loss 0.6571   AUC 0.9087
# Epoch 72/200 | Train Loss 0.6038  AUC 0.9171 | Test Loss 0.6668   AUC 0.9070
# Epoch 73/200 | Train Loss 0.6081  AUC 0.9086 | Test Loss 0.6558   AUC 0.9089
# Epoch 74/200 | Train Loss 0.6210  AUC 0.9020 | Test Loss 0.6492   AUC 0.9109
# Epoch 75/200 | Train Loss 0.6259  AUC 0.8966 | Test Loss 0.6530   AUC 0.9118
# Epoch 76/200 | Train Loss 0.6099  AUC 0.9055 | Test Loss 0.6490   AUC 0.9103
# Epoch 77/200 | Train Loss 0.6296  AUC 0.8840 | Test Loss 0.6594   AUC 0.9127
# Epoch 78/200 | Train Loss 0.6221  AUC 0.8949 | Test Loss 0.6508   AUC 0.9123
# Epoch 79/200 | Train Loss 0.5881  AUC 0.9149 | Test Loss 0.6522   AUC 0.9101
# Epoch 80/200 | Train Loss 0.6037  AUC 0.9045 | Test Loss 0.6407   AUC 0.9099
# Epoch 81/200 | Train Loss 0.5977  AUC 0.9115 | Test Loss 0.6460   AUC 0.9090
# Epoch 82/200 | Train Loss 0.5949  AUC 0.9013 | Test Loss 0.6432   AUC 0.9133
# Epoch 83/200 | Train Loss 0.5941  AUC 0.9144 | Test Loss 0.6275   AUC 0.9120
# Epoch 84/200 | Train Loss 0.5914  AUC 0.9161 | Test Loss 0.6312   AUC 0.9128
# Epoch 85/200 | Train Loss 0.6028  AUC 0.9057 | Test Loss 0.6291   AUC 0.9137
# Epoch 86/200 | Train Loss 0.5994  AUC 0.9052 | Test Loss 0.6353   AUC 0.9162
# Epoch 87/200 | Train Loss 0.6023  AUC 0.9032 | Test Loss 0.6271   AUC 0.9147
# Epoch 88/200 | Train Loss 0.6037  AUC 0.9047 | Test Loss 0.6259   AUC 0.9161
# Epoch 89/200 | Train Loss 0.5930  AUC 0.9112 | Test Loss 0.6277   AUC 0.9153
# Epoch 90/200 | Train Loss 0.6034  AUC 0.8968 | Test Loss 0.6309   AUC 0.9159
# Epoch 91/200 | Train Loss 0.5764  AUC 0.9151 | Test Loss 0.6182   AUC 0.9144
# Epoch 92/200 | Train Loss 0.5801  AUC 0.9106 | Test Loss 0.6228   AUC 0.9136
# Epoch 93/200 | Train Loss 0.5893  AUC 0.9055 | Test Loss 0.6300   AUC 0.9164
# Epoch 94/200 | Train Loss 0.5824  AUC 0.9102 | Test Loss 0.6201   AUC 0.9166
# Epoch 95/200 | Train Loss 0.5581  AUC 0.9197 | Test Loss 0.6268   AUC 0.9178
# Epoch 96/200 | Train Loss 0.5622  AUC 0.9178 | Test Loss 0.6047   AUC 0.9175
# Epoch 97/200 | Train Loss 0.5860  AUC 0.9076 | Test Loss 0.6081   AUC 0.9169
# Epoch 98/200 | Train Loss 0.5673  AUC 0.9165 | Test Loss 0.6049   AUC 0.9168
# Epoch 99/200 | Train Loss 0.5851  AUC 0.9044 | Test Loss 0.6115   AUC 0.9158
# Epoch 100/200 | Train Loss 0.5623  AUC 0.9102 | Test Loss 0.6036   AUC 0.9154
# Epoch 101/200 | Train Loss 0.5772  AUC 0.9067 | Test Loss 0.6068   AUC 0.9165
# Epoch 102/200 | Train Loss 0.5686  AUC 0.9113 | Test Loss 0.6007   AUC 0.9152
# Epoch 103/200 | Train Loss 0.5544  AUC 0.9143 | Test Loss 0.6038   AUC 0.9173
# Epoch 104/200 | Train Loss 0.5629  AUC 0.9114 | Test Loss 0.5922   AUC 0.9125
# Epoch 105/200 | Train Loss 0.5763  AUC 0.9080 | Test Loss 0.5871   AUC 0.9159
# Epoch 106/200 | Train Loss 0.5576  AUC 0.9099 | Test Loss 0.5998   AUC 0.9169
# Epoch 107/200 | Train Loss 0.5485  AUC 0.9118 | Test Loss 0.5939   AUC 0.9177
# Epoch 108/200 | Train Loss 0.5645  AUC 0.9073 | Test Loss 0.5987   AUC 0.9180
# Epoch 109/200 | Train Loss 0.5590  AUC 0.9095 | Test Loss 0.5883   AUC 0.9181
# Epoch 110/200 | Train Loss 0.5477  AUC 0.9175 | Test Loss 0.5926   AUC 0.9174
# Epoch 111/200 | Train Loss 0.5346  AUC 0.9175 | Test Loss 0.5833   AUC 0.9184
# Epoch 112/200 | Train Loss 0.5516  AUC 0.9176 | Test Loss 0.5871   AUC 0.9181
# Epoch 113/200 | Train Loss 0.5412  AUC 0.9192 | Test Loss 0.5959   AUC 0.9188
# Epoch 114/200 | Train Loss 0.5621  AUC 0.9038 | Test Loss 0.5903   AUC 0.9180
# Epoch 115/200 | Train Loss 0.5727  AUC 0.9054 | Test Loss 0.5831   AUC 0.9188
# Epoch 116/200 | Train Loss 0.5457  AUC 0.9182 | Test Loss 0.5730   AUC 0.9182
# Epoch 117/200 | Train Loss 0.5385  AUC 0.9204 | Test Loss 0.5732   AUC 0.9169
# Epoch 118/200 | Train Loss 0.5414  AUC 0.9148 | Test Loss 0.5756   AUC 0.9162
# Epoch 119/200 | Train Loss 0.5383  AUC 0.9209 | Test Loss 0.5811   AUC 0.9182
# Epoch 120/200 | Train Loss 0.5226  AUC 0.9249 | Test Loss 0.5825   AUC 0.9197
# Epoch 121/200 | Train Loss 0.5524  AUC 0.9090 | Test Loss 0.5827   AUC 0.9184
# Epoch 122/200 | Train Loss 0.5212  AUC 0.9207 | Test Loss 0.5781   AUC 0.9185
# Epoch 123/200 | Train Loss 0.5339  AUC 0.9200 | Test Loss 0.5833   AUC 0.9184
# Epoch 124/200 | Train Loss 0.5731  AUC 0.8987 | Test Loss 0.5948   AUC 0.9206
# Epoch 125/200 | Train Loss 0.5212  AUC 0.9265 | Test Loss 0.5801   AUC 0.9198
# Epoch 126/200 | Train Loss 0.5314  AUC 0.9201 | Test Loss 0.5757   AUC 0.9194
# Epoch 127/200 | Train Loss 0.5398  AUC 0.9084 | Test Loss 0.5779   AUC 0.9198
# Epoch 128/200 | Train Loss 0.5539  AUC 0.9128 | Test Loss 0.5765   AUC 0.9195
# Epoch 129/200 | Train Loss 0.5130  AUC 0.9303 | Test Loss 0.5824   AUC 0.9205
# Epoch 130/200 | Train Loss 0.5402  AUC 0.9097 | Test Loss 0.5763   AUC 0.9188
# Epoch 131/200 | Train Loss 0.5224  AUC 0.9194 | Test Loss 0.5631   AUC 0.9185
# Epoch 132/200 | Train Loss 0.5333  AUC 0.9184 | Test Loss 0.5737   AUC 0.9216
# Epoch 133/200 | Train Loss 0.5133  AUC 0.9198 | Test Loss 0.5630   AUC 0.9203
# Epoch 134/200 | Train Loss 0.5258  AUC 0.9169 | Test Loss 0.5643   AUC 0.9192
# Epoch 135/200 | Train Loss 0.5260  AUC 0.9142 | Test Loss 0.5610   AUC 0.9181
# Epoch 136/200 | Train Loss 0.5176  AUC 0.9212 | Test Loss 0.5768   AUC 0.9204
# Epoch 137/200 | Train Loss 0.5330  AUC 0.9148 | Test Loss 0.5691   AUC 0.9207
# Epoch 138/200 | Train Loss 0.5238  AUC 0.9150 | Test Loss 0.5785   AUC 0.9199
# Epoch 139/200 | Train Loss 0.4915  AUC 0.9351 | Test Loss 0.5731   AUC 0.9212
# Epoch 140/200 | Train Loss 0.4931  AUC 0.9297 | Test Loss 0.5631   AUC 0.9194
# Epoch 141/200 | Train Loss 0.5256  AUC 0.9182 | Test Loss 0.5602   AUC 0.9188
# Epoch 142/200 | Train Loss 0.5254  AUC 0.9164 | Test Loss 0.5630   AUC 0.9195
# Epoch 143/200 | Train Loss 0.5081  AUC 0.9229 | Test Loss 0.5591   AUC 0.9217
# Epoch 144/200 | Train Loss 0.5086  AUC 0.9223 | Test Loss 0.5685   AUC 0.9195
# Epoch 145/200 | Train Loss 0.5102  AUC 0.9216 | Test Loss 0.5686   AUC 0.9213
# Epoch 146/200 | Train Loss 0.5045  AUC 0.9270 | Test Loss 0.5686   AUC 0.9197
# Epoch 147/200 | Train Loss 0.4986  AUC 0.9285 | Test Loss 0.5674   AUC 0.9205
# Epoch 148/200 | Train Loss 0.5061  AUC 0.9268 | Test Loss 0.5688   AUC 0.9212
# Epoch 149/200 | Train Loss 0.4718  AUC 0.9389 | Test Loss 0.5692   AUC 0.9198
# Epoch 150/200 | Train Loss 0.4908  AUC 0.9317 | Test Loss 0.5525   AUC 0.9193
# Epoch 151/200 | Train Loss 0.4716  AUC 0.9385 | Test Loss 0.5493   AUC 0.9188
# Epoch 152/200 | Train Loss 0.4767  AUC 0.9319 | Test Loss 0.5568   AUC 0.9208
# Epoch 153/200 | Train Loss 0.5090  AUC 0.9223 | Test Loss 0.5623   AUC 0.9204
# Epoch 154/200 | Train Loss 0.4791  AUC 0.9366 | Test Loss 0.5548   AUC 0.9205
# Epoch 155/200 | Train Loss 0.4770  AUC 0.9366 | Test Loss 0.5532   AUC 0.9190
# Epoch 156/200 | Train Loss 0.4591  AUC 0.9430 | Test Loss 0.5454   AUC 0.9212
# Epoch 157/200 | Train Loss 0.5061  AUC 0.9217 | Test Loss 0.5555   AUC 0.9210
# Epoch 158/200 | Train Loss 0.4786  AUC 0.9318 | Test Loss 0.5506   AUC 0.9226
# Epoch 159/200 | Train Loss 0.5087  AUC 0.9209 | Test Loss 0.5489   AUC 0.9217
# Epoch 160/200 | Train Loss 0.4884  AUC 0.9257 | Test Loss 0.5532   AUC 0.9214
# Epoch 161/200 | Train Loss 0.4837  AUC 0.9303 | Test Loss 0.5511   AUC 0.9218
# Epoch 162/200 | Train Loss 0.4802  AUC 0.9339 | Test Loss 0.5477   AUC 0.9221
# Epoch 163/200 | Train Loss 0.5018  AUC 0.9231 | Test Loss 0.5519   AUC 0.9202
# Epoch 164/200 | Train Loss 0.4826  AUC 0.9326 | Test Loss 0.5494   AUC 0.9221
# Epoch 165/200 | Train Loss 0.4846  AUC 0.9280 | Test Loss 0.5478   AUC 0.9228
# Epoch 166/200 | Train Loss 0.4830  AUC 0.9287 | Test Loss 0.5474   AUC 0.9213
# Epoch 167/200 | Train Loss 0.4906  AUC 0.9276 | Test Loss 0.5496   AUC 0.9198
# Epoch 168/200 | Train Loss 0.4760  AUC 0.9344 | Test Loss 0.5494   AUC 0.9210
# Epoch 169/200 | Train Loss 0.4881  AUC 0.9268 | Test Loss 0.5488   AUC 0.9200
# Epoch 170/200 | Train Loss 0.4738  AUC 0.9284 | Test Loss 0.5424   AUC 0.9215
# Epoch 171/200 | Train Loss 0.4730  AUC 0.9285 | Test Loss 0.5406   AUC 0.9184
# Epoch 172/200 | Train Loss 0.4663  AUC 0.9329 | Test Loss 0.5424   AUC 0.9187
# Epoch 173/200 | Train Loss 0.4745  AUC 0.9309 | Test Loss 0.5454   AUC 0.9194
# Epoch 174/200 | Train Loss 0.4902  AUC 0.9226 | Test Loss 0.5386   AUC 0.9202
# Epoch 175/200 | Train Loss 0.4646  AUC 0.9332 | Test Loss 0.5445   AUC 0.9213
# Epoch 176/200 | Train Loss 0.5038  AUC 0.9185 | Test Loss 0.5383   AUC 0.9210
# Epoch 177/200 | Train Loss 0.4790  AUC 0.9240 | Test Loss 0.5389   AUC 0.9201
# Epoch 178/200 | Train Loss 0.5008  AUC 0.9224 | Test Loss 0.5474   AUC 0.9229
# Epoch 179/200 | Train Loss 0.4634  AUC 0.9356 | Test Loss 0.5385   AUC 0.9226
# Epoch 180/200 | Train Loss 0.4689  AUC 0.9342 | Test Loss 0.5405   AUC 0.9221
# Epoch 181/200 | Train Loss 0.4610  AUC 0.9367 | Test Loss 0.5403   AUC 0.9212
# Epoch 182/200 | Train Loss 0.4625  AUC 0.9337 | Test Loss 0.5366   AUC 0.9204
# Epoch 183/200 | Train Loss 0.4524  AUC 0.9428 | Test Loss 0.5406   AUC 0.9207
# Epoch 184/200 | Train Loss 0.4489  AUC 0.9440 | Test Loss 0.5379   AUC 0.9193
# Epoch 185/200 | Train Loss 0.4666  AUC 0.9252 | Test Loss 0.5450   AUC 0.9207
# Epoch 186/200 | Train Loss 0.4561  AUC 0.9356 | Test Loss 0.5370   AUC 0.9215
# Epoch 187/200 | Train Loss 0.4732  AUC 0.9267 | Test Loss 0.5334   AUC 0.9212
# Epoch 188/200 | Train Loss 0.4635  AUC 0.9340 | Test Loss 0.5311   AUC 0.9187
# Epoch 189/200 | Train Loss 0.4650  AUC 0.9311 | Test Loss 0.5314   AUC 0.9195
# Epoch 190/200 | Train Loss 0.4680  AUC 0.9382 | Test Loss 0.5329   AUC 0.9188
# Epoch 191/200 | Train Loss 0.4637  AUC 0.9356 | Test Loss 0.5377   AUC 0.9196
# Epoch 192/200 | Train Loss 0.4637  AUC 0.9347 | Test Loss 0.5319   AUC 0.9210
# Epoch 193/200 | Train Loss 0.4556  AUC 0.9405 | Test Loss 0.5380   AUC 0.9203
# Epoch 194/200 | Train Loss 0.4967  AUC 0.9265 | Test Loss 0.5414   AUC 0.9210
# Epoch 195/200 | Train Loss 0.4674  AUC 0.9295 | Test Loss 0.5334   AUC 0.9189
# Epoch 196/200 | Train Loss 0.4423  AUC 0.9422 | Test Loss 0.5377   AUC 0.9195
# Epoch 197/200 | Train Loss 0.4590  AUC 0.9360 | Test Loss 0.5355   AUC 0.9186
# Epoch 198/200 | Train Loss 0.4411  AUC 0.9409 | Test Loss 0.5307   AUC 0.9189
# Epoch 199/200 | Train Loss 0.4639  AUC 0.9292 | Test Loss 0.5336   AUC 0.9180
# Epoch 200/200 | Train Loss 0.4616  AUC 0.9348 | Test Loss 0.5309   AUC 0.9179

# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import torch

model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    # ★ 修改点：从 loader 中解包出 4 个变量
    for inputs, kg_seq, kg_mask, labels in val_loader:
        inputs = inputs.to(device)
        kg_seq = kg_seq.to(device)
        kg_mask = kg_mask.to(device)
        labels = labels.to(device).long()
        
        # ★ 修改点：模型现在接收特征、图谱序列和掩码三个输入
        outputs = model(inputs, kg_seq, kg_mask)
        
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.8209
# Precision: 0.8060
# Recall:    0.8147
# F1 Score:  0.8062
# AUC-ROC:   0.9477

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("ADNI AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("ADNI Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
from torchinfo import summary
import torch

# 1. 确保模型处于正确的设备上
model = model.to(device)

# 2. 构造与实际训练时维度相同的虚拟输入 (以 batch_size=32 为例)
# x 维度 = 14 (EHR) + 64 (img) + 39 (bio) = 117
dummy_x = torch.randn(32, 117).to(device)

# kg_seq 维度 = [batch_size, max_seq_len, embed_dim] = [32, 35, 128]
dummy_seq = torch.randn(32, 35, 128).to(device)

# kg_mask 维度 = [batch_size, max_seq_len] = [32, 35]，布尔型数据 (False代表有效节点)
dummy_mask = torch.zeros(32, 35, dtype=torch.bool).to(device)

# 3. 使用 torchinfo 获取模型详细结构和参数量
# 设置 verbose=0 阻止其自动打印英文
model_stats = summary(
    model, 
    input_data=(dummy_x, dummy_seq, dummy_mask), 
    col_names=["input_size", "output_size", "num_params", "mult_adds", "trainable"],
    verbose=0 
)

# 4. 提取输出字符串并执行中文替换
stats_str = str(model_stats)
stats_str = stats_str.replace("Layer (type:depth-idx)", "网络层 (类型:深度-索引)")
stats_str = stats_str.replace("Input Shape", "输入尺寸")
stats_str = stats_str.replace("Output Shape", "输出尺寸")
stats_str = stats_str.replace("Param #", "参数量")
stats_str = stats_str.replace("Mult-Adds", "算力损耗(乘加数)")
stats_str = stats_str.replace("Trainable", "可训练状态")
stats_str = stats_str.replace("Total params", "总参数量")
stats_str = stats_str.replace("Trainable params", "可训练参数量")
stats_str = stats_str.replace("Non-trainable params", "不可训练参数量")
stats_str = stats_str.replace("Total mult-adds", "总算力损耗 (Mult-Adds)")
stats_str = stats_str.replace("Input size (MB)", "输入数据大小 (MB)")
stats_str = stats_str.replace("Forward/backward pass size (MB)", "前反向传播显存 (MB)")
stats_str = stats_str.replace("Params size (MB)", "模型参数大小 (MB)")
stats_str = stats_str.replace("Estimated Total Size (MB)", "预估总显存占用 (MB)")

# 5. 打印中文版统计信息
print(stats_str)
# Out:
# =====================================================================================================================================================================
# 网络层 (类型:深度-索引)                   输入尺寸               输出尺寸              参数量                   算力损耗(乘加数)                 可训练状态
# =====================================================================================================================================================================
# KGMultiModalPerceiver                    [32, 117]                 [32, 3]                   --                        --                        True
# ├─Sequential: 1-1                        [32, 14]                  [32, 128]                 --                        --                        True
# │    └─Linear: 2-1                       [32, 14]                  [32, 16]                  240                       7,680                     True
# │    └─BatchNorm1d: 2-2                  [32, 16]                  [32, 16]                  32                        1,024                     True
# │    └─ReLU: 2-3                         [32, 16]                  [32, 16]                  --                        --                        --
# │    └─Dropout: 2-4                      [32, 16]                  [32, 16]                  --                        --                        --
# │    └─Linear: 2-5                       [32, 16]                  [32, 128]                 2,176                     69,632                    True
# │    └─BatchNorm1d: 2-6                  [32, 128]                 [32, 128]                 256                       8,192                     True
# │    └─ReLU: 2-7                         [32, 128]                 [32, 128]                 --                        --                        --
# ├─Sequential: 1-2                        [32, 64]                  [32, 128]                 --                        --                        True
# │    └─Linear: 2-8                       [32, 64]                  [32, 32]                  2,080                     66,560                    True
# │    └─BatchNorm1d: 2-9                  [32, 32]                  [32, 32]                  64                        2,048                     True
# │    └─ReLU: 2-10                        [32, 32]                  [32, 32]                  --                        --                        --
# │    └─Dropout: 2-11                     [32, 32]                  [32, 32]                  --                        --                        --
# │    └─Linear: 2-12                      [32, 32]                  [32, 128]                 4,224                     135,168                   True
# │    └─BatchNorm1d: 2-13                 [32, 128]                 [32, 128]                 256                       8,192                     True
# │    └─ReLU: 2-14                        [32, 128]                 [32, 128]                 --                        --                        --
# ├─Sequential: 1-3                        [32, 39]                  [32, 128]                 --                        --                        True
# │    └─Linear: 2-15                      [32, 39]                  [32, 32]                  1,280                     40,960                    True
# │    └─BatchNorm1d: 2-16                 [32, 32]                  [32, 32]                  64                        2,048                     True
# │    └─ReLU: 2-17                        [32, 32]                  [32, 32]                  --                        --                        --
# │    └─Dropout: 2-18                     [32, 32]                  [32, 32]                  --                        --                        --
# │    └─Linear: 2-19                      [32, 32]                  [32, 16]                  528                       16,896                    True
# │    └─BatchNorm1d: 2-20                 [32, 16]                  [32, 16]                  32                        1,024                     True
# │    └─ReLU: 2-21                        [32, 16]                  [32, 16]                  --                        --                        --
# │    └─Dropout: 2-22                     [32, 16]                  [32, 16]                  --                        --                        --
# │    └─Linear: 2-23                      [32, 16]                  [32, 128]                 2,176                     69,632                    True
# │    └─BatchNorm1d: 2-24                 [32, 128]                 [32, 128]                 256                       8,192                     True
# │    └─ReLU: 2-25                        [32, 128]                 [32, 128]                 --                        --                        --
# ├─Sequential: 1-4                        [32, 35, 128]             [32, 35, 128]             --                        --                        True
# │    └─Linear: 2-26                      [32, 35, 128]             [32, 35, 64]              8,256                     264,192                   True
# │    └─ReLU: 2-27                        [32, 35, 64]              [32, 35, 64]              --                        --                        --
# │    └─Dropout: 2-28                     [32, 35, 64]              [32, 35, 64]              --                        --                        --
# │    └─Linear: 2-29                      [32, 35, 64]              [32, 35, 128]             8,320                     266,240                   True
# ├─PerceiverAttentionBlock: 1-5           [32, 35, 128]             [32, 32, 128]             4,096                     --                        True
# │    └─MultiheadAttention: 2-30          --                        [32, 32, 128]             66,048                    --                        True
# │    └─LayerNorm: 2-31                   [32, 32, 128]             [32, 32, 128]             256                       8,192                     True
# │    └─MultiheadAttention: 2-32          --                        [32, 32, 128]             66,048                    --                        True
# │    └─LayerNorm: 2-33                   [32, 32, 128]             [32, 32, 128]             256                       8,192                     True
# │    └─Sequential: 2-34                  [32, 32, 128]             [32, 32, 128]             --                        --                        True
# │    │    └─Linear: 3-1                  [32, 32, 128]             [32, 32, 512]             66,048                    2,113,536                 True
# │    │    └─GELU: 3-2                    [32, 32, 512]             [32, 32, 512]             --                        --                        --
# │    │    └─Dropout: 3-3                 [32, 32, 512]             [32, 32, 512]             --                        --                        --
# │    │    └─Linear: 3-4                  [32, 32, 512]             [32, 32, 128]             65,664                    2,101,248                 True
# │    └─LayerNorm: 2-35                   [32, 32, 128]             [32, 32, 128]             256                       8,192                     True
# ├─Embedding: 1-6                         --                        [128]                     512                       65,536                    True
# ├─Embedding: 1-7                         --                        [128]                     (recursive)               65,536                    True
# ├─Embedding: 1-8                         --                        [128]                     (recursive)               65,536                    True
# ├─Embedding: 1-9                         --                        [128]                     (recursive)               65,536                    True
# ├─PerceiverAttentionBlock: 1-10          [32, 34, 128]             [32, 32, 128]             4,096                     --                        True
# │    └─MultiheadAttention: 2-36          --                        [32, 32, 128]             66,048                    --                        True
# │    └─LayerNorm: 2-37                   [32, 32, 128]             [32, 32, 128]             256                       8,192                     True
# │    └─MultiheadAttention: 2-38          --                        [32, 32, 128]             66,048                    --                        True
# │    └─LayerNorm: 2-39                   [32, 32, 128]             [32, 32, 128]             256                       8,192                     True
# │    └─Sequential: 2-40                  [32, 32, 128]             [32, 32, 128]             --                        --                        True
# │    │    └─Linear: 3-5                  [32, 32, 128]             [32, 32, 512]             66,048                    2,113,536                 True
# │    │    └─GELU: 3-6                    [32, 32, 512]             [32, 32, 512]             --                        --                        --
# │    │    └─Dropout: 3-7                 [32, 32, 512]             [32, 32, 512]             --                        --                        --
# │    │    └─Linear: 3-8                  [32, 32, 512]             [32, 32, 128]             65,664                    2,101,248                 True
# │    └─LayerNorm: 2-41                   [32, 32, 128]             [32, 32, 128]             256                       8,192                     True
# ├─PerceiverAttentionBlock: 1-11          [32, 33, 128]             [32, 16, 128]             2,048                     --                        True
# │    └─MultiheadAttention: 2-42          --                        [32, 16, 128]             66,048                    --                        True
# │    └─LayerNorm: 2-43                   [32, 16, 128]             [32, 16, 128]             256                       8,192                     True
# │    └─MultiheadAttention: 2-44          --                        [32, 16, 128]             66,048                    --                        True
# │    └─LayerNorm: 2-45                   [32, 16, 128]             [32, 16, 128]             256                       8,192                     True
# │    └─Sequential: 2-46                  [32, 16, 128]             [32, 16, 128]             --                        --                        True
# │    │    └─Linear: 3-9                  [32, 16, 128]             [32, 16, 512]             66,048                    2,113,536                 True
# │    │    └─GELU: 3-10                   [32, 16, 512]             [32, 16, 512]             --                        --                        --
# │    │    └─Dropout: 3-11                [32, 16, 512]             [32, 16, 512]             --                        --                        --
# │    │    └─Linear: 3-12                 [32, 16, 512]             [32, 16, 128]             65,664                    2,101,248                 True
# │    └─LayerNorm: 2-47                   [32, 16, 128]             [32, 16, 128]             256                       8,192                     True
# ├─Sequential: 1-12                       [32, 16, 128]             [32, 16, 1]               --                        --                        True
# │    └─Linear: 2-48                      [32, 16, 128]             [32, 16, 1]               129                       4,128                     True
# │    └─Softmax: 2-49                     [32, 16, 1]               [32, 16, 1]               --                        --                        --
# ├─Sequential: 1-13                       [32, 128]                 [32, 3]                   --                        --                        True
# │    └─Linear: 2-50                      [32, 128]                 [32, 64]                  8,256                     264,192                   True
# │    └─BatchNorm1d: 2-51                 [32, 64]                  [32, 64]                  128                       4,096                     True
# │    └─ReLU: 2-52                        [32, 64]                  [32, 64]                  --                        --                        --
# │    └─Dropout: 2-53                     [32, 64]                  [32, 64]                  --                        --                        --
# │    └─Linear: 2-54                      [32, 64]                  [32, 3]                   195                       6,240                     True
# =====================================================================================================================================================================
# 总参数量: 843,428
# 可训练状态 params: 843,428
# 不可训练参数量: 0
# 总算力损耗 (Mult-Adds) (Units.MEGABYTES): 14.23
# =====================================================================================================================================================================
# 输入数据大小 (MB): 0.59
# 前反向传播显存 (MB): 22.98
# 模型参数大小 (MB): 1.75
# 预估总显存占用 (MB): 25.32
# =====================================================================================================================================================================
