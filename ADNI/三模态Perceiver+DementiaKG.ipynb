# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd
import numpy as np
import torch
import pandas as pd
import json
import os
import re

# %%
#生物标志物 ad 90*48   no 349*58
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'normal_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'ad_nii_KG/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NC_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #151
print(count_no) #211
print(count_mci) #475
# Out:
# 151
# 211
# 475

# %%
ad_arrays=[]
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','ind':'3','ans':'4'}
for i in data_ad:   #第13行开始为基因、蛋白水平
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    ad_array = np.array(num_list)
    ad_arrays.append(ad_array)
ad_array = np.vstack(ad_arrays)

normal_arrays=[]
for i in data_normal:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    normal_array = np.array(num_list)
    normal_arrays.append(normal_array)
normal_array = np.vstack(normal_arrays)

mci_arrays=[]
for i in data_mci:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    mci_array = np.array(num_list)
    mci_arrays.append(mci_array)
mci_array = np.vstack(mci_arrays)

#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # 推荐：引入激活函数库

# 1. 转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 2. 定义网络层 
# 关键修复：输入维度由 45 改为 52 (匹配你的数据列数)
# 关键优化：使用不同的变量名 (fc1, fc2, fc3) 防止层被覆盖
fc1 = nn.Linear(52, 32)
fc2 = nn.Linear(32, 16)
fc3 = nn.Linear(16, 1)

# 3. 前向传播
# 注意：多层网络通常需要在层与层之间加激活函数(如 ReLU)，否则它数学上等价于单层网络。
# 为了保持代码运行，这里先按你的逻辑写，如果需要增加非线性能力，请取消注释 relu 行。

# 第一层
ad_tensor = fc1(ad_tensor)
# ad_tensor = F.relu(ad_tensor) 
normal_tensor = fc1(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc1(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第二层
ad_tensor = fc2(ad_tensor)
# ad_tensor = F.relu(ad_tensor)
normal_tensor = fc2(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc2(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第三层 (输出层)
ad_tensor = fc3(ad_tensor)
normal_tensor = fc3(normal_tensor)
mci_tensor = fc3(mci_tensor)

# 4. 打印结果
print('AD_tensor shape:', ad_tensor.shape)      # 预期: (151, 1)
print('Normal_tensor shape:', normal_tensor.shape) # 预期: (211, 1)
print('MCI_tensor shape:', mci_tensor.shape)    # 预期: (475, 1)
# Out:
# AD_tensor shape: torch.Size([151, 1])
# Normal_tensor shape: torch.Size([211, 1])
# MCI_tensor shape: torch.Size([475, 1])

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        # 替换字典中的值
        row = [replace_dict.get(item, item) for item in row]
        # 将类别型变量转换为数值
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[2:16])
    return np.array(processed_data)

# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict)
normal_data = preprocess_data(data_normal, replace_dict)
mci_data = preprocess_data(data_mci, replace_dict)

categorical_indices = [3,4,5,6,7]  # gender, education, hispanic, race
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(14, 16)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(16, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#医学图像
nii = CNN_3D(num_class=1)
nii= nii.to(device)
all_ad = 'ad_nii_KG/'
all_normal = 'normal_nii_kg/'
all_mci = 'NC_nii_kg/'
dataset = NiiDataset(all_ad)
batch_size = 16
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_normal)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_mci)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)

# %%
# ---------- Cell 9 : 加载 ADNI KG Embeddings (最终修正版：找回列名 + 特征聚合) ----------

# 1. 配置文件路径
ENTITY_EMB_NPY = "adni_kg_embeddings.npy"
ENTITY2ID_FILE = "adni_kg_entity2id.json"
# 重新定义 CSV 路径，确保能读到列名
CSV_PATHS = {
    'AD': 'AD.csv',
    'MCI': 'mci.csv',
    'NC': 'normal.csv'
}

print(f"Loading {ENTITY2ID_FILE}...")
with open(ENTITY2ID_FILE, 'r') as f:
    entity2id = json.load(f)

print(f"Loading {ENTITY_EMB_NPY}...")
emb = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()

# 定义提取器
class DistMultExtract:
    def get(self, ent: str):
        return emb[entity2id[ent]] if ent in entity2id else None

extractor = DistMultExtract()

# 2. 定义映射与分箱逻辑 (必须与构建图谱时完全一致)
SYMPTOM_MAP = {
    "npiq_DEL": "PrimeKG:Delusions",
    "npiq_HALL": "PrimeKG:Hallucinations",
    "npiq_AGIT": "PrimeKG:Agitation",
    "npiq_DEPD": "PrimeKG:Depressivity",
    "npiq_ANX": "PrimeKG:Anxiety",
    "npiq_ELAT": "PrimeKG:Conspicuously happy disposition",
    "npiq_APA": "PrimeKG:Apathy",
    "npiq_DISN": "PrimeKG:Disinhibition",
    "npiq_IRR": "PrimeKG:Irritability",
    "npiq_MOT": "PrimeKG:Restlessness",
}

IMPORTANT_PREFIXES = ["Tesla", "faq_", "his_", "trail", "lm_", "boston", "animal", "vege", "digit", "gds", "moca"]

def discretize_val(col_name, val):
    try: v = float(val)
    except: return str(val).strip().lower()
    col_lower = col_name.lower()
    if "tesla" in col_lower or "brain" in col_lower:
        return str(int(v // 50 * 50)) if v > 100 else f"{v:.1f}"
    if "age" in col_lower: return str(int(v // 5 * 5))
    if "trail" in col_lower: return str(int(v // 10 * 10))
    if any(x in col_lower for x in ["faq", "gds", "moca", "digit", "boston", "animal"]): return str(int(v))
    return f"{v:.2f}"

# 3. 定义特征聚合函数 (解决过拟合的关键)
def row_embed(row: pd.Series) -> torch.Tensor:
    vecs = []
    
    # A. 聚合 PrimeKG 症状 (利用外部知识)
    for col, prime_node in SYMPTOM_MAP.items():
        if col in row and pd.notna(row[col]): # 确保列存在且值有效
            try:
                if float(row[col]) > 0:
                    vec = extractor.get(prime_node)
                    if vec is not None:
                        w = 1.0 + (float(row[col]) * 0.5) # 加权
                        vecs.append(vec * w)
            except: pass

    # B. 聚合本地强特征 (MRI, FAQ...)
    for col_name in row.index:
        is_imp = False
        for prefix in IMPORTANT_PREFIXES:
            if str(col_name).startswith(prefix):
                is_imp = True; break
        
        if is_imp:
            val = row[col_name]
            if pd.notna(val) and str(val) not in ['', 'nan', '0', '0.0']:
                val_bin = discretize_val(col_name, val)
                # 构造节点名 (如 Feature:Tesla_1200)
                node_name = f"Feature:{col_name}_{val_bin}"
                
                vec = extractor.get(node_name)
                if vec is not None:
                    vecs.append(vec)

    # C. 聚合基因 (APOE)
    if 'apoe' in row and pd.notna(row['apoe']):
        try:
            aval = int(float(row['apoe']))
            if aval > 0:
                gnode = f"Gene:APOE_e4_Copies:{aval}"
                vec = extractor.get(gnode)
                if vec is not None: vecs.append(vec * 2.0)
        except: pass

    # 平均池化
    if len(vecs) > 0:
        return torch.stack(vecs).mean(0)
    else:
        return torch.zeros(128)

# 4. 执行提取 (关键：重新读取 CSV 以获取列名)
print("Reloading DataFrames to ensure headers...")
# 重新读取，保证 row['npiq_DEL'] 能取到值
df_ad_real = pd.read_csv(CSV_PATHS['AD'])
df_mci_real = pd.read_csv(CSV_PATHS['MCI'])
df_nc_real = pd.read_csv(CSV_PATHS['NC'])

print(f"Columns check (AD): {list(df_ad_real.columns)[:3]} ... (Headers exist!)")

print("Processing AD (Feature Aggregation)...")
ad_transe = torch.stack([row_embed(r) for _, r in df_ad_real.iterrows()])

print("Processing MCI (Feature Aggregation)...")
mci_transe = torch.stack([row_embed(r) for _, r in df_mci_real.iterrows()])

print("Processing Normal (Feature Aggregation)...")
normal_transe = torch.stack([row_embed(r) for _, r in df_nc_real.iterrows()])

print("\nShapes:", ad_transe.shape, mci_transe.shape, normal_transe.shape)

# 自检
zero_cnt = 0
if torch.all(ad_transe == 0): zero_cnt += 1
if torch.all(normal_transe == 0): zero_cnt += 1

if zero_cnt > 0:
    print("❌ 警告：依然有全0向量！请检查 'build_adni_primekg.py' 是否已运行并生成了包含 Feature 节点的图谱。")
else:
    print("✅ 成功！特征向量生成完毕 (Inductive Mode)。")
# Out:
# Loading adni_kg_entity2id.json...
# Loading adni_kg_embeddings.npy...
# Reloading DataFrames to ensure headers...
# Columns check (AD): ['path', 'filename', 'age'] ... (Headers exist!)
# Processing AD (Feature Aggregation)...
# Processing MCI (Feature Aggregation)...
# Processing Normal (Feature Aggregation)...
#
# Shapes: torch.Size([151, 128]) torch.Size([475, 128]) torch.Size([211, 128])
# ✅ 成功！特征向量生成完毕 (Inductive Mode)。

# %%
# ---------- Cell 10  ----------
# 维度改为 128
transe_embed_dim = 128  

# 下面的代码保持不变
X_ad = torch.cat([ad_EHR, ad_output.cpu(), ad_tensor, ad_transe], dim=1) 
X_mci = torch.cat([mci_EHR, mci_output.cpu(), mci_tensor, mci_transe], dim=1)
X_normal = torch.cat([normal_EHR, normal_output.cpu(), normal_tensor, normal_transe], dim=1)

y_ad = torch.ones(len(X_ad)) * 2 
y_mci = torch.ones(len(X_mci)) * 1 
y_normal = torch.ones(len(X_normal)) * 0 

X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()

# 切片分割特征
features = X[:, :-transe_embed_dim]  
transe_embeddings = X[:, -transe_embed_dim:]

# %%
X_train, X_test, y_train, y_test, transe_train, transe_test = train_test_split(
    features.detach().numpy(), y.numpy(), transe_embeddings.detach().numpy(),
    test_size=0.20,
    stratify=y.numpy(),
    random_state=32
)
X_train, X_val, y_train, y_val, transe_train, transe_val = train_test_split(
    X_train, y_train, transe_train,
    test_size=0.20,
    stratify=y_train,
    random_state=30
)


X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)  # Use LongTensor for classification labels
transe_train_tensor = torch.FloatTensor(transe_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
transe_val_tensor = torch.FloatTensor(transe_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
transe_test_tensor = torch.FloatTensor(transe_test).to(device)


train_dataset = TensorDataset(X_train_tensor, transe_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, transe_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, transe_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
import torch
import torch.nn as nn

class KGMultiModalPerceiver(nn.Module):
    def __init__(self, embed_dim=16, num_heads=2, num_layers=2, transe_embed_dim=32, num_latents=4, dropout_rate=0.3):
        super().__init__()
        self.ehr_encoder = nn.Sequential(
            nn.Linear(1, embed_dim),
            nn.ReLU()
        )
        self.img_encoder = nn.Sequential(
            nn.Linear(1, embed_dim),
            nn.ReLU()
        )
        self.bio_encoder = nn.Sequential(
            nn.Linear(1, embed_dim),
            nn.ReLU()
        )

        self.transe_proj = nn.Linear(transe_embed_dim, embed_dim)

        self.latents = nn.Parameter(torch.randn(1, num_latents, embed_dim) * 0.02)
        
        self.cross_attention = nn.MultiheadAttention(
            embed_dim=embed_dim, 
            num_heads=num_heads, 
            batch_first=True,
            dropout=dropout_rate
        )
        
        self.latent_self_attns = nn.ModuleList([
            nn.MultiheadAttention(embed_dim=embed_dim, num_heads=num_heads, batch_first=True, dropout=dropout_rate)
            for _ in range(num_layers)
        ])
        
        self.latent_norms = nn.ModuleList([
            nn.LayerNorm(embed_dim)
            for _ in range(num_layers)
        ])

        self.latent_ffns = nn.ModuleList([
            nn.Sequential(
                nn.Linear(embed_dim, embed_dim * 2),
                nn.ReLU(),
                nn.Dropout(dropout_rate),
                nn.Linear(embed_dim * 2, embed_dim),
                nn.Dropout(dropout_rate)
            )
            for _ in range(num_layers)
        ])
        
        self.latent_ffn_norms = nn.ModuleList([
            nn.LayerNorm(embed_dim)
            for _ in range(num_layers)
        ])
        
        # 核心修改：由于后续采用全局平均池化，输入维度由 num_latents * embed_dim 变更为 embed_dim
        self.latent_proj = nn.Linear(embed_dim, embed_dim * 2)

        self.fusion = nn.Sequential(
            nn.Linear(embed_dim * 3, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(64, 3)
        )

    def forward(self, x, transe_embed):
        ehr = x[:, 0].unsqueeze(1)
        img = x[:, 1].unsqueeze(1)
        bio = x[:, 2].unsqueeze(1)

        ehr_feat = self.ehr_encoder(ehr).unsqueeze(1)
        img_feat = self.img_encoder(img).unsqueeze(1)
        bio_feat = self.bio_encoder(bio).unsqueeze(1)

        transe_feat = self.transe_proj(transe_embed).unsqueeze(1)

        bio_feat = torch.cat([bio_feat, transe_feat], dim=1)
        ehr_feat = torch.cat([ehr_feat, transe_feat], dim=1)
        img_feat = torch.cat([img_feat, transe_feat], dim=1)

        inputs_seq = torch.cat([bio_feat, ehr_feat, img_feat], dim=1)

        batch_size = x.size(0)
        latents_batch = self.latents.expand(batch_size, -1, -1)

        latent_out, _ = self.cross_attention(query=latents_batch, key=inputs_seq, value=inputs_seq)

        for attn, norm, ffn, ffn_norm in zip(self.latent_self_attns, self.latent_norms, self.latent_ffns, self.latent_ffn_norms):
            attn_out, _ = attn(query=latent_out, key=latent_out, value=latent_out)
            latent_out = norm(latent_out + attn_out)
            
            ffn_out = ffn(latent_out)
            latent_out = ffn_norm(latent_out + ffn_out)

        # 核心修改：使用全局平均池化替代展平操作，构建信息瓶颈
        latent_pooled = latent_out.mean(dim=1)
        modalities_combined = self.latent_proj(latent_pooled)

        final_combined = torch.cat(
            [
                modalities_combined,
                transe_feat.squeeze(1)
            ],
            dim=1
        )
        
        return self.fusion(final_combined)

# %%
embed_dim        = 128
# ★★★ 修改点：输入维度必须匹配 .npy 文件 ★★★
transe_embed_dim = 128           
num_epochs       = 200
batch_size       = 32
learning_rate    = 1e-5
weight_decay     = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 初始化模型 (注意 model1.py 里的 KGMultiModalPerceiver 已经写好了接收这个参数)
model = KGMultiModalPerceiver(
            embed_dim=embed_dim,
            transe_embed_dim=transe_embed_dim
        ).to(device)

criterion  = nn.CrossEntropyLoss()
optimizer  = optim.Adam(model.parameters(),
                        lr=learning_rate,
                        weight_decay=weight_decay)

train_losses  = []; train_aucs  = []; train_f1s  = []
train_recalls = []; train_precisions = []
test_losses   = []; test_aucs   = []; test_f1s   = []
test_recalls  = []; test_precisions  = []

for epoch in range(num_epochs):
    tr_loss, tr_auc, tr_f1, tr_rec, tr_prec = train_epoch(
        model, train_loader, optimizer, criterion, device)
    te_loss, te_auc, te_f1, te_rec, te_prec = validate_epoch(
        model, test_loader,  criterion, device)

    train_losses.append(tr_loss);    test_losses.append(te_loss)
    train_aucs.append(tr_auc);       test_aucs.append(te_auc)
    train_f1s.append(tr_f1);         test_f1s.append(te_f1)
    train_recalls.append(tr_rec);    test_recalls.append(te_rec)
    train_precisions.append(tr_prec);test_precisions.append(te_prec)

    print(f"Epoch {epoch+1}/{num_epochs} | "
          f"Train Loss {tr_loss:.4f}  AUC {tr_auc:.4f} | "
          f"Test Loss {te_loss:.4f}   AUC {te_auc:.4f}")
# -------------------------------------------------------------------------------
# Out:
# Epoch 1/200 | Train Loss 1.1659  AUC 0.5234 | Test Loss 1.0754   AUC 0.6483
# Epoch 2/200 | Train Loss 1.1497  AUC 0.5601 | Test Loss 1.0672   AUC 0.7101
# Epoch 3/200 | Train Loss 1.1206  AUC 0.6186 | Test Loss 1.0623   AUC 0.7472
# Epoch 4/200 | Train Loss 1.0880  AUC 0.6537 | Test Loss 1.0577   AUC 0.7696
# Epoch 5/200 | Train Loss 1.0836  AUC 0.6576 | Test Loss 1.0423   AUC 0.7743
# Epoch 6/200 | Train Loss 1.0800  AUC 0.6620 | Test Loss 1.0400   AUC 0.7796
# Epoch 7/200 | Train Loss 1.0778  AUC 0.6707 | Test Loss 1.0336   AUC 0.7916
# Epoch 8/200 | Train Loss 1.0543  AUC 0.7042 | Test Loss 1.0215   AUC 0.8033
# Epoch 9/200 | Train Loss 1.0518  AUC 0.6895 | Test Loss 1.0078   AUC 0.8095
# Epoch 10/200 | Train Loss 1.0260  AUC 0.7260 | Test Loss 1.0034   AUC 0.8195
# Epoch 11/200 | Train Loss 1.0153  AUC 0.7379 | Test Loss 0.9915   AUC 0.8257
# Epoch 12/200 | Train Loss 1.0117  AUC 0.7377 | Test Loss 0.9808   AUC 0.8323
# Epoch 13/200 | Train Loss 1.0158  AUC 0.7276 | Test Loss 0.9761   AUC 0.8377
# Epoch 14/200 | Train Loss 1.0145  AUC 0.7199 | Test Loss 0.9515   AUC 0.8412
# Epoch 15/200 | Train Loss 0.9928  AUC 0.7500 | Test Loss 0.9483   AUC 0.8437
# Epoch 16/200 | Train Loss 0.9821  AUC 0.7575 | Test Loss 0.9448   AUC 0.8478
# Epoch 17/200 | Train Loss 0.9777  AUC 0.7533 | Test Loss 0.9340   AUC 0.8517
# Epoch 18/200 | Train Loss 0.9726  AUC 0.7650 | Test Loss 0.9304   AUC 0.8521
# Epoch 19/200 | Train Loss 0.9717  AUC 0.7590 | Test Loss 0.9196   AUC 0.8591
# Epoch 20/200 | Train Loss 0.9675  AUC 0.7658 | Test Loss 0.9199   AUC 0.8673
# Epoch 21/200 | Train Loss 0.9427  AUC 0.7966 | Test Loss 0.9119   AUC 0.8667
# Epoch 22/200 | Train Loss 0.9481  AUC 0.7851 | Test Loss 0.9092   AUC 0.8680
# Epoch 23/200 | Train Loss 0.9336  AUC 0.8024 | Test Loss 0.9029   AUC 0.8683
# Epoch 24/200 | Train Loss 0.9207  AUC 0.7934 | Test Loss 0.8894   AUC 0.8680
# Epoch 25/200 | Train Loss 0.9222  AUC 0.7936 | Test Loss 0.8951   AUC 0.8729
# Epoch 26/200 | Train Loss 0.9155  AUC 0.8083 | Test Loss 0.8892   AUC 0.8725
# Epoch 27/200 | Train Loss 0.9190  AUC 0.8008 | Test Loss 0.8855   AUC 0.8772
# Epoch 28/200 | Train Loss 0.9170  AUC 0.7923 | Test Loss 0.8834   AUC 0.8791
# Epoch 29/200 | Train Loss 0.9190  AUC 0.7970 | Test Loss 0.8738   AUC 0.8785
# Epoch 30/200 | Train Loss 0.8932  AUC 0.8104 | Test Loss 0.8697   AUC 0.8778
# Epoch 31/200 | Train Loss 0.8959  AUC 0.8169 | Test Loss 0.8652   AUC 0.8814
# Epoch 32/200 | Train Loss 0.9016  AUC 0.8053 | Test Loss 0.8631   AUC 0.8831
# Epoch 33/200 | Train Loss 0.8893  AUC 0.8242 | Test Loss 0.8542   AUC 0.8830
# Epoch 34/200 | Train Loss 0.8823  AUC 0.8196 | Test Loss 0.8509   AUC 0.8856
# Epoch 35/200 | Train Loss 0.8794  AUC 0.8146 | Test Loss 0.8524   AUC 0.8869
# Epoch 36/200 | Train Loss 0.8575  AUC 0.8312 | Test Loss 0.8381   AUC 0.8883
# Epoch 37/200 | Train Loss 0.8595  AUC 0.8337 | Test Loss 0.8340   AUC 0.8899
# Epoch 38/200 | Train Loss 0.8406  AUC 0.8395 | Test Loss 0.8288   AUC 0.8903
# Epoch 39/200 | Train Loss 0.8556  AUC 0.8316 | Test Loss 0.8262   AUC 0.8899
# Epoch 40/200 | Train Loss 0.8487  AUC 0.8306 | Test Loss 0.8161   AUC 0.8906
# Epoch 41/200 | Train Loss 0.8412  AUC 0.8399 | Test Loss 0.8096   AUC 0.8916
# Epoch 42/200 | Train Loss 0.8503  AUC 0.8258 | Test Loss 0.8164   AUC 0.8935
# Epoch 43/200 | Train Loss 0.8470  AUC 0.8327 | Test Loss 0.8123   AUC 0.8960
# Epoch 44/200 | Train Loss 0.8134  AUC 0.8463 | Test Loss 0.7970   AUC 0.8947
# Epoch 45/200 | Train Loss 0.8475  AUC 0.8292 | Test Loss 0.7902   AUC 0.8959
# Epoch 46/200 | Train Loss 0.8394  AUC 0.8350 | Test Loss 0.7840   AUC 0.8947
# Epoch 47/200 | Train Loss 0.8098  AUC 0.8513 | Test Loss 0.7860   AUC 0.8949
# Epoch 48/200 | Train Loss 0.7975  AUC 0.8524 | Test Loss 0.7818   AUC 0.8980
# Epoch 49/200 | Train Loss 0.8189  AUC 0.8437 | Test Loss 0.7784   AUC 0.8996
# Epoch 50/200 | Train Loss 0.8131  AUC 0.8431 | Test Loss 0.7663   AUC 0.9022
# Epoch 51/200 | Train Loss 0.8167  AUC 0.8437 | Test Loss 0.7714   AUC 0.9004
# Epoch 52/200 | Train Loss 0.7983  AUC 0.8571 | Test Loss 0.7698   AUC 0.8998
# Epoch 53/200 | Train Loss 0.8195  AUC 0.8403 | Test Loss 0.7678   AUC 0.9028
# Epoch 54/200 | Train Loss 0.7920  AUC 0.8594 | Test Loss 0.7712   AUC 0.9018
# Epoch 55/200 | Train Loss 0.8024  AUC 0.8528 | Test Loss 0.7575   AUC 0.8995
# Epoch 56/200 | Train Loss 0.7992  AUC 0.8517 | Test Loss 0.7576   AUC 0.9005
# Epoch 57/200 | Train Loss 0.7961  AUC 0.8485 | Test Loss 0.7497   AUC 0.9037
# Epoch 58/200 | Train Loss 0.7816  AUC 0.8576 | Test Loss 0.7500   AUC 0.9035
# Epoch 59/200 | Train Loss 0.7938  AUC 0.8525 | Test Loss 0.7414   AUC 0.9058
# Epoch 60/200 | Train Loss 0.7865  AUC 0.8506 | Test Loss 0.7429   AUC 0.9044
# Epoch 61/200 | Train Loss 0.7668  AUC 0.8665 | Test Loss 0.7350   AUC 0.9047
# Epoch 62/200 | Train Loss 0.7579  AUC 0.8676 | Test Loss 0.7241   AUC 0.9058
# Epoch 63/200 | Train Loss 0.7644  AUC 0.8640 | Test Loss 0.7253   AUC 0.9053
# Epoch 64/200 | Train Loss 0.7566  AUC 0.8712 | Test Loss 0.7294   AUC 0.9062
# Epoch 65/200 | Train Loss 0.7594  AUC 0.8678 | Test Loss 0.7258   AUC 0.9066
# Epoch 66/200 | Train Loss 0.7481  AUC 0.8682 | Test Loss 0.7297   AUC 0.9065
# Epoch 67/200 | Train Loss 0.7502  AUC 0.8687 | Test Loss 0.7129   AUC 0.9074
# Epoch 68/200 | Train Loss 0.7621  AUC 0.8586 | Test Loss 0.7067   AUC 0.9081
# Epoch 69/200 | Train Loss 0.7499  AUC 0.8705 | Test Loss 0.7054   AUC 0.9080
# Epoch 70/200 | Train Loss 0.7559  AUC 0.8658 | Test Loss 0.7003   AUC 0.9082
# Epoch 71/200 | Train Loss 0.7609  AUC 0.8612 | Test Loss 0.7051   AUC 0.9083
# Epoch 72/200 | Train Loss 0.7529  AUC 0.8715 | Test Loss 0.6989   AUC 0.9087
# Epoch 73/200 | Train Loss 0.7414  AUC 0.8709 | Test Loss 0.6938   AUC 0.9075
# Epoch 74/200 | Train Loss 0.7455  AUC 0.8675 | Test Loss 0.6907   AUC 0.9070
# Epoch 75/200 | Train Loss 0.7344  AUC 0.8730 | Test Loss 0.6932   AUC 0.9080
# Epoch 76/200 | Train Loss 0.7232  AUC 0.8807 | Test Loss 0.6807   AUC 0.9093
# Epoch 77/200 | Train Loss 0.7488  AUC 0.8645 | Test Loss 0.6875   AUC 0.9086
# Epoch 78/200 | Train Loss 0.7120  AUC 0.8843 | Test Loss 0.6935   AUC 0.9090
# Epoch 79/200 | Train Loss 0.7284  AUC 0.8748 | Test Loss 0.6896   AUC 0.9098
# Epoch 80/200 | Train Loss 0.7368  AUC 0.8688 | Test Loss 0.6886   AUC 0.9100
# Epoch 81/200 | Train Loss 0.7138  AUC 0.8862 | Test Loss 0.6743   AUC 0.9097
# Epoch 82/200 | Train Loss 0.7001  AUC 0.8889 | Test Loss 0.6786   AUC 0.9100
# Epoch 83/200 | Train Loss 0.7151  AUC 0.8775 | Test Loss 0.6730   AUC 0.9109
# Epoch 84/200 | Train Loss 0.7121  AUC 0.8779 | Test Loss 0.6691   AUC 0.9102
# Epoch 85/200 | Train Loss 0.7083  AUC 0.8831 | Test Loss 0.6679   AUC 0.9093
# Epoch 86/200 | Train Loss 0.7087  AUC 0.8812 | Test Loss 0.6632   AUC 0.9112
# Epoch 87/200 | Train Loss 0.7048  AUC 0.8808 | Test Loss 0.6701   AUC 0.9113
# Epoch 88/200 | Train Loss 0.7199  AUC 0.8732 | Test Loss 0.6623   AUC 0.9112
# Epoch 89/200 | Train Loss 0.6935  AUC 0.8882 | Test Loss 0.6607   AUC 0.9122
# Epoch 90/200 | Train Loss 0.7137  AUC 0.8730 | Test Loss 0.6584   AUC 0.9121
# Epoch 91/200 | Train Loss 0.6893  AUC 0.8903 | Test Loss 0.6527   AUC 0.9101
# Epoch 92/200 | Train Loss 0.7011  AUC 0.8836 | Test Loss 0.6596   AUC 0.9115
# Epoch 93/200 | Train Loss 0.6888  AUC 0.8865 | Test Loss 0.6573   AUC 0.9101
# Epoch 94/200 | Train Loss 0.7037  AUC 0.8822 | Test Loss 0.6547   AUC 0.9123
# Epoch 95/200 | Train Loss 0.7010  AUC 0.8801 | Test Loss 0.6447   AUC 0.9116
# Epoch 96/200 | Train Loss 0.6934  AUC 0.8839 | Test Loss 0.6426   AUC 0.9127
# Epoch 97/200 | Train Loss 0.6907  AUC 0.8837 | Test Loss 0.6439   AUC 0.9116
# Epoch 98/200 | Train Loss 0.7097  AUC 0.8767 | Test Loss 0.6509   AUC 0.9122
# Epoch 99/200 | Train Loss 0.6822  AUC 0.8856 | Test Loss 0.6465   AUC 0.9135
# Epoch 100/200 | Train Loss 0.6848  AUC 0.8870 | Test Loss 0.6448   AUC 0.9130
# Epoch 101/200 | Train Loss 0.6921  AUC 0.8763 | Test Loss 0.6404   AUC 0.9132
# Epoch 102/200 | Train Loss 0.6815  AUC 0.8831 | Test Loss 0.6398   AUC 0.9134
# Epoch 103/200 | Train Loss 0.6768  AUC 0.8888 | Test Loss 0.6461   AUC 0.9121
# Epoch 104/200 | Train Loss 0.6740  AUC 0.8919 | Test Loss 0.6366   AUC 0.9128
# Epoch 105/200 | Train Loss 0.6921  AUC 0.8768 | Test Loss 0.6304   AUC 0.9118
# Epoch 106/200 | Train Loss 0.6582  AUC 0.8999 | Test Loss 0.6388   AUC 0.9127
# Epoch 107/200 | Train Loss 0.6719  AUC 0.8920 | Test Loss 0.6382   AUC 0.9132
# Epoch 108/200 | Train Loss 0.6781  AUC 0.8859 | Test Loss 0.6334   AUC 0.9115
# Epoch 109/200 | Train Loss 0.6574  AUC 0.8948 | Test Loss 0.6352   AUC 0.9120
# Epoch 110/200 | Train Loss 0.6511  AUC 0.9011 | Test Loss 0.6355   AUC 0.9137
# Epoch 111/200 | Train Loss 0.6652  AUC 0.8921 | Test Loss 0.6292   AUC 0.9127
# Epoch 112/200 | Train Loss 0.6725  AUC 0.8882 | Test Loss 0.6245   AUC 0.9125
# Epoch 113/200 | Train Loss 0.6578  AUC 0.8935 | Test Loss 0.6224   AUC 0.9130
# Epoch 114/200 | Train Loss 0.6624  AUC 0.8910 | Test Loss 0.6220   AUC 0.9133
# Epoch 115/200 | Train Loss 0.6652  AUC 0.8888 | Test Loss 0.6233   AUC 0.9129
# Epoch 116/200 | Train Loss 0.6477  AUC 0.8963 | Test Loss 0.6195   AUC 0.9131
# Epoch 117/200 | Train Loss 0.6613  AUC 0.8878 | Test Loss 0.6188   AUC 0.9134
# Epoch 118/200 | Train Loss 0.6646  AUC 0.8927 | Test Loss 0.6236   AUC 0.9119
# Epoch 119/200 | Train Loss 0.6501  AUC 0.8941 | Test Loss 0.6197   AUC 0.9129
# Epoch 120/200 | Train Loss 0.6622  AUC 0.8884 | Test Loss 0.6213   AUC 0.9128
# Epoch 121/200 | Train Loss 0.6593  AUC 0.8914 | Test Loss 0.6222   AUC 0.9137
# Epoch 122/200 | Train Loss 0.6311  AUC 0.9060 | Test Loss 0.6177   AUC 0.9136
# Epoch 123/200 | Train Loss 0.6441  AUC 0.8951 | Test Loss 0.6109   AUC 0.9117
# Epoch 124/200 | Train Loss 0.6499  AUC 0.8942 | Test Loss 0.6229   AUC 0.9110
# Epoch 125/200 | Train Loss 0.6322  AUC 0.9032 | Test Loss 0.6205   AUC 0.9123
# Epoch 126/200 | Train Loss 0.6348  AUC 0.9015 | Test Loss 0.6155   AUC 0.9133
# Epoch 127/200 | Train Loss 0.6283  AUC 0.9043 | Test Loss 0.6192   AUC 0.9122
# Epoch 128/200 | Train Loss 0.6442  AUC 0.8976 | Test Loss 0.6166   AUC 0.9121
# Epoch 129/200 | Train Loss 0.6347  AUC 0.8964 | Test Loss 0.6089   AUC 0.9100
# Epoch 130/200 | Train Loss 0.6293  AUC 0.8984 | Test Loss 0.6076   AUC 0.9099
# Epoch 131/200 | Train Loss 0.6184  AUC 0.9059 | Test Loss 0.6069   AUC 0.9110
# Epoch 132/200 | Train Loss 0.6308  AUC 0.9025 | Test Loss 0.6121   AUC 0.9110
# Epoch 133/200 | Train Loss 0.6269  AUC 0.9068 | Test Loss 0.6102   AUC 0.9113
# Epoch 134/200 | Train Loss 0.6264  AUC 0.8982 | Test Loss 0.6141   AUC 0.9120
# Epoch 135/200 | Train Loss 0.6180  AUC 0.9047 | Test Loss 0.6093   AUC 0.9122
# Epoch 136/200 | Train Loss 0.6148  AUC 0.9085 | Test Loss 0.6015   AUC 0.9114
# Epoch 137/200 | Train Loss 0.6295  AUC 0.8982 | Test Loss 0.5984   AUC 0.9125
# Epoch 138/200 | Train Loss 0.6044  AUC 0.9114 | Test Loss 0.6024   AUC 0.9136
# Epoch 139/200 | Train Loss 0.6170  AUC 0.9027 | Test Loss 0.6015   AUC 0.9117
# Epoch 140/200 | Train Loss 0.6003  AUC 0.9124 | Test Loss 0.5966   AUC 0.9133
# Epoch 141/200 | Train Loss 0.6215  AUC 0.9012 | Test Loss 0.6024   AUC 0.9130
# Epoch 142/200 | Train Loss 0.6178  AUC 0.9006 | Test Loss 0.6026   AUC 0.9135
# Epoch 143/200 | Train Loss 0.5958  AUC 0.9131 | Test Loss 0.6037   AUC 0.9139
# Epoch 144/200 | Train Loss 0.6087  AUC 0.9085 | Test Loss 0.5984   AUC 0.9132
# Epoch 145/200 | Train Loss 0.6223  AUC 0.8997 | Test Loss 0.5998   AUC 0.9136
# Epoch 146/200 | Train Loss 0.6036  AUC 0.9065 | Test Loss 0.5999   AUC 0.9138
# Epoch 147/200 | Train Loss 0.6100  AUC 0.9037 | Test Loss 0.6002   AUC 0.9127
# Epoch 148/200 | Train Loss 0.6190  AUC 0.9019 | Test Loss 0.5954   AUC 0.9124
# Epoch 149/200 | Train Loss 0.6034  AUC 0.9097 | Test Loss 0.5985   AUC 0.9107
# Epoch 150/200 | Train Loss 0.6109  AUC 0.9063 | Test Loss 0.5970   AUC 0.9112
# Epoch 151/200 | Train Loss 0.6224  AUC 0.9005 | Test Loss 0.5924   AUC 0.9119
# Epoch 152/200 | Train Loss 0.5986  AUC 0.9074 | Test Loss 0.5954   AUC 0.9117
# Epoch 153/200 | Train Loss 0.5991  AUC 0.9115 | Test Loss 0.5958   AUC 0.9106

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("ADNI AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("ADNI Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
