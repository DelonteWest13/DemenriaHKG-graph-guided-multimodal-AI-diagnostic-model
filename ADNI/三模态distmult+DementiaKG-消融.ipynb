# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,KGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
#生物标志物 ad 90*48   no 349*58
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'normal_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'ad_nii_KG/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NC_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #151
print(count_no) #211
print(count_mci) #475
# Out:
# 151
# 211
# 475

# %%
ad_arrays=[]
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','ind':'3','ans':'4'}
for i in data_ad:   #第13行开始为基因、蛋白水平
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    ad_array = np.array(num_list)
    ad_arrays.append(ad_array)
ad_array = np.vstack(ad_arrays)

normal_arrays=[]
for i in data_normal:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    normal_array = np.array(num_list)
    normal_arrays.append(normal_array)
normal_array = np.vstack(normal_arrays)

mci_arrays=[]
for i in data_mci:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    mci_array = np.array(num_list)
    mci_arrays.append(mci_array)
mci_array = np.vstack(mci_arrays)

#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # 推荐：引入激活函数库

# 1. 转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 2. 定义网络层 
# 关键修复：输入维度由 45 改为 52 (匹配你的数据列数)
# 关键优化：使用不同的变量名 (fc1, fc2, fc3) 防止层被覆盖
fc1 = nn.Linear(52, 32)
fc2 = nn.Linear(32, 16)
fc3 = nn.Linear(16, 1)

# 3. 前向传播
# 注意：多层网络通常需要在层与层之间加激活函数(如 ReLU)，否则它数学上等价于单层网络。
# 为了保持代码运行，这里先按你的逻辑写，如果需要增加非线性能力，请取消注释 relu 行。

# 第一层
ad_tensor = fc1(ad_tensor)
# ad_tensor = F.relu(ad_tensor) 
normal_tensor = fc1(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc1(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第二层
ad_tensor = fc2(ad_tensor)
# ad_tensor = F.relu(ad_tensor)
normal_tensor = fc2(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc2(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第三层 (输出层)
ad_tensor = fc3(ad_tensor)
normal_tensor = fc3(normal_tensor)
mci_tensor = fc3(mci_tensor)

# 4. 打印结果
print('AD_tensor shape:', ad_tensor.shape)      # 预期: (151, 1)
print('Normal_tensor shape:', normal_tensor.shape) # 预期: (211, 1)
print('MCI_tensor shape:', mci_tensor.shape)    # 预期: (475, 1)
# Out:
# AD_tensor shape: torch.Size([151, 1])
# Normal_tensor shape: torch.Size([211, 1])
# MCI_tensor shape: torch.Size([475, 1])

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        # 替换字典中的值
        row = [replace_dict.get(item, item) for item in row]
        # 将类别型变量转换为数值
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[2:16])
    return np.array(processed_data)

# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict)
normal_data = preprocess_data(data_normal, replace_dict)
mci_data = preprocess_data(data_mci, replace_dict)

categorical_indices = [3,4,5,6,7]  # gender, education, hispanic, race
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(14, 16)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(16, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#医学图像
nii = CNN_3D(num_class=1)
nii= nii.to(device)
all_ad = 'ad_nii_KG/'
all_normal = 'normal_nii_kg/'
all_mci = 'NC_nii_kg/'
dataset = NiiDataset(all_ad)
batch_size = 16
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_normal)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_mci)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)

# %%
# ---------- Cell 9 : 加载 ADNI KG Embeddings (最终修正版：找回列名 + 特征聚合) ----------
import numpy as np
import torch
import pandas as pd
import json
import os
import re

# 1. 配置文件路径
ENTITY_EMB_NPY = "adni_kg_embeddings.npy"
ENTITY2ID_FILE = "adni_kg_entity2id.json"
# 重新定义 CSV 路径，确保能读到列名
CSV_PATHS = {
    'AD': 'AD.csv',
    'MCI': 'mci.csv',
    'NC': 'normal.csv'
}

print(f"Loading {ENTITY2ID_FILE}...")
with open(ENTITY2ID_FILE, 'r') as f:
    entity2id = json.load(f)

print(f"Loading {ENTITY_EMB_NPY}...")
emb = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()

# 定义提取器
class DistMultExtract:
    def get(self, ent: str):
        return emb[entity2id[ent]] if ent in entity2id else None

extractor = DistMultExtract()

# 2. 定义映射与分箱逻辑 (必须与构建图谱时完全一致)
SYMPTOM_MAP = {
    "npiq_DEL": "PrimeKG:Delusions",
    "npiq_HALL": "PrimeKG:Hallucinations",
    "npiq_AGIT": "PrimeKG:Agitation",
    "npiq_DEPD": "PrimeKG:Depressivity",
    "npiq_ANX": "PrimeKG:Anxiety",
    "npiq_ELAT": "PrimeKG:Conspicuously happy disposition",
    "npiq_APA": "PrimeKG:Apathy",
    "npiq_DISN": "PrimeKG:Disinhibition",
    "npiq_IRR": "PrimeKG:Irritability",
    "npiq_MOT": "PrimeKG:Restlessness",
}

IMPORTANT_PREFIXES = ["Tesla", "faq_", "his_", "trail", "lm_", "boston", "animal", "vege", "digit", "gds", "moca"]

def discretize_val(col_name, val):
    try: v = float(val)
    except: return str(val).strip().lower()
    col_lower = col_name.lower()
    if "tesla" in col_lower or "brain" in col_lower:
        return str(int(v // 50 * 50)) if v > 100 else f"{v:.1f}"
    if "age" in col_lower: return str(int(v // 5 * 5))
    if "trail" in col_lower: return str(int(v // 10 * 10))
    if any(x in col_lower for x in ["faq", "gds", "moca", "digit", "boston", "animal"]): return str(int(v))
    return f"{v:.2f}"

# 3. 定义特征聚合函数 (解决过拟合的关键)
def row_embed(row: pd.Series) -> torch.Tensor:
    vecs = []
    
    # A. 聚合 PrimeKG 症状 (利用外部知识)
    for col, prime_node in SYMPTOM_MAP.items():
        if col in row and pd.notna(row[col]): # 确保列存在且值有效
            try:
                if float(row[col]) > 0:
                    vec = extractor.get(prime_node)
                    if vec is not None:
                        w = 1.0 + (float(row[col]) * 0.5) # 加权
                        vecs.append(vec * w)
            except: pass

    # B. 聚合本地强特征 (MRI, FAQ...)
    for col_name in row.index:
        is_imp = False
        for prefix in IMPORTANT_PREFIXES:
            if str(col_name).startswith(prefix):
                is_imp = True; break
        
        if is_imp:
            val = row[col_name]
            if pd.notna(val) and str(val) not in ['', 'nan', '0', '0.0']:
                val_bin = discretize_val(col_name, val)
                # 构造节点名 (如 Feature:Tesla_1200)
                node_name = f"Feature:{col_name}_{val_bin}"
                
                vec = extractor.get(node_name)
                if vec is not None:
                    vecs.append(vec)

    # C. 聚合基因 (APOE)
    if 'apoe' in row and pd.notna(row['apoe']):
        try:
            aval = int(float(row['apoe']))
            if aval > 0:
                gnode = f"Gene:APOE_e4_Copies:{aval}"
                vec = extractor.get(gnode)
                if vec is not None: vecs.append(vec * 2.0)
        except: pass

    # 平均池化
    if len(vecs) > 0:
        return torch.stack(vecs).mean(0)
    else:
        return torch.zeros(128)

# 4. 执行提取 (关键：重新读取 CSV 以获取列名)
print("Reloading DataFrames to ensure headers...")
# 重新读取，保证 row['npiq_DEL'] 能取到值
df_ad_real = pd.read_csv(CSV_PATHS['AD'])
df_mci_real = pd.read_csv(CSV_PATHS['MCI'])
df_nc_real = pd.read_csv(CSV_PATHS['NC'])

print(f"Columns check (AD): {list(df_ad_real.columns)[:3]} ... (Headers exist!)")

print("Processing AD (Feature Aggregation)...")
ad_transe = torch.stack([row_embed(r) for _, r in df_ad_real.iterrows()])

print("Processing MCI (Feature Aggregation)...")
mci_transe = torch.stack([row_embed(r) for _, r in df_mci_real.iterrows()])

print("Processing Normal (Feature Aggregation)...")
normal_transe = torch.stack([row_embed(r) for _, r in df_nc_real.iterrows()])

print("\nShapes:", ad_transe.shape, mci_transe.shape, normal_transe.shape)

# 自检
zero_cnt = 0
if torch.all(ad_transe == 0): zero_cnt += 1
if torch.all(normal_transe == 0): zero_cnt += 1

if zero_cnt > 0:
    print("❌ 警告：依然有全0向量！请检查 'build_adni_primekg.py' 是否已运行并生成了包含 Feature 节点的图谱。")
else:
    print("✅ 成功！特征向量生成完毕 (Inductive Mode)。")
# Out:
# Loading adni_kg_entity2id.json...
# Loading adni_kg_embeddings.npy...
# Reloading DataFrames to ensure headers...
# Columns check (AD): ['path', 'filename', 'age'] ... (Headers exist!)
# Processing AD (Feature Aggregation)...
# Processing MCI (Feature Aggregation)...
# Processing Normal (Feature Aggregation)...
#
# Shapes: torch.Size([151, 128]) torch.Size([475, 128]) torch.Size([211, 128])
# ✅ 成功！特征向量生成完毕 (Inductive Mode)。

# %%
# ---------- Cell 10: 特征拼接与消融实验配置 ---------- #
import torch
import numpy as np

# ================= 消融实验配置 =================
# 0: ALL (全模态/Baseline)
# 1: 消去 EHR 特征 (临床表格/人口统计学)
# 2: 消去 MRI 影像特征 (CNN提取的特征)
# 3: 消去 Tensor 特征 (神经网络加权特征)
# 4: 消去 KG 知识图谱特征 (DistMult嵌入)
ABLATION_MODE = 0 # <--- 修改此处切换实验模式
# ===============================================

print(f"当前消融实验模式: {ABLATION_MODE}")

def mask_tensor(tensor, mode_code):
    """如果当前模式代码匹配，则返回同形状的全0张量"""
    if ABLATION_MODE == mode_code:
        return torch.zeros_like(tensor)
    return tensor

# 维度设定
transe_embed_dim = 128  

# 1. 拼接 AD 特征 (注意 ad_output.cpu())
X_ad = torch.cat([
    mask_tensor(ad_EHR, 1), 
    mask_tensor(ad_output.cpu(), 2), 
    mask_tensor(ad_tensor, 3), 
    mask_tensor(ad_transe, 4)
], dim=1) 

# 2. 拼接 MCI 特征
X_mci = torch.cat([
    mask_tensor(mci_EHR, 1), 
    mask_tensor(mci_output.cpu(), 2), 
    mask_tensor(mci_tensor, 3), 
    mask_tensor(mci_transe, 4)
], dim=1)

# 3. 拼接 Normal 特征
X_normal = torch.cat([
    mask_tensor(normal_EHR, 1), 
    mask_tensor(normal_output.cpu(), 2), 
    mask_tensor(normal_tensor, 3), 
    mask_tensor(normal_transe, 4)
], dim=1)

# --- 验证拼接后的特征情况 (可选) ---
def check_modality_status(name, tensor):
    # 根据 Cell 6 和 Cell 4 的定义，各部分维度如下：
    # EHR: 1, MRI: 1, Tensor: 1, KG: 128 (注：本代码中前三者投影后均为了1)
    ehr = tensor[:, 0:1]
    mri = tensor[:, 1:2]
    tens = tensor[:, 2:3]
    kg = tensor[:, 3:]
    print(f"--- {name} 特征验证 ---")
    print(f"EHR 非零占比: {torch.count_nonzero(ehr)/ehr.numel():.1%}")
    print(f"MRI 非零占比: {torch.count_nonzero(mri)/mri.numel():.1%}")
    print(f"Tensor 非零占比: {torch.count_nonzero(tens)/tens.numel():.1%}")
    print(f"KG 非零占比: {torch.count_nonzero(kg)/kg.numel():.1%}")

check_modality_status("AD", X_ad)

# 构造标签与数据切分
y_ad = torch.ones(len(X_ad)) * 2 
y_mci = torch.ones(len(X_mci)) * 1 
y_normal = torch.ones(len(X_normal)) * 0 

X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()

# 切片分割特征 (注意：这里要保持与后续训练代码逻辑一致)
features = X[:, :-transe_embed_dim]  
transe_embeddings = X[:, -transe_embed_dim:]
# Out:
# 当前消融实验模式: 0
# --- AD 特征验证 ---
# EHR 非零占比: 100.0%
# MRI 非零占比: 100.0%
# Tensor 非零占比: 100.0%
# KG 非零占比: 100.0%

# %%
X_train, X_test, y_train, y_test, transe_train, transe_test = train_test_split(
    features.detach().numpy(), y.numpy(), transe_embeddings.detach().numpy(),
    test_size=0.20,
    stratify=y.numpy(),
    random_state=32
)
X_train, X_val, y_train, y_val, transe_train, transe_val = train_test_split(
    X_train, y_train, transe_train,
    test_size=0.20,
    stratify=y_train,
    random_state=30
)


X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)  # Use LongTensor for classification labels
transe_train_tensor = torch.FloatTensor(transe_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
transe_val_tensor = torch.FloatTensor(transe_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
transe_test_tensor = torch.FloatTensor(transe_test).to(device)


train_dataset = TensorDataset(X_train_tensor, transe_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, transe_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, transe_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
embed_dim        = 32
# ★★★ 修改点：输入维度必须匹配 .npy 文件 ★★★
transe_embed_dim = 128           
num_epochs       = 300
batch_size       = 32
learning_rate    = 1e-5
weight_decay     = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 初始化模型 (注意 model1.py 里的 KGMultiModalTransformer 已经写好了接收这个参数)
model = KGMultiModalTransformer(
            embed_dim=embed_dim,
            transe_embed_dim=transe_embed_dim
        ).to(device)

criterion  = nn.CrossEntropyLoss()
optimizer  = optim.Adam(model.parameters(),
                        lr=learning_rate,
                        weight_decay=weight_decay)

train_losses  = []; train_aucs  = []; train_f1s  = []
train_recalls = []; train_precisions = []
test_losses   = []; test_aucs   = []; test_f1s   = []
test_recalls  = []; test_precisions  = []

for epoch in range(num_epochs):
    tr_loss, tr_auc, tr_f1, tr_rec, tr_prec = train_epoch(
        model, train_loader, optimizer, criterion, device)
    te_loss, te_auc, te_f1, te_rec, te_prec = validate_epoch(
        model, test_loader,  criterion, device)

    train_losses.append(tr_loss);    test_losses.append(te_loss)
    train_aucs.append(tr_auc);       test_aucs.append(te_auc)
    train_f1s.append(tr_f1);         test_f1s.append(te_f1)
    train_recalls.append(tr_rec);    test_recalls.append(te_rec)
    train_precisions.append(tr_prec);test_precisions.append(te_prec)

    print(f"Epoch {epoch+1}/{num_epochs} | "
          f"Train Loss {tr_loss:.4f}  AUC {tr_auc:.4f} | "
          f"Test Loss {te_loss:.4f}   AUC {te_auc:.4f}")
# -------------------------------------------------------------------------------
# Out:
# Epoch 1/300 | Train Loss 1.1201  AUC 0.6202 | Test Loss 1.0805   AUC 0.6956
# Epoch 2/300 | Train Loss 1.0857  AUC 0.6526 | Test Loss 1.0675   AUC 0.7036
# Epoch 3/300 | Train Loss 1.0693  AUC 0.6742 | Test Loss 1.0562   AUC 0.7189
# Epoch 4/300 | Train Loss 1.0812  AUC 0.6614 | Test Loss 1.0435   AUC 0.7341
# Epoch 5/300 | Train Loss 1.0623  AUC 0.6867 | Test Loss 1.0345   AUC 0.7418
# Epoch 6/300 | Train Loss 1.0548  AUC 0.6904 | Test Loss 1.0306   AUC 0.7587
# Epoch 7/300 | Train Loss 1.0383  AUC 0.7274 | Test Loss 1.0251   AUC 0.7669
# Epoch 8/300 | Train Loss 1.0400  AUC 0.7180 | Test Loss 1.0180   AUC 0.7765
# Epoch 9/300 | Train Loss 1.0545  AUC 0.6970 | Test Loss 1.0128   AUC 0.7835
# Epoch 10/300 | Train Loss 1.0209  AUC 0.7190 | Test Loss 1.0077   AUC 0.7885
# Epoch 11/300 | Train Loss 1.0176  AUC 0.7367 | Test Loss 1.0008   AUC 0.7927
# Epoch 12/300 | Train Loss 1.0047  AUC 0.7342 | Test Loss 0.9962   AUC 0.7920
# Epoch 13/300 | Train Loss 1.0081  AUC 0.7376 | Test Loss 0.9888   AUC 0.8005
# Epoch 14/300 | Train Loss 0.9978  AUC 0.7501 | Test Loss 0.9858   AUC 0.8042
# Epoch 15/300 | Train Loss 0.9815  AUC 0.7639 | Test Loss 0.9819   AUC 0.8110
# Epoch 16/300 | Train Loss 0.9977  AUC 0.7389 | Test Loss 0.9719   AUC 0.8115
# Epoch 17/300 | Train Loss 0.9959  AUC 0.7460 | Test Loss 0.9676   AUC 0.8141
# Epoch 18/300 | Train Loss 1.0009  AUC 0.7354 | Test Loss 0.9630   AUC 0.8140
# Epoch 19/300 | Train Loss 0.9846  AUC 0.7572 | Test Loss 0.9592   AUC 0.8191
# Epoch 20/300 | Train Loss 0.9829  AUC 0.7496 | Test Loss 0.9544   AUC 0.8201
# Epoch 21/300 | Train Loss 0.9632  AUC 0.7744 | Test Loss 0.9490   AUC 0.8218
# Epoch 22/300 | Train Loss 0.9518  AUC 0.7861 | Test Loss 0.9464   AUC 0.8259
# Epoch 23/300 | Train Loss 0.9537  AUC 0.7832 | Test Loss 0.9434   AUC 0.8271
# Epoch 24/300 | Train Loss 0.9583  AUC 0.7777 | Test Loss 0.9399   AUC 0.8284
# Epoch 25/300 | Train Loss 0.9385  AUC 0.8009 | Test Loss 0.9335   AUC 0.8281
# Epoch 26/300 | Train Loss 0.9384  AUC 0.7949 | Test Loss 0.9360   AUC 0.8325
# Epoch 27/300 | Train Loss 0.9385  AUC 0.7876 | Test Loss 0.9282   AUC 0.8342
# Epoch 28/300 | Train Loss 0.9402  AUC 0.7905 | Test Loss 0.9214   AUC 0.8340
# Epoch 29/300 | Train Loss 0.9427  AUC 0.7833 | Test Loss 0.9191   AUC 0.8350
# Epoch 30/300 | Train Loss 0.9241  AUC 0.8033 | Test Loss 0.9175   AUC 0.8370
# Epoch 31/300 | Train Loss 0.9286  AUC 0.7921 | Test Loss 0.9099   AUC 0.8402
# Epoch 32/300 | Train Loss 0.9229  AUC 0.7929 | Test Loss 0.9069   AUC 0.8391
# Epoch 33/300 | Train Loss 0.9171  AUC 0.8098 | Test Loss 0.8988   AUC 0.8411
# Epoch 34/300 | Train Loss 0.9083  AUC 0.8059 | Test Loss 0.8991   AUC 0.8441
# Epoch 35/300 | Train Loss 0.9081  AUC 0.8040 | Test Loss 0.8917   AUC 0.8428
# Epoch 36/300 | Train Loss 0.9058  AUC 0.8174 | Test Loss 0.8952   AUC 0.8459
# Epoch 37/300 | Train Loss 0.9067  AUC 0.8127 | Test Loss 0.8846   AUC 0.8452
# Epoch 38/300 | Train Loss 0.8945  AUC 0.8191 | Test Loss 0.8852   AUC 0.8467
# Epoch 39/300 | Train Loss 0.8896  AUC 0.8155 | Test Loss 0.8785   AUC 0.8473
# Epoch 40/300 | Train Loss 0.8927  AUC 0.8091 | Test Loss 0.8750   AUC 0.8490
# Epoch 41/300 | Train Loss 0.8906  AUC 0.8179 | Test Loss 0.8720   AUC 0.8490
# Epoch 42/300 | Train Loss 0.8856  AUC 0.8153 | Test Loss 0.8685   AUC 0.8487
# Epoch 43/300 | Train Loss 0.8695  AUC 0.8232 | Test Loss 0.8693   AUC 0.8513
# Epoch 44/300 | Train Loss 0.8638  AUC 0.8311 | Test Loss 0.8605   AUC 0.8509
# Epoch 45/300 | Train Loss 0.8584  AUC 0.8320 | Test Loss 0.8566   AUC 0.8517
# Epoch 46/300 | Train Loss 0.8713  AUC 0.8263 | Test Loss 0.8555   AUC 0.8541
# Epoch 47/300 | Train Loss 0.8711  AUC 0.8246 | Test Loss 0.8564   AUC 0.8552
# Epoch 48/300 | Train Loss 0.8613  AUC 0.8320 | Test Loss 0.8525   AUC 0.8556
# Epoch 49/300 | Train Loss 0.8433  AUC 0.8442 | Test Loss 0.8523   AUC 0.8571
# Epoch 50/300 | Train Loss 0.8475  AUC 0.8379 | Test Loss 0.8426   AUC 0.8570
# Epoch 51/300 | Train Loss 0.8481  AUC 0.8352 | Test Loss 0.8403   AUC 0.8563
# Epoch 52/300 | Train Loss 0.8387  AUC 0.8435 | Test Loss 0.8427   AUC 0.8588
# Epoch 53/300 | Train Loss 0.8423  AUC 0.8349 | Test Loss 0.8401   AUC 0.8590
# Epoch 54/300 | Train Loss 0.8355  AUC 0.8464 | Test Loss 0.8300   AUC 0.8600
# Epoch 55/300 | Train Loss 0.8335  AUC 0.8474 | Test Loss 0.8313   AUC 0.8597
# Epoch 56/300 | Train Loss 0.8259  AUC 0.8482 | Test Loss 0.8253   AUC 0.8610
# Epoch 57/300 | Train Loss 0.8314  AUC 0.8500 | Test Loss 0.8238   AUC 0.8614
# Epoch 58/300 | Train Loss 0.8377  AUC 0.8370 | Test Loss 0.8282   AUC 0.8622
# Epoch 59/300 | Train Loss 0.8292  AUC 0.8424 | Test Loss 0.8223   AUC 0.8636
# Epoch 60/300 | Train Loss 0.8287  AUC 0.8412 | Test Loss 0.8137   AUC 0.8643
# Epoch 61/300 | Train Loss 0.8226  AUC 0.8433 | Test Loss 0.8050   AUC 0.8636
# Epoch 62/300 | Train Loss 0.8163  AUC 0.8452 | Test Loss 0.8077   AUC 0.8643
# Epoch 63/300 | Train Loss 0.8128  AUC 0.8513 | Test Loss 0.8101   AUC 0.8643
# Epoch 64/300 | Train Loss 0.8161  AUC 0.8405 | Test Loss 0.8099   AUC 0.8659
# Epoch 65/300 | Train Loss 0.8082  AUC 0.8500 | Test Loss 0.8027   AUC 0.8673
# Epoch 66/300 | Train Loss 0.8095  AUC 0.8463 | Test Loss 0.8060   AUC 0.8677
# Epoch 67/300 | Train Loss 0.8038  AUC 0.8508 | Test Loss 0.7989   AUC 0.8682
# Epoch 68/300 | Train Loss 0.7833  AUC 0.8689 | Test Loss 0.7938   AUC 0.8680
# Epoch 69/300 | Train Loss 0.7965  AUC 0.8643 | Test Loss 0.7912   AUC 0.8691
# Epoch 70/300 | Train Loss 0.8020  AUC 0.8570 | Test Loss 0.8002   AUC 0.8688
# Epoch 71/300 | Train Loss 0.7981  AUC 0.8492 | Test Loss 0.7968   AUC 0.8700
# Epoch 72/300 | Train Loss 0.7905  AUC 0.8584 | Test Loss 0.7932   AUC 0.8708
# Epoch 73/300 | Train Loss 0.7842  AUC 0.8670 | Test Loss 0.7873   AUC 0.8712
# Epoch 74/300 | Train Loss 0.7759  AUC 0.8615 | Test Loss 0.7869   AUC 0.8708
# Epoch 75/300 | Train Loss 0.7802  AUC 0.8602 | Test Loss 0.7820   AUC 0.8716
# Epoch 76/300 | Train Loss 0.7725  AUC 0.8680 | Test Loss 0.7841   AUC 0.8721
# Epoch 77/300 | Train Loss 0.7638  AUC 0.8742 | Test Loss 0.7830   AUC 0.8724
# Epoch 78/300 | Train Loss 0.7760  AUC 0.8588 | Test Loss 0.7804   AUC 0.8720
# Epoch 79/300 | Train Loss 0.7831  AUC 0.8533 | Test Loss 0.7788   AUC 0.8728
# Epoch 80/300 | Train Loss 0.7692  AUC 0.8703 | Test Loss 0.7759   AUC 0.8728
# Epoch 81/300 | Train Loss 0.7763  AUC 0.8650 | Test Loss 0.7705   AUC 0.8736
# Epoch 82/300 | Train Loss 0.7697  AUC 0.8659 | Test Loss 0.7673   AUC 0.8735
# Epoch 83/300 | Train Loss 0.7749  AUC 0.8591 | Test Loss 0.7694   AUC 0.8741
# Epoch 84/300 | Train Loss 0.7611  AUC 0.8705 | Test Loss 0.7627   AUC 0.8743
# Epoch 85/300 | Train Loss 0.7612  AUC 0.8666 | Test Loss 0.7643   AUC 0.8754
# Epoch 86/300 | Train Loss 0.7505  AUC 0.8775 | Test Loss 0.7687   AUC 0.8747
# Epoch 87/300 | Train Loss 0.7632  AUC 0.8590 | Test Loss 0.7637   AUC 0.8759
# Epoch 88/300 | Train Loss 0.7501  AUC 0.8766 | Test Loss 0.7623   AUC 0.8753
# Epoch 89/300 | Train Loss 0.7411  AUC 0.8784 | Test Loss 0.7559   AUC 0.8762
# Epoch 90/300 | Train Loss 0.7434  AUC 0.8759 | Test Loss 0.7553   AUC 0.8768
# Epoch 91/300 | Train Loss 0.7455  AUC 0.8665 | Test Loss 0.7534   AUC 0.8770
# Epoch 92/300 | Train Loss 0.7363  AUC 0.8767 | Test Loss 0.7510   AUC 0.8771
# Epoch 93/300 | Train Loss 0.7356  AUC 0.8792 | Test Loss 0.7547   AUC 0.8773
# Epoch 94/300 | Train Loss 0.7368  AUC 0.8688 | Test Loss 0.7540   AUC 0.8785
# Epoch 95/300 | Train Loss 0.7339  AUC 0.8746 | Test Loss 0.7465   AUC 0.8789
# Epoch 96/300 | Train Loss 0.7361  AUC 0.8731 | Test Loss 0.7421   AUC 0.8783
# Epoch 97/300 | Train Loss 0.7354  AUC 0.8720 | Test Loss 0.7352   AUC 0.8798
# Epoch 98/300 | Train Loss 0.7295  AUC 0.8807 | Test Loss 0.7387   AUC 0.8799
# Epoch 99/300 | Train Loss 0.7252  AUC 0.8836 | Test Loss 0.7374   AUC 0.8786
# Epoch 100/300 | Train Loss 0.7352  AUC 0.8722 | Test Loss 0.7371   AUC 0.8799
# Epoch 101/300 | Train Loss 0.7225  AUC 0.8853 | Test Loss 0.7359   AUC 0.8798
# Epoch 102/300 | Train Loss 0.7218  AUC 0.8808 | Test Loss 0.7295   AUC 0.8810
# Epoch 103/300 | Train Loss 0.7316  AUC 0.8765 | Test Loss 0.7242   AUC 0.8812
# Epoch 104/300 | Train Loss 0.7139  AUC 0.8862 | Test Loss 0.7301   AUC 0.8816
# Epoch 105/300 | Train Loss 0.7156  AUC 0.8775 | Test Loss 0.7315   AUC 0.8819
# Epoch 106/300 | Train Loss 0.7149  AUC 0.8848 | Test Loss 0.7268   AUC 0.8822
# Epoch 107/300 | Train Loss 0.7135  AUC 0.8782 | Test Loss 0.7207   AUC 0.8820
# Epoch 108/300 | Train Loss 0.7234  AUC 0.8732 | Test Loss 0.7250   AUC 0.8824
# Epoch 109/300 | Train Loss 0.7167  AUC 0.8731 | Test Loss 0.7211   AUC 0.8821
# Epoch 110/300 | Train Loss 0.7019  AUC 0.8873 | Test Loss 0.7199   AUC 0.8834
# Epoch 111/300 | Train Loss 0.7056  AUC 0.8830 | Test Loss 0.7167   AUC 0.8822
# Epoch 112/300 | Train Loss 0.7036  AUC 0.8864 | Test Loss 0.7133   AUC 0.8830
# Epoch 113/300 | Train Loss 0.7028  AUC 0.8805 | Test Loss 0.7125   AUC 0.8835
# Epoch 114/300 | Train Loss 0.6976  AUC 0.8887 | Test Loss 0.7098   AUC 0.8836
# Epoch 115/300 | Train Loss 0.6917  AUC 0.8918 | Test Loss 0.7093   AUC 0.8839
# Epoch 116/300 | Train Loss 0.6958  AUC 0.8876 | Test Loss 0.7121   AUC 0.8841
# Epoch 117/300 | Train Loss 0.6908  AUC 0.8901 | Test Loss 0.7162   AUC 0.8834
# Epoch 118/300 | Train Loss 0.6996  AUC 0.8832 | Test Loss 0.7091   AUC 0.8858
# Epoch 119/300 | Train Loss 0.6793  AUC 0.8954 | Test Loss 0.7142   AUC 0.8841
# Epoch 120/300 | Train Loss 0.7029  AUC 0.8820 | Test Loss 0.7028   AUC 0.8856
# Epoch 121/300 | Train Loss 0.6894  AUC 0.8890 | Test Loss 0.7007   AUC 0.8858
# Epoch 122/300 | Train Loss 0.6937  AUC 0.8853 | Test Loss 0.6971   AUC 0.8871
# Epoch 123/300 | Train Loss 0.6793  AUC 0.8941 | Test Loss 0.7002   AUC 0.8866
# Epoch 124/300 | Train Loss 0.6849  AUC 0.8888 | Test Loss 0.7042   AUC 0.8862
# Epoch 125/300 | Train Loss 0.6745  AUC 0.8916 | Test Loss 0.6945   AUC 0.8868
# Epoch 126/300 | Train Loss 0.6710  AUC 0.8964 | Test Loss 0.6984   AUC 0.8871
# Epoch 127/300 | Train Loss 0.6731  AUC 0.8959 | Test Loss 0.6928   AUC 0.8876
# Epoch 128/300 | Train Loss 0.6651  AUC 0.9028 | Test Loss 0.6884   AUC 0.8873
# Epoch 129/300 | Train Loss 0.6842  AUC 0.8838 | Test Loss 0.6887   AUC 0.8877
# Epoch 130/300 | Train Loss 0.6710  AUC 0.8935 | Test Loss 0.6916   AUC 0.8885
# Epoch 131/300 | Train Loss 0.6734  AUC 0.8864 | Test Loss 0.6869   AUC 0.8879
# Epoch 132/300 | Train Loss 0.6680  AUC 0.8973 | Test Loss 0.6890   AUC 0.8886
# Epoch 133/300 | Train Loss 0.6670  AUC 0.8945 | Test Loss 0.6826   AUC 0.8881
# Epoch 134/300 | Train Loss 0.6703  AUC 0.8947 | Test Loss 0.6839   AUC 0.8890
# Epoch 135/300 | Train Loss 0.6596  AUC 0.8970 | Test Loss 0.6842   AUC 0.8875
# Epoch 136/300 | Train Loss 0.6770  AUC 0.8907 | Test Loss 0.6868   AUC 0.8887
# Epoch 137/300 | Train Loss 0.6595  AUC 0.8961 | Test Loss 0.6811   AUC 0.8891
# Epoch 138/300 | Train Loss 0.6595  AUC 0.8954 | Test Loss 0.6749   AUC 0.8892
# Epoch 139/300 | Train Loss 0.6573  AUC 0.8992 | Test Loss 0.6746   AUC 0.8899
# Epoch 140/300 | Train Loss 0.6623  AUC 0.8941 | Test Loss 0.6732   AUC 0.8905
# Epoch 141/300 | Train Loss 0.6661  AUC 0.8914 | Test Loss 0.6757   AUC 0.8897
# Epoch 142/300 | Train Loss 0.6567  AUC 0.8973 | Test Loss 0.6799   AUC 0.8904
# Epoch 143/300 | Train Loss 0.6557  AUC 0.8960 | Test Loss 0.6737   AUC 0.8908
# Epoch 144/300 | Train Loss 0.6534  AUC 0.9002 | Test Loss 0.6709   AUC 0.8899
# Epoch 145/300 | Train Loss 0.6468  AUC 0.9064 | Test Loss 0.6690   AUC 0.8914
# Epoch 146/300 | Train Loss 0.6548  AUC 0.8949 | Test Loss 0.6700   AUC 0.8915
# Epoch 147/300 | Train Loss 0.6510  AUC 0.8983 | Test Loss 0.6671   AUC 0.8912
# Epoch 148/300 | Train Loss 0.6351  AUC 0.9045 | Test Loss 0.6665   AUC 0.8906
# Epoch 149/300 | Train Loss 0.6514  AUC 0.8953 | Test Loss 0.6658   AUC 0.8912
# Epoch 150/300 | Train Loss 0.6458  AUC 0.9001 | Test Loss 0.6630   AUC 0.8915
# Epoch 151/300 | Train Loss 0.6410  AUC 0.9009 | Test Loss 0.6611   AUC 0.8917
# Epoch 152/300 | Train Loss 0.6289  AUC 0.9085 | Test Loss 0.6661   AUC 0.8906
# Epoch 153/300 | Train Loss 0.6311  AUC 0.9059 | Test Loss 0.6624   AUC 0.8914
# Epoch 154/300 | Train Loss 0.6383  AUC 0.9019 | Test Loss 0.6587   AUC 0.8920
# Epoch 155/300 | Train Loss 0.6356  AUC 0.9024 | Test Loss 0.6569   AUC 0.8922
# Epoch 156/300 | Train Loss 0.6299  AUC 0.9021 | Test Loss 0.6540   AUC 0.8911
# Epoch 157/300 | Train Loss 0.6325  AUC 0.9038 | Test Loss 0.6524   AUC 0.8932
# Epoch 158/300 | Train Loss 0.6311  AUC 0.9007 | Test Loss 0.6576   AUC 0.8933
# Epoch 159/300 | Train Loss 0.6378  AUC 0.8961 | Test Loss 0.6524   AUC 0.8926
# Epoch 160/300 | Train Loss 0.6206  AUC 0.9120 | Test Loss 0.6560   AUC 0.8924
# Epoch 161/300 | Train Loss 0.6342  AUC 0.9025 | Test Loss 0.6482   AUC 0.8932
# Epoch 162/300 | Train Loss 0.6226  AUC 0.9090 | Test Loss 0.6505   AUC 0.8936
# Epoch 163/300 | Train Loss 0.6241  AUC 0.9041 | Test Loss 0.6477   AUC 0.8931
# Epoch 164/300 | Train Loss 0.6277  AUC 0.9023 | Test Loss 0.6462   AUC 0.8936
# Epoch 165/300 | Train Loss 0.6060  AUC 0.9149 | Test Loss 0.6462   AUC 0.8932
# Epoch 166/300 | Train Loss 0.6193  AUC 0.9046 | Test Loss 0.6443   AUC 0.8935
# Epoch 167/300 | Train Loss 0.6170  AUC 0.9098 | Test Loss 0.6443   AUC 0.8939
# Epoch 168/300 | Train Loss 0.6194  AUC 0.9085 | Test Loss 0.6440   AUC 0.8942
# Epoch 169/300 | Train Loss 0.6086  AUC 0.9130 | Test Loss 0.6443   AUC 0.8940
# Epoch 170/300 | Train Loss 0.6219  AUC 0.9044 | Test Loss 0.6398   AUC 0.8940
# Epoch 171/300 | Train Loss 0.6250  AUC 0.9015 | Test Loss 0.6377   AUC 0.8938
# Epoch 172/300 | Train Loss 0.6169  AUC 0.9060 | Test Loss 0.6340   AUC 0.8955
# Epoch 173/300 | Train Loss 0.6238  AUC 0.8998 | Test Loss 0.6335   AUC 0.8932
# Epoch 174/300 | Train Loss 0.6107  AUC 0.9044 | Test Loss 0.6321   AUC 0.8943
# Epoch 175/300 | Train Loss 0.6058  AUC 0.9102 | Test Loss 0.6320   AUC 0.8946
# Epoch 176/300 | Train Loss 0.6098  AUC 0.9102 | Test Loss 0.6300   AUC 0.8943
# Epoch 177/300 | Train Loss 0.6099  AUC 0.9088 | Test Loss 0.6318   AUC 0.8944
# Epoch 178/300 | Train Loss 0.6140  AUC 0.9042 | Test Loss 0.6291   AUC 0.8945
# Epoch 179/300 | Train Loss 0.5946  AUC 0.9164 | Test Loss 0.6313   AUC 0.8957
# Epoch 180/300 | Train Loss 0.5909  AUC 0.9155 | Test Loss 0.6288   AUC 0.8951
# Epoch 181/300 | Train Loss 0.6147  AUC 0.9065 | Test Loss 0.6286   AUC 0.8946
# Epoch 182/300 | Train Loss 0.5925  AUC 0.9191 | Test Loss 0.6322   AUC 0.8949
# Epoch 183/300 | Train Loss 0.6004  AUC 0.9077 | Test Loss 0.6253   AUC 0.8949
# Epoch 184/300 | Train Loss 0.5957  AUC 0.9107 | Test Loss 0.6247   AUC 0.8941
# Epoch 185/300 | Train Loss 0.5924  AUC 0.9139 | Test Loss 0.6230   AUC 0.8962
# Epoch 186/300 | Train Loss 0.6153  AUC 0.8986 | Test Loss 0.6222   AUC 0.8961
# Epoch 187/300 | Train Loss 0.5939  AUC 0.9130 | Test Loss 0.6243   AUC 0.8953
# Epoch 188/300 | Train Loss 0.6040  AUC 0.9105 | Test Loss 0.6216   AUC 0.8957
# Epoch 189/300 | Train Loss 0.5849  AUC 0.9155 | Test Loss 0.6198   AUC 0.8946
# Epoch 190/300 | Train Loss 0.5897  AUC 0.9139 | Test Loss 0.6178   AUC 0.8953
# Epoch 191/300 | Train Loss 0.5922  AUC 0.9144 | Test Loss 0.6160   AUC 0.8955
# Epoch 192/300 | Train Loss 0.5954  AUC 0.9096 | Test Loss 0.6161   AUC 0.8952
# Epoch 193/300 | Train Loss 0.5841  AUC 0.9155 | Test Loss 0.6176   AUC 0.8963
# Epoch 194/300 | Train Loss 0.5942  AUC 0.9088 | Test Loss 0.6155   AUC 0.8958
# Epoch 195/300 | Train Loss 0.5993  AUC 0.9082 | Test Loss 0.6140   AUC 0.8957
# Epoch 196/300 | Train Loss 0.5838  AUC 0.9156 | Test Loss 0.6133   AUC 0.8957
# Epoch 197/300 | Train Loss 0.5943  AUC 0.9060 | Test Loss 0.6120   AUC 0.8969
# Epoch 198/300 | Train Loss 0.5801  AUC 0.9163 | Test Loss 0.6126   AUC 0.8956
# Epoch 199/300 | Train Loss 0.5893  AUC 0.9102 | Test Loss 0.6153   AUC 0.8959
# Epoch 200/300 | Train Loss 0.5808  AUC 0.9118 | Test Loss 0.6118   AUC 0.8958
# Epoch 201/300 | Train Loss 0.5777  AUC 0.9202 | Test Loss 0.6111   AUC 0.8970
# Epoch 202/300 | Train Loss 0.5696  AUC 0.9215 | Test Loss 0.6097   AUC 0.8974
# Epoch 203/300 | Train Loss 0.5722  AUC 0.9198 | Test Loss 0.6094   AUC 0.8973
# Epoch 204/300 | Train Loss 0.5859  AUC 0.9098 | Test Loss 0.6080   AUC 0.8963
# Epoch 205/300 | Train Loss 0.5765  AUC 0.9162 | Test Loss 0.6065   AUC 0.8971
# Epoch 206/300 | Train Loss 0.5743  AUC 0.9162 | Test Loss 0.6079   AUC 0.8977
# Epoch 207/300 | Train Loss 0.5672  AUC 0.9204 | Test Loss 0.6066   AUC 0.8969
# Epoch 208/300 | Train Loss 0.5793  AUC 0.9132 | Test Loss 0.6084   AUC 0.8965
# Epoch 209/300 | Train Loss 0.5767  AUC 0.9144 | Test Loss 0.6063   AUC 0.8970
# Epoch 210/300 | Train Loss 0.5866  AUC 0.9121 | Test Loss 0.6048   AUC 0.8971
# Epoch 211/300 | Train Loss 0.5676  AUC 0.9188 | Test Loss 0.6065   AUC 0.8973
# Epoch 212/300 | Train Loss 0.5748  AUC 0.9148 | Test Loss 0.6042   AUC 0.8976
# Epoch 213/300 | Train Loss 0.5654  AUC 0.9172 | Test Loss 0.6012   AUC 0.8983
# Epoch 214/300 | Train Loss 0.5591  AUC 0.9235 | Test Loss 0.6039   AUC 0.8976
# Epoch 215/300 | Train Loss 0.5820  AUC 0.9114 | Test Loss 0.6024   AUC 0.8980
# Epoch 216/300 | Train Loss 0.5605  AUC 0.9203 | Test Loss 0.6017   AUC 0.8982
# Epoch 217/300 | Train Loss 0.5670  AUC 0.9151 | Test Loss 0.5976   AUC 0.8990
# Epoch 218/300 | Train Loss 0.5621  AUC 0.9216 | Test Loss 0.5979   AUC 0.8992
# Epoch 219/300 | Train Loss 0.5604  AUC 0.9214 | Test Loss 0.5977   AUC 0.8990
# Epoch 220/300 | Train Loss 0.5536  AUC 0.9196 | Test Loss 0.5981   AUC 0.8985
# Epoch 221/300 | Train Loss 0.5599  AUC 0.9215 | Test Loss 0.5997   AUC 0.8973
# Epoch 222/300 | Train Loss 0.5579  AUC 0.9213 | Test Loss 0.5980   AUC 0.8979
# Epoch 223/300 | Train Loss 0.5600  AUC 0.9193 | Test Loss 0.5959   AUC 0.8995
# Epoch 224/300 | Train Loss 0.5569  AUC 0.9210 | Test Loss 0.5948   AUC 0.8989
# Epoch 225/300 | Train Loss 0.5633  AUC 0.9187 | Test Loss 0.5908   AUC 0.9011
# Epoch 226/300 | Train Loss 0.5543  AUC 0.9213 | Test Loss 0.5959   AUC 0.9000
# Epoch 227/300 | Train Loss 0.5483  AUC 0.9260 | Test Loss 0.5934   AUC 0.8994
# Epoch 228/300 | Train Loss 0.5710  AUC 0.9130 | Test Loss 0.5959   AUC 0.8997
# Epoch 229/300 | Train Loss 0.5587  AUC 0.9189 | Test Loss 0.5933   AUC 0.8991
# Epoch 230/300 | Train Loss 0.5470  AUC 0.9261 | Test Loss 0.5946   AUC 0.8991
# Epoch 231/300 | Train Loss 0.5399  AUC 0.9298 | Test Loss 0.5929   AUC 0.9004
# Epoch 232/300 | Train Loss 0.5498  AUC 0.9255 | Test Loss 0.5911   AUC 0.8993
# Epoch 233/300 | Train Loss 0.5490  AUC 0.9249 | Test Loss 0.5883   AUC 0.8996
# Epoch 234/300 | Train Loss 0.5409  AUC 0.9265 | Test Loss 0.5915   AUC 0.9006
# Epoch 235/300 | Train Loss 0.5573  AUC 0.9163 | Test Loss 0.5912   AUC 0.8999
# Epoch 236/300 | Train Loss 0.5460  AUC 0.9271 | Test Loss 0.5889   AUC 0.9002
# Epoch 237/300 | Train Loss 0.5323  AUC 0.9285 | Test Loss 0.5894   AUC 0.9009
# Epoch 238/300 | Train Loss 0.5518  AUC 0.9203 | Test Loss 0.5887   AUC 0.9011
# Epoch 239/300 | Train Loss 0.5441  AUC 0.9235 | Test Loss 0.5900   AUC 0.9003
# Epoch 240/300 | Train Loss 0.5481  AUC 0.9206 | Test Loss 0.5890   AUC 0.9012
# Epoch 241/300 | Train Loss 0.5351  AUC 0.9272 | Test Loss 0.5886   AUC 0.9013
# Epoch 242/300 | Train Loss 0.5415  AUC 0.9256 | Test Loss 0.5862   AUC 0.9008
# Epoch 243/300 | Train Loss 0.5377  AUC 0.9265 | Test Loss 0.5880   AUC 0.9007
# Epoch 244/300 | Train Loss 0.5562  AUC 0.9174 | Test Loss 0.5852   AUC 0.9006
# Epoch 245/300 | Train Loss 0.5391  AUC 0.9257 | Test Loss 0.5859   AUC 0.9013
# Epoch 246/300 | Train Loss 0.5348  AUC 0.9241 | Test Loss 0.5850   AUC 0.9009
# Epoch 247/300 | Train Loss 0.5562  AUC 0.9177 | Test Loss 0.5856   AUC 0.9015
# Epoch 248/300 | Train Loss 0.5322  AUC 0.9288 | Test Loss 0.5850   AUC 0.9008
# Epoch 249/300 | Train Loss 0.5330  AUC 0.9252 | Test Loss 0.5829   AUC 0.9010
# Epoch 250/300 | Train Loss 0.5403  AUC 0.9225 | Test Loss 0.5854   AUC 0.9000
# Epoch 251/300 | Train Loss 0.5230  AUC 0.9314 | Test Loss 0.5821   AUC 0.9012
# Epoch 252/300 | Train Loss 0.5361  AUC 0.9276 | Test Loss 0.5826   AUC 0.9017
# Epoch 253/300 | Train Loss 0.5228  AUC 0.9322 | Test Loss 0.5808   AUC 0.9029
# Epoch 254/300 | Train Loss 0.5416  AUC 0.9235 | Test Loss 0.5797   AUC 0.9036
# Epoch 255/300 | Train Loss 0.5331  AUC 0.9256 | Test Loss 0.5807   AUC 0.9024
# Epoch 256/300 | Train Loss 0.5259  AUC 0.9300 | Test Loss 0.5791   AUC 0.9021
# Epoch 257/300 | Train Loss 0.5358  AUC 0.9229 | Test Loss 0.5809   AUC 0.9016
# Epoch 258/300 | Train Loss 0.5343  AUC 0.9231 | Test Loss 0.5821   AUC 0.9020
# Epoch 259/300 | Train Loss 0.5412  AUC 0.9212 | Test Loss 0.5783   AUC 0.9020
# Epoch 260/300 | Train Loss 0.5439  AUC 0.9213 | Test Loss 0.5801   AUC 0.9027
# Epoch 261/300 | Train Loss 0.5200  AUC 0.9309 | Test Loss 0.5829   AUC 0.9015
# Epoch 262/300 | Train Loss 0.5296  AUC 0.9259 | Test Loss 0.5767   AUC 0.9032
# Epoch 263/300 | Train Loss 0.5263  AUC 0.9276 | Test Loss 0.5779   AUC 0.9022
# Epoch 264/300 | Train Loss 0.5333  AUC 0.9238 | Test Loss 0.5756   AUC 0.9034
# Epoch 265/300 | Train Loss 0.5186  AUC 0.9287 | Test Loss 0.5732   AUC 0.9030
# Epoch 266/300 | Train Loss 0.5256  AUC 0.9301 | Test Loss 0.5728   AUC 0.9045
# Epoch 267/300 | Train Loss 0.5290  AUC 0.9253 | Test Loss 0.5758   AUC 0.9033
# Epoch 268/300 | Train Loss 0.5233  AUC 0.9295 | Test Loss 0.5736   AUC 0.9042
# Epoch 269/300 | Train Loss 0.5278  AUC 0.9248 | Test Loss 0.5743   AUC 0.9043
# Epoch 270/300 | Train Loss 0.5242  AUC 0.9274 | Test Loss 0.5741   AUC 0.9046
# Epoch 271/300 | Train Loss 0.5254  AUC 0.9247 | Test Loss 0.5759   AUC 0.9033
# Epoch 272/300 | Train Loss 0.5250  AUC 0.9307 | Test Loss 0.5774   AUC 0.9030
# Epoch 273/300 | Train Loss 0.5257  AUC 0.9254 | Test Loss 0.5742   AUC 0.9038
# Epoch 274/300 | Train Loss 0.5122  AUC 0.9352 | Test Loss 0.5761   AUC 0.9024
# Epoch 275/300 | Train Loss 0.5316  AUC 0.9244 | Test Loss 0.5746   AUC 0.9039
# Epoch 276/300 | Train Loss 0.5155  AUC 0.9309 | Test Loss 0.5760   AUC 0.9017
# Epoch 277/300 | Train Loss 0.5248  AUC 0.9264 | Test Loss 0.5727   AUC 0.9037
# Epoch 278/300 | Train Loss 0.5215  AUC 0.9300 | Test Loss 0.5711   AUC 0.9045
# Epoch 279/300 | Train Loss 0.5103  AUC 0.9329 | Test Loss 0.5714   AUC 0.9043
# Epoch 280/300 | Train Loss 0.5375  AUC 0.9177 | Test Loss 0.5735   AUC 0.9041
# Epoch 281/300 | Train Loss 0.5026  AUC 0.9355 | Test Loss 0.5728   AUC 0.9039
# Epoch 282/300 | Train Loss 0.5165  AUC 0.9285 | Test Loss 0.5678   AUC 0.9059
# Epoch 283/300 | Train Loss 0.5291  AUC 0.9236 | Test Loss 0.5722   AUC 0.9034
# Epoch 284/300 | Train Loss 0.5233  AUC 0.9257 | Test Loss 0.5712   AUC 0.9048
# Epoch 285/300 | Train Loss 0.5105  AUC 0.9318 | Test Loss 0.5716   AUC 0.9029
# Epoch 286/300 | Train Loss 0.5091  AUC 0.9337 | Test Loss 0.5717   AUC 0.9034
# Epoch 287/300 | Train Loss 0.5297  AUC 0.9224 | Test Loss 0.5692   AUC 0.9047
# Epoch 288/300 | Train Loss 0.5126  AUC 0.9334 | Test Loss 0.5695   AUC 0.9052
# Epoch 289/300 | Train Loss 0.5008  AUC 0.9380 | Test Loss 0.5681   AUC 0.9046
# Epoch 290/300 | Train Loss 0.5180  AUC 0.9284 | Test Loss 0.5661   AUC 0.9054
# Epoch 291/300 | Train Loss 0.5094  AUC 0.9317 | Test Loss 0.5701   AUC 0.9049
# Epoch 292/300 | Train Loss 0.5074  AUC 0.9309 | Test Loss 0.5695   AUC 0.9043
# Epoch 293/300 | Train Loss 0.4970  AUC 0.9352 | Test Loss 0.5676   AUC 0.9051
# Epoch 294/300 | Train Loss 0.5096  AUC 0.9288 | Test Loss 0.5673   AUC 0.9048
# Epoch 295/300 | Train Loss 0.5069  AUC 0.9303 | Test Loss 0.5704   AUC 0.9039
# Epoch 296/300 | Train Loss 0.5086  AUC 0.9294 | Test Loss 0.5695   AUC 0.9043
# Epoch 297/300 | Train Loss 0.5060  AUC 0.9338 | Test Loss 0.5690   AUC 0.9055
# Epoch 298/300 | Train Loss 0.4983  AUC 0.9352 | Test Loss 0.5662   AUC 0.9053
# Epoch 299/300 | Train Loss 0.4995  AUC 0.9349 | Test Loss 0.5687   AUC 0.9046
# Epoch 300/300 | Train Loss 0.4985  AUC 0.9333 | Test Loss 0.5682   AUC 0.9045

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.7985
# Precision: 0.7812
# Recall:    0.7826
# F1 Score:  0.7815
# AUC-ROC:   0.9278

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("ADNI AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("ADNI Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
