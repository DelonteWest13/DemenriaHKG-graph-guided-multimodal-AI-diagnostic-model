# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,NeuralNet,MultiModalCAMera
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#生物标志物 ad 90*48   no 349*58
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'normal_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'ad_nii_KG/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NC_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #151
print(count_no) #211
print(count_mci) #475
# Out:
# 151
# 211
# 475

# %%
# 基础替换字典
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0', 'ind':'3', 'ans':'4'}

# 隔离诊断标签的列索引提取规则
# EHR (14维): age(2), gender(3), education(4), hispanic(5), race(6) + his_系列(57-65)
ehr_cols = [2, 3, 4, 5, 6] + list(range(57, 66))
# BIO (39维): apoe(7) + mmse/cdr(20-22) + gds/moca(66, 67) + trail/npiq/faq等(24-56)
bio_cols = [7, 20, 21, 22, 66, 67] + list(range(24, 57))

# 统一且安全的预处理函数
def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        extracted_row = [row[idx] for idx in target_cols]
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                if math.isnan(val):
                    val = np.nan
            except ValueError:
                val = np.nan
            numerical_row.append(val)
        processed_data.append(numerical_row)
    return np.array(processed_data, dtype=float)

# 1. 提取 BIO 数组 (39 维特征)
ad_array = preprocess_data(data_ad, replace_dict, bio_cols)

normal_array = preprocess_data(data_normal, replace_dict, bio_cols)
mci_array = preprocess_data(data_mci, replace_dict, bio_cols)
print('ad.BIO--->', ad_array.shape)
print('normal.BIO--->', normal_array.shape)
print('mci.BIO--->', mci_array.shape)
# Out:
# ad.BIO---> (151, 39)
# normal.BIO---> (211, 39)
# mci.BIO---> (475, 39)

# %%
#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # 推荐：引入激活函数库

# 1. 转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 2. 定义网络层 
# 关键修复：输入维度改为 39（BIO 特征维度）
# 关键优化：使用不同的变量名 (fc1, fc2, fc3) 防止层被覆盖
fc1 = nn.Linear(39, 32)
fc2 = nn.Linear(32, 16)
fc3 = nn.Linear(16, 1)

# 3. 前向传播
# 注意：多层网络通常需要在层与层之间加激活函数(如 ReLU)，否则它数学上等价于单层网络。
# 为了保持代码运行，这里先按你的逻辑写，如果需要增加非线性能力，请取消注释 relu 行。

# 第一层
ad_tensor = fc1(ad_tensor)
# ad_tensor = F.relu(ad_tensor) 
normal_tensor = fc1(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc1(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第二层
ad_tensor = fc2(ad_tensor)
# ad_tensor = F.relu(ad_tensor)
normal_tensor = fc2(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc2(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第三层 (输出层)
ad_tensor = fc3(ad_tensor)
normal_tensor = fc3(normal_tensor)
mci_tensor = fc3(mci_tensor)

# 4. 打印结果
print('AD_tensor shape:', ad_tensor.shape)      # 预期: (151, 1)
print('Normal_tensor shape:', normal_tensor.shape) # 预期: (211, 1)
print('MCI_tensor shape:', mci_tensor.shape)    # 预期: (475, 1)
# Out:
# AD_tensor shape: torch.Size([151, 1])
# Normal_tensor shape: torch.Size([211, 1])
# MCI_tensor shape: torch.Size([475, 1])

# %%
# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict, ehr_cols)
normal_data = preprocess_data(data_normal, replace_dict, ehr_cols)
mci_data = preprocess_data(data_mci, replace_dict, ehr_cols)

categorical_indices = [1, 2, 3, 4]  # gender, education, hispanic, race
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(14, 16)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(16, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])

# %%
#医学图像
nii = CNN_3D(num_class=1)
nii = nii.to(device)
all_ad = 'ad_nii_KG/'
all_normal = 'normal_nii_kg/'
all_mci = 'NC_nii_kg/'

# 打印原始 NIfTI tensor 形状，确保 MRI 提取的 nii.shape 可见

def print_raw_nii_shape(folder, label):
    dataset = NiiDataset(folder)
    if len(dataset) == 0:
        print(f'{label} raw nii tensor shape---> empty dataset')
        return
    print(f'{label} raw nii tensor shape--->', dataset[0].shape)

print_raw_nii_shape(all_ad, 'ad')
print_raw_nii_shape(all_normal, 'normal')
print_raw_nii_shape(all_mci, 'mci')

dataset = NiiDataset(all_ad)
batch_size = 16
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_normal)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_mci)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)
# Out:
# ad raw nii tensor shape---> torch.Size([1, 64, 64, 64])
# normal raw nii tensor shape---> torch.Size([1, 64, 64, 64])
# mci raw nii tensor shape---> torch.Size([1, 64, 64, 64])

# %%
print('ad.BIO--->', ad_tensor.shape)
print('normal.BIO--->', normal_tensor.shape)
print('mci.BIO--->', mci_tensor.shape)
print('ad.EHR--->', ad_EHR.shape)
print('normal.EHR--->', normal_EHR.shape)
print('mci.EHR--->', mci_EHR.shape)
print('ad nii shape--->', ad_output.shape)
print('normal nii shape--->', normal_output.shape)
print('mci nii shape--->', mci_output.shape)
# Out:
# ad.BIO---> torch.Size([151, 1])
# normal.BIO---> torch.Size([211, 1])
# mci.BIO---> torch.Size([475, 1])
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])
# ad nii shape---> torch.Size([151, 1])
# normal nii shape---> torch.Size([211, 1])
# mci nii shape---> torch.Size([475, 1])

# %%
ad_EHR = ad_EHR.cpu()
ad_tensor = ad_tensor.cpu()
mci_EHR = mci_EHR.cpu()
mci_tensor = mci_tensor.cpu()
normal_EHR = normal_EHR.cpu()
normal_tensor = normal_tensor.cpu()
ad_output = ad_output.cpu()
mci_output = mci_output.cpu()
normal_output = normal_output.cpu()

X_ad = torch.cat([ad_EHR, ad_output, ad_tensor], dim=1)
X_mci = torch.cat([mci_EHR, mci_output, mci_tensor], dim=1)
X_normal = torch.cat([normal_EHR, normal_output, normal_tensor], dim=1)
y_ad = torch.ones(len(X_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(X_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(X_normal)) * 0  # Nc 类别标签为 0
# 拼接特征和标签
X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()

# 数据划分
X_train, X_test, y_train, y_test = train_test_split(X.detach().numpy(), y.numpy(),
                                                    test_size=0.25,
                                                    stratify=y.numpy(),
                                                    random_state=34)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                  test_size=0.25,
                                                  stratify=y_train,
                                                  random_state=34)

# %%
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.FloatTensor(y_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.FloatTensor(y_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.FloatTensor(y_test).to(device)

# 创建 TensorDataset
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        labels = labels.long()
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        # 获取预测概率
        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc

# %%
def evaluate(model, loader):
    model.eval()
    all_probs = []
    all_labels = []
    total_loss = 0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.long()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            # 获取预测概率
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
    test_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, test_auc

# %%
train_losses = []
train_aucs = []
test_losses = []
test_aucs = []
# 将原本的 MultiModalTransformer 替换为新模型
model = MultiModalCAMera(input_dim=39, hidden_dim=64, num_classes=3).to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-5, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()    
for epoch in range(201):
    train_loss, train_auc = train_epoch(model, train_loader)
    test_loss, test_auc = evaluate(model, test_loader)
        
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    print(f"Epoch {epoch:03d} | "
            f"Train Loss: {train_loss:.4f} | Train AUC: {train_auc:.4f} | "
            f"Test Loss: {test_loss:.4f} | Test AUC: {test_auc:.4f}")
# Out:
# Epoch 000 | Train Loss: 1.2989 | Train AUC: 0.5248 | Test Loss: 1.3413 | Test AUC: 0.4364
# Epoch 001 | Train Loss: 1.2552 | Train AUC: 0.5413 | Test Loss: 1.2862 | Test AUC: 0.4725
# Epoch 002 | Train Loss: 1.3041 | Train AUC: 0.5265 | Test Loss: 1.2215 | Test AUC: 0.5430
# Epoch 003 | Train Loss: 1.2496 | Train AUC: 0.5539 | Test Loss: 1.2199 | Test AUC: 0.5441
# Epoch 004 | Train Loss: 1.2497 | Train AUC: 0.5636 | Test Loss: 1.1993 | Test AUC: 0.5378
# Epoch 005 | Train Loss: 1.3288 | Train AUC: 0.4948 | Test Loss: 1.2075 | Test AUC: 0.6311
# Epoch 006 | Train Loss: 1.2864 | Train AUC: 0.5228 | Test Loss: 1.1849 | Test AUC: 0.6333
# Epoch 007 | Train Loss: 1.2278 | Train AUC: 0.5513 | Test Loss: 1.2071 | Test AUC: 0.6337
# Epoch 008 | Train Loss: 1.2521 | Train AUC: 0.5565 | Test Loss: 1.1924 | Test AUC: 0.6303
# Epoch 009 | Train Loss: 1.2881 | Train AUC: 0.5127 | Test Loss: 1.1848 | Test AUC: 0.6388
# Epoch 010 | Train Loss: 1.2905 | Train AUC: 0.5075 | Test Loss: 1.1844 | Test AUC: 0.6319
# Epoch 011 | Train Loss: 1.2668 | Train AUC: 0.5278 | Test Loss: 1.1904 | Test AUC: 0.6357
# Epoch 012 | Train Loss: 1.2648 | Train AUC: 0.5262 | Test Loss: 1.1871 | Test AUC: 0.6462
# Epoch 013 | Train Loss: 1.2773 | Train AUC: 0.5279 | Test Loss: 1.1798 | Test AUC: 0.6440
# Epoch 014 | Train Loss: 1.2848 | Train AUC: 0.5059 | Test Loss: 1.1925 | Test AUC: 0.6438
# Epoch 015 | Train Loss: 1.1957 | Train AUC: 0.5635 | Test Loss: 1.1650 | Test AUC: 0.6316
# Epoch 016 | Train Loss: 1.2788 | Train AUC: 0.4944 | Test Loss: 1.1182 | Test AUC: 0.6377
# Epoch 017 | Train Loss: 1.2307 | Train AUC: 0.5178 | Test Loss: 1.1111 | Test AUC: 0.6352
# Epoch 018 | Train Loss: 1.2054 | Train AUC: 0.5444 | Test Loss: 1.1343 | Test AUC: 0.6293
# Epoch 019 | Train Loss: 1.2133 | Train AUC: 0.5492 | Test Loss: 1.1332 | Test AUC: 0.6325
# Epoch 020 | Train Loss: 1.2851 | Train AUC: 0.4987 | Test Loss: 1.1334 | Test AUC: 0.6334
# Epoch 021 | Train Loss: 1.2008 | Train AUC: 0.5643 | Test Loss: 1.1119 | Test AUC: 0.6323
# Epoch 022 | Train Loss: 1.2553 | Train AUC: 0.5163 | Test Loss: 1.0953 | Test AUC: 0.6296
# Epoch 023 | Train Loss: 1.2202 | Train AUC: 0.5293 | Test Loss: 1.1178 | Test AUC: 0.6331
# Epoch 024 | Train Loss: 1.2178 | Train AUC: 0.5363 | Test Loss: 1.0923 | Test AUC: 0.6334
# Epoch 025 | Train Loss: 1.2169 | Train AUC: 0.5435 | Test Loss: 1.0727 | Test AUC: 0.6364
# Epoch 026 | Train Loss: 1.2652 | Train AUC: 0.5194 | Test Loss: 1.0505 | Test AUC: 0.6344
# Epoch 027 | Train Loss: 1.2218 | Train AUC: 0.5012 | Test Loss: 1.0949 | Test AUC: 0.6340
# Epoch 028 | Train Loss: 1.1929 | Train AUC: 0.5409 | Test Loss: 1.0615 | Test AUC: 0.6342
# Epoch 029 | Train Loss: 1.2441 | Train AUC: 0.5234 | Test Loss: 1.0895 | Test AUC: 0.6347
# Epoch 030 | Train Loss: 1.2589 | Train AUC: 0.4996 | Test Loss: 1.0505 | Test AUC: 0.6337
# Epoch 031 | Train Loss: 1.2315 | Train AUC: 0.5144 | Test Loss: 1.0956 | Test AUC: 0.6348
# Epoch 032 | Train Loss: 1.2782 | Train AUC: 0.4980 | Test Loss: 1.1203 | Test AUC: 0.6354
# Epoch 033 | Train Loss: 1.2293 | Train AUC: 0.5335 | Test Loss: 1.0769 | Test AUC: 0.6335
# Epoch 034 | Train Loss: 1.2739 | Train AUC: 0.4868 | Test Loss: 1.0534 | Test AUC: 0.6335
# Epoch 035 | Train Loss: 1.2301 | Train AUC: 0.5175 | Test Loss: 1.0821 | Test AUC: 0.6330
# Epoch 036 | Train Loss: 1.1709 | Train AUC: 0.5515 | Test Loss: 1.0701 | Test AUC: 0.6326
# Epoch 037 | Train Loss: 1.2165 | Train AUC: 0.5074 | Test Loss: 1.0608 | Test AUC: 0.6369
# Epoch 038 | Train Loss: 1.2418 | Train AUC: 0.4950 | Test Loss: 1.0802 | Test AUC: 0.6356
# Epoch 039 | Train Loss: 1.2024 | Train AUC: 0.5023 | Test Loss: 1.0457 | Test AUC: 0.6377
# Epoch 040 | Train Loss: 1.1688 | Train AUC: 0.5376 | Test Loss: 1.0387 | Test AUC: 0.6375
# Epoch 041 | Train Loss: 1.1958 | Train AUC: 0.5225 | Test Loss: 1.0469 | Test AUC: 0.6395
# Epoch 042 | Train Loss: 1.2169 | Train AUC: 0.5143 | Test Loss: 1.0408 | Test AUC: 0.6323
# Epoch 043 | Train Loss: 1.1849 | Train AUC: 0.5153 | Test Loss: 1.0470 | Test AUC: 0.6372
# Epoch 044 | Train Loss: 1.2330 | Train AUC: 0.5136 | Test Loss: 1.0274 | Test AUC: 0.6382
# Epoch 045 | Train Loss: 1.1907 | Train AUC: 0.5545 | Test Loss: 1.0453 | Test AUC: 0.6321
# Epoch 046 | Train Loss: 1.1678 | Train AUC: 0.5255 | Test Loss: 1.0247 | Test AUC: 0.6351
# Epoch 047 | Train Loss: 1.1560 | Train AUC: 0.5424 | Test Loss: 1.0401 | Test AUC: 0.6355
# Epoch 048 | Train Loss: 1.2342 | Train AUC: 0.4760 | Test Loss: 1.0360 | Test AUC: 0.6376
# Epoch 049 | Train Loss: 1.1578 | Train AUC: 0.5579 | Test Loss: 1.0280 | Test AUC: 0.6337
# Epoch 050 | Train Loss: 1.2080 | Train AUC: 0.5142 | Test Loss: 1.0199 | Test AUC: 0.6333
# Epoch 051 | Train Loss: 1.1646 | Train AUC: 0.5317 | Test Loss: 1.0363 | Test AUC: 0.6339
# Epoch 052 | Train Loss: 1.1430 | Train AUC: 0.5512 | Test Loss: 1.0334 | Test AUC: 0.6345
# Epoch 053 | Train Loss: 1.1608 | Train AUC: 0.5417 | Test Loss: 1.0319 | Test AUC: 0.6358
# Epoch 054 | Train Loss: 1.1494 | Train AUC: 0.5427 | Test Loss: 1.0228 | Test AUC: 0.6388
# Epoch 055 | Train Loss: 1.0884 | Train AUC: 0.5832 | Test Loss: 1.0145 | Test AUC: 0.6377
# Epoch 056 | Train Loss: 1.1381 | Train AUC: 0.5461 | Test Loss: 0.9893 | Test AUC: 0.6369
# Epoch 057 | Train Loss: 1.1578 | Train AUC: 0.5425 | Test Loss: 0.9876 | Test AUC: 0.6306
# Epoch 058 | Train Loss: 1.1689 | Train AUC: 0.5221 | Test Loss: 1.0013 | Test AUC: 0.6357
# Epoch 059 | Train Loss: 1.1119 | Train AUC: 0.5575 | Test Loss: 0.9787 | Test AUC: 0.6181
# Epoch 060 | Train Loss: 1.1631 | Train AUC: 0.5357 | Test Loss: 1.0013 | Test AUC: 0.6359
# Epoch 061 | Train Loss: 1.2029 | Train AUC: 0.4975 | Test Loss: 0.9958 | Test AUC: 0.6415
# Epoch 062 | Train Loss: 1.1664 | Train AUC: 0.5155 | Test Loss: 0.9977 | Test AUC: 0.6356
# Epoch 063 | Train Loss: 1.1687 | Train AUC: 0.5225 | Test Loss: 0.9898 | Test AUC: 0.6201
# Epoch 064 | Train Loss: 1.1376 | Train AUC: 0.5536 | Test Loss: 0.9819 | Test AUC: 0.6325
# Epoch 065 | Train Loss: 1.1499 | Train AUC: 0.5312 | Test Loss: 0.9934 | Test AUC: 0.6245
# Epoch 066 | Train Loss: 1.1022 | Train AUC: 0.5801 | Test Loss: 0.9820 | Test AUC: 0.6114
# Epoch 067 | Train Loss: 1.1711 | Train AUC: 0.5186 | Test Loss: 0.9980 | Test AUC: 0.6346
# Epoch 068 | Train Loss: 1.1694 | Train AUC: 0.5224 | Test Loss: 0.9991 | Test AUC: 0.6120
# Epoch 069 | Train Loss: 1.1269 | Train AUC: 0.5556 | Test Loss: 1.0059 | Test AUC: 0.6051
# Epoch 070 | Train Loss: 1.1752 | Train AUC: 0.5173 | Test Loss: 0.9853 | Test AUC: 0.6180
# Epoch 071 | Train Loss: 1.1317 | Train AUC: 0.5579 | Test Loss: 0.9862 | Test AUC: 0.6017
# Epoch 072 | Train Loss: 1.1807 | Train AUC: 0.5136 | Test Loss: 0.9783 | Test AUC: 0.5903
# Epoch 073 | Train Loss: 1.1678 | Train AUC: 0.5073 | Test Loss: 0.9895 | Test AUC: 0.6314
# Epoch 074 | Train Loss: 1.1106 | Train AUC: 0.5772 | Test Loss: 0.9876 | Test AUC: 0.6370
# Epoch 075 | Train Loss: 1.2061 | Train AUC: 0.4865 | Test Loss: 0.9941 | Test AUC: 0.6321
# Epoch 076 | Train Loss: 1.1534 | Train AUC: 0.5210 | Test Loss: 0.9926 | Test AUC: 0.6350
# Epoch 077 | Train Loss: 1.1194 | Train AUC: 0.5453 | Test Loss: 0.9908 | Test AUC: 0.6323
# Epoch 078 | Train Loss: 1.1294 | Train AUC: 0.5517 | Test Loss: 0.9864 | Test AUC: 0.6168
# Epoch 079 | Train Loss: 1.1216 | Train AUC: 0.5416 | Test Loss: 0.9806 | Test AUC: 0.6347
# Epoch 080 | Train Loss: 1.1248 | Train AUC: 0.5439 | Test Loss: 0.9788 | Test AUC: 0.6371
# Epoch 081 | Train Loss: 1.1122 | Train AUC: 0.5415 | Test Loss: 0.9668 | Test AUC: 0.6259
# Epoch 082 | Train Loss: 1.1249 | Train AUC: 0.5414 | Test Loss: 0.9683 | Test AUC: 0.6150
# Epoch 083 | Train Loss: 1.1471 | Train AUC: 0.5165 | Test Loss: 0.9656 | Test AUC: 0.6317
# Epoch 084 | Train Loss: 1.1247 | Train AUC: 0.5571 | Test Loss: 0.9701 | Test AUC: 0.6157
# Epoch 085 | Train Loss: 1.1090 | Train AUC: 0.5455 | Test Loss: 0.9715 | Test AUC: 0.6328
# Epoch 086 | Train Loss: 1.1344 | Train AUC: 0.5272 | Test Loss: 0.9671 | Test AUC: 0.6186
# Epoch 087 | Train Loss: 1.1480 | Train AUC: 0.5222 | Test Loss: 0.9727 | Test AUC: 0.6349
# Epoch 088 | Train Loss: 1.1352 | Train AUC: 0.5220 | Test Loss: 0.9638 | Test AUC: 0.6189
# Epoch 089 | Train Loss: 1.1139 | Train AUC: 0.5408 | Test Loss: 0.9600 | Test AUC: 0.6129
# Epoch 090 | Train Loss: 1.1336 | Train AUC: 0.5413 | Test Loss: 0.9800 | Test AUC: 0.6221
# Epoch 091 | Train Loss: 1.1417 | Train AUC: 0.5206 | Test Loss: 0.9652 | Test AUC: 0.6272
# Epoch 092 | Train Loss: 1.1221 | Train AUC: 0.5431 | Test Loss: 0.9673 | Test AUC: 0.6125
# Epoch 093 | Train Loss: 1.1170 | Train AUC: 0.5348 | Test Loss: 0.9657 | Test AUC: 0.6184
# Epoch 094 | Train Loss: 1.1464 | Train AUC: 0.5155 | Test Loss: 0.9624 | Test AUC: 0.6264
# Epoch 095 | Train Loss: 1.1418 | Train AUC: 0.5333 | Test Loss: 0.9598 | Test AUC: 0.6169
# Epoch 096 | Train Loss: 1.1166 | Train AUC: 0.5446 | Test Loss: 0.9590 | Test AUC: 0.6315
# Epoch 097 | Train Loss: 1.1267 | Train AUC: 0.5244 | Test Loss: 0.9603 | Test AUC: 0.6160
# Epoch 098 | Train Loss: 1.1519 | Train AUC: 0.4974 | Test Loss: 0.9626 | Test AUC: 0.6160
# Epoch 099 | Train Loss: 1.1266 | Train AUC: 0.5411 | Test Loss: 0.9703 | Test AUC: 0.6214
# Epoch 100 | Train Loss: 1.0801 | Train AUC: 0.5630 | Test Loss: 0.9554 | Test AUC: 0.6291
# Epoch 101 | Train Loss: 1.1359 | Train AUC: 0.5319 | Test Loss: 0.9572 | Test AUC: 0.6173
# Epoch 102 | Train Loss: 1.1382 | Train AUC: 0.5140 | Test Loss: 0.9545 | Test AUC: 0.6149
# Epoch 103 | Train Loss: 1.0729 | Train AUC: 0.5683 | Test Loss: 0.9623 | Test AUC: 0.6210
# Epoch 104 | Train Loss: 1.1259 | Train AUC: 0.5252 | Test Loss: 0.9641 | Test AUC: 0.6155
# Epoch 105 | Train Loss: 1.1433 | Train AUC: 0.5308 | Test Loss: 0.9546 | Test AUC: 0.6153
# Epoch 106 | Train Loss: 1.1083 | Train AUC: 0.5346 | Test Loss: 0.9474 | Test AUC: 0.6229
# Epoch 107 | Train Loss: 1.1332 | Train AUC: 0.5231 | Test Loss: 0.9506 | Test AUC: 0.6167
# Epoch 108 | Train Loss: 1.1621 | Train AUC: 0.4900 | Test Loss: 0.9478 | Test AUC: 0.6146
# Epoch 109 | Train Loss: 1.1275 | Train AUC: 0.5234 | Test Loss: 0.9514 | Test AUC: 0.6299
# Epoch 110 | Train Loss: 1.1095 | Train AUC: 0.5237 | Test Loss: 0.9479 | Test AUC: 0.6255
# Epoch 111 | Train Loss: 1.1322 | Train AUC: 0.5284 | Test Loss: 0.9427 | Test AUC: 0.6308
# Epoch 112 | Train Loss: 1.0812 | Train AUC: 0.5567 | Test Loss: 0.9502 | Test AUC: 0.6277
# Epoch 113 | Train Loss: 1.0755 | Train AUC: 0.5482 | Test Loss: 0.9489 | Test AUC: 0.6201
# Epoch 114 | Train Loss: 1.0792 | Train AUC: 0.5522 | Test Loss: 0.9547 | Test AUC: 0.6126
# Epoch 115 | Train Loss: 1.0525 | Train AUC: 0.5698 | Test Loss: 0.9501 | Test AUC: 0.6265
# Epoch 116 | Train Loss: 1.0789 | Train AUC: 0.5549 | Test Loss: 0.9516 | Test AUC: 0.6164
# Epoch 117 | Train Loss: 1.1402 | Train AUC: 0.5128 | Test Loss: 0.9490 | Test AUC: 0.6097
# Epoch 118 | Train Loss: 1.0941 | Train AUC: 0.5554 | Test Loss: 0.9430 | Test AUC: 0.6362
# Epoch 119 | Train Loss: 1.1233 | Train AUC: 0.5519 | Test Loss: 0.9477 | Test AUC: 0.6181
# Epoch 120 | Train Loss: 1.0878 | Train AUC: 0.5544 | Test Loss: 0.9464 | Test AUC: 0.6163
# Epoch 121 | Train Loss: 1.0796 | Train AUC: 0.5596 | Test Loss: 0.9471 | Test AUC: 0.5994
# Epoch 122 | Train Loss: 1.0874 | Train AUC: 0.5517 | Test Loss: 0.9475 | Test AUC: 0.6143
# Epoch 123 | Train Loss: 1.0826 | Train AUC: 0.5577 | Test Loss: 0.9490 | Test AUC: 0.6129
# Epoch 124 | Train Loss: 1.0993 | Train AUC: 0.5480 | Test Loss: 0.9535 | Test AUC: 0.6332
# Epoch 125 | Train Loss: 1.1075 | Train AUC: 0.5462 | Test Loss: 0.9514 | Test AUC: 0.6259
# Epoch 126 | Train Loss: 1.0603 | Train AUC: 0.5770 | Test Loss: 0.9466 | Test AUC: 0.6147
# Epoch 127 | Train Loss: 1.1023 | Train AUC: 0.5148 | Test Loss: 0.9527 | Test AUC: 0.6033
# Epoch 128 | Train Loss: 1.1110 | Train AUC: 0.5304 | Test Loss: 0.9549 | Test AUC: 0.6382
# Epoch 129 | Train Loss: 1.0975 | Train AUC: 0.5361 | Test Loss: 0.9467 | Test AUC: 0.6309
# Epoch 130 | Train Loss: 1.0680 | Train AUC: 0.5628 | Test Loss: 0.9505 | Test AUC: 0.6287
# Epoch 131 | Train Loss: 1.1049 | Train AUC: 0.5458 | Test Loss: 0.9502 | Test AUC: 0.6366
# Epoch 132 | Train Loss: 1.1128 | Train AUC: 0.5314 | Test Loss: 0.9463 | Test AUC: 0.6379
# Epoch 133 | Train Loss: 1.0744 | Train AUC: 0.5573 | Test Loss: 0.9457 | Test AUC: 0.6309
# Epoch 134 | Train Loss: 1.0308 | Train AUC: 0.5962 | Test Loss: 0.9485 | Test AUC: 0.6280
# Epoch 135 | Train Loss: 1.0722 | Train AUC: 0.5558 | Test Loss: 0.9508 | Test AUC: 0.6363
# Epoch 136 | Train Loss: 1.1208 | Train AUC: 0.5295 | Test Loss: 0.9439 | Test AUC: 0.6376
# Epoch 137 | Train Loss: 1.0883 | Train AUC: 0.5416 | Test Loss: 0.9437 | Test AUC: 0.6315
# Epoch 138 | Train Loss: 1.0670 | Train AUC: 0.5582 | Test Loss: 0.9534 | Test AUC: 0.6342
# Epoch 139 | Train Loss: 1.1088 | Train AUC: 0.5333 | Test Loss: 0.9503 | Test AUC: 0.6292
# Epoch 140 | Train Loss: 1.0930 | Train AUC: 0.5526 | Test Loss: 0.9516 | Test AUC: 0.6261
# Epoch 141 | Train Loss: 1.0954 | Train AUC: 0.5420 | Test Loss: 0.9527 | Test AUC: 0.6380
# Epoch 142 | Train Loss: 1.1234 | Train AUC: 0.5144 | Test Loss: 0.9587 | Test AUC: 0.6241
# Epoch 143 | Train Loss: 1.1240 | Train AUC: 0.5371 | Test Loss: 0.9468 | Test AUC: 0.6354
# Epoch 144 | Train Loss: 1.0762 | Train AUC: 0.5497 | Test Loss: 0.9554 | Test AUC: 0.6352
# Epoch 145 | Train Loss: 1.0997 | Train AUC: 0.5460 | Test Loss: 0.9535 | Test AUC: 0.6382
# Epoch 146 | Train Loss: 1.0673 | Train AUC: 0.5604 | Test Loss: 0.9579 | Test AUC: 0.6334
# Epoch 147 | Train Loss: 1.1582 | Train AUC: 0.4905 | Test Loss: 0.9537 | Test AUC: 0.6374
# Epoch 148 | Train Loss: 1.0813 | Train AUC: 0.5309 | Test Loss: 0.9495 | Test AUC: 0.6379
# Epoch 149 | Train Loss: 1.1259 | Train AUC: 0.5174 | Test Loss: 0.9463 | Test AUC: 0.6246
# Epoch 150 | Train Loss: 1.0982 | Train AUC: 0.5304 | Test Loss: 0.9478 | Test AUC: 0.6383
# Epoch 151 | Train Loss: 1.1253 | Train AUC: 0.5178 | Test Loss: 0.9436 | Test AUC: 0.6357
# Epoch 152 | Train Loss: 1.0920 | Train AUC: 0.5504 | Test Loss: 0.9556 | Test AUC: 0.6372
# Epoch 153 | Train Loss: 1.0787 | Train AUC: 0.5502 | Test Loss: 0.9465 | Test AUC: 0.6208
# Epoch 154 | Train Loss: 1.0965 | Train AUC: 0.5314 | Test Loss: 0.9403 | Test AUC: 0.6372
# Epoch 155 | Train Loss: 1.0527 | Train AUC: 0.5615 | Test Loss: 0.9479 | Test AUC: 0.6378
# Epoch 156 | Train Loss: 1.1561 | Train AUC: 0.4968 | Test Loss: 0.9446 | Test AUC: 0.6353
# Epoch 157 | Train Loss: 1.1157 | Train AUC: 0.5140 | Test Loss: 0.9460 | Test AUC: 0.6368
# Epoch 158 | Train Loss: 1.0817 | Train AUC: 0.5558 | Test Loss: 0.9449 | Test AUC: 0.6356
# Epoch 159 | Train Loss: 1.1035 | Train AUC: 0.5329 | Test Loss: 0.9496 | Test AUC: 0.6382
# Epoch 160 | Train Loss: 1.0811 | Train AUC: 0.5289 | Test Loss: 0.9493 | Test AUC: 0.6331
# Epoch 161 | Train Loss: 1.0880 | Train AUC: 0.5479 | Test Loss: 0.9484 | Test AUC: 0.6337
# Epoch 162 | Train Loss: 1.0947 | Train AUC: 0.5228 | Test Loss: 0.9495 | Test AUC: 0.6268
# Epoch 163 | Train Loss: 1.0819 | Train AUC: 0.5417 | Test Loss: 0.9453 | Test AUC: 0.6349
# Epoch 164 | Train Loss: 1.1194 | Train AUC: 0.5102 | Test Loss: 0.9475 | Test AUC: 0.6363
# Epoch 165 | Train Loss: 1.0993 | Train AUC: 0.5290 | Test Loss: 0.9446 | Test AUC: 0.6379
# Epoch 166 | Train Loss: 1.0664 | Train AUC: 0.5474 | Test Loss: 0.9458 | Test AUC: 0.6392
# Epoch 167 | Train Loss: 1.0974 | Train AUC: 0.5369 | Test Loss: 0.9496 | Test AUC: 0.6344
# Epoch 168 | Train Loss: 1.0552 | Train AUC: 0.5568 | Test Loss: 0.9453 | Test AUC: 0.6386
# Epoch 169 | Train Loss: 1.1023 | Train AUC: 0.5357 | Test Loss: 0.9456 | Test AUC: 0.6271
# Epoch 170 | Train Loss: 1.1384 | Train AUC: 0.4878 | Test Loss: 0.9506 | Test AUC: 0.6395
# Epoch 171 | Train Loss: 1.0678 | Train AUC: 0.5558 | Test Loss: 0.9523 | Test AUC: 0.6380
# Epoch 172 | Train Loss: 1.1249 | Train AUC: 0.5043 | Test Loss: 0.9441 | Test AUC: 0.6349
# Epoch 173 | Train Loss: 1.1143 | Train AUC: 0.4993 | Test Loss: 0.9408 | Test AUC: 0.6313
# Epoch 174 | Train Loss: 1.0866 | Train AUC: 0.5308 | Test Loss: 0.9455 | Test AUC: 0.6375
# Epoch 175 | Train Loss: 1.0881 | Train AUC: 0.5509 | Test Loss: 0.9472 | Test AUC: 0.6399
# Epoch 176 | Train Loss: 1.1139 | Train AUC: 0.5183 | Test Loss: 0.9473 | Test AUC: 0.6348
# Epoch 177 | Train Loss: 1.0442 | Train AUC: 0.5666 | Test Loss: 0.9494 | Test AUC: 0.6339
# Epoch 178 | Train Loss: 1.0791 | Train AUC: 0.5409 | Test Loss: 0.9472 | Test AUC: 0.6390
# Epoch 179 | Train Loss: 1.0824 | Train AUC: 0.5491 | Test Loss: 0.9403 | Test AUC: 0.6399
# Epoch 180 | Train Loss: 1.0492 | Train AUC: 0.5717 | Test Loss: 0.9524 | Test AUC: 0.6326
# Epoch 181 | Train Loss: 1.0701 | Train AUC: 0.5497 | Test Loss: 0.9516 | Test AUC: 0.6312
# Epoch 182 | Train Loss: 1.0442 | Train AUC: 0.5656 | Test Loss: 0.9423 | Test AUC: 0.6269
# Epoch 183 | Train Loss: 1.0394 | Train AUC: 0.5655 | Test Loss: 0.9459 | Test AUC: 0.6332
# Epoch 184 | Train Loss: 1.0370 | Train AUC: 0.5756 | Test Loss: 0.9405 | Test AUC: 0.6420
# Epoch 185 | Train Loss: 1.0865 | Train AUC: 0.5289 | Test Loss: 0.9400 | Test AUC: 0.6402
# Epoch 186 | Train Loss: 1.0660 | Train AUC: 0.5594 | Test Loss: 0.9429 | Test AUC: 0.6304
# Epoch 187 | Train Loss: 1.0762 | Train AUC: 0.5451 | Test Loss: 0.9477 | Test AUC: 0.6097
# Epoch 188 | Train Loss: 1.0598 | Train AUC: 0.5632 | Test Loss: 0.9504 | Test AUC: 0.6354
# Epoch 189 | Train Loss: 1.0507 | Train AUC: 0.5601 | Test Loss: 0.9503 | Test AUC: 0.6259
# Epoch 190 | Train Loss: 1.0303 | Train AUC: 0.5839 | Test Loss: 0.9398 | Test AUC: 0.6387
# Epoch 191 | Train Loss: 1.0869 | Train AUC: 0.5365 | Test Loss: 0.9464 | Test AUC: 0.6373
# Epoch 192 | Train Loss: 1.0365 | Train AUC: 0.5749 | Test Loss: 0.9468 | Test AUC: 0.6384
# Epoch 193 | Train Loss: 1.0200 | Train AUC: 0.5846 | Test Loss: 0.9489 | Test AUC: 0.6363
# Epoch 194 | Train Loss: 1.1094 | Train AUC: 0.5222 | Test Loss: 0.9464 | Test AUC: 0.6283
# Epoch 195 | Train Loss: 1.1082 | Train AUC: 0.5071 | Test Loss: 0.9481 | Test AUC: 0.6197
# Epoch 196 | Train Loss: 1.0585 | Train AUC: 0.5486 | Test Loss: 0.9475 | Test AUC: 0.6346
# Epoch 197 | Train Loss: 1.0619 | Train AUC: 0.5579 | Test Loss: 0.9486 | Test AUC: 0.6362
# Epoch 198 | Train Loss: 1.0460 | Train AUC: 0.5722 | Test Loss: 0.9475 | Test AUC: 0.6391
# Epoch 199 | Train Loss: 1.0643 | Train AUC: 0.5591 | Test Loss: 0.9429 | Test AUC: 0.6394
# Epoch 200 | Train Loss: 1.1223 | Train AUC: 0.5326 | Test Loss: 0.9440 | Test AUC: 0.6372

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
# 获取预测类别
preds = np.argmax(all_probs, axis=1)
# 计算指标
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro') 
recall = recall_score(all_labels, preds, average='macro')       
f1 = f1_score(all_labels, preds, average='macro')               
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')  
print("\n=== Final Test Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Test Metrics ===
# Accuracy:  0.5702
# Precision: 0.5231
# Recall:    0.3362
# F1 Score:  0.2475
# AUC-ROC:   0.6433
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("Train and Test AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("Train and Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
def evaluate_model():
    model.eval()
    all_preds, all_probs, all_labels = [], [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.softmax(outputs, dim=1)
            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    all_probs = np.array(all_probs)
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=['NC', 'MCI', 'AD']))
    print("Confusion Matrix:")
    print(confusion_matrix(all_labels, all_preds))
    auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')  # 使用 'ovr' 或 'ovo'
    print(f"AUC Score (Ovr): {auc:.4f}")

evaluate_model()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           NC       0.00      0.00      0.00        40
#          MCI       0.57      1.00      0.72        89
#           AD       0.00      0.00      0.00        28
#
#     accuracy                           0.57       157
#    macro avg       0.19      0.33      0.24       157
# weighted avg       0.32      0.57      0.41       157
#
# Confusion Matrix:
# [[ 0 40  0]
#  [ 0 89  0]
#  [ 0 28  0]]
# AUC Score (Ovr): 0.6856
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
