# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,KGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
#生物标志物 ad 90*48   no 349*58
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'normal_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'ad_nii_KG/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NC_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #151
print(count_no) #211
print(count_mci) #475
# Out:
# 151
# 211
# 475

# %%
ad_arrays=[]
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','ind':'3','ans':'4'}
for i in data_ad:   #第13行开始为基因、蛋白水平
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    ad_array = np.array(num_list)
    ad_arrays.append(ad_array)
ad_array = np.vstack(ad_arrays)

normal_arrays=[]
for i in data_normal:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    normal_array = np.array(num_list)
    normal_arrays.append(normal_array)
normal_array = np.vstack(normal_arrays)

mci_arrays=[]
for i in data_mci:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    mci_array = np.array(num_list)
    mci_arrays.append(mci_array)
mci_array = np.vstack(mci_arrays)

#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # 推荐：引入激活函数库

# 1. 转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 2. 定义网络层 
# 关键修复：输入维度由 45 改为 52 (匹配你的数据列数)
# 关键优化：使用不同的变量名 (fc1, fc2, fc3) 防止层被覆盖
fc1 = nn.Linear(52, 32)
fc2 = nn.Linear(32, 16)
fc3 = nn.Linear(16, 1)

# 3. 前向传播
# 注意：多层网络通常需要在层与层之间加激活函数(如 ReLU)，否则它数学上等价于单层网络。
# 为了保持代码运行，这里先按你的逻辑写，如果需要增加非线性能力，请取消注释 relu 行。

# 第一层
ad_tensor = fc1(ad_tensor)
# ad_tensor = F.relu(ad_tensor) 
normal_tensor = fc1(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc1(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第二层
ad_tensor = fc2(ad_tensor)
# ad_tensor = F.relu(ad_tensor)
normal_tensor = fc2(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc2(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第三层 (输出层)
ad_tensor = fc3(ad_tensor)
normal_tensor = fc3(normal_tensor)
mci_tensor = fc3(mci_tensor)

# 4. 打印结果
print('AD_tensor shape:', ad_tensor.shape)      # 预期: (151, 1)
print('Normal_tensor shape:', normal_tensor.shape) # 预期: (211, 1)
print('MCI_tensor shape:', mci_tensor.shape)    # 预期: (475, 1)
# Out:
# AD_tensor shape: torch.Size([151, 1])
# Normal_tensor shape: torch.Size([211, 1])
# MCI_tensor shape: torch.Size([475, 1])

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        # 替换字典中的值
        row = [replace_dict.get(item, item) for item in row]
        # 将类别型变量转换为数值
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[2:16])
    return np.array(processed_data)

# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict)
normal_data = preprocess_data(data_normal, replace_dict)
mci_data = preprocess_data(data_mci, replace_dict)

categorical_indices = [3,4,5,6,7]  # gender, education, hispanic, race
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(14, 16)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(16, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#医学图像
nii = CNN_3D(num_class=1)
nii= nii.to(device)
all_ad = 'ad_nii_KG/'
all_normal = 'normal_nii_kg/'
all_mci = 'NC_nii_kg/'
dataset = NiiDataset(all_ad)
batch_size = 16
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_normal)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_mci)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)

# %%
# ---------- Cell 9 : DistMult 嵌入加载 (ADNI) ----------
import numpy as np, torch, pandas as pd, os

ENTITY_EMB_NPY = "entity_embeddings_distmult_ADNI.npy"
ENTITY2ID_TXT  = "entity2id_distmult_ADNI.txt"

entity2id = {e: i for e, i in map(str.split, open(ENTITY2ID_TXT))}
emb       = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
id2row    = {id_: idx for idx, id_ in enumerate(sorted(entity2id.values(), key=int))}

class DistMultExtract:
    def get(self, ent: str):
        idx_str = entity2id.get(ent)
        return emb[id2row[idx_str]] if idx_str else None

extractor = DistMultExtract()

# DataFrames
df_ad      = pd.DataFrame(data_ad)
df_mci     = pd.DataFrame(data_mci)
df_normal  = pd.DataFrame(data_normal)

SUBJ_IDX = 0   # Subject / RID 所在列
FILE_IDX = 1   # NIfTI 文件名所在列
START_IDX = 16 # 表型列起点，与 Cell3 的 row[16:] 对齐

def row_embed(row: pd.Series) -> torch.Tensor:
    vecs = []
    # —— 表型 / 生化 —— #
    for v in row.iloc[START_IDX:]:
        vec = extractor.get(str(v))
        if vec is not None:
            vecs.append(vec)
    # —— Subject & 文件名 —— #
    for ent in (row.iloc[SUBJ_IDX], row.iloc[FILE_IDX]):
        vec = extractor.get(str(ent))
        if vec is not None:
            vecs.append(vec)

    return torch.stack(vecs).mean(0) if vecs else torch.zeros(32)

# 生成张量
ad_transe      = torch.stack([row_embed(r) for _, r in df_ad.iterrows()])
mci_transe     = torch.stack([row_embed(r) for _, r in df_mci.iterrows()])
normal_transe  = torch.stack([row_embed(r) for _, r in df_normal.iterrows()])

print("DistMult shapes:", ad_transe.shape, mci_transe.shape, normal_transe.shape)
# -------------------------------------------------------------------------------
# Out:
# DistMult shapes: torch.Size([151, 128]) torch.Size([475, 128]) torch.Size([211, 128])

# %%
transe_embed_dim = 32
X_ad = torch.cat([ad_EHR, ad_output.cpu(), ad_tensor, ad_transe], dim=1)  # [batch_size_ad, EHR_dim + output_dim + tensor_dim + transe_embed_dim]
X_mci = torch.cat([mci_EHR, mci_output.cpu(), mci_tensor, mci_transe], dim=1)
X_normal = torch.cat([normal_EHR, normal_output.cpu(), normal_tensor, normal_transe], dim=1)

y_ad = torch.ones(len(X_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(X_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(X_normal)) * 0  # Nc 类别标签为 0

X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()
features = X[:, :-transe_embed_dim]  
transe_embeddings = X[:, -transe_embed_dim:]

# %%
X_train, X_test, y_train, y_test, transe_train, transe_test = train_test_split(
    features.detach().numpy(), y.numpy(), transe_embeddings.detach().numpy(),
    test_size=0.20,
    stratify=y.numpy(),
    random_state=32
)
X_train, X_val, y_train, y_val, transe_train, transe_val = train_test_split(
    X_train, y_train, transe_train,
    test_size=0.20,
    stratify=y_train,
    random_state=30
)


X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)  # Use LongTensor for classification labels
transe_train_tensor = torch.FloatTensor(transe_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
transe_val_tensor = torch.FloatTensor(transe_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
transe_test_tensor = torch.FloatTensor(transe_test).to(device)


train_dataset = TensorDataset(X_train_tensor, transe_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, transe_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, transe_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
# ---------- Cell 14 : 定义 KGMultiModalTransformer 并训练 ----------
embed_dim        = 32
transe_embed_dim = 32          # 维度与 DistMult 向量一致
num_epochs       = 300
batch_size       = 32
learning_rate    = 1e-5
weight_decay     = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = KGMultiModalTransformer(
            embed_dim=embed_dim,
            transe_embed_dim=transe_embed_dim
        ).to(device)

criterion  = nn.CrossEntropyLoss()
optimizer  = optim.Adam(model.parameters(),
                        lr=learning_rate,
                        weight_decay=weight_decay)

train_losses  = []; train_aucs  = []; train_f1s  = []
train_recalls = []; train_precisions = []
test_losses   = []; test_aucs   = []; test_f1s   = []
test_recalls  = []; test_precisions  = []

for epoch in range(num_epochs):
    tr_loss, tr_auc, tr_f1, tr_rec, tr_prec = train_epoch(
        model, train_loader, optimizer, criterion, device)
    te_loss, te_auc, te_f1, te_rec, te_prec = validate_epoch(
        model, test_loader,  criterion, device)

    train_losses.append(tr_loss);    test_losses.append(te_loss)
    train_aucs.append(tr_auc);       test_aucs.append(te_auc)
    train_f1s.append(tr_f1);         test_f1s.append(te_f1)
    train_recalls.append(tr_rec);    test_recalls.append(te_rec)
    train_precisions.append(tr_prec);test_precisions.append(te_prec)

    print(f"Epoch {epoch+1}/{num_epochs} | "
          f"Train Loss {tr_loss:.4f}  AUC {tr_auc:.4f} | "
          f"Test Loss {te_loss:.4f}   AUC {te_auc:.4f}")
# -------------------------------------------------------------------------------
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/300 | Train Loss 1.2014  AUC 0.5522 | Test Loss 1.1233   AUC 0.5906
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 2/300 | Train Loss 1.2056  AUC 0.5331 | Test Loss 1.1254   AUC 0.6022
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/300 | Train Loss 1.1956  AUC 0.5382 | Test Loss 1.1318   AUC 0.5710
# Epoch 4/300 | Train Loss 1.1701  AUC 0.5933 | Test Loss 1.1401   AUC 0.5892
# Epoch 5/300 | Train Loss 1.1515  AUC 0.5978 | Test Loss 1.1428   AUC 0.6036
# Epoch 6/300 | Train Loss 1.1585  AUC 0.5975 | Test Loss 1.1365   AUC 0.6240
# Epoch 7/300 | Train Loss 1.1426  AUC 0.6122 | Test Loss 1.1316   AUC 0.6433
# Epoch 8/300 | Train Loss 1.1590  AUC 0.6184 | Test Loss 1.1281   AUC 0.6617
# Epoch 9/300 | Train Loss 1.1511  AUC 0.5924 | Test Loss 1.1200   AUC 0.6595
# Epoch 10/300 | Train Loss 1.1484  AUC 0.6110 | Test Loss 1.1213   AUC 0.6590
# Epoch 11/300 | Train Loss 1.1202  AUC 0.6645 | Test Loss 1.1150   AUC 0.6785
# Epoch 12/300 | Train Loss 1.1352  AUC 0.6155 | Test Loss 1.1122   AUC 0.6799
# Epoch 13/300 | Train Loss 1.1149  AUC 0.6476 | Test Loss 1.1013   AUC 0.7091
# Epoch 14/300 | Train Loss 1.1113  AUC 0.6662 | Test Loss 1.0967   AUC 0.7074
# Epoch 15/300 | Train Loss 1.0985  AUC 0.6816 | Test Loss 1.0947   AUC 0.7216
# Epoch 16/300 | Train Loss 1.0764  AUC 0.7290 | Test Loss 1.0902   AUC 0.7316
# Epoch 17/300 | Train Loss 1.0954  AUC 0.6738 | Test Loss 1.0898   AUC 0.7089
# Epoch 18/300 | Train Loss 1.0768  AUC 0.7006 | Test Loss 1.0830   AUC 0.7275
# Epoch 19/300 | Train Loss 1.0771  AUC 0.7176 | Test Loss 1.0805   AUC 0.7318
# Epoch 20/300 | Train Loss 1.0778  AUC 0.6948 | Test Loss 1.0827   AUC 0.7241
# Epoch 21/300 | Train Loss 1.0773  AUC 0.6915 | Test Loss 1.0783   AUC 0.7252
# Epoch 22/300 | Train Loss 1.0632  AUC 0.7266 | Test Loss 1.0793   AUC 0.7432
# Epoch 23/300 | Train Loss 1.0579  AUC 0.7232 | Test Loss 1.0750   AUC 0.7524
# Epoch 24/300 | Train Loss 1.0682  AUC 0.7261 | Test Loss 1.0689   AUC 0.7650
# Epoch 25/300 | Train Loss 1.0456  AUC 0.7489 | Test Loss 1.0703   AUC 0.7650
# Epoch 26/300 | Train Loss 1.0470  AUC 0.7330 | Test Loss 1.0566   AUC 0.7672
# Epoch 27/300 | Train Loss 1.0469  AUC 0.7388 | Test Loss 1.0647   AUC 0.7627
# Epoch 28/300 | Train Loss 1.0488  AUC 0.7304 | Test Loss 1.0486   AUC 0.7743
# Epoch 29/300 | Train Loss 1.0485  AUC 0.7184 | Test Loss 1.0585   AUC 0.7707
# Epoch 30/300 | Train Loss 1.0378  AUC 0.7339 | Test Loss 1.0622   AUC 0.7754
# Epoch 31/300 | Train Loss 1.0262  AUC 0.7642 | Test Loss 1.0491   AUC 0.7782
# Epoch 32/300 | Train Loss 1.0412  AUC 0.7361 | Test Loss 1.0423   AUC 0.7815
# Epoch 33/300 | Train Loss 1.0236  AUC 0.7641 | Test Loss 1.0433   AUC 0.7791
# Epoch 34/300 | Train Loss 1.0256  AUC 0.7576 | Test Loss 1.0428   AUC 0.7784
# Epoch 35/300 | Train Loss 1.0156  AUC 0.7594 | Test Loss 1.0588   AUC 0.7763
# Epoch 36/300 | Train Loss 1.0168  AUC 0.7769 | Test Loss 1.0446   AUC 0.7920
# Epoch 37/300 | Train Loss 1.0184  AUC 0.7610 | Test Loss 1.0414   AUC 0.7921
# Epoch 38/300 | Train Loss 1.0160  AUC 0.7621 | Test Loss 1.0381   AUC 0.7873
# Epoch 39/300 | Train Loss 1.0123  AUC 0.7555 | Test Loss 1.0365   AUC 0.7973
# Epoch 40/300 | Train Loss 1.0011  AUC 0.7850 | Test Loss 1.0323   AUC 0.7979
# Epoch 41/300 | Train Loss 1.0024  AUC 0.7646 | Test Loss 1.0330   AUC 0.8046
# Epoch 42/300 | Train Loss 1.0053  AUC 0.7700 | Test Loss 1.0250   AUC 0.7974
# Epoch 43/300 | Train Loss 1.0063  AUC 0.7645 | Test Loss 1.0200   AUC 0.8077
# Epoch 44/300 | Train Loss 1.0105  AUC 0.7524 | Test Loss 1.0151   AUC 0.7968
# Epoch 45/300 | Train Loss 0.9891  AUC 0.7909 | Test Loss 1.0188   AUC 0.8091
# Epoch 46/300 | Train Loss 0.9903  AUC 0.7912 | Test Loss 1.0193   AUC 0.8120
# Epoch 47/300 | Train Loss 0.9849  AUC 0.7881 | Test Loss 1.0106   AUC 0.8122
# Epoch 48/300 | Train Loss 0.9865  AUC 0.7838 | Test Loss 0.9970   AUC 0.8069
# Epoch 49/300 | Train Loss 0.9758  AUC 0.7973 | Test Loss 1.0031   AUC 0.8132
# Epoch 50/300 | Train Loss 0.9685  AUC 0.8038 | Test Loss 1.0075   AUC 0.8147
# Epoch 51/300 | Train Loss 0.9739  AUC 0.7802 | Test Loss 1.0087   AUC 0.8113
# Epoch 52/300 | Train Loss 0.9772  AUC 0.7829 | Test Loss 1.0018   AUC 0.8143
# Epoch 53/300 | Train Loss 0.9682  AUC 0.7857 | Test Loss 1.0032   AUC 0.8206
# Epoch 54/300 | Train Loss 0.9633  AUC 0.7989 | Test Loss 0.9975   AUC 0.8178
# Epoch 55/300 | Train Loss 0.9674  AUC 0.7971 | Test Loss 0.9900   AUC 0.8250
# Epoch 56/300 | Train Loss 0.9601  AUC 0.7983 | Test Loss 0.9925   AUC 0.8257
# Epoch 57/300 | Train Loss 0.9608  AUC 0.8041 | Test Loss 0.9913   AUC 0.8259
# Epoch 58/300 | Train Loss 0.9549  AUC 0.7951 | Test Loss 0.9777   AUC 0.8348
# Epoch 59/300 | Train Loss 0.9630  AUC 0.7884 | Test Loss 0.9862   AUC 0.8296
# Epoch 60/300 | Train Loss 0.9437  AUC 0.8133 | Test Loss 0.9718   AUC 0.8380
# Epoch 61/300 | Train Loss 0.9437  AUC 0.8143 | Test Loss 0.9741   AUC 0.8372
# Epoch 62/300 | Train Loss 0.9518  AUC 0.8063 | Test Loss 0.9583   AUC 0.8424
# Epoch 63/300 | Train Loss 0.9598  AUC 0.7960 | Test Loss 0.9623   AUC 0.8397
# Epoch 64/300 | Train Loss 0.9385  AUC 0.8238 | Test Loss 0.9627   AUC 0.8497
# Epoch 65/300 | Train Loss 0.9447  AUC 0.8053 | Test Loss 0.9620   AUC 0.8420
# Epoch 66/300 | Train Loss 0.9428  AUC 0.8083 | Test Loss 0.9496   AUC 0.8475
# Epoch 67/300 | Train Loss 0.9346  AUC 0.8084 | Test Loss 0.9609   AUC 0.8487
# Epoch 68/300 | Train Loss 0.9407  AUC 0.8029 | Test Loss 0.9525   AUC 0.8426
# Epoch 69/300 | Train Loss 0.9168  AUC 0.8348 | Test Loss 0.9453   AUC 0.8505
# Epoch 70/300 | Train Loss 0.9187  AUC 0.8251 | Test Loss 0.9411   AUC 0.8525
# Epoch 71/300 | Train Loss 0.9205  AUC 0.8224 | Test Loss 0.9397   AUC 0.8450
# Epoch 72/300 | Train Loss 0.9166  AUC 0.8263 | Test Loss 0.9437   AUC 0.8504
# Epoch 73/300 | Train Loss 0.9206  AUC 0.8147 | Test Loss 0.9430   AUC 0.8518
# Epoch 74/300 | Train Loss 0.9094  AUC 0.8254 | Test Loss 0.9343   AUC 0.8496
# Epoch 75/300 | Train Loss 0.9202  AUC 0.8138 | Test Loss 0.9340   AUC 0.8483
# Epoch 76/300 | Train Loss 0.9115  AUC 0.8289 | Test Loss 0.9296   AUC 0.8529
# Epoch 77/300 | Train Loss 0.9122  AUC 0.8274 | Test Loss 0.9254   AUC 0.8510
# Epoch 78/300 | Train Loss 0.9091  AUC 0.8304 | Test Loss 0.9335   AUC 0.8493
# Epoch 79/300 | Train Loss 0.9148  AUC 0.8178 | Test Loss 0.9236   AUC 0.8553
# Epoch 80/300 | Train Loss 0.8958  AUC 0.8421 | Test Loss 0.9178   AUC 0.8611
# Epoch 81/300 | Train Loss 0.9008  AUC 0.8312 | Test Loss 0.9131   AUC 0.8568
# Epoch 82/300 | Train Loss 0.9137  AUC 0.8101 | Test Loss 0.9066   AUC 0.8530
# Epoch 83/300 | Train Loss 0.8952  AUC 0.8411 | Test Loss 0.9103   AUC 0.8549
# Epoch 84/300 | Train Loss 0.8953  AUC 0.8206 | Test Loss 0.9070   AUC 0.8595
# Epoch 85/300 | Train Loss 0.8981  AUC 0.8282 | Test Loss 0.8997   AUC 0.8619
# Epoch 86/300 | Train Loss 0.8952  AUC 0.8313 | Test Loss 0.8981   AUC 0.8580
# Epoch 87/300 | Train Loss 0.8902  AUC 0.8294 | Test Loss 0.9079   AUC 0.8610
# Epoch 88/300 | Train Loss 0.8820  AUC 0.8374 | Test Loss 0.9024   AUC 0.8642
# Epoch 89/300 | Train Loss 0.8846  AUC 0.8350 | Test Loss 0.8968   AUC 0.8696
# Epoch 90/300 | Train Loss 0.8704  AUC 0.8522 | Test Loss 0.8984   AUC 0.8563
# Epoch 91/300 | Train Loss 0.8696  AUC 0.8429 | Test Loss 0.8882   AUC 0.8673
# Epoch 92/300 | Train Loss 0.8763  AUC 0.8372 | Test Loss 0.8926   AUC 0.8644
# Epoch 93/300 | Train Loss 0.8794  AUC 0.8328 | Test Loss 0.9016   AUC 0.8541
# Epoch 94/300 | Train Loss 0.8738  AUC 0.8429 | Test Loss 0.8821   AUC 0.8655
# Epoch 95/300 | Train Loss 0.8733  AUC 0.8515 | Test Loss 0.8860   AUC 0.8718
# Epoch 96/300 | Train Loss 0.8632  AUC 0.8510 | Test Loss 0.8810   AUC 0.8680
# Epoch 97/300 | Train Loss 0.8651  AUC 0.8449 | Test Loss 0.8833   AUC 0.8672
# Epoch 98/300 | Train Loss 0.8645  AUC 0.8428 | Test Loss 0.8877   AUC 0.8639
# Epoch 99/300 | Train Loss 0.8579  AUC 0.8450 | Test Loss 0.8801   AUC 0.8667
# Epoch 100/300 | Train Loss 0.8610  AUC 0.8412 | Test Loss 0.8687   AUC 0.8744
# Epoch 101/300 | Train Loss 0.8561  AUC 0.8548 | Test Loss 0.8733   AUC 0.8727
# Epoch 102/300 | Train Loss 0.8443  AUC 0.8580 | Test Loss 0.8696   AUC 0.8727
# Epoch 103/300 | Train Loss 0.8484  AUC 0.8517 | Test Loss 0.8701   AUC 0.8704
# Epoch 104/300 | Train Loss 0.8543  AUC 0.8370 | Test Loss 0.8574   AUC 0.8686
# Epoch 105/300 | Train Loss 0.8595  AUC 0.8396 | Test Loss 0.8591   AUC 0.8703
# Epoch 106/300 | Train Loss 0.8417  AUC 0.8563 | Test Loss 0.8683   AUC 0.8680
# Epoch 107/300 | Train Loss 0.8336  AUC 0.8602 | Test Loss 0.8579   AUC 0.8707
# Epoch 108/300 | Train Loss 0.8347  AUC 0.8573 | Test Loss 0.8544   AUC 0.8789
# Epoch 109/300 | Train Loss 0.8423  AUC 0.8544 | Test Loss 0.8558   AUC 0.8724
# Epoch 110/300 | Train Loss 0.8483  AUC 0.8478 | Test Loss 0.8524   AUC 0.8755
# Epoch 111/300 | Train Loss 0.8423  AUC 0.8489 | Test Loss 0.8499   AUC 0.8738
# Epoch 112/300 | Train Loss 0.8273  AUC 0.8589 | Test Loss 0.8479   AUC 0.8807
# Epoch 113/300 | Train Loss 0.8333  AUC 0.8584 | Test Loss 0.8496   AUC 0.8720
# Epoch 114/300 | Train Loss 0.8351  AUC 0.8496 | Test Loss 0.8383   AUC 0.8765
# Epoch 115/300 | Train Loss 0.8317  AUC 0.8447 | Test Loss 0.8440   AUC 0.8779
# Epoch 116/300 | Train Loss 0.8223  AUC 0.8622 | Test Loss 0.8419   AUC 0.8722
# Epoch 117/300 | Train Loss 0.8232  AUC 0.8653 | Test Loss 0.8439   AUC 0.8762
# Epoch 118/300 | Train Loss 0.8359  AUC 0.8457 | Test Loss 0.8392   AUC 0.8757
# Epoch 119/300 | Train Loss 0.8242  AUC 0.8567 | Test Loss 0.8280   AUC 0.8798
# Epoch 120/300 | Train Loss 0.8096  AUC 0.8640 | Test Loss 0.8377   AUC 0.8770
# Epoch 121/300 | Train Loss 0.8234  AUC 0.8544 | Test Loss 0.8317   AUC 0.8792
# Epoch 122/300 | Train Loss 0.8118  AUC 0.8629 | Test Loss 0.8297   AUC 0.8799
# Epoch 123/300 | Train Loss 0.8128  AUC 0.8589 | Test Loss 0.8286   AUC 0.8783
# Epoch 124/300 | Train Loss 0.8227  AUC 0.8540 | Test Loss 0.8322   AUC 0.8784
# Epoch 125/300 | Train Loss 0.8113  AUC 0.8631 | Test Loss 0.8291   AUC 0.8845
# Epoch 126/300 | Train Loss 0.8158  AUC 0.8513 | Test Loss 0.8287   AUC 0.8830
# Epoch 127/300 | Train Loss 0.8119  AUC 0.8559 | Test Loss 0.8242   AUC 0.8826
# Epoch 128/300 | Train Loss 0.8102  AUC 0.8596 | Test Loss 0.8262   AUC 0.8794
# Epoch 129/300 | Train Loss 0.8123  AUC 0.8575 | Test Loss 0.8242   AUC 0.8815
# Epoch 130/300 | Train Loss 0.7988  AUC 0.8675 | Test Loss 0.8224   AUC 0.8847
# Epoch 131/300 | Train Loss 0.7962  AUC 0.8652 | Test Loss 0.8155   AUC 0.8844
# Epoch 132/300 | Train Loss 0.7973  AUC 0.8635 | Test Loss 0.8214   AUC 0.8771
# Epoch 133/300 | Train Loss 0.7981  AUC 0.8646 | Test Loss 0.8176   AUC 0.8824
# Epoch 134/300 | Train Loss 0.7986  AUC 0.8554 | Test Loss 0.8129   AUC 0.8864
# Epoch 135/300 | Train Loss 0.8088  AUC 0.8466 | Test Loss 0.8166   AUC 0.8857
# Epoch 136/300 | Train Loss 0.8020  AUC 0.8570 | Test Loss 0.8109   AUC 0.8852
# Epoch 137/300 | Train Loss 0.7866  AUC 0.8698 | Test Loss 0.8101   AUC 0.8851
# Epoch 138/300 | Train Loss 0.7933  AUC 0.8661 | Test Loss 0.8105   AUC 0.8832
# Epoch 139/300 | Train Loss 0.7945  AUC 0.8602 | Test Loss 0.8050   AUC 0.8856
# Epoch 140/300 | Train Loss 0.7880  AUC 0.8635 | Test Loss 0.8067   AUC 0.8833
# Epoch 141/300 | Train Loss 0.7793  AUC 0.8642 | Test Loss 0.8018   AUC 0.8826
# Epoch 142/300 | Train Loss 0.7712  AUC 0.8753 | Test Loss 0.7994   AUC 0.8829
# Epoch 143/300 | Train Loss 0.7774  AUC 0.8764 | Test Loss 0.8052   AUC 0.8830
# Epoch 144/300 | Train Loss 0.7862  AUC 0.8664 | Test Loss 0.7980   AUC 0.8851
# Epoch 145/300 | Train Loss 0.7798  AUC 0.8665 | Test Loss 0.8030   AUC 0.8863
# Epoch 146/300 | Train Loss 0.7839  AUC 0.8605 | Test Loss 0.7913   AUC 0.8876
# Epoch 147/300 | Train Loss 0.7704  AUC 0.8742 | Test Loss 0.7919   AUC 0.8866
# Epoch 148/300 | Train Loss 0.7731  AUC 0.8769 | Test Loss 0.7909   AUC 0.8868
# Epoch 149/300 | Train Loss 0.7696  AUC 0.8732 | Test Loss 0.7902   AUC 0.8857
# Epoch 150/300 | Train Loss 0.7641  AUC 0.8747 | Test Loss 0.7860   AUC 0.8855
# Epoch 151/300 | Train Loss 0.7683  AUC 0.8681 | Test Loss 0.7877   AUC 0.8853
# Epoch 152/300 | Train Loss 0.7608  AUC 0.8725 | Test Loss 0.7871   AUC 0.8877
# Epoch 153/300 | Train Loss 0.7699  AUC 0.8674 | Test Loss 0.7884   AUC 0.8875
# Epoch 154/300 | Train Loss 0.7634  AUC 0.8732 | Test Loss 0.7870   AUC 0.8890
# Epoch 155/300 | Train Loss 0.7626  AUC 0.8706 | Test Loss 0.7808   AUC 0.8882
# Epoch 156/300 | Train Loss 0.7550  AUC 0.8760 | Test Loss 0.7827   AUC 0.8878
# Epoch 157/300 | Train Loss 0.7555  AUC 0.8710 | Test Loss 0.7756   AUC 0.8870
# Epoch 158/300 | Train Loss 0.7621  AUC 0.8759 | Test Loss 0.7764   AUC 0.8888
# Epoch 159/300 | Train Loss 0.7605  AUC 0.8716 | Test Loss 0.7767   AUC 0.8869
# Epoch 160/300 | Train Loss 0.7585  AUC 0.8747 | Test Loss 0.7746   AUC 0.8880
# Epoch 161/300 | Train Loss 0.7510  AUC 0.8752 | Test Loss 0.7796   AUC 0.8878
# Epoch 162/300 | Train Loss 0.7665  AUC 0.8635 | Test Loss 0.7737   AUC 0.8870
# Epoch 163/300 | Train Loss 0.7552  AUC 0.8708 | Test Loss 0.7727   AUC 0.8886
# Epoch 164/300 | Train Loss 0.7603  AUC 0.8741 | Test Loss 0.7717   AUC 0.8893
# Epoch 165/300 | Train Loss 0.7455  AUC 0.8802 | Test Loss 0.7629   AUC 0.8890
# Epoch 166/300 | Train Loss 0.7511  AUC 0.8737 | Test Loss 0.7641   AUC 0.8894
# Epoch 167/300 | Train Loss 0.7483  AUC 0.8702 | Test Loss 0.7693   AUC 0.8881
# Epoch 168/300 | Train Loss 0.7592  AUC 0.8615 | Test Loss 0.7664   AUC 0.8885
# Epoch 169/300 | Train Loss 0.7619  AUC 0.8536 | Test Loss 0.7664   AUC 0.8895
# Epoch 170/300 | Train Loss 0.7381  AUC 0.8823 | Test Loss 0.7662   AUC 0.8898
# Epoch 171/300 | Train Loss 0.7517  AUC 0.8677 | Test Loss 0.7606   AUC 0.8882
# Epoch 172/300 | Train Loss 0.7399  AUC 0.8746 | Test Loss 0.7682   AUC 0.8878
# Epoch 173/300 | Train Loss 0.7341  AUC 0.8829 | Test Loss 0.7651   AUC 0.8890
# Epoch 174/300 | Train Loss 0.7314  AUC 0.8861 | Test Loss 0.7664   AUC 0.8894
# Epoch 175/300 | Train Loss 0.7368  AUC 0.8745 | Test Loss 0.7550   AUC 0.8893
# Epoch 176/300 | Train Loss 0.7294  AUC 0.8837 | Test Loss 0.7598   AUC 0.8898
# Epoch 177/300 | Train Loss 0.7341  AUC 0.8758 | Test Loss 0.7547   AUC 0.8892
# Epoch 178/300 | Train Loss 0.7328  AUC 0.8812 | Test Loss 0.7546   AUC 0.8894
# Epoch 179/300 | Train Loss 0.7349  AUC 0.8731 | Test Loss 0.7464   AUC 0.8884
# Epoch 180/300 | Train Loss 0.7365  AUC 0.8747 | Test Loss 0.7498   AUC 0.8904
# Epoch 181/300 | Train Loss 0.7391  AUC 0.8719 | Test Loss 0.7511   AUC 0.8901
# Epoch 182/300 | Train Loss 0.7328  AUC 0.8741 | Test Loss 0.7512   AUC 0.8891
# Epoch 183/300 | Train Loss 0.7314  AUC 0.8782 | Test Loss 0.7494   AUC 0.8899
# Epoch 184/300 | Train Loss 0.7240  AUC 0.8780 | Test Loss 0.7455   AUC 0.8903
# Epoch 185/300 | Train Loss 0.7276  AUC 0.8791 | Test Loss 0.7412   AUC 0.8898
# Epoch 186/300 | Train Loss 0.7345  AUC 0.8739 | Test Loss 0.7499   AUC 0.8892
# Epoch 187/300 | Train Loss 0.7263  AUC 0.8797 | Test Loss 0.7434   AUC 0.8905
# Epoch 188/300 | Train Loss 0.7172  AUC 0.8871 | Test Loss 0.7472   AUC 0.8901
# Epoch 189/300 | Train Loss 0.7180  AUC 0.8748 | Test Loss 0.7376   AUC 0.8887
# Epoch 190/300 | Train Loss 0.7268  AUC 0.8760 | Test Loss 0.7378   AUC 0.8909
# Epoch 191/300 | Train Loss 0.7150  AUC 0.8842 | Test Loss 0.7423   AUC 0.8921
# Epoch 192/300 | Train Loss 0.7244  AUC 0.8743 | Test Loss 0.7392   AUC 0.8899
# Epoch 193/300 | Train Loss 0.7057  AUC 0.8841 | Test Loss 0.7337   AUC 0.8913
# Epoch 194/300 | Train Loss 0.7141  AUC 0.8813 | Test Loss 0.7340   AUC 0.8900
# Epoch 195/300 | Train Loss 0.7073  AUC 0.8872 | Test Loss 0.7291   AUC 0.8917
# Epoch 196/300 | Train Loss 0.7254  AUC 0.8716 | Test Loss 0.7346   AUC 0.8910
# Epoch 197/300 | Train Loss 0.7060  AUC 0.8832 | Test Loss 0.7299   AUC 0.8909
# Epoch 198/300 | Train Loss 0.7017  AUC 0.8849 | Test Loss 0.7335   AUC 0.8918
# Epoch 199/300 | Train Loss 0.7109  AUC 0.8807 | Test Loss 0.7284   AUC 0.8911
# Epoch 200/300 | Train Loss 0.7031  AUC 0.8853 | Test Loss 0.7268   AUC 0.8898
# Epoch 201/300 | Train Loss 0.7068  AUC 0.8826 | Test Loss 0.7281   AUC 0.8921
# Epoch 202/300 | Train Loss 0.7120  AUC 0.8735 | Test Loss 0.7230   AUC 0.8935
# Epoch 203/300 | Train Loss 0.7011  AUC 0.8841 | Test Loss 0.7255   AUC 0.8919
# Epoch 204/300 | Train Loss 0.7095  AUC 0.8803 | Test Loss 0.7200   AUC 0.8918
# Epoch 205/300 | Train Loss 0.6997  AUC 0.8841 | Test Loss 0.7239   AUC 0.8941
# Epoch 206/300 | Train Loss 0.6969  AUC 0.8862 | Test Loss 0.7208   AUC 0.8933
# Epoch 207/300 | Train Loss 0.6947  AUC 0.8880 | Test Loss 0.7169   AUC 0.8931
# Epoch 208/300 | Train Loss 0.7050  AUC 0.8828 | Test Loss 0.7211   AUC 0.8941
# Epoch 209/300 | Train Loss 0.6943  AUC 0.8853 | Test Loss 0.7184   AUC 0.8940
# Epoch 210/300 | Train Loss 0.6970  AUC 0.8814 | Test Loss 0.7125   AUC 0.8934
# Epoch 211/300 | Train Loss 0.6841  AUC 0.8945 | Test Loss 0.7161   AUC 0.8937
# Epoch 212/300 | Train Loss 0.7074  AUC 0.8798 | Test Loss 0.7131   AUC 0.8931
# Epoch 213/300 | Train Loss 0.6949  AUC 0.8874 | Test Loss 0.7136   AUC 0.8920
# Epoch 214/300 | Train Loss 0.6985  AUC 0.8793 | Test Loss 0.7192   AUC 0.8940
# Epoch 215/300 | Train Loss 0.6989  AUC 0.8770 | Test Loss 0.7143   AUC 0.8937
# Epoch 216/300 | Train Loss 0.6893  AUC 0.8883 | Test Loss 0.7099   AUC 0.8937
# Epoch 217/300 | Train Loss 0.6768  AUC 0.8937 | Test Loss 0.7103   AUC 0.8926
# Epoch 218/300 | Train Loss 0.6748  AUC 0.8950 | Test Loss 0.7121   AUC 0.8936
# Epoch 219/300 | Train Loss 0.6886  AUC 0.8873 | Test Loss 0.7072   AUC 0.8935
# Epoch 220/300 | Train Loss 0.6812  AUC 0.8934 | Test Loss 0.7057   AUC 0.8941
# Epoch 221/300 | Train Loss 0.6805  AUC 0.8866 | Test Loss 0.7068   AUC 0.8944
# Epoch 222/300 | Train Loss 0.6811  AUC 0.8905 | Test Loss 0.7044   AUC 0.8939
# Epoch 223/300 | Train Loss 0.6768  AUC 0.8909 | Test Loss 0.7024   AUC 0.8941
# Epoch 224/300 | Train Loss 0.6780  AUC 0.8939 | Test Loss 0.7043   AUC 0.8943
# Epoch 225/300 | Train Loss 0.6828  AUC 0.8879 | Test Loss 0.7029   AUC 0.8944
# Epoch 226/300 | Train Loss 0.6925  AUC 0.8764 | Test Loss 0.6982   AUC 0.8956
# Epoch 227/300 | Train Loss 0.6776  AUC 0.8897 | Test Loss 0.6973   AUC 0.8948
# Epoch 228/300 | Train Loss 0.6717  AUC 0.8952 | Test Loss 0.6973   AUC 0.8952
# Epoch 229/300 | Train Loss 0.6788  AUC 0.8882 | Test Loss 0.7012   AUC 0.8956
# Epoch 230/300 | Train Loss 0.6811  AUC 0.8847 | Test Loss 0.6967   AUC 0.8944
# Epoch 231/300 | Train Loss 0.6791  AUC 0.8865 | Test Loss 0.6958   AUC 0.8953
# Epoch 232/300 | Train Loss 0.6780  AUC 0.8837 | Test Loss 0.6947   AUC 0.8950
# Epoch 233/300 | Train Loss 0.6776  AUC 0.8880 | Test Loss 0.6868   AUC 0.8958
# Epoch 234/300 | Train Loss 0.6653  AUC 0.8918 | Test Loss 0.6984   AUC 0.8962
# Epoch 235/300 | Train Loss 0.6727  AUC 0.8904 | Test Loss 0.6979   AUC 0.8957
# Epoch 236/300 | Train Loss 0.6689  AUC 0.8910 | Test Loss 0.6943   AUC 0.8956
# Epoch 237/300 | Train Loss 0.6785  AUC 0.8858 | Test Loss 0.6908   AUC 0.8956
# Epoch 238/300 | Train Loss 0.6725  AUC 0.8849 | Test Loss 0.6899   AUC 0.8957
# Epoch 239/300 | Train Loss 0.6623  AUC 0.8960 | Test Loss 0.6901   AUC 0.8958
# Epoch 240/300 | Train Loss 0.6777  AUC 0.8820 | Test Loss 0.6893   AUC 0.8960
# Epoch 241/300 | Train Loss 0.6633  AUC 0.8911 | Test Loss 0.6911   AUC 0.8970
# Epoch 242/300 | Train Loss 0.6559  AUC 0.8960 | Test Loss 0.6858   AUC 0.8963
# Epoch 243/300 | Train Loss 0.6666  AUC 0.8897 | Test Loss 0.6894   AUC 0.8944
# Epoch 244/300 | Train Loss 0.6750  AUC 0.8806 | Test Loss 0.6889   AUC 0.8946
# Epoch 245/300 | Train Loss 0.6549  AUC 0.8973 | Test Loss 0.6867   AUC 0.8946
# Epoch 246/300 | Train Loss 0.6595  AUC 0.8924 | Test Loss 0.6820   AUC 0.8956
# Epoch 247/300 | Train Loss 0.6610  AUC 0.8878 | Test Loss 0.6804   AUC 0.8971
# Epoch 248/300 | Train Loss 0.6590  AUC 0.8892 | Test Loss 0.6788   AUC 0.8968
# Epoch 249/300 | Train Loss 0.6562  AUC 0.8949 | Test Loss 0.6777   AUC 0.8970
# Epoch 250/300 | Train Loss 0.6603  AUC 0.8876 | Test Loss 0.6804   AUC 0.8979
# Epoch 251/300 | Train Loss 0.6501  AUC 0.8973 | Test Loss 0.6827   AUC 0.8976
# Epoch 252/300 | Train Loss 0.6529  AUC 0.8956 | Test Loss 0.6800   AUC 0.8974
# Epoch 253/300 | Train Loss 0.6567  AUC 0.8879 | Test Loss 0.6775   AUC 0.8972
# Epoch 254/300 | Train Loss 0.6561  AUC 0.8932 | Test Loss 0.6776   AUC 0.8974
# Epoch 255/300 | Train Loss 0.6419  AUC 0.9029 | Test Loss 0.6823   AUC 0.8967
# Epoch 256/300 | Train Loss 0.6544  AUC 0.8929 | Test Loss 0.6797   AUC 0.8979
# Epoch 257/300 | Train Loss 0.6530  AUC 0.8929 | Test Loss 0.6772   AUC 0.8979
# Epoch 258/300 | Train Loss 0.6348  AUC 0.9047 | Test Loss 0.6759   AUC 0.8974
# Epoch 259/300 | Train Loss 0.6424  AUC 0.9025 | Test Loss 0.6686   AUC 0.8979
# Epoch 260/300 | Train Loss 0.6439  AUC 0.8975 | Test Loss 0.6670   AUC 0.8979
# Epoch 261/300 | Train Loss 0.6486  AUC 0.8946 | Test Loss 0.6666   AUC 0.8985
# Epoch 262/300 | Train Loss 0.6493  AUC 0.8918 | Test Loss 0.6703   AUC 0.8987
# Epoch 263/300 | Train Loss 0.6481  AUC 0.8935 | Test Loss 0.6752   AUC 0.8992
# Epoch 264/300 | Train Loss 0.6502  AUC 0.8900 | Test Loss 0.6738   AUC 0.8987
# Epoch 265/300 | Train Loss 0.6491  AUC 0.8928 | Test Loss 0.6748   AUC 0.8984
# Epoch 266/300 | Train Loss 0.6426  AUC 0.8952 | Test Loss 0.6691   AUC 0.8989
# Epoch 267/300 | Train Loss 0.6238  AUC 0.9064 | Test Loss 0.6659   AUC 0.8998
# Epoch 268/300 | Train Loss 0.6403  AUC 0.9008 | Test Loss 0.6678   AUC 0.8997
# Epoch 269/300 | Train Loss 0.6401  AUC 0.8974 | Test Loss 0.6681   AUC 0.8988
# Epoch 270/300 | Train Loss 0.6361  AUC 0.8958 | Test Loss 0.6634   AUC 0.8992
# Epoch 271/300 | Train Loss 0.6387  AUC 0.8978 | Test Loss 0.6611   AUC 0.8997
# Epoch 272/300 | Train Loss 0.6323  AUC 0.9023 | Test Loss 0.6606   AUC 0.9003
# Epoch 273/300 | Train Loss 0.6370  AUC 0.8959 | Test Loss 0.6585   AUC 0.8998
# Epoch 274/300 | Train Loss 0.6457  AUC 0.8889 | Test Loss 0.6540   AUC 0.9001
# Epoch 275/300 | Train Loss 0.6293  AUC 0.9028 | Test Loss 0.6560   AUC 0.9003
# Epoch 276/300 | Train Loss 0.6351  AUC 0.8927 | Test Loss 0.6553   AUC 0.9003
# Epoch 277/300 | Train Loss 0.6368  AUC 0.8960 | Test Loss 0.6541   AUC 0.9005
# Epoch 278/300 | Train Loss 0.6390  AUC 0.8920 | Test Loss 0.6476   AUC 0.9004
# Epoch 279/300 | Train Loss 0.6347  AUC 0.8968 | Test Loss 0.6550   AUC 0.9011
# Epoch 280/300 | Train Loss 0.6382  AUC 0.8912 | Test Loss 0.6568   AUC 0.9005
# Epoch 281/300 | Train Loss 0.6426  AUC 0.8899 | Test Loss 0.6494   AUC 0.9009
# Epoch 282/300 | Train Loss 0.6373  AUC 0.8933 | Test Loss 0.6578   AUC 0.9008
# Epoch 283/300 | Train Loss 0.6211  AUC 0.9061 | Test Loss 0.6567   AUC 0.9003
# Epoch 284/300 | Train Loss 0.6215  AUC 0.8997 | Test Loss 0.6507   AUC 0.9010
# Epoch 285/300 | Train Loss 0.6301  AUC 0.8969 | Test Loss 0.6514   AUC 0.8997
# Epoch 286/300 | Train Loss 0.6253  AUC 0.8983 | Test Loss 0.6523   AUC 0.8994
# Epoch 287/300 | Train Loss 0.6270  AUC 0.8990 | Test Loss 0.6487   AUC 0.9003
# Epoch 288/300 | Train Loss 0.6211  AUC 0.9032 | Test Loss 0.6510   AUC 0.9001
# Epoch 289/300 | Train Loss 0.6342  AUC 0.8928 | Test Loss 0.6459   AUC 0.9011
# Epoch 290/300 | Train Loss 0.6177  AUC 0.9057 | Test Loss 0.6489   AUC 0.8999
# Epoch 291/300 | Train Loss 0.6078  AUC 0.9077 | Test Loss 0.6484   AUC 0.9012
# Epoch 292/300 | Train Loss 0.6306  AUC 0.8932 | Test Loss 0.6459   AUC 0.9013
# Epoch 293/300 | Train Loss 0.6199  AUC 0.9019 | Test Loss 0.6448   AUC 0.9015
# Epoch 294/300 | Train Loss 0.6093  AUC 0.9057 | Test Loss 0.6451   AUC 0.9017
# Epoch 295/300 | Train Loss 0.6259  AUC 0.8960 | Test Loss 0.6464   AUC 0.9009
# Epoch 296/300 | Train Loss 0.6138  AUC 0.9024 | Test Loss 0.6444   AUC 0.9012
# Epoch 297/300 | Train Loss 0.6232  AUC 0.9017 | Test Loss 0.6424   AUC 0.9021
# Epoch 298/300 | Train Loss 0.6137  AUC 0.9064 | Test Loss 0.6413   AUC 0.9020
# Epoch 299/300 | Train Loss 0.6069  AUC 0.9084 | Test Loss 0.6408   AUC 0.9012
# Epoch 300/300 | Train Loss 0.6183  AUC 0.9027 | Test Loss 0.6428   AUC 0.9022

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.7313
# Precision: 0.7102
# Recall:    0.7458
# F1 Score:  0.7251
# AUC-ROC:   0.8964

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("ADNI AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("ADNI Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
