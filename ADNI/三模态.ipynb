# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#生物标志物 ad 90*48   no 349*58
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'normal_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'ad_nii_KG/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NC_nii_kg/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #151
print(count_no) #211
print(count_mci) #475
# Out:
# 151
# 211
# 475

# %%
ad_arrays=[]
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','ind':'3','ans':'4'}
for i in data_ad:   #第13行开始为基因、蛋白水平
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    ad_array = np.array(num_list)
    ad_arrays.append(ad_array)
ad_array = np.vstack(ad_arrays)

# %%
normal_arrays=[]
for i in data_normal:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    normal_array = np.array(num_list)
    normal_arrays.append(normal_array)
normal_array = np.vstack(normal_arrays)

# %%
mci_arrays=[]
for i in data_mci:
    j= i[16:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    mci_array = np.array(num_list)
    mci_arrays.append(mci_array)
mci_array = np.vstack(mci_arrays)

# %%
#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # 推荐：引入激活函数库

# 1. 转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 2. 定义网络层 
# 关键修复：输入维度由 45 改为 52 (匹配你的数据列数)
# 关键优化：使用不同的变量名 (fc1, fc2, fc3) 防止层被覆盖
fc1 = nn.Linear(52, 32)
fc2 = nn.Linear(32, 16)
fc3 = nn.Linear(16, 1)

# 3. 前向传播
# 注意：多层网络通常需要在层与层之间加激活函数(如 ReLU)，否则它数学上等价于单层网络。
# 为了保持代码运行，这里先按你的逻辑写，如果需要增加非线性能力，请取消注释 relu 行。

# 第一层
ad_tensor = fc1(ad_tensor)
# ad_tensor = F.relu(ad_tensor) 
normal_tensor = fc1(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc1(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第二层
ad_tensor = fc2(ad_tensor)
# ad_tensor = F.relu(ad_tensor)
normal_tensor = fc2(normal_tensor)
# normal_tensor = F.relu(normal_tensor)
mci_tensor = fc2(mci_tensor)
# mci_tensor = F.relu(mci_tensor)

# 第三层 (输出层)
ad_tensor = fc3(ad_tensor)
normal_tensor = fc3(normal_tensor)
mci_tensor = fc3(mci_tensor)

# 4. 打印结果
print('AD_tensor shape:', ad_tensor.shape)      # 预期: (151, 1)
print('Normal_tensor shape:', normal_tensor.shape) # 预期: (211, 1)
print('MCI_tensor shape:', mci_tensor.shape)    # 预期: (475, 1)
# Out:
# AD_tensor shape: torch.Size([151, 1])
# Normal_tensor shape: torch.Size([211, 1])
# MCI_tensor shape: torch.Size([475, 1])

# %%
'''
#线性 48--->16--->1  两个线性层
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

linear_layer = nn.Linear(48, 32)
normal_tensor = linear_layer(normal_tensor)
ad_tensor = linear_layer(ad_tensor)
mci_tensor = linear_layer(mci_tensor)

linear_layer = nn.Linear(32, 16)
normal_tensor = linear_layer(normal_tensor)
ad_tensor = linear_layer(ad_tensor)
mci_tensor = linear_layer(mci_tensor)

linear_layer = nn.Linear(16,1)
normal_tensor = linear_layer(normal_tensor)
ad_tensor = linear_layer(ad_tensor)
mci_tensor = linear_layer(mci_tensor)'''
# Out:
# '\n#线性 48--->16--->1  两个线性层\nad_tensor = torch.from_numpy(ad_array).float()\nnormal_tensor = torch.from_numpy(normal_array).float()\nmci_tensor = torch.from_numpy(mci_array).float()\n\nlinear_layer = nn.Linear(48, 32)\nnormal_tensor = linear_layer(normal_tensor)\nad_tensor = linear_layer(ad_tensor)\nmci_tensor = linear_layer(mci_tensor)\n\nlinear_layer = nn.Linear(32, 16)\nnormal_tensor = linear_layer(normal_tensor)\nad_tensor = linear_layer(ad_tensor)\nmci_tensor = linear_layer(mci_tensor)\n\nlinear_layer = nn.Linear(16,1)\nnormal_tensor = linear_layer(normal_tensor)\nad_tensor = linear_layer(ad_tensor)\nmci_tensor = linear_layer(mci_tensor)'

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        # 替换字典中的值
        row = [replace_dict.get(item, item) for item in row]
        # 将类别型变量转换为数值
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[2:16])
    return np.array(processed_data)

# %%
# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict)
normal_data = preprocess_data(data_normal, replace_dict)
mci_data = preprocess_data(data_mci, replace_dict)

categorical_indices = [3,4,5,6,7]  # gender, education, hispanic, race
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(14, 16)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(16, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# mci.EHR---> torch.Size([475, 1])

# %%
#医学图像
nii = CNN_3D(num_class=1)
nii= nii.to(device)
all_ad = 'ad_nii_KG/'
all_normal = 'normal_nii_kg/'
all_mci = 'NC_nii_kg/'
dataset = NiiDataset(all_ad)
batch_size = 16
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_normal)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)

dataset = NiiDataset(all_mci)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)

# %%
print('ad.shape--->',ad_tensor.shape)
print("normal.shape--->",normal_tensor.shape)
print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('ad nii shape--->',ad_output.shape)
print('normal nii shape--->',normal_output.shape)
# Out:
# ad.shape---> torch.Size([151, 1])
# normal.shape---> torch.Size([211, 1])
# ad.EHR---> torch.Size([151, 1])
# normal.EHR---> torch.Size([211, 1])
# ad nii shape---> torch.Size([151, 1])
# normal nii shape---> torch.Size([211, 1])

# %%
ad_EHR = ad_EHR.cpu()
ad_tensor = ad_tensor.cpu()
mci_EHR = mci_EHR.cpu()
mci_tensor = mci_tensor.cpu()
normal_EHR = normal_EHR.cpu()
normal_tensor = normal_tensor.cpu()
ad_output = ad_output.cpu()
mci_output = mci_output.cpu()
normal_output = normal_output.cpu()

X_ad = torch.cat([ad_EHR, ad_output, ad_tensor], dim=1)
X_mci = torch.cat([mci_EHR, mci_output, mci_tensor], dim=1)
X_normal = torch.cat([normal_EHR, normal_output, normal_tensor], dim=1)
y_ad = torch.ones(len(X_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(X_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(X_normal)) * 0  # Nc 类别标签为 0
# 拼接特征和标签
X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()

# 数据划分
X_train, X_test, y_train, y_test = train_test_split(X.detach().numpy(), y.numpy(),
                                                    test_size=0.25,
                                                    stratify=y.numpy(),
                                                    random_state=34)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                  test_size=0.25,
                                                  stratify=y_train,
                                                  random_state=34)

# %%
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.FloatTensor(y_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.FloatTensor(y_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.FloatTensor(y_test).to(device)

# 创建 TensorDataset
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        labels = labels.long()
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        # 获取预测概率
        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc

# %%
def evaluate(model, loader):
    model.eval()
    all_probs = []
    all_labels = []
    total_loss = 0
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.long()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            # 获取预测概率
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
    test_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, test_auc

# %%
train_losses = []
train_aucs = []
test_losses = []
test_aucs = []
model = MultiModalTransformer().to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-5, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()    
for epoch in range(125):
    train_loss, train_auc = train_epoch(model, train_loader)
    test_loss, test_auc = evaluate(model, test_loader)
        
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    print(f"Epoch {epoch:03d} | "
            f"Train Loss: {train_loss:.4f} | Train AUC: {train_auc:.4f} | "
            f"Test Loss: {test_loss:.4f} | Test AUC: {test_auc:.4f}")
# Out:
# Epoch 000 | Train Loss: 1.1408 | Train AUC: 0.5161 | Test Loss: 1.1143 | Test AUC: 0.4556
# Epoch 001 | Train Loss: 1.1431 | Train AUC: 0.5046 | Test Loss: 1.1380 | Test AUC: 0.4502
# Epoch 002 | Train Loss: 1.1420 | Train AUC: 0.5123 | Test Loss: 1.1539 | Test AUC: 0.4964
# Epoch 003 | Train Loss: 1.1341 | Train AUC: 0.4978 | Test Loss: 1.1474 | Test AUC: 0.4954
# Epoch 004 | Train Loss: 1.1390 | Train AUC: 0.4773 | Test Loss: 1.1451 | Test AUC: 0.5018
# Epoch 005 | Train Loss: 1.1161 | Train AUC: 0.4981 | Test Loss: 1.1422 | Test AUC: 0.5096
# Epoch 006 | Train Loss: 1.1212 | Train AUC: 0.5054 | Test Loss: 1.1429 | Test AUC: 0.5113
# Epoch 007 | Train Loss: 1.0935 | Train AUC: 0.4972 | Test Loss: 1.1330 | Test AUC: 0.5168
# Epoch 008 | Train Loss: 1.0847 | Train AUC: 0.5195 | Test Loss: 1.1052 | Test AUC: 0.5235
# Epoch 009 | Train Loss: 1.0752 | Train AUC: 0.5542 | Test Loss: 1.0983 | Test AUC: 0.5254
# Epoch 010 | Train Loss: 1.0687 | Train AUC: 0.5434 | Test Loss: 1.0964 | Test AUC: 0.5104
# Epoch 011 | Train Loss: 1.0753 | Train AUC: 0.5487 | Test Loss: 1.0902 | Test AUC: 0.5169
# Epoch 012 | Train Loss: 1.0638 | Train AUC: 0.5495 | Test Loss: 1.0949 | Test AUC: 0.5321
# Epoch 013 | Train Loss: 1.0830 | Train AUC: 0.4923 | Test Loss: 1.0702 | Test AUC: 0.5338
# Epoch 014 | Train Loss: 1.0489 | Train AUC: 0.5665 | Test Loss: 1.0839 | Test AUC: 0.5483
# Epoch 015 | Train Loss: 1.0552 | Train AUC: 0.5694 | Test Loss: 1.0771 | Test AUC: 0.5428
# Epoch 016 | Train Loss: 1.0534 | Train AUC: 0.5409 | Test Loss: 1.0741 | Test AUC: 0.5498
# Epoch 017 | Train Loss: 1.0653 | Train AUC: 0.5454 | Test Loss: 1.0662 | Test AUC: 0.5423
# Epoch 018 | Train Loss: 1.0395 | Train AUC: 0.5852 | Test Loss: 1.0549 | Test AUC: 0.5575
# Epoch 019 | Train Loss: 1.0504 | Train AUC: 0.5694 | Test Loss: 1.0572 | Test AUC: 0.5694
# Epoch 020 | Train Loss: 1.0331 | Train AUC: 0.5802 | Test Loss: 1.0547 | Test AUC: 0.5647
# Epoch 021 | Train Loss: 1.0395 | Train AUC: 0.5865 | Test Loss: 1.0554 | Test AUC: 0.5489
# Epoch 022 | Train Loss: 1.0453 | Train AUC: 0.5605 | Test Loss: 1.0516 | Test AUC: 0.5754
# Epoch 023 | Train Loss: 1.0316 | Train AUC: 0.5788 | Test Loss: 1.0485 | Test AUC: 0.5606
# Epoch 024 | Train Loss: 1.0294 | Train AUC: 0.5642 | Test Loss: 1.0543 | Test AUC: 0.5627
# Epoch 025 | Train Loss: 1.0057 | Train AUC: 0.6114 | Test Loss: 1.0463 | Test AUC: 0.5755
# Epoch 026 | Train Loss: 1.0207 | Train AUC: 0.5973 | Test Loss: 1.0409 | Test AUC: 0.5865
# Epoch 027 | Train Loss: 1.0222 | Train AUC: 0.5742 | Test Loss: 1.0494 | Test AUC: 0.5659
# Epoch 028 | Train Loss: 1.0171 | Train AUC: 0.5970 | Test Loss: 1.0406 | Test AUC: 0.5707
# Epoch 029 | Train Loss: 1.0180 | Train AUC: 0.5790 | Test Loss: 1.0477 | Test AUC: 0.5647
# Epoch 030 | Train Loss: 1.0226 | Train AUC: 0.5828 | Test Loss: 1.0377 | Test AUC: 0.5916
# Epoch 031 | Train Loss: 1.0115 | Train AUC: 0.6125 | Test Loss: 1.0270 | Test AUC: 0.5838
# Epoch 032 | Train Loss: 1.0115 | Train AUC: 0.6044 | Test Loss: 1.0311 | Test AUC: 0.5927
# Epoch 033 | Train Loss: 1.0186 | Train AUC: 0.5817 | Test Loss: 1.0565 | Test AUC: 0.5850
# Epoch 034 | Train Loss: 1.0102 | Train AUC: 0.5813 | Test Loss: 1.0379 | Test AUC: 0.5862
# Epoch 035 | Train Loss: 1.0042 | Train AUC: 0.6049 | Test Loss: 1.0388 | Test AUC: 0.5841
# Epoch 036 | Train Loss: 1.0175 | Train AUC: 0.5873 | Test Loss: 1.0480 | Test AUC: 0.5829
# Epoch 037 | Train Loss: 1.0035 | Train AUC: 0.5841 | Test Loss: 1.0331 | Test AUC: 0.6020
# Epoch 038 | Train Loss: 0.9982 | Train AUC: 0.6094 | Test Loss: 1.0208 | Test AUC: 0.5992
# Epoch 039 | Train Loss: 0.9994 | Train AUC: 0.5965 | Test Loss: 1.0154 | Test AUC: 0.6034
# Epoch 040 | Train Loss: 0.9980 | Train AUC: 0.6164 | Test Loss: 1.0170 | Test AUC: 0.6081
# Epoch 041 | Train Loss: 1.0052 | Train AUC: 0.5765 | Test Loss: 1.0244 | Test AUC: 0.5953
# Epoch 042 | Train Loss: 0.9908 | Train AUC: 0.6123 | Test Loss: 1.0271 | Test AUC: 0.6128
# Epoch 043 | Train Loss: 0.9880 | Train AUC: 0.6242 | Test Loss: 1.0190 | Test AUC: 0.6160
# Epoch 044 | Train Loss: 0.9831 | Train AUC: 0.6403 | Test Loss: 1.0204 | Test AUC: 0.6041
# Epoch 045 | Train Loss: 0.9839 | Train AUC: 0.6328 | Test Loss: 1.0263 | Test AUC: 0.6077
# Epoch 046 | Train Loss: 1.0024 | Train AUC: 0.5932 | Test Loss: 1.0259 | Test AUC: 0.5947
# Epoch 047 | Train Loss: 0.9841 | Train AUC: 0.6003 | Test Loss: 1.0081 | Test AUC: 0.6212
# Epoch 048 | Train Loss: 0.9821 | Train AUC: 0.6265 | Test Loss: 1.0235 | Test AUC: 0.6034
# Epoch 049 | Train Loss: 0.9844 | Train AUC: 0.6148 | Test Loss: 1.0065 | Test AUC: 0.6145
# Epoch 050 | Train Loss: 0.9803 | Train AUC: 0.6220 | Test Loss: 1.0083 | Test AUC: 0.6128
# Epoch 051 | Train Loss: 0.9907 | Train AUC: 0.5811 | Test Loss: 0.9988 | Test AUC: 0.6219
# Epoch 052 | Train Loss: 0.9762 | Train AUC: 0.6367 | Test Loss: 1.0169 | Test AUC: 0.6159
# Epoch 053 | Train Loss: 0.9837 | Train AUC: 0.6324 | Test Loss: 1.0056 | Test AUC: 0.6151
# Epoch 054 | Train Loss: 0.9767 | Train AUC: 0.6249 | Test Loss: 1.0005 | Test AUC: 0.6206
# Epoch 055 | Train Loss: 0.9872 | Train AUC: 0.6114 | Test Loss: 0.9929 | Test AUC: 0.6286
# Epoch 056 | Train Loss: 0.9790 | Train AUC: 0.6095 | Test Loss: 1.0088 | Test AUC: 0.6220
# Epoch 057 | Train Loss: 0.9806 | Train AUC: 0.6147 | Test Loss: 1.0304 | Test AUC: 0.5964
# Epoch 058 | Train Loss: 0.9738 | Train AUC: 0.6483 | Test Loss: 0.9991 | Test AUC: 0.6144
# Epoch 059 | Train Loss: 0.9635 | Train AUC: 0.6294 | Test Loss: 1.0123 | Test AUC: 0.6138
# Epoch 060 | Train Loss: 0.9622 | Train AUC: 0.6327 | Test Loss: 0.9918 | Test AUC: 0.6283
# Epoch 061 | Train Loss: 0.9766 | Train AUC: 0.6183 | Test Loss: 0.9891 | Test AUC: 0.6269
# Epoch 062 | Train Loss: 0.9852 | Train AUC: 0.6187 | Test Loss: 0.9868 | Test AUC: 0.6294
# Epoch 063 | Train Loss: 0.9782 | Train AUC: 0.6014 | Test Loss: 0.9811 | Test AUC: 0.6277
# Epoch 064 | Train Loss: 0.9686 | Train AUC: 0.6256 | Test Loss: 0.9869 | Test AUC: 0.6246
# Epoch 065 | Train Loss: 0.9702 | Train AUC: 0.6209 | Test Loss: 0.9851 | Test AUC: 0.6269
# Epoch 066 | Train Loss: 0.9626 | Train AUC: 0.6335 | Test Loss: 0.9865 | Test AUC: 0.6227
# Epoch 067 | Train Loss: 0.9701 | Train AUC: 0.6179 | Test Loss: 0.9936 | Test AUC: 0.6156
# Epoch 068 | Train Loss: 0.9646 | Train AUC: 0.6328 | Test Loss: 0.9896 | Test AUC: 0.6312
# Epoch 069 | Train Loss: 0.9623 | Train AUC: 0.6321 | Test Loss: 0.9828 | Test AUC: 0.6299
# Epoch 070 | Train Loss: 0.9672 | Train AUC: 0.6254 | Test Loss: 0.9854 | Test AUC: 0.6263
# Epoch 071 | Train Loss: 0.9529 | Train AUC: 0.6338 | Test Loss: 0.9796 | Test AUC: 0.6287
# Epoch 072 | Train Loss: 0.9721 | Train AUC: 0.6184 | Test Loss: 0.9901 | Test AUC: 0.6274
# Epoch 073 | Train Loss: 0.9652 | Train AUC: 0.6247 | Test Loss: 0.9893 | Test AUC: 0.6283
# Epoch 074 | Train Loss: 0.9585 | Train AUC: 0.6214 | Test Loss: 0.9751 | Test AUC: 0.6304
# Epoch 075 | Train Loss: 0.9789 | Train AUC: 0.5907 | Test Loss: 0.9862 | Test AUC: 0.6188
# Epoch 076 | Train Loss: 0.9606 | Train AUC: 0.6090 | Test Loss: 0.9911 | Test AUC: 0.6246
# Epoch 077 | Train Loss: 0.9785 | Train AUC: 0.5997 | Test Loss: 0.9792 | Test AUC: 0.6275
# Epoch 078 | Train Loss: 0.9655 | Train AUC: 0.6240 | Test Loss: 0.9869 | Test AUC: 0.6240
# Epoch 079 | Train Loss: 0.9595 | Train AUC: 0.6164 | Test Loss: 0.9895 | Test AUC: 0.6266
# Epoch 080 | Train Loss: 0.9616 | Train AUC: 0.6256 | Test Loss: 0.9809 | Test AUC: 0.6262
# Epoch 081 | Train Loss: 0.9464 | Train AUC: 0.6414 | Test Loss: 0.9969 | Test AUC: 0.6223
# Epoch 082 | Train Loss: 0.9575 | Train AUC: 0.6383 | Test Loss: 0.9982 | Test AUC: 0.6234
# Epoch 083 | Train Loss: 0.9605 | Train AUC: 0.6063 | Test Loss: 0.9882 | Test AUC: 0.6207
# Epoch 084 | Train Loss: 0.9490 | Train AUC: 0.6466 | Test Loss: 0.9827 | Test AUC: 0.6291
# Epoch 085 | Train Loss: 0.9583 | Train AUC: 0.6287 | Test Loss: 0.9914 | Test AUC: 0.6255
# Epoch 086 | Train Loss: 0.9288 | Train AUC: 0.6672 | Test Loss: 0.9904 | Test AUC: 0.6270
# Epoch 087 | Train Loss: 0.9613 | Train AUC: 0.6340 | Test Loss: 0.9766 | Test AUC: 0.6273
# Epoch 088 | Train Loss: 0.9634 | Train AUC: 0.6272 | Test Loss: 0.9652 | Test AUC: 0.6305
# Epoch 089 | Train Loss: 0.9530 | Train AUC: 0.6137 | Test Loss: 0.9744 | Test AUC: 0.6286
# Epoch 090 | Train Loss: 0.9540 | Train AUC: 0.6322 | Test Loss: 0.9844 | Test AUC: 0.6289
# Epoch 091 | Train Loss: 0.9535 | Train AUC: 0.6428 | Test Loss: 0.9653 | Test AUC: 0.6312
# Epoch 092 | Train Loss: 0.9424 | Train AUC: 0.6615 | Test Loss: 0.9688 | Test AUC: 0.6295
# Epoch 093 | Train Loss: 0.9605 | Train AUC: 0.6104 | Test Loss: 0.9707 | Test AUC: 0.6287
# Epoch 094 | Train Loss: 0.9492 | Train AUC: 0.6321 | Test Loss: 0.9793 | Test AUC: 0.6276
# Epoch 095 | Train Loss: 0.9440 | Train AUC: 0.6386 | Test Loss: 0.9904 | Test AUC: 0.6244
# Epoch 096 | Train Loss: 0.9548 | Train AUC: 0.6310 | Test Loss: 0.9802 | Test AUC: 0.6300
# Epoch 097 | Train Loss: 0.9467 | Train AUC: 0.6420 | Test Loss: 0.9640 | Test AUC: 0.6302
# Epoch 098 | Train Loss: 0.9394 | Train AUC: 0.6366 | Test Loss: 0.9746 | Test AUC: 0.6280
# Epoch 099 | Train Loss: 0.9502 | Train AUC: 0.6505 | Test Loss: 0.9679 | Test AUC: 0.6300
# Epoch 100 | Train Loss: 0.9415 | Train AUC: 0.6519 | Test Loss: 0.9805 | Test AUC: 0.6278
# Epoch 101 | Train Loss: 0.9521 | Train AUC: 0.6208 | Test Loss: 0.9722 | Test AUC: 0.6257
# Epoch 102 | Train Loss: 0.9413 | Train AUC: 0.6496 | Test Loss: 0.9692 | Test AUC: 0.6305
# Epoch 103 | Train Loss: 0.9387 | Train AUC: 0.6546 | Test Loss: 0.9785 | Test AUC: 0.6256
# Epoch 104 | Train Loss: 0.9586 | Train AUC: 0.6009 | Test Loss: 0.9595 | Test AUC: 0.6311
# Epoch 105 | Train Loss: 0.9425 | Train AUC: 0.6186 | Test Loss: 0.9636 | Test AUC: 0.6302
# Epoch 106 | Train Loss: 0.9505 | Train AUC: 0.6514 | Test Loss: 0.9696 | Test AUC: 0.6296
# Epoch 107 | Train Loss: 0.9530 | Train AUC: 0.6233 | Test Loss: 0.9824 | Test AUC: 0.6294
# Epoch 108 | Train Loss: 0.9220 | Train AUC: 0.6707 | Test Loss: 0.9866 | Test AUC: 0.6273
# Epoch 109 | Train Loss: 0.9251 | Train AUC: 0.6617 | Test Loss: 0.9654 | Test AUC: 0.6242
# Epoch 110 | Train Loss: 0.9562 | Train AUC: 0.5919 | Test Loss: 0.9772 | Test AUC: 0.6260
# Epoch 111 | Train Loss: 0.9557 | Train AUC: 0.6265 | Test Loss: 0.9808 | Test AUC: 0.6303
# Epoch 112 | Train Loss: 0.9269 | Train AUC: 0.6552 | Test Loss: 0.9636 | Test AUC: 0.6293
# Epoch 113 | Train Loss: 0.9446 | Train AUC: 0.6352 | Test Loss: 0.9651 | Test AUC: 0.6303
# Epoch 114 | Train Loss: 0.9486 | Train AUC: 0.6294 | Test Loss: 0.9650 | Test AUC: 0.6291
# Epoch 115 | Train Loss: 0.9284 | Train AUC: 0.6402 | Test Loss: 0.9686 | Test AUC: 0.6262
# Epoch 116 | Train Loss: 0.9531 | Train AUC: 0.6222 | Test Loss: 0.9595 | Test AUC: 0.6295
# Epoch 117 | Train Loss: 0.9390 | Train AUC: 0.6411 | Test Loss: 0.9758 | Test AUC: 0.6304
# Epoch 118 | Train Loss: 0.9653 | Train AUC: 0.6048 | Test Loss: 0.9619 | Test AUC: 0.6281
# Epoch 119 | Train Loss: 0.9258 | Train AUC: 0.6494 | Test Loss: 0.9642 | Test AUC: 0.6269
# Epoch 120 | Train Loss: 0.9440 | Train AUC: 0.6435 | Test Loss: 0.9519 | Test AUC: 0.6339
# Epoch 121 | Train Loss: 0.9370 | Train AUC: 0.6469 | Test Loss: 0.9604 | Test AUC: 0.6297
# Epoch 122 | Train Loss: 0.9376 | Train AUC: 0.6310 | Test Loss: 0.9602 | Test AUC: 0.6317
# Epoch 123 | Train Loss: 0.9209 | Train AUC: 0.6684 | Test Loss: 0.9594 | Test AUC: 0.6316
# Epoch 124 | Train Loss: 0.9393 | Train AUC: 0.6376 | Test Loss: 0.9729 | Test AUC: 0.6308

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
# 获取预测类别
preds = np.argmax(all_probs, axis=1)
# 计算指标
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro') 
recall = recall_score(all_labels, preds, average='macro')       
f1 = f1_score(all_labels, preds, average='macro')               
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')  
print("\n=== Final Test Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Test Metrics ===
# Accuracy:  0.5723
# Precision: 0.3255
# Recall:    0.3652
# F1 Score:  0.3075
# AUC-ROC:   0.6792
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("Train and Test AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("Train and Test Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
def evaluate_model():
    model.eval()
    all_preds, all_probs, all_labels = [], [], []
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.softmax(outputs, dim=1)
            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    all_probs = np.array(all_probs)
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=['NC', 'MCI', 'AD']))
    print("Confusion Matrix:")
    print(confusion_matrix(all_labels, all_preds))
    auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')  # 使用 'ovr' 或 'ovo'
    print(f"AUC Score (Ovr): {auc:.4f}")

evaluate_model()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           NC       0.50      0.05      0.09        40
#          MCI       0.57      0.98      0.72        89
#           AD       0.00      0.00      0.00        28
#
#     accuracy                           0.57       157
#    macro avg       0.36      0.34      0.27       157
# weighted avg       0.45      0.57      0.43       157
#
# Confusion Matrix:
# [[ 2 38  0]
#  [ 1 87  1]
#  [ 1 27  0]]
# AUC Score (Ovr): 0.6241
