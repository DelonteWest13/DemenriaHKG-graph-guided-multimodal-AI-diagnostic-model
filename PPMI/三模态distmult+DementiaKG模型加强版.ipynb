# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
import json
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,TransEModel,KGMultiModalTransformer,EnhancedKGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_prodromal=[]
data_swedd=[]
data_control=[]
data_PD = []
count_control = 0
count_PD = 0
count_swedd = 0
count_prodromal = 0
with open('PD1.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'PD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_PD=count_PD+1
            data_PD.append(row)
            
with open('control.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'Control/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_control=count_control+1
            data_control.append(row)
            
with open('swedd.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'SWEDD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_swedd=count_swedd+1
            data_swedd.append(row)

with open('prodromal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'Prodromal/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_prodromal=count_prodromal+1
            data_prodromal.append(row)
print(count_PD) 
print(count_control) 
print(count_swedd) 
print(count_prodromal)
# Out:
# 125
# 132
# 72
# 80

# %%
PD_arrays=[]
replace_dict = {'F': '0','M':'1','Normal':'0','Slight':'1','Mild':'2','Moderate':'3','Severe':'4','T1-anatomical':'1','Processed':'1', 
               'BL':'0','V04':'1','V06':'2','V06':'3','V08':'4','V10':'5','NiFTI':'1','':'0','No':'0','Yes':'1','Stage 1':'1','Stage 2':'2','Stage 3':'3','Stage 4':'4'
               ,'On':'1','Off':'0','Stage 0':'0'}
for i in data_PD:
    j= i[21:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    PD_array = np.array(num_list)
    PD_arrays.append(PD_array)
PD_array = np.vstack(PD_arrays)

control_arrays = []
for i in data_control:
    j = i[21:]
    j = [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    control_array = np.array(num_list)
    control_arrays.append(control_array)
control_array = np.vstack(control_arrays)

swedd_arrays = []
for i in data_swedd:
    j = i[21:]
    j = [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    swedd_array = np.array(num_list)
    swedd_arrays.append(swedd_array)
swedd_array = np.vstack(swedd_arrays)

prodromal_arrays = []
for i in data_prodromal:
    j = i[21:]
    j = [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    prodromal_array = np.array(num_list)
    prodromal_arrays.append(prodromal_array)
prodromal_array = np.vstack(prodromal_arrays)

#加权算值
def weighted_sum(tensor):
    weights = [0.1, 0.3, 0.5 , 0.7]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
pd_tensor = torch.from_numpy(PD_array).float()
control_tensor = torch.from_numpy(control_array).float()
swedd_tensor = torch.from_numpy(swedd_array).float()
prodromal_tensor = torch.from_numpy(prodromal_array).float()

pd_labels = torch.zeros(pd_tensor.shape[0], dtype=torch.long)
control_labels = torch.ones(control_tensor.shape[0], dtype=torch.long)
swedd_labels = torch.full((swedd_tensor.shape[0],), 3, dtype=torch.long)
prodromal_labels = torch.full((prodromal_tensor.shape[0],), 2, dtype=torch.long)

X = torch.cat([pd_tensor, control_tensor, swedd_tensor,prodromal_tensor], dim=0)
y = torch.cat([pd_labels , control_labels  ,swedd_labels, prodromal_labels], dim=0)

dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
model = NeuralNet(embedding=64)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 50
for epoch in range(num_epochs):
    for inputs, labels in dataloader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
        
with torch.no_grad():
    pd_tensor = model(pd_tensor)
    control_tensor = model(control_tensor)
    swedd_tensor = model(swedd_tensor)
    prodromal_tensor = model(prodromal_tensor)
    
pd_tensor = weighted_sum(pd_tensor)
control_tensor = weighted_sum(control_tensor)
swedd_tensor = weighted_sum(swedd_tensor)
prodromal_tensor = weighted_sum(prodromal_tensor)
# Out:
# Epoch [10/50], Loss: 1.2108
# Epoch [20/50], Loss: 0.6591
# Epoch [30/50], Loss: 0.6653
# Epoch [40/50], Loss: 0.4815
# Epoch [50/50], Loss: 0.3557

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        row = [replace_dict.get(item, item) for item in row]
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[4:22])
    return np.array(processed_data)
# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
pd_data = preprocess_data(data_PD, replace_dict)
control_data = preprocess_data(data_control, replace_dict)
swedd_data = preprocess_data(data_swedd, replace_dict)
prodromal_data = preprocess_data(data_prodromal, replace_dict)

categorical_indices = [2, 3, 4, 5]  # gender, education, hispanic, race, apoe
pd_EHR = encode_categorical(pd_data, categorical_indices)
control_EHR = encode_categorical(control_data, categorical_indices)
swedd_EHR = encode_categorical(swedd_data, categorical_indices)
prodromal_EHR = encode_categorical(prodromal_data, categorical_indices)

pd_EHR = torch.from_numpy(pd_EHR).float()
control_EHR = torch.from_numpy(control_EHR).float()
swedd_EHR = torch.from_numpy(swedd_EHR).float()
prodromal_EHR = torch.from_numpy(prodromal_EHR).float()

linear_layer = nn.Linear(18, 16)
control_EHR = linear_layer(control_EHR)
pd_EHR = linear_layer(pd_EHR)
swedd_EHR = linear_layer(swedd_EHR)
prodromal_EHR = linear_layer(prodromal_EHR)

linear_layer = nn.Linear(16, 1)
control_EHR = linear_layer(control_EHR)
pd_EHR = linear_layer(pd_EHR)
swedd_EHR = linear_layer(swedd_EHR)
prodromal_EHR = linear_layer(prodromal_EHR)

print('pd.EHR--->', pd_EHR.shape)
print('control.EHR--->', control_EHR.shape)
print('swedd.EHR--->', swedd_EHR.shape)
print('prodromal.EHR--->', prodromal_EHR.shape)
# Out:
# pd.EHR---> torch.Size([125, 1])
# control.EHR---> torch.Size([132, 1])
# swedd.EHR---> torch.Size([72, 1])
# prodromal.EHR---> torch.Size([80, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def center_crop_3d(tensor, size):
    depth, height, width = tensor.shape
    target_depth, target_height, target_width = size

    start_depth = (depth - target_depth) // 2
    start_height = (height - target_height) // 2
    start_width = (width - target_width) // 2

    end_depth = start_depth + target_depth
    end_height = start_height + target_height
    end_width = start_width + target_width

    return tensor[start_depth:end_depth, start_height:end_height, start_width:end_width]

# %%
import os
import torch
from torch.utils.data import DataLoader, Dataset
import nibabel as nib

# 你的 NiiDataset，务必用这版
class NiiDataset(Dataset):
    def __init__(self, file_list_or_folder):
        if isinstance(file_list_or_folder, list):
            self.file_list = file_list_or_folder
        elif isinstance(file_list_or_folder, str):
            folder_path = file_list_or_folder
            self.file_list = [os.path.join(folder_path, filename)
                              for filename in os.listdir(folder_path)
                              if filename.endswith('.nii') or filename.endswith('.nii.gz')]
        else:
            raise ValueError("参数应为list或str")
    def __len__(self):
        return len(self.file_list)
    def __getitem__(self, idx):
        file_path = self.file_list[idx]
        img = nib.load(file_path)
        img_data = img.get_fdata()
        img_tensor = torch.from_numpy(img_data).float()
        cropped_tensor = center_crop_3d(img_tensor, (64, 64, 64))   # 你的裁剪函数
        input_tensor = cropped_tensor.unsqueeze(0)
        return input_tensor

# 1. 严格用csv顺序生成影像路径
pd_img_paths = [os.path.join('PD', row[1]) for row in data_PD if os.path.exists(os.path.join('PD', row[1]))]
control_img_paths = [os.path.join('Control', row[1]) for row in data_control if os.path.exists(os.path.join('Control', row[1]))]
swedd_img_paths = [os.path.join('SWEDD', row[1]) for row in data_swedd if os.path.exists(os.path.join('SWEDD', row[1]))]
prodromal_img_paths = [os.path.join('Prodromal', row[1]) for row in data_prodromal if os.path.exists(os.path.join('Prodromal', row[1]))]

print(f'PD影像数量: {len(pd_img_paths)}')
print(f'Control影像数量: {len(control_img_paths)}')
print(f'SWEDD影像数量: {len(swedd_img_paths)}')
print(f'Prodromal影像数量: {len(prodromal_img_paths)}')

batch_size = 16
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
nii = CNN_3D(num_class=1)
nii = nii.to(device)

# 2. 用于影像特征提取
# PD组
dataset = NiiDataset(pd_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
PD_output = torch.cat(all_outputs, dim=0)
print('PD nii shape--->', PD_output.shape)

# Control组
dataset = NiiDataset(control_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
control_output = torch.cat(all_outputs, dim=0)
print('control nii shape--->', control_output.shape)

# Prodromal组
dataset = NiiDataset(prodromal_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
prodromal_output = torch.cat(all_outputs, dim=0)
print('prodromal nii shape--->', prodromal_output.shape)

# SWEDD组
dataset = NiiDataset(swedd_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
swedd_output = torch.cat(all_outputs, dim=0)
print('swedd nii shape--->', swedd_output.shape)
# Out:
# PD影像数量: 125
# Control影像数量: 132
# SWEDD影像数量: 72
# Prodromal影像数量: 80
# PD nii shape---> torch.Size([125, 1])
# control nii shape---> torch.Size([132, 1])
# prodromal nii shape---> torch.Size([80, 1])
# swedd nii shape---> torch.Size([72, 1])

# %%
# ===== 读取 DementiaKG (128维) 实体向量 =====
pd_df        = pd.read_csv('PD1.csv')
control_df   = pd.read_csv('control.csv')
prodromal_df = pd.read_csv('prodromal.csv')
swedd_df     = pd.read_csv('swedd.csv')

# 1. 修改文件名 (请确保你的 128维 npy 文件名是正确的，这里假设叫 ppmi_kg_embeddings.npy)
ENTITY_EMB_NPY = "ppmi_kg_embeddings.npy"  # <--- 修改这里：你的128维向量文件
ENTITY2ID_JSON  = "ppmi_kg_entity2id.json"  # <--- 修改这里：构建脚本生成的json文件

# 2. 修改读取映射表的逻辑 (从 TXT 改为 JSON)
print(f"正在加载映射表: {ENTITY2ID_JSON} ...")
with open(ENTITY2ID_JSON, "r", encoding="utf-8") as f:
    entity2id = json.load(f)  # 直接用 json.load 读取

# 3. 加载实体嵌入矩阵
# 注意：这里加载后的 shape 应该是 [N, 128]
entity_embeddings = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
print(f"KG Embeddings Shape: {entity_embeddings.shape}") # 打印确认一下是不是 (N, 128)

# 4. 把 id (int) 映射到 行号 (index)
# 新构建脚本生成的 json value 已经是 int 类型的 ID 了，通常不需要再转换，但为了保险起见保持逻辑：
# 如果 json 里 value 是 0, 1, 2... 这种连续整数，其实 id_to_index 就是 value 本身。
# 但为了兼容你的 DistMultExtract 类，我们保留 id_to_index 字典。
id_to_index = {str(v): v for k, v in entity2id.items()} 

# 5. DistMultExtract 类 (保持不变)
class DistMultExtract:
    def __init__(self, entity_embeddings, entity2id, id_to_index):
        self.entity_embeddings = entity_embeddings
        self.entity2id = entity2id
        self.id_to_index = id_to_index

    def get_entity_embedding(self, entity):
        # 这里的 entity 是 csv 里的症状字符串 (如 "Tremor")
        # 新构建脚本生成的 entity2id 里的 key 应该是 "PrimeKG:Tremor" 或 "Tremor" (取决于构建脚本)
        # 根据 build_ppmi_DementiaKG.ipynb 的输出，key 可能是 "PrimeKG:Tremor"
        # 所以这里可能需要加一个前缀尝试
        
        target_key = entity
        # 尝试直接查找
        if target_key in self.entity2id:
            pass
        # 尝试加前缀查找 (构建脚本里加了 PrimeKG: 前缀)
        elif f"PrimeKG:{entity}" in self.entity2id:
            target_key = f"PrimeKG:{entity}"
        elif f"Concept:{entity}" in self.entity2id:
            target_key = f"Concept:{entity}"
            
        if target_key in self.entity2id:
            ent_id = self.entity2id[target_key]
            # 如果 ent_id 已经是 int，直接用；如果是 str，转 int
            row_idx = int(ent_id) 
            return self.entity_embeddings[row_idx]
        else:
            # 找不到就返回 0 向量或者跳过，这里为了防止报错，可以打印一下
            # raise KeyError(f"Entity {entity} not found...") 
            return torch.zeros(entity_embeddings.shape[1]) # 返回全0向量兜底

# 6. 初始化提取器
kg_extractor = DistMultExtract(entity_embeddings, entity2id, id_to_index)

# 7. get_embeddings 函数 (保持不变)
def get_embeddings(df, extractor, nii_folder):
    embeddings_list = []
    skipped_rows = 0
    for _, row in df.iterrows():
        nii_file = row.iloc[1]
        nii_path = os.path.join(nii_folder, nii_file)
        if not os.path.exists(nii_path):
            skipped_rows += 1
            continue
        row_embeddings = []
        # 遍历症状列
        for col in df.columns[7:]:
            entity = str(row[col])
            # 过滤掉无意义的值
            if entity != '0' and entity != 'nan' and entity != '':
                emb = extractor.get_entity_embedding(entity)
                if not torch.equal(emb, torch.zeros(entity_embeddings.shape[1])): # 只要不是全0兜底
                    row_embeddings.append(emb)
        
        # 你的逻辑里好像把 Subject ID 也作为实体去查了？
        # 如果新 KG 里有 Patient:XXXX 节点，可以保留下面这段：
        filename = f"Patient:{int(row['Subject'])}" # 新格式通常有 Patient: 前缀
        emb_subj = extractor.get_entity_embedding(filename)
        if not torch.equal(emb_subj, torch.zeros(entity_embeddings.shape[1])):
             row_embeddings.append(emb_subj)

        if row_embeddings:
            mean_embedding = torch.stack(row_embeddings).mean(dim=0)
            embeddings_list.append(mean_embedding)
        else:
            # 如果没有找到任何症状，补一个全0
            embeddings_list.append(torch.zeros(entity_embeddings.shape[1]))
            
    if not embeddings_list:
        return torch.empty((0, entity_embeddings.shape[1]))
    return torch.stack(embeddings_list)

# 8. 获取嵌入
# 注意：这里会花一点时间
pd_transe        = get_embeddings(pd_df,        kg_extractor, 'PD')
control_transe   = get_embeddings(control_df,   kg_extractor, 'Control')
prodromal_transe = get_embeddings(prodromal_df, kg_extractor, 'Prodromal')
swedd_transe     = get_embeddings(swedd_df,     kg_extractor, 'SWEDD')

print(pd_transe.shape, control_transe.shape, prodromal_transe.shape, swedd_transe.shape)
# 预期输出: (125, 128) ... 也就是第二维应该是 128
# Out:
# 正在加载映射表: ppmi_kg_entity2id.json ...
# KG Embeddings Shape: torch.Size([1079, 128])
# torch.Size([125, 128]) torch.Size([132, 128]) torch.Size([80, 128]) torch.Size([72, 128])

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
# ------- 重新拼接特征 + 构造 DataLoader ------- #
transe_embed_dim = 128   # DistMult 嵌入维度

X_pd = torch.cat([pd_EHR, PD_output.cpu(), pd_tensor, pd_transe], dim=1)
X_control = torch.cat([control_EHR, control_output.cpu(), control_tensor, control_transe], dim=1)
X_swedd = torch.cat([swedd_EHR, swedd_output.cpu(), swedd_tensor, swedd_transe], dim=1)
X_prodromal = torch.cat([prodromal_EHR, prodromal_output.cpu(), prodromal_tensor, prodromal_transe], dim=1)

y_pd = torch.zeros(len(X_pd))          # 标签顺序 PD=0
y_control = torch.ones(len(X_control)) # Control=1
y_swedd = torch.full((len(X_swedd),), 2)
y_prodromal = torch.full((len(X_prodromal),), 3)

X = torch.cat([X_pd[:120], X_control, X_prodromal, X_swedd], dim=0).float()
y = torch.cat([y_pd[:120], y_control, y_prodromal, y_swedd], dim=0).float()

features = X[:, :-transe_embed_dim]
kg_embed = X[:, -transe_embed_dim:]





from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, kg_train, kg_test = train_test_split(
    features.detach().cpu().numpy(),          # ←★ 改这里
    y.cpu().numpy(),
    kg_embed.detach().cpu().numpy(),          # ←★ 以及这里
    test_size=0.20, stratify=y.cpu().numpy(), random_state=32
)

X_train, X_val, y_train, y_val, kg_train, kg_val = train_test_split(
    X_train, y_train, kg_train,
    test_size=0.20, stratify=y_train, random_state=30
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)
kg_train_tensor = torch.FloatTensor(kg_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
kg_val_tensor = torch.FloatTensor(kg_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
kg_test_tensor = torch.FloatTensor(kg_test).to(device)

from torch.utils.data import TensorDataset, DataLoader
batch_size = 32
train_dataset = TensorDataset(X_train_tensor, kg_train_tensor, y_train_tensor)
val_dataset   = TensorDataset(X_val_tensor,   kg_val_tensor, y_val_tensor)
test_dataset  = TensorDataset(X_test_tensor,  kg_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size)
print("DataLoaders ready:", len(train_loader), len(val_loader), len(test_loader))
# ------------------------------------------- #
# Out:
# DataLoaders ready: 9 3 3

# %%
"""
class EnhancedKGMultiModalTransformer(nn.Module):
    def __init__(self, embed_dim=128, num_heads=4, num_layers=2, transe_embed_dim=128):
        super().__init__()
        
        # 1. 基础模态编码器
        self.ehr_encoder = nn.Sequential(nn.Linear(1, embed_dim), nn.ReLU())
        self.img_encoder = nn.Sequential(nn.Linear(1, embed_dim), nn.ReLU())
        self.bio_encoder = nn.Sequential(nn.Linear(1, embed_dim), nn.ReLU())

        # 2. KG 投影层 (保持 MLP，但 Drop 狠一点)
        self.transe_proj = nn.Sequential(
            nn.Linear(transe_embed_dim, embed_dim * 2),# 升维：将特征投影到更高维流形
            nn.BatchNorm1d(embed_dim * 2),# 归一化：稳定分布
            nn.GELU(),# 激活：引入非线性，GELU比ReLU更平滑
            nn.Dropout(0.7),             # 正则化：高强度Dropout防止记忆特定知识条目
            nn.Linear(embed_dim * 2, embed_dim)# 降维：压缩至目标维度
        )

        self.bio_q = nn.Linear(embed_dim, embed_dim)
        self.bio_k = nn.Linear(embed_dim, embed_dim)
        self.bio_v = nn.Linear(embed_dim, embed_dim)
        self.ehr_q = nn.Linear(embed_dim, embed_dim)
        self.ehr_k = nn.Linear(embed_dim, embed_dim)
        self.ehr_v = nn.Linear(embed_dim, embed_dim)
        self.img_q = nn.Linear(embed_dim, embed_dim)
        self.img_k = nn.Linear(embed_dim, embed_dim)
        self.img_v = nn.Linear(embed_dim, embed_dim)

        self.cross_attention = nn.MultiheadAttention(
            embed_dim=embed_dim,
            num_heads=num_heads,
            batch_first=True,
            dropout=0.6 # <--- 改为 0.4 (原0.2)
        )

        self.ab_proj = nn.Sequential(
            nn.Linear(4 * embed_dim, 2 * embed_dim),# 第一级压缩：保留主要交互模式
            nn.GELU(),
            nn.Linear(2 * embed_dim, embed_dim)# 第二级压缩：映射至目标空间S
        )

        self.final_norm = nn.LayerNorm(embed_dim * 3)

        # 融合分类层
        self.fusion = nn.Sequential(
            nn.Linear(embed_dim * 3, 64), 
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Dropout(0.7), # <--- 改为 0.5 (原0.3)
            nn.Linear(64, 4)
        )

    def forward(self, x, transe_embed):
        # ... (前向传播代码完全不变，直接复制之前的即可) ...
        ehr = x[:, 0].unsqueeze(1)
        img = x[:, 1].unsqueeze(1)
        bio = x[:, 2].unsqueeze(1)
        ehr_feat = self.ehr_encoder(ehr).unsqueeze(1)
        img_feat = self.img_encoder(img).unsqueeze(1)
        bio_feat = self.bio_encoder(bio).unsqueeze(1)
        transe_feat = self.transe_proj(transe_embed).unsqueeze(1) 
        bio_feat = torch.cat([bio_feat, transe_feat], dim=1)
        ehr_feat = torch.cat([ehr_feat, transe_feat], dim=1)
        img_feat = torch.cat([img_feat, transe_feat], dim=1)
        Qa = self.bio_q(bio_feat); Ka = self.bio_k(bio_feat); Va = self.bio_v(bio_feat)
        Qb = self.ehr_q(ehr_feat); Kb = self.ehr_k(ehr_feat); Vb = self.ehr_v(ehr_feat)
        Qc = self.img_q(img_feat); Kc = self.img_k(img_feat); Vc = self.img_v(img_feat)
        bio_ehr_attn, _ = self.cross_attention(query=Qa, key=Kb, value=Vb) 
        ehr_bio_attn, _ = self.cross_attention(query=Qb, key=Ka, value=Va)
        ab_combined = torch.cat([bio_ehr_attn, ehr_bio_attn], dim=1) 
        ab_combined = ab_combined.view(ab_combined.size(0), -1)      
        ab_combined = self.ab_proj(ab_combined).unsqueeze(1)         
        img_ab_attn, _ = self.cross_attention(query=Qc, key=ab_combined, value=ab_combined)
        final_input = torch.cat([ab_combined.squeeze(1), img_ab_attn.mean(dim=1), transe_feat.squeeze(1)], dim=1)
        final_input = self.final_norm(final_input)
        
        return self.fusion(final_input)
"""
# Out:
# '\nclass EnhancedKGMultiModalTransformer(nn.Module):\n    def __init__(self, embed_dim=128, num_heads=4, num_layers=2, transe_embed_dim=128):\n        super().__init__()\n        \n        # 1. 基础模态编码器\n        self.ehr_encoder = nn.Sequential(nn.Linear(1, embed_dim), nn.ReLU())\n        self.img_encoder = nn.Sequential(nn.Linear(1, embed_dim), nn.ReLU())\n        self.bio_encoder = nn.Sequential(nn.Linear(1, embed_dim), nn.ReLU())\n\n        # 2. KG 投影层 (保持 MLP，但 Drop 狠一点)\n        self.transe_proj = nn.Sequential(\n            nn.Linear(transe_embed_dim, embed_dim * 2),# 升维：将特征投影到更高维流形\n            nn.BatchNorm1d(embed_dim * 2),# 归一化：稳定分布\n            nn.GELU(),# 激活：引入非线性，GELU比ReLU更平滑\n            nn.Dropout(0.7),             # 正则化：高强度Dropout防止记忆特定知识条目\n            nn.Linear(embed_dim * 2, embed_dim)# 降维：压缩至目标维度\n        )\n\n        self.bio_q = nn.Linear(embed_dim, embed_dim)\n        self.bio_k = nn.Linear(embed_dim, embed_dim)\n        self.bio_v = nn.Linear(embed_dim, embed_dim)\n        self.ehr_q = nn.Linear(embed_dim, embed_dim)\n        self.ehr_k = nn.Linear(embed_dim, embed_dim)\n        self.ehr_v = nn.Linear(embed_dim, embed_dim)\n        self.img_q = nn.Linear(embed_dim, embed_dim)\n        self.img_k = nn.Linear(embed_dim, embed_dim)\n        self.img_v = nn.Linear(embed_dim, embed_dim)\n\n        self.cross_attention = nn.MultiheadAttention(\n            embed_dim=embed_dim,\n            num_heads=num_heads,\n            batch_first=True,\n            dropout=0.6 # <--- 改为 0.4 (原0.2)\n        )\n\n        self.ab_proj = nn.Sequential(\n            nn.Linear(4 * embed_dim, 2 * embed_dim),# 第一级压缩：保留主要交互模式\n            nn.GELU(),\n            nn.Linear(2 * embed_dim, embed_dim)# 第二级压缩：映射至目标空间S\n        )\n\n        self.final_norm = nn.LayerNorm(embed_dim * 3)\n\n        # 融合分类层\n        self.fusion = nn.Sequential(\n            nn.Linear(embed_dim * 3, 64), \n            nn.BatchNorm1d(64),\n            nn.ReLU(),\n            nn.Dropout(0.7), # <--- 改为 0.5 (原0.3)\n            nn.Linear(64, 4)\n        )\n\n    def forward(self, x, transe_embed):\n        # ... (前向传播代码完全不变，直接复制之前的即可) ...\n        ehr = x[:, 0].unsqueeze(1)\n        img = x[:, 1].unsqueeze(1)\n        bio = x[:, 2].unsqueeze(1)\n        ehr_feat = self.ehr_encoder(ehr).unsqueeze(1)\n        img_feat = self.img_encoder(img).unsqueeze(1)\n        bio_feat = self.bio_encoder(bio).unsqueeze(1)\n        transe_feat = self.transe_proj(transe_embed).unsqueeze(1) \n        bio_feat = torch.cat([bio_feat, transe_feat], dim=1)\n        ehr_feat = torch.cat([ehr_feat, transe_feat], dim=1)\n        img_feat = torch.cat([img_feat, transe_feat], dim=1)\n        Qa = self.bio_q(bio_feat); Ka = self.bio_k(bio_feat); Va = self.bio_v(bio_feat)\n        Qb = self.ehr_q(ehr_feat); Kb = self.ehr_k(ehr_feat); Vb = self.ehr_v(ehr_feat)\n        Qc = self.img_q(img_feat); Kc = self.img_k(img_feat); Vc = self.img_v(img_feat)\n        bio_ehr_attn, _ = self.cross_attention(query=Qa, key=Kb, value=Vb) \n        ehr_bio_attn, _ = self.cross_attention(query=Qb, key=Ka, value=Va)\n        ab_combined = torch.cat([bio_ehr_attn, ehr_bio_attn], dim=1) \n        ab_combined = ab_combined.view(ab_combined.size(0), -1)      \n        ab_combined = self.ab_proj(ab_combined).unsqueeze(1)         \n        img_ab_attn, _ = self.cross_attention(query=Qc, key=ab_combined, value=ab_combined)\n        final_input = torch.cat([ab_combined.squeeze(1), img_ab_attn.mean(dim=1), transe_feat.squeeze(1)], dim=1)\n        final_input = self.final_norm(final_input)\n        \n        return self.fusion(final_input)\n'

# %%
# 重新初始化模型
model = EnhancedKGMultiModalTransformer(
    embed_dim=128, 
    num_heads=4, 
    num_layers=2, 
    transe_embed_dim=128 # 名字不改省事；实际装的是 DistMult
).to(device)

# 1. 增加 weight_decay (L2 正则化)
# 这会像橡皮筋一样拉住模型的参数，不让它疯跑
optimizer = optim.Adam(model.parameters(), lr=0.0005, weight_decay=1e-4) 

# 2. 增加 label_smoothing
# 告诉模型：“别太绝对，留点余地”。这能有效防止 Train AUC 直接变成 1
criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

num_epochs=200

train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"test Loss: {test_loss:.4f}, test AUC: {test_auc:.4f}")
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/200, Train Loss: 1.4782, Train AUC: 0.5101  test Loss: 1.2041, test AUC: 0.7787
# Epoch 2/200, Train Loss: 1.3004, Train AUC: 0.6547  test Loss: 1.0126, test AUC: 0.7951
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/200, Train Loss: 1.2184, Train AUC: 0.7141  test Loss: 0.9854, test AUC: 0.8233
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 4/200, Train Loss: 1.0956, Train AUC: 0.7746  test Loss: 0.9957, test AUC: 0.8463
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 5/200, Train Loss: 1.1168, Train AUC: 0.8008  test Loss: 1.0007, test AUC: 0.8682
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 6/200, Train Loss: 1.0675, Train AUC: 0.8276  test Loss: 0.9844, test AUC: 0.8687
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 7/200, Train Loss: 1.0154, Train AUC: 0.8263  test Loss: 0.9815, test AUC: 0.8696
# Epoch 8/200, Train Loss: 1.0531, Train AUC: 0.8376  test Loss: 0.9294, test AUC: 0.8811
# Epoch 9/200, Train Loss: 0.9896, Train AUC: 0.8302  test Loss: 0.8868, test AUC: 0.8952
# Epoch 10/200, Train Loss: 0.9306, Train AUC: 0.8760  test Loss: 0.8486, test AUC: 0.9053
# Epoch 11/200, Train Loss: 0.8959, Train AUC: 0.8842  test Loss: 0.8282, test AUC: 0.9139
# Epoch 12/200, Train Loss: 0.9546, Train AUC: 0.8780  test Loss: 0.8151, test AUC: 0.9170
# Epoch 13/200, Train Loss: 0.9465, Train AUC: 0.8981  test Loss: 0.8179, test AUC: 0.9151
# Epoch 14/200, Train Loss: 0.9835, Train AUC: 0.9028  test Loss: 0.8034, test AUC: 0.9132
# Epoch 15/200, Train Loss: 0.9135, Train AUC: 0.9006  test Loss: 0.7835, test AUC: 0.9228
# Epoch 16/200, Train Loss: 0.9464, Train AUC: 0.9150  test Loss: 0.7855, test AUC: 0.9267
# Epoch 17/200, Train Loss: 0.8292, Train AUC: 0.9116  test Loss: 0.7846, test AUC: 0.9281
# Epoch 18/200, Train Loss: 0.7894, Train AUC: 0.9404  test Loss: 0.7797, test AUC: 0.9243
# Epoch 19/200, Train Loss: 0.9278, Train AUC: 0.9173  test Loss: 0.7686, test AUC: 0.9238
# Epoch 20/200, Train Loss: 0.8794, Train AUC: 0.9453  test Loss: 0.7372, test AUC: 0.9348
# Epoch 21/200, Train Loss: 0.8560, Train AUC: 0.9449  test Loss: 0.7501, test AUC: 0.9372
# Epoch 22/200, Train Loss: 0.8169, Train AUC: 0.9347  test Loss: 0.7303, test AUC: 0.9376
# Epoch 23/200, Train Loss: 0.7663, Train AUC: 0.9484  test Loss: 0.7075, test AUC: 0.9362
# Epoch 24/200, Train Loss: 0.7211, Train AUC: 0.9510  test Loss: 0.7104, test AUC: 0.9343
# Epoch 25/200, Train Loss: 0.7191, Train AUC: 0.9444  test Loss: 0.6841, test AUC: 0.9463
# Epoch 26/200, Train Loss: 0.7614, Train AUC: 0.9534  test Loss: 0.6898, test AUC: 0.9410
# Epoch 27/200, Train Loss: 0.7394, Train AUC: 0.9595  test Loss: 0.6913, test AUC: 0.9365
# Epoch 28/200, Train Loss: 0.8799, Train AUC: 0.9557  test Loss: 0.6960, test AUC: 0.9364
# Epoch 29/200, Train Loss: 0.9234, Train AUC: 0.9534  test Loss: 0.6832, test AUC: 0.9427
# Epoch 30/200, Train Loss: 0.8338, Train AUC: 0.9658  test Loss: 0.6565, test AUC: 0.9535
# Epoch 31/200, Train Loss: 0.8641, Train AUC: 0.9587  test Loss: 0.6728, test AUC: 0.9511
# Epoch 32/200, Train Loss: 0.7501, Train AUC: 0.9711  test Loss: 0.6419, test AUC: 0.9577
# Epoch 33/200, Train Loss: 0.8143, Train AUC: 0.9662  test Loss: 0.6049, test AUC: 0.9672
# Epoch 34/200, Train Loss: 0.6803, Train AUC: 0.9672  test Loss: 0.5967, test AUC: 0.9682
# Epoch 35/200, Train Loss: 0.6517, Train AUC: 0.9753  test Loss: 0.5904, test AUC: 0.9713
# Epoch 36/200, Train Loss: 0.7725, Train AUC: 0.9647  test Loss: 0.5781, test AUC: 0.9721
# Epoch 37/200, Train Loss: 0.7111, Train AUC: 0.9733  test Loss: 0.5849, test AUC: 0.9721
# Epoch 38/200, Train Loss: 0.6893, Train AUC: 0.9767  test Loss: 0.5685, test AUC: 0.9725
# Epoch 39/200, Train Loss: 0.6690, Train AUC: 0.9836  test Loss: 0.5892, test AUC: 0.9667
# Epoch 40/200, Train Loss: 0.5926, Train AUC: 0.9884  test Loss: 0.5730, test AUC: 0.9724
# Epoch 41/200, Train Loss: 0.7184, Train AUC: 0.9778  test Loss: 0.5794, test AUC: 0.9714
# Epoch 42/200, Train Loss: 0.6060, Train AUC: 0.9884  test Loss: 0.5707, test AUC: 0.9721
# Epoch 43/200, Train Loss: 0.8585, Train AUC: 0.9736  test Loss: 0.5424, test AUC: 0.9785
# Epoch 44/200, Train Loss: 0.6927, Train AUC: 0.9776  test Loss: 0.5354, test AUC: 0.9784
# Epoch 45/200, Train Loss: 0.6535, Train AUC: 0.9764  test Loss: 0.5440, test AUC: 0.9781
# Epoch 46/200, Train Loss: 0.6259, Train AUC: 0.9940  test Loss: 0.5279, test AUC: 0.9785
# Epoch 47/200, Train Loss: 0.6541, Train AUC: 0.9828  test Loss: 0.5257, test AUC: 0.9810
# Epoch 48/200, Train Loss: 0.6157, Train AUC: 0.9861  test Loss: 0.5524, test AUC: 0.9783
# Epoch 49/200, Train Loss: 0.6097, Train AUC: 0.9853  test Loss: 0.5550, test AUC: 0.9777
# Epoch 50/200, Train Loss: 0.6362, Train AUC: 0.9817  test Loss: 0.5817, test AUC: 0.9680
# Epoch 51/200, Train Loss: 0.9915, Train AUC: 0.9701  test Loss: 0.6465, test AUC: 0.9658
# Epoch 52/200, Train Loss: 0.7314, Train AUC: 0.9713  test Loss: 0.5929, test AUC: 0.9709
# Epoch 53/200, Train Loss: 0.9424, Train AUC: 0.9611  test Loss: 0.5679, test AUC: 0.9717
# Epoch 54/200, Train Loss: 0.7387, Train AUC: 0.9787  test Loss: 0.5698, test AUC: 0.9747
# Epoch 55/200, Train Loss: 0.6911, Train AUC: 0.9798  test Loss: 0.5786, test AUC: 0.9739
# Epoch 56/200, Train Loss: 0.7580, Train AUC: 0.9699  test Loss: 0.5580, test AUC: 0.9771
# Epoch 57/200, Train Loss: 0.6910, Train AUC: 0.9829  test Loss: 0.5505, test AUC: 0.9792
# Epoch 58/200, Train Loss: 0.5475, Train AUC: 0.9879  test Loss: 0.5271, test AUC: 0.9843
# Epoch 59/200, Train Loss: 0.5675, Train AUC: 0.9874  test Loss: 0.5283, test AUC: 0.9829
# Epoch 60/200, Train Loss: 0.6224, Train AUC: 0.9902  test Loss: 0.5562, test AUC: 0.9758
# Epoch 61/200, Train Loss: 0.6279, Train AUC: 0.9913  test Loss: 0.5230, test AUC: 0.9824
# Epoch 62/200, Train Loss: 0.6540, Train AUC: 0.9918  test Loss: 0.5299, test AUC: 0.9817
# Epoch 63/200, Train Loss: 0.6578, Train AUC: 0.9867  test Loss: 0.5144, test AUC: 0.9844
# Epoch 64/200, Train Loss: 0.7388, Train AUC: 0.9906  test Loss: 0.5154, test AUC: 0.9828
# Epoch 65/200, Train Loss: 0.6442, Train AUC: 0.9844  test Loss: 0.5144, test AUC: 0.9853
# Epoch 66/200, Train Loss: 0.8012, Train AUC: 0.9723  test Loss: 0.5253, test AUC: 0.9840
# Epoch 67/200, Train Loss: 0.6525, Train AUC: 0.9754  test Loss: 0.5534, test AUC: 0.9760
# Epoch 68/200, Train Loss: 0.7173, Train AUC: 0.9769  test Loss: 0.5345, test AUC: 0.9762
# Epoch 69/200, Train Loss: 0.6194, Train AUC: 0.9913  test Loss: 0.5249, test AUC: 0.9754
# Epoch 70/200, Train Loss: 0.5816, Train AUC: 0.9795  test Loss: 0.5238, test AUC: 0.9815
# Epoch 71/200, Train Loss: 0.7175, Train AUC: 0.9847  test Loss: 0.5206, test AUC: 0.9818
# Epoch 72/200, Train Loss: 0.6722, Train AUC: 0.9849  test Loss: 0.5308, test AUC: 0.9804
# Epoch 73/200, Train Loss: 0.6269, Train AUC: 0.9948  test Loss: 0.5303, test AUC: 0.9810
# Epoch 74/200, Train Loss: 0.5730, Train AUC: 0.9933  test Loss: 0.5458, test AUC: 0.9781
# Epoch 75/200, Train Loss: 0.7103, Train AUC: 0.9863  test Loss: 0.5375, test AUC: 0.9806
# Epoch 76/200, Train Loss: 0.6450, Train AUC: 0.9860  test Loss: 0.5476, test AUC: 0.9780
# Epoch 77/200, Train Loss: 0.6348, Train AUC: 0.9833  test Loss: 0.5366, test AUC: 0.9805
# Epoch 78/200, Train Loss: 0.7243, Train AUC: 0.9816  test Loss: 0.5520, test AUC: 0.9769
# Epoch 79/200, Train Loss: 0.7663, Train AUC: 0.9813  test Loss: 0.5223, test AUC: 0.9816
# Epoch 80/200, Train Loss: 0.5760, Train AUC: 0.9854  test Loss: 0.5229, test AUC: 0.9857
# Epoch 81/200, Train Loss: 0.7247, Train AUC: 0.9870  test Loss: 0.5245, test AUC: 0.9865
# Epoch 82/200, Train Loss: 0.7306, Train AUC: 0.9820  test Loss: 0.5324, test AUC: 0.9820
# Epoch 83/200, Train Loss: 0.6300, Train AUC: 0.9838  test Loss: 0.5376, test AUC: 0.9835
# Epoch 84/200, Train Loss: 0.6032, Train AUC: 0.9847  test Loss: 0.5205, test AUC: 0.9875
# Epoch 85/200, Train Loss: 0.5857, Train AUC: 0.9822  test Loss: 0.5053, test AUC: 0.9904
# Epoch 86/200, Train Loss: 0.5580, Train AUC: 0.9906  test Loss: 0.4915, test AUC: 0.9905
# Epoch 87/200, Train Loss: 0.6281, Train AUC: 0.9815  test Loss: 0.4931, test AUC: 0.9893
# Epoch 88/200, Train Loss: 0.5777, Train AUC: 0.9944  test Loss: 0.5392, test AUC: 0.9787
# Epoch 89/200, Train Loss: 0.6174, Train AUC: 0.9803  test Loss: 0.6984, test AUC: 0.9795
# Epoch 90/200, Train Loss: 0.7419, Train AUC: 0.9735  test Loss: 0.5344, test AUC: 0.9873
# Epoch 91/200, Train Loss: 0.7189, Train AUC: 0.9817  test Loss: 0.5439, test AUC: 0.9907
# Epoch 92/200, Train Loss: 0.6528, Train AUC: 0.9697  test Loss: 0.5224, test AUC: 0.9919
# Epoch 93/200, Train Loss: 0.6143, Train AUC: 0.9791  test Loss: 0.5350, test AUC: 0.9858
# Epoch 94/200, Train Loss: 0.6875, Train AUC: 0.9790  test Loss: 0.5248, test AUC: 0.9878
# Epoch 95/200, Train Loss: 0.7685, Train AUC: 0.9776  test Loss: 0.5231, test AUC: 0.9870
# Epoch 96/200, Train Loss: 0.8134, Train AUC: 0.9745  test Loss: 0.5366, test AUC: 0.9824
# Epoch 97/200, Train Loss: 0.6395, Train AUC: 0.9680  test Loss: 0.5436, test AUC: 0.9836
# Epoch 98/200, Train Loss: 0.7118, Train AUC: 0.9776  test Loss: 0.5490, test AUC: 0.9836
# Epoch 99/200, Train Loss: 0.7265, Train AUC: 0.9702  test Loss: 0.5450, test AUC: 0.9833
# Epoch 100/200, Train Loss: 0.5887, Train AUC: 0.9817  test Loss: 0.5184, test AUC: 0.9867
# Epoch 101/200, Train Loss: 0.5855, Train AUC: 0.9903  test Loss: 0.5193, test AUC: 0.9862
# Epoch 102/200, Train Loss: 0.5637, Train AUC: 0.9882  test Loss: 0.5360, test AUC: 0.9844
# Epoch 103/200, Train Loss: 0.6960, Train AUC: 0.9852  test Loss: 0.5413, test AUC: 0.9842
# Epoch 104/200, Train Loss: 0.6465, Train AUC: 0.9865  test Loss: 0.5465, test AUC: 0.9833
# Epoch 105/200, Train Loss: 0.6151, Train AUC: 0.9904  test Loss: 0.5340, test AUC: 0.9848
# Epoch 106/200, Train Loss: 0.6024, Train AUC: 0.9840  test Loss: 0.5336, test AUC: 0.9845
# Epoch 107/200, Train Loss: 0.5440, Train AUC: 0.9913  test Loss: 0.5432, test AUC: 0.9808
# Epoch 108/200, Train Loss: 0.7670, Train AUC: 0.9867  test Loss: 0.5188, test AUC: 0.9854
# Epoch 109/200, Train Loss: 0.6153, Train AUC: 0.9879  test Loss: 0.5172, test AUC: 0.9850
# Epoch 110/200, Train Loss: 0.7696, Train AUC: 0.9879  test Loss: 0.5086, test AUC: 0.9859
# Epoch 111/200, Train Loss: 0.5650, Train AUC: 0.9904  test Loss: 0.5152, test AUC: 0.9858
# Epoch 112/200, Train Loss: 0.5556, Train AUC: 0.9948  test Loss: 0.5117, test AUC: 0.9857
# Epoch 113/200, Train Loss: 0.6448, Train AUC: 0.9931  test Loss: 0.5116, test AUC: 0.9885
# Epoch 114/200, Train Loss: 0.5110, Train AUC: 0.9972  test Loss: 0.5138, test AUC: 0.9871
# Epoch 115/200, Train Loss: 0.6046, Train AUC: 0.9870  test Loss: 0.5037, test AUC: 0.9876
# Epoch 116/200, Train Loss: 0.5750, Train AUC: 0.9950  test Loss: 0.5039, test AUC: 0.9897
# Epoch 117/200, Train Loss: 0.6702, Train AUC: 0.9927  test Loss: 0.5065, test AUC: 0.9876
# Epoch 118/200, Train Loss: 0.5543, Train AUC: 0.9915  test Loss: 0.5091, test AUC: 0.9877
# Epoch 119/200, Train Loss: 0.5456, Train AUC: 0.9905  test Loss: 0.5082, test AUC: 0.9887
# Epoch 120/200, Train Loss: 0.6082, Train AUC: 0.9821  test Loss: 0.6061, test AUC: 0.9813
# Epoch 121/200, Train Loss: 0.8171, Train AUC: 0.9721  test Loss: 0.5705, test AUC: 0.9887
# Epoch 122/200, Train Loss: 0.8834, Train AUC: 0.9763  test Loss: 0.5512, test AUC: 0.9903
# Epoch 123/200, Train Loss: 0.6291, Train AUC: 0.9813  test Loss: 0.5240, test AUC: 0.9911
# Epoch 124/200, Train Loss: 0.6647, Train AUC: 0.9830  test Loss: 0.5109, test AUC: 0.9900
# Epoch 125/200, Train Loss: 0.7908, Train AUC: 0.9728  test Loss: 0.5120, test AUC: 0.9883
# Epoch 126/200, Train Loss: 0.7431, Train AUC: 0.9855  test Loss: 0.5252, test AUC: 0.9877
# Epoch 127/200, Train Loss: 0.7451, Train AUC: 0.9822  test Loss: 0.5040, test AUC: 0.9916
# Epoch 128/200, Train Loss: 0.9057, Train AUC: 0.9696  test Loss: 0.5588, test AUC: 0.9894
# Epoch 129/200, Train Loss: 0.6654, Train AUC: 0.9694  test Loss: 0.6679, test AUC: 0.9917
# Epoch 130/200, Train Loss: 0.7751, Train AUC: 0.9418  test Loss: 0.6416, test AUC: 0.9920
# Epoch 131/200, Train Loss: 0.7083, Train AUC: 0.9713  test Loss: 0.5547, test AUC: 0.9928
# Epoch 132/200, Train Loss: 0.7536, Train AUC: 0.9746  test Loss: 0.5424, test AUC: 0.9888
# Epoch 133/200, Train Loss: 0.7999, Train AUC: 0.9526  test Loss: 0.5296, test AUC: 0.9863
# Epoch 134/200, Train Loss: 0.7219, Train AUC: 0.9697  test Loss: 0.5145, test AUC: 0.9944
# Epoch 135/200, Train Loss: 0.8281, Train AUC: 0.9644  test Loss: 0.5272, test AUC: 0.9906
# Epoch 136/200, Train Loss: 0.8210, Train AUC: 0.9697  test Loss: 0.5477, test AUC: 0.9920
# Epoch 137/200, Train Loss: 0.7294, Train AUC: 0.9749  test Loss: 0.5384, test AUC: 0.9901
# Epoch 138/200, Train Loss: 0.8034, Train AUC: 0.9740  test Loss: 0.5452, test AUC: 0.9892
# Epoch 139/200, Train Loss: 0.6773, Train AUC: 0.9774  test Loss: 0.5104, test AUC: 0.9889
# Epoch 140/200, Train Loss: 0.7809, Train AUC: 0.9810  test Loss: 0.5354, test AUC: 0.9834
# Epoch 141/200, Train Loss: 0.7413, Train AUC: 0.9759  test Loss: 0.5165, test AUC: 0.9893
# Epoch 142/200, Train Loss: 0.8031, Train AUC: 0.9681  test Loss: 0.5296, test AUC: 0.9846
# Epoch 143/200, Train Loss: 0.7993, Train AUC: 0.9782  test Loss: 0.5022, test AUC: 0.9907
# Epoch 144/200, Train Loss: 0.9284, Train AUC: 0.9637  test Loss: 0.5265, test AUC: 0.9871
# Epoch 145/200, Train Loss: 0.7690, Train AUC: 0.9728  test Loss: 0.5167, test AUC: 0.9887
# Epoch 146/200, Train Loss: 0.5798, Train AUC: 0.9887  test Loss: 0.5137, test AUC: 0.9868
# Epoch 147/200, Train Loss: 0.7537, Train AUC: 0.9745  test Loss: 0.5315, test AUC: 0.9899
# Epoch 148/200, Train Loss: 0.8404, Train AUC: 0.9789  test Loss: 0.5292, test AUC: 0.9907
# Epoch 149/200, Train Loss: 0.8191, Train AUC: 0.9735  test Loss: 0.5329, test AUC: 0.9886
# Epoch 150/200, Train Loss: 0.5707, Train AUC: 0.9896  test Loss: 0.5357, test AUC: 0.9885
# Epoch 151/200, Train Loss: 0.7146, Train AUC: 0.9835  test Loss: 0.5298, test AUC: 0.9867
# Epoch 152/200, Train Loss: 0.8165, Train AUC: 0.9717  test Loss: 0.5199, test AUC: 0.9867
# Epoch 153/200, Train Loss: 0.5801, Train AUC: 0.9917  test Loss: 0.5287, test AUC: 0.9817
# Epoch 154/200, Train Loss: 0.7005, Train AUC: 0.9900  test Loss: 0.5340, test AUC: 0.9854
# Epoch 155/200, Train Loss: 0.8583, Train AUC: 0.9771  test Loss: 0.5286, test AUC: 0.9877
# Epoch 156/200, Train Loss: 0.5736, Train AUC: 0.9910  test Loss: 0.5047, test AUC: 0.9879
# Epoch 157/200, Train Loss: 0.6496, Train AUC: 0.9906  test Loss: 0.5043, test AUC: 0.9879
# Epoch 158/200, Train Loss: 0.7408, Train AUC: 0.9825  test Loss: 0.5057, test AUC: 0.9882
# Epoch 159/200, Train Loss: 0.7572, Train AUC: 0.9847  test Loss: 0.5110, test AUC: 0.9886
# Epoch 160/200, Train Loss: 0.7017, Train AUC: 0.9893  test Loss: 0.5037, test AUC: 0.9880
# Epoch 161/200, Train Loss: 0.6430, Train AUC: 0.9881  test Loss: 0.5275, test AUC: 0.9889
# Epoch 162/200, Train Loss: 0.5580, Train AUC: 0.9908  test Loss: 0.5331, test AUC: 0.9883
# Epoch 163/200, Train Loss: 0.5245, Train AUC: 0.9916  test Loss: 0.5326, test AUC: 0.9877
# Epoch 164/200, Train Loss: 0.6688, Train AUC: 0.9893  test Loss: 0.5051, test AUC: 0.9867
# Epoch 165/200, Train Loss: 0.6358, Train AUC: 0.9852  test Loss: 0.5277, test AUC: 0.9897
# Epoch 166/200, Train Loss: 0.6241, Train AUC: 0.9881  test Loss: 0.5250, test AUC: 0.9855
# Epoch 167/200, Train Loss: 0.7494, Train AUC: 0.9908  test Loss: 0.5142, test AUC: 0.9887
# Epoch 168/200, Train Loss: 0.6849, Train AUC: 0.9856  test Loss: 0.5086, test AUC: 0.9888
# Epoch 169/200, Train Loss: 0.5422, Train AUC: 0.9869  test Loss: 0.5196, test AUC: 0.9888
# Epoch 170/200, Train Loss: 0.5804, Train AUC: 0.9976  test Loss: 0.5137, test AUC: 0.9897
# Epoch 171/200, Train Loss: 0.6420, Train AUC: 0.9820  test Loss: 0.5028, test AUC: 0.9893
# Epoch 172/200, Train Loss: 0.5216, Train AUC: 0.9965  test Loss: 0.5140, test AUC: 0.9899
# Epoch 173/200, Train Loss: 0.6134, Train AUC: 0.9915  test Loss: 0.5442, test AUC: 0.9872
# Epoch 174/200, Train Loss: 0.5640, Train AUC: 0.9975  test Loss: 0.5281, test AUC: 0.9882
# Epoch 175/200, Train Loss: 0.8388, Train AUC: 0.9922  test Loss: 0.5225, test AUC: 0.9877
# Epoch 176/200, Train Loss: 0.5095, Train AUC: 0.9926  test Loss: 0.5235, test AUC: 0.9883
# Epoch 177/200, Train Loss: 0.5161, Train AUC: 0.9963  test Loss: 0.5250, test AUC: 0.9893
# Epoch 178/200, Train Loss: 0.6733, Train AUC: 0.9890  test Loss: 0.5547, test AUC: 0.9890
# Epoch 179/200, Train Loss: 0.6624, Train AUC: 0.9967  test Loss: 0.5291, test AUC: 0.9887
# Epoch 180/200, Train Loss: 0.5741, Train AUC: 0.9933  test Loss: 0.5106, test AUC: 0.9877
# Epoch 181/200, Train Loss: 0.5727, Train AUC: 0.9881  test Loss: 0.5106, test AUC: 0.9861
# Epoch 182/200, Train Loss: 0.6433, Train AUC: 0.9947  test Loss: 0.5179, test AUC: 0.9856
# Epoch 183/200, Train Loss: 0.5548, Train AUC: 0.9954  test Loss: 0.5360, test AUC: 0.9854
# Epoch 184/200, Train Loss: 0.5806, Train AUC: 0.9837  test Loss: 0.5651, test AUC: 0.9831
# Epoch 185/200, Train Loss: 0.6995, Train AUC: 0.9518  test Loss: 0.5194, test AUC: 0.9887
# Epoch 186/200, Train Loss: 0.6209, Train AUC: 0.9822  test Loss: 0.5131, test AUC: 0.9890
# Epoch 187/200, Train Loss: 0.6109, Train AUC: 0.9855  test Loss: 0.5411, test AUC: 0.9889
# Epoch 188/200, Train Loss: 0.8316, Train AUC: 0.9846  test Loss: 0.5056, test AUC: 0.9888
# Epoch 189/200, Train Loss: 0.7731, Train AUC: 0.9873  test Loss: 0.5375, test AUC: 0.9759
# Epoch 190/200, Train Loss: 0.7067, Train AUC: 0.9928  test Loss: 0.5551, test AUC: 0.9705
# Epoch 191/200, Train Loss: 0.5796, Train AUC: 0.9923  test Loss: 0.5240, test AUC: 0.9849
# Epoch 192/200, Train Loss: 0.7209, Train AUC: 0.9964  test Loss: 0.5399, test AUC: 0.9741
# Epoch 193/200, Train Loss: 0.5298, Train AUC: 0.9918  test Loss: 0.5268, test AUC: 0.9832
# Epoch 194/200, Train Loss: 0.7209, Train AUC: 0.9804  test Loss: 0.5226, test AUC: 0.9853
# Epoch 195/200, Train Loss: 0.4961, Train AUC: 0.9983  test Loss: 0.5363, test AUC: 0.9859
# Epoch 196/200, Train Loss: 0.7288, Train AUC: 0.9866  test Loss: 0.5457, test AUC: 0.9850
# Epoch 197/200, Train Loss: 0.5497, Train AUC: 0.9962  test Loss: 0.5314, test AUC: 0.9853
# Epoch 198/200, Train Loss: 0.5710, Train AUC: 0.9926  test Loss: 0.5237, test AUC: 0.9878
# Epoch 199/200, Train Loss: 0.5455, Train AUC: 0.9926  test Loss: 0.5264, test AUC: 0.9874
# Epoch 200/200, Train Loss: 0.7017, Train AUC: 0.9943  test Loss: 0.5598, test AUC: 0.9889

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.7846
# Precision: 0.7875
# Recall:    0.7671
# F1 Score:  0.7718
# AUC-ROC:   0.9403

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("PPMI AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("PPMI Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
