# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
import json
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,TransEModel,KGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_prodromal=[]
data_swedd=[]
data_control=[]
data_PD = []
count_control = 0
count_PD = 0
count_swedd = 0
count_prodromal = 0
with open('PD1.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'PD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_PD=count_PD+1
            data_PD.append(row)
            
with open('control.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'Control/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_control=count_control+1
            data_control.append(row)
            
with open('swedd.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'SWEDD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_swedd=count_swedd+1
            data_swedd.append(row)

with open('prodromal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'Prodromal/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_prodromal=count_prodromal+1
            data_prodromal.append(row)
print(count_PD) 
print(count_control) 
print(count_swedd) 
print(count_prodromal)
# Out:
# 125
# 132
# 72
# 80

# %%
PD_arrays=[]
replace_dict = {'F': '0','M':'1','Normal':'0','Slight':'1','Mild':'2','Moderate':'3','Severe':'4','T1-anatomical':'1','Processed':'1', 
               'BL':'0','V04':'1','V06':'2','V06':'3','V08':'4','V10':'5','NiFTI':'1','':'0','No':'0','Yes':'1','Stage 1':'1','Stage 2':'2','Stage 3':'3','Stage 4':'4'
               ,'On':'1','Off':'0','Stage 0':'0'}
for i in data_PD:
    j= i[21:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    PD_array = np.array(num_list)
    PD_arrays.append(PD_array)
PD_array = np.vstack(PD_arrays)

control_arrays = []
for i in data_control:
    j = i[21:]
    j = [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    control_array = np.array(num_list)
    control_arrays.append(control_array)
control_array = np.vstack(control_arrays)

swedd_arrays = []
for i in data_swedd:
    j = i[21:]
    j = [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    swedd_array = np.array(num_list)
    swedd_arrays.append(swedd_array)
swedd_array = np.vstack(swedd_arrays)

prodromal_arrays = []
for i in data_prodromal:
    j = i[21:]
    j = [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    prodromal_array = np.array(num_list)
    prodromal_arrays.append(prodromal_array)
prodromal_array = np.vstack(prodromal_arrays)

#加权算值
def weighted_sum(tensor):
    weights = [0.1, 0.3, 0.5 , 0.7]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
pd_tensor = torch.from_numpy(PD_array).float()
control_tensor = torch.from_numpy(control_array).float()
swedd_tensor = torch.from_numpy(swedd_array).float()
prodromal_tensor = torch.from_numpy(prodromal_array).float()

pd_labels = torch.zeros(pd_tensor.shape[0], dtype=torch.long)
control_labels = torch.ones(control_tensor.shape[0], dtype=torch.long)
swedd_labels = torch.full((swedd_tensor.shape[0],), 3, dtype=torch.long)
prodromal_labels = torch.full((prodromal_tensor.shape[0],), 2, dtype=torch.long)

X = torch.cat([pd_tensor, control_tensor, swedd_tensor,prodromal_tensor], dim=0)
y = torch.cat([pd_labels , control_labels  ,swedd_labels, prodromal_labels], dim=0)

dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
model = NeuralNet(embedding=64)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
num_epochs = 50
for epoch in range(num_epochs):
    for inputs, labels in dataloader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
        
with torch.no_grad():
    pd_tensor = model(pd_tensor)
    control_tensor = model(control_tensor)
    swedd_tensor = model(swedd_tensor)
    prodromal_tensor = model(prodromal_tensor)
    
pd_tensor = weighted_sum(pd_tensor)
control_tensor = weighted_sum(control_tensor)
swedd_tensor = weighted_sum(swedd_tensor)
prodromal_tensor = weighted_sum(prodromal_tensor)
# Out:
# Epoch [10/50], Loss: 0.8358
# Epoch [20/50], Loss: 0.5177
# Epoch [30/50], Loss: 0.5330
# Epoch [40/50], Loss: 0.3444
# Epoch [50/50], Loss: 0.5925

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        row = [replace_dict.get(item, item) for item in row]
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[4:22])
    return np.array(processed_data)
# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
pd_data = preprocess_data(data_PD, replace_dict)
control_data = preprocess_data(data_control, replace_dict)
swedd_data = preprocess_data(data_swedd, replace_dict)
prodromal_data = preprocess_data(data_prodromal, replace_dict)

categorical_indices = [2, 3, 4, 5]  # gender, education, hispanic, race, apoe
pd_EHR = encode_categorical(pd_data, categorical_indices)
control_EHR = encode_categorical(control_data, categorical_indices)
swedd_EHR = encode_categorical(swedd_data, categorical_indices)
prodromal_EHR = encode_categorical(prodromal_data, categorical_indices)

pd_EHR = torch.from_numpy(pd_EHR).float()
control_EHR = torch.from_numpy(control_EHR).float()
swedd_EHR = torch.from_numpy(swedd_EHR).float()
prodromal_EHR = torch.from_numpy(prodromal_EHR).float()

linear_layer = nn.Linear(18, 16)
control_EHR = linear_layer(control_EHR)
pd_EHR = linear_layer(pd_EHR)
swedd_EHR = linear_layer(swedd_EHR)
prodromal_EHR = linear_layer(prodromal_EHR)

linear_layer = nn.Linear(16, 1)
control_EHR = linear_layer(control_EHR)
pd_EHR = linear_layer(pd_EHR)
swedd_EHR = linear_layer(swedd_EHR)
prodromal_EHR = linear_layer(prodromal_EHR)

print('pd.EHR--->', pd_EHR.shape)
print('control.EHR--->', control_EHR.shape)
print('swedd.EHR--->', swedd_EHR.shape)
print('prodromal.EHR--->', prodromal_EHR.shape)
# Out:
# pd.EHR---> torch.Size([125, 1])
# control.EHR---> torch.Size([132, 1])
# swedd.EHR---> torch.Size([72, 1])
# prodromal.EHR---> torch.Size([80, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def center_crop_3d(tensor, size):
    depth, height, width = tensor.shape
    target_depth, target_height, target_width = size

    start_depth = (depth - target_depth) // 2
    start_height = (height - target_height) // 2
    start_width = (width - target_width) // 2

    end_depth = start_depth + target_depth
    end_height = start_height + target_height
    end_width = start_width + target_width

    return tensor[start_depth:end_depth, start_height:end_height, start_width:end_width]

# %%
import os
import torch
from torch.utils.data import DataLoader, Dataset
import nibabel as nib

# 你的 NiiDataset，务必用这版
class NiiDataset(Dataset):
    def __init__(self, file_list_or_folder):
        if isinstance(file_list_or_folder, list):
            self.file_list = file_list_or_folder
        elif isinstance(file_list_or_folder, str):
            folder_path = file_list_or_folder
            self.file_list = [os.path.join(folder_path, filename)
                              for filename in os.listdir(folder_path)
                              if filename.endswith('.nii') or filename.endswith('.nii.gz')]
        else:
            raise ValueError("参数应为list或str")
    def __len__(self):
        return len(self.file_list)
    def __getitem__(self, idx):
        file_path = self.file_list[idx]
        img = nib.load(file_path)
        img_data = img.get_fdata()
        img_tensor = torch.from_numpy(img_data).float()
        cropped_tensor = center_crop_3d(img_tensor, (64, 64, 64))   # 你的裁剪函数
        input_tensor = cropped_tensor.unsqueeze(0)
        return input_tensor

# 1. 严格用csv顺序生成影像路径
pd_img_paths = [os.path.join('PD', row[1]) for row in data_PD if os.path.exists(os.path.join('PD', row[1]))]
control_img_paths = [os.path.join('Control', row[1]) for row in data_control if os.path.exists(os.path.join('Control', row[1]))]
swedd_img_paths = [os.path.join('SWEDD', row[1]) for row in data_swedd if os.path.exists(os.path.join('SWEDD', row[1]))]
prodromal_img_paths = [os.path.join('Prodromal', row[1]) for row in data_prodromal if os.path.exists(os.path.join('Prodromal', row[1]))]

print(f'PD影像数量: {len(pd_img_paths)}')
print(f'Control影像数量: {len(control_img_paths)}')
print(f'SWEDD影像数量: {len(swedd_img_paths)}')
print(f'Prodromal影像数量: {len(prodromal_img_paths)}')

batch_size = 16
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
nii = CNN_3D(num_class=1)
nii = nii.to(device)

# 2. 用于影像特征提取
# PD组
dataset = NiiDataset(pd_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
PD_output = torch.cat(all_outputs, dim=0)
print('PD nii shape--->', PD_output.shape)

# Control组
dataset = NiiDataset(control_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
control_output = torch.cat(all_outputs, dim=0)
print('control nii shape--->', control_output.shape)

# Prodromal组
dataset = NiiDataset(prodromal_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
prodromal_output = torch.cat(all_outputs, dim=0)
print('prodromal nii shape--->', prodromal_output.shape)

# SWEDD组
dataset = NiiDataset(swedd_img_paths)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
swedd_output = torch.cat(all_outputs, dim=0)
print('swedd nii shape--->', swedd_output.shape)
# Out:
# PD影像数量: 125
# Control影像数量: 132
# SWEDD影像数量: 72
# Prodromal影像数量: 80
# PD nii shape---> torch.Size([125, 1])
# control nii shape---> torch.Size([132, 1])
# prodromal nii shape---> torch.Size([80, 1])
# swedd nii shape---> torch.Size([72, 1])

# %%
# ===== 读取 DementiaKG (128维) 实体向量 =====
pd_df        = pd.read_csv('PD1.csv')
control_df   = pd.read_csv('control.csv')
prodromal_df = pd.read_csv('prodromal.csv')
swedd_df     = pd.read_csv('swedd.csv')

# 1. 修改文件名 (请确保你的 128维 npy 文件名是正确的，这里假设叫 ppmi_kg_embeddings.npy)
ENTITY_EMB_NPY = "ppmi_kg_embeddings.npy"  # <--- 修改这里：你的128维向量文件
ENTITY2ID_JSON  = "ppmi_kg_entity2id.json"  # <--- 修改这里：构建脚本生成的json文件

# 2. 修改读取映射表的逻辑 (从 TXT 改为 JSON)
print(f"正在加载映射表: {ENTITY2ID_JSON} ...")
with open(ENTITY2ID_JSON, "r", encoding="utf-8") as f:
    entity2id = json.load(f)  # 直接用 json.load 读取

# 3. 加载实体嵌入矩阵
# 注意：这里加载后的 shape 应该是 [N, 128]
entity_embeddings = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
print(f"KG Embeddings Shape: {entity_embeddings.shape}") # 打印确认一下是不是 (N, 128)

# 4. 把 id (int) 映射到 行号 (index)
# 新构建脚本生成的 json value 已经是 int 类型的 ID 了，通常不需要再转换，但为了保险起见保持逻辑：
# 如果 json 里 value 是 0, 1, 2... 这种连续整数，其实 id_to_index 就是 value 本身。
# 但为了兼容你的 DistMultExtract 类，我们保留 id_to_index 字典。
id_to_index = {str(v): v for k, v in entity2id.items()} 

# 5. DistMultExtract 类 (保持不变)
class DistMultExtract:
    def __init__(self, entity_embeddings, entity2id, id_to_index):
        self.entity_embeddings = entity_embeddings
        self.entity2id = entity2id
        self.id_to_index = id_to_index

    def get_entity_embedding(self, entity):
        # 这里的 entity 是 csv 里的症状字符串 (如 "Tremor")
        # 新构建脚本生成的 entity2id 里的 key 应该是 "PrimeKG:Tremor" 或 "Tremor" (取决于构建脚本)
        # 根据 build_ppmi_DementiaKG.ipynb 的输出，key 可能是 "PrimeKG:Tremor"
        # 所以这里可能需要加一个前缀尝试
        
        target_key = entity
        # 尝试直接查找
        if target_key in self.entity2id:
            pass
        # 尝试加前缀查找 (构建脚本里加了 PrimeKG: 前缀)
        elif f"PrimeKG:{entity}" in self.entity2id:
            target_key = f"PrimeKG:{entity}"
        elif f"Concept:{entity}" in self.entity2id:
            target_key = f"Concept:{entity}"
            
        if target_key in self.entity2id:
            ent_id = self.entity2id[target_key]
            # 如果 ent_id 已经是 int，直接用；如果是 str，转 int
            row_idx = int(ent_id) 
            return self.entity_embeddings[row_idx]
        else:
            # 找不到就返回 0 向量或者跳过，这里为了防止报错，可以打印一下
            # raise KeyError(f"Entity {entity} not found...") 
            return torch.zeros(entity_embeddings.shape[1]) # 返回全0向量兜底

# 6. 初始化提取器
kg_extractor = DistMultExtract(entity_embeddings, entity2id, id_to_index)

# 7. get_embeddings 函数 (保持不变)
def get_embeddings(df, extractor, nii_folder):
    embeddings_list = []
    skipped_rows = 0
    for _, row in df.iterrows():
        nii_file = row.iloc[1]
        nii_path = os.path.join(nii_folder, nii_file)
        if not os.path.exists(nii_path):
            skipped_rows += 1
            continue
        row_embeddings = []
        # 遍历症状列
        for col in df.columns[7:]:
            entity = str(row[col])
            # 过滤掉无意义的值
            if entity != '0' and entity != 'nan' and entity != '':
                emb = extractor.get_entity_embedding(entity)
                if not torch.equal(emb, torch.zeros(entity_embeddings.shape[1])): # 只要不是全0兜底
                    row_embeddings.append(emb)
        
        # 新 KG 里有 Patient:XXXX 节点，保留下面这段：
        filename = f"Patient:{int(row['Subject'])}" # 新格式通常有 Patient: 前缀
        emb_subj = extractor.get_entity_embedding(filename)
        if not torch.equal(emb_subj, torch.zeros(entity_embeddings.shape[1])):
             row_embeddings.append(emb_subj)

        if row_embeddings:
            mean_embedding = torch.stack(row_embeddings).mean(dim=0)
            embeddings_list.append(mean_embedding)
        else:
            # 如果没有找到任何症状，补一个全0
            embeddings_list.append(torch.zeros(entity_embeddings.shape[1]))
            
    if not embeddings_list:
        return torch.empty((0, entity_embeddings.shape[1]))
    return torch.stack(embeddings_list)

# 8. 获取嵌入
# 注意：这里会花一点时间
pd_transe        = get_embeddings(pd_df,        kg_extractor, 'PD')
control_transe   = get_embeddings(control_df,   kg_extractor, 'Control')
prodromal_transe = get_embeddings(prodromal_df, kg_extractor, 'Prodromal')
swedd_transe     = get_embeddings(swedd_df,     kg_extractor, 'SWEDD')

print(pd_transe.shape, control_transe.shape, prodromal_transe.shape, swedd_transe.shape)
# 预期输出: (125, 128) ... 也就是第二维应该是 128
# Out:
# 正在加载映射表: ppmi_kg_entity2id.json ...
# KG Embeddings Shape: torch.Size([1079, 128])
# torch.Size([125, 128]) torch.Size([132, 128]) torch.Size([80, 128]) torch.Size([72, 128])

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
# ------- 重新拼接特征 + 构造 DataLoader ------- #
import torch
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader

embed_dim        = 128
transe_embed_dim = 128          # 名字不改省事；实际装的是 DistMult

# ================= 消融实验配置 =================
# 0: ALL (全模态/Baseline)
# 1: 消去 EHR 特征 (临床文本/表格特征)
# 2: 消去 MRI 影像特征
# 3: 消去 Tensor 特征 (神经网络加权特征)
# 4: 消去 KG 知识图谱 (TransE/DistMult) 特征
ABLATION_MODE = 3  # 修改此处以切换不同实验 (0, 1, 2, 3, 4)
# ===============================================

print(f"当前消融实验模式代码: {ABLATION_MODE}")

def mask_tensor(tensor, mode_code):
    """如果当前模式代码匹配，则返回全0张量"""
    if ABLATION_MODE == mode_code:
        return torch.zeros_like(tensor)
    return tensor

X_pd = torch.cat([mask_tensor(pd_EHR, 1), mask_tensor(PD_output.cpu(), 2), mask_tensor(pd_tensor, 3), mask_tensor(pd_transe, 4)], dim=1)
X_control = torch.cat([mask_tensor(control_EHR, 1), mask_tensor(control_output.cpu(), 2), mask_tensor(control_tensor, 3), mask_tensor(control_transe, 4)], dim=1)
X_swedd = torch.cat([mask_tensor(swedd_EHR, 1), mask_tensor(swedd_output.cpu(), 2), mask_tensor(swedd_tensor, 3), mask_tensor(swedd_transe, 4)], dim=1)
X_prodromal = torch.cat([mask_tensor(prodromal_EHR, 1), mask_tensor(prodromal_output.cpu(), 2), mask_tensor(prodromal_tensor, 3), mask_tensor(prodromal_transe, 4)], dim=1)

def check_modality_status(tensor):
    ehr  = tensor[:, 0]
    mri  = tensor[:, 1]
    tens = tensor[:, 2]
    kg   = tensor[:, 3:]
    print("--- 特征拼接情况验证 ---")
    print(f"EHR特征 非零占比: {torch.count_nonzero(ehr)/ehr.numel():.1%}, 均值: {ehr.mean():.4f}")
    print(f"MRI特征 非零占比: {torch.count_nonzero(mri)/mri.numel():.1%}, 均值: {mri.mean():.4f}")
    print(f"Tensor特征 非零占比: {torch.count_nonzero(tens)/tens.numel():.1%}, 均值: {tens.mean():.4f}")
    print(f"KG特征 非零占比: {torch.count_nonzero(kg)/kg.numel():.1%}, 均值: {kg.mean():.4f}")

check_modality_status(X_pd)
# Out:
# 当前消融实验模式代码: 3
# --- 特征拼接情况验证 ---
# EHR特征 非零占比: 100.0%, 均值: 4.3105
# MRI特征 非零占比: 100.0%, 均值: -0.0055
# Tensor特征 非零占比: 0.0%, 均值: 0.0000
# KG特征 非零占比: 100.0%, 均值: -0.0243

# %%
y_pd = torch.zeros(len(X_pd))          # 标签顺序 PD=0
y_control = torch.ones(len(X_control)) # Control=1
y_swedd = torch.full((len(X_swedd),), 2)
y_prodromal = torch.full((len(X_prodromal),), 3)

X = torch.cat([X_pd[:120], X_control, X_prodromal, X_swedd], dim=0).float()
y = torch.cat([y_pd[:120], y_control, y_prodromal, y_swedd], dim=0).float()

features = X[:, :-transe_embed_dim]
kg_embed = X[:, -transe_embed_dim:]

X_train, X_test, y_train, y_test, kg_train, kg_test = train_test_split(
    features.detach().cpu().numpy(),          # ←★ 改这里
    y.cpu().numpy(),
    kg_embed.detach().cpu().numpy(),          # ←★ 以及这里
    test_size=0.20, stratify=y.cpu().numpy(), random_state=32
)

X_train, X_val, y_train, y_val, kg_train, kg_val = train_test_split(
    X_train, y_train, kg_train,
    test_size=0.20, stratify=y_train, random_state=30
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)
kg_train_tensor = torch.FloatTensor(kg_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
kg_val_tensor = torch.FloatTensor(kg_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
kg_test_tensor = torch.FloatTensor(kg_test).to(device)

batch_size = 32
train_dataset = TensorDataset(X_train_tensor, kg_train_tensor, y_train_tensor)
val_dataset   = TensorDataset(X_val_tensor,   kg_val_tensor, y_val_tensor)
test_dataset  = TensorDataset(X_test_tensor,  kg_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size)
print("DataLoaders ready:", len(train_loader), len(val_loader), len(test_loader))
# ------------------------------------------- #
# Out:
# DataLoaders ready: 9 3 3

# %%
num_epochs       = 200
batch_size       = 32
learning_rate    = 1e-5
weight_decay     = 1e-3
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# KGMultiModalTransformer 保持不变，只是继续把 transe_embed_dim=32 传进去
model = KGMultiModalTransformer(embed_dim=embed_dim,
                                transe_embed_dim=transe_embed_dim).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"test Loss: {test_loss:.4f}, test AUC: {test_auc:.4f}")
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/200, Train Loss: 1.3757, Train AUC: 0.5381  test Loss: 1.3784, test AUC: 0.5504
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 2/200, Train Loss: 1.4332, Train AUC: 0.5149  test Loss: 1.3757, test AUC: 0.5515
# Epoch 3/200, Train Loss: 1.3929, Train AUC: 0.5575  test Loss: 1.3701, test AUC: 0.5644
# Epoch 4/200, Train Loss: 1.3899, Train AUC: 0.5573  test Loss: 1.3623, test AUC: 0.5725
# Epoch 5/200, Train Loss: 1.4071, Train AUC: 0.5530  test Loss: 1.3570, test AUC: 0.5710
# Epoch 6/200, Train Loss: 1.3868, Train AUC: 0.5761  test Loss: 1.3518, test AUC: 0.5809
# Epoch 7/200, Train Loss: 1.3776, Train AUC: 0.5694  test Loss: 1.3477, test AUC: 0.5789
# Epoch 8/200, Train Loss: 1.4192, Train AUC: 0.5901  test Loss: 1.3465, test AUC: 0.5892
# Epoch 9/200, Train Loss: 1.3501, Train AUC: 0.5815  test Loss: 1.3436, test AUC: 0.5919
# Epoch 10/200, Train Loss: 1.3785, Train AUC: 0.5626  test Loss: 1.3408, test AUC: 0.6006
# Epoch 11/200, Train Loss: 1.3871, Train AUC: 0.6000  test Loss: 1.3351, test AUC: 0.6055
# Epoch 12/200, Train Loss: 1.3281, Train AUC: 0.6118  test Loss: 1.3299, test AUC: 0.6032
# Epoch 13/200, Train Loss: 1.3507, Train AUC: 0.6037  test Loss: 1.3281, test AUC: 0.6089
# Epoch 14/200, Train Loss: 1.3728, Train AUC: 0.6193  test Loss: 1.3258, test AUC: 0.6106
# Epoch 15/200, Train Loss: 1.3473, Train AUC: 0.6379  test Loss: 1.3278, test AUC: 0.6064
# Epoch 16/200, Train Loss: 1.3132, Train AUC: 0.6316  test Loss: 1.3199, test AUC: 0.6177
# Epoch 17/200, Train Loss: 1.3259, Train AUC: 0.6583  test Loss: 1.3154, test AUC: 0.6191
# Epoch 18/200, Train Loss: 1.3761, Train AUC: 0.6335  test Loss: 1.3049, test AUC: 0.6392
# Epoch 19/200, Train Loss: 1.3435, Train AUC: 0.6395  test Loss: 1.2970, test AUC: 0.6426
# Epoch 20/200, Train Loss: 1.3194, Train AUC: 0.6572  test Loss: 1.3014, test AUC: 0.6385
# Epoch 21/200, Train Loss: 1.2949, Train AUC: 0.6459  test Loss: 1.2890, test AUC: 0.6519
# Epoch 22/200, Train Loss: 1.3073, Train AUC: 0.6632  test Loss: 1.2822, test AUC: 0.6616
# Epoch 23/200, Train Loss: 1.2791, Train AUC: 0.6869  test Loss: 1.2832, test AUC: 0.6582
# Epoch 24/200, Train Loss: 1.2622, Train AUC: 0.6849  test Loss: 1.2842, test AUC: 0.6573
# Epoch 25/200, Train Loss: 1.3277, Train AUC: 0.6827  test Loss: 1.2765, test AUC: 0.6651
# Epoch 26/200, Train Loss: 1.3137, Train AUC: 0.6664  test Loss: 1.2723, test AUC: 0.6713
# Epoch 27/200, Train Loss: 1.2968, Train AUC: 0.6699  test Loss: 1.2778, test AUC: 0.6639
# Epoch 28/200, Train Loss: 1.2457, Train AUC: 0.6855  test Loss: 1.2702, test AUC: 0.6680
# Epoch 29/200, Train Loss: 1.2592, Train AUC: 0.7036  test Loss: 1.2642, test AUC: 0.6830
# Epoch 30/200, Train Loss: 1.2617, Train AUC: 0.6940  test Loss: 1.2651, test AUC: 0.6776
# Epoch 31/200, Train Loss: 1.2874, Train AUC: 0.6822  test Loss: 1.2612, test AUC: 0.6849
# Epoch 32/200, Train Loss: 1.2776, Train AUC: 0.7144  test Loss: 1.2549, test AUC: 0.6939
# Epoch 33/200, Train Loss: 1.2585, Train AUC: 0.7078  test Loss: 1.2460, test AUC: 0.6997
# Epoch 34/200, Train Loss: 1.2602, Train AUC: 0.7097  test Loss: 1.2480, test AUC: 0.7031
# Epoch 35/200, Train Loss: 1.2559, Train AUC: 0.7044  test Loss: 1.2433, test AUC: 0.7046
# Epoch 36/200, Train Loss: 1.2074, Train AUC: 0.7328  test Loss: 1.2387, test AUC: 0.7056
# Epoch 37/200, Train Loss: 1.2007, Train AUC: 0.7587  test Loss: 1.2466, test AUC: 0.6996
# Epoch 38/200, Train Loss: 1.2476, Train AUC: 0.7518  test Loss: 1.2418, test AUC: 0.6957
# Epoch 39/200, Train Loss: 1.2509, Train AUC: 0.7261  test Loss: 1.2369, test AUC: 0.6971
# Epoch 40/200, Train Loss: 1.2163, Train AUC: 0.7268  test Loss: 1.2324, test AUC: 0.7101
# Epoch 41/200, Train Loss: 1.2102, Train AUC: 0.7424  test Loss: 1.2221, test AUC: 0.7224
# Epoch 42/200, Train Loss: 1.1962, Train AUC: 0.7585  test Loss: 1.2224, test AUC: 0.7223
# Epoch 43/200, Train Loss: 1.2186, Train AUC: 0.7194  test Loss: 1.2197, test AUC: 0.7316
# Epoch 44/200, Train Loss: 1.1997, Train AUC: 0.7579  test Loss: 1.2112, test AUC: 0.7268
# Epoch 45/200, Train Loss: 1.1632, Train AUC: 0.7757  test Loss: 1.2080, test AUC: 0.7321
# Epoch 46/200, Train Loss: 1.2350, Train AUC: 0.7437  test Loss: 1.2040, test AUC: 0.7316
# Epoch 47/200, Train Loss: 1.2012, Train AUC: 0.7522  test Loss: 1.2065, test AUC: 0.7311
# Epoch 48/200, Train Loss: 1.2088, Train AUC: 0.7682  test Loss: 1.2079, test AUC: 0.7270
# Epoch 49/200, Train Loss: 1.1697, Train AUC: 0.7749  test Loss: 1.2044, test AUC: 0.7412
# Epoch 50/200, Train Loss: 1.2121, Train AUC: 0.7740  test Loss: 1.1959, test AUC: 0.7423
# Epoch 51/200, Train Loss: 1.2469, Train AUC: 0.7763  test Loss: 1.1976, test AUC: 0.7402
# Epoch 52/200, Train Loss: 1.1690, Train AUC: 0.7833  test Loss: 1.1960, test AUC: 0.7391
# Epoch 53/200, Train Loss: 1.1691, Train AUC: 0.7746  test Loss: 1.1898, test AUC: 0.7484
# Epoch 54/200, Train Loss: 1.1521, Train AUC: 0.7918  test Loss: 1.1930, test AUC: 0.7427
# Epoch 55/200, Train Loss: 1.1604, Train AUC: 0.7867  test Loss: 1.1942, test AUC: 0.7440
# Epoch 56/200, Train Loss: 1.1828, Train AUC: 0.7836  test Loss: 1.1857, test AUC: 0.7539
# Epoch 57/200, Train Loss: 1.1738, Train AUC: 0.7903  test Loss: 1.1812, test AUC: 0.7617
# Epoch 58/200, Train Loss: 1.1585, Train AUC: 0.7758  test Loss: 1.1794, test AUC: 0.7575
# Epoch 59/200, Train Loss: 1.1513, Train AUC: 0.7933  test Loss: 1.1715, test AUC: 0.7594
# Epoch 60/200, Train Loss: 1.1722, Train AUC: 0.8264  test Loss: 1.1676, test AUC: 0.7673
# Epoch 61/200, Train Loss: 1.1454, Train AUC: 0.8221  test Loss: 1.1732, test AUC: 0.7672
# Epoch 62/200, Train Loss: 1.1401, Train AUC: 0.8019  test Loss: 1.1710, test AUC: 0.7736
# Epoch 63/200, Train Loss: 1.1307, Train AUC: 0.7982  test Loss: 1.1676, test AUC: 0.7756
# Epoch 64/200, Train Loss: 1.1382, Train AUC: 0.8075  test Loss: 1.1556, test AUC: 0.7738
# Epoch 65/200, Train Loss: 1.1685, Train AUC: 0.8248  test Loss: 1.1610, test AUC: 0.7657
# Epoch 66/200, Train Loss: 1.1473, Train AUC: 0.8124  test Loss: 1.1566, test AUC: 0.7779
# Epoch 67/200, Train Loss: 1.1399, Train AUC: 0.8185  test Loss: 1.1478, test AUC: 0.7763
# Epoch 68/200, Train Loss: 1.1324, Train AUC: 0.8146  test Loss: 1.1517, test AUC: 0.7679
# Epoch 69/200, Train Loss: 1.1126, Train AUC: 0.8077  test Loss: 1.1484, test AUC: 0.7799
# Epoch 70/200, Train Loss: 1.0883, Train AUC: 0.8302  test Loss: 1.1525, test AUC: 0.7852
# Epoch 71/200, Train Loss: 1.0972, Train AUC: 0.8305  test Loss: 1.1443, test AUC: 0.7853
# Epoch 72/200, Train Loss: 1.0875, Train AUC: 0.8211  test Loss: 1.1349, test AUC: 0.7907
# Epoch 73/200, Train Loss: 1.1279, Train AUC: 0.8380  test Loss: 1.1358, test AUC: 0.7906
# Epoch 74/200, Train Loss: 1.1490, Train AUC: 0.8299  test Loss: 1.1286, test AUC: 0.7934
# Epoch 75/200, Train Loss: 1.0625, Train AUC: 0.8580  test Loss: 1.1230, test AUC: 0.7986
# Epoch 76/200, Train Loss: 1.0990, Train AUC: 0.8403  test Loss: 1.1172, test AUC: 0.8018
# Epoch 77/200, Train Loss: 1.1536, Train AUC: 0.8422  test Loss: 1.1208, test AUC: 0.7943
# Epoch 78/200, Train Loss: 1.0961, Train AUC: 0.8296  test Loss: 1.1242, test AUC: 0.7965
# Epoch 79/200, Train Loss: 1.1234, Train AUC: 0.8490  test Loss: 1.1231, test AUC: 0.8059
# Epoch 80/200, Train Loss: 1.0475, Train AUC: 0.8478  test Loss: 1.1205, test AUC: 0.8040
# Epoch 81/200, Train Loss: 1.0677, Train AUC: 0.8431  test Loss: 1.1156, test AUC: 0.8156
# Epoch 82/200, Train Loss: 1.0649, Train AUC: 0.8470  test Loss: 1.1031, test AUC: 0.8131
# Epoch 83/200, Train Loss: 1.0825, Train AUC: 0.8415  test Loss: 1.0966, test AUC: 0.8181
# Epoch 84/200, Train Loss: 1.0385, Train AUC: 0.8466  test Loss: 1.1031, test AUC: 0.8119
# Epoch 85/200, Train Loss: 1.0677, Train AUC: 0.8615  test Loss: 1.0997, test AUC: 0.8131
# Epoch 86/200, Train Loss: 1.1595, Train AUC: 0.8442  test Loss: 1.0952, test AUC: 0.8142
# Epoch 87/200, Train Loss: 1.0452, Train AUC: 0.8507  test Loss: 1.0996, test AUC: 0.8139
# Epoch 88/200, Train Loss: 1.1103, Train AUC: 0.8477  test Loss: 1.0970, test AUC: 0.8074
# Epoch 89/200, Train Loss: 1.0803, Train AUC: 0.8664  test Loss: 1.0871, test AUC: 0.8173
# Epoch 90/200, Train Loss: 1.0202, Train AUC: 0.8591  test Loss: 1.0909, test AUC: 0.8204
# Epoch 91/200, Train Loss: 1.0244, Train AUC: 0.8616  test Loss: 1.0842, test AUC: 0.8224
# Epoch 92/200, Train Loss: 1.0481, Train AUC: 0.8637  test Loss: 1.0793, test AUC: 0.8254
# Epoch 93/200, Train Loss: 1.0366, Train AUC: 0.8737  test Loss: 1.0753, test AUC: 0.8275
# Epoch 94/200, Train Loss: 1.0778, Train AUC: 0.8744  test Loss: 1.0664, test AUC: 0.8327
# Epoch 95/200, Train Loss: 1.0455, Train AUC: 0.8810  test Loss: 1.0636, test AUC: 0.8317
# Epoch 96/200, Train Loss: 1.0150, Train AUC: 0.8671  test Loss: 1.0697, test AUC: 0.8346
# Epoch 97/200, Train Loss: 1.0474, Train AUC: 0.8750  test Loss: 1.0743, test AUC: 0.8318
# Epoch 98/200, Train Loss: 1.0406, Train AUC: 0.8641  test Loss: 1.0642, test AUC: 0.8351
# Epoch 99/200, Train Loss: 1.0071, Train AUC: 0.8753  test Loss: 1.0568, test AUC: 0.8402
# Epoch 100/200, Train Loss: 1.0459, Train AUC: 0.8832  test Loss: 1.0569, test AUC: 0.8410
# Epoch 101/200, Train Loss: 1.0588, Train AUC: 0.8667  test Loss: 1.0557, test AUC: 0.8440
# Epoch 102/200, Train Loss: 0.9870, Train AUC: 0.8836  test Loss: 1.0554, test AUC: 0.8396
# Epoch 103/200, Train Loss: 1.0780, Train AUC: 0.8764  test Loss: 1.0481, test AUC: 0.8398
# Epoch 104/200, Train Loss: 1.0065, Train AUC: 0.8832  test Loss: 1.0466, test AUC: 0.8415
# Epoch 105/200, Train Loss: 0.9581, Train AUC: 0.8842  test Loss: 1.0544, test AUC: 0.8445
# Epoch 106/200, Train Loss: 1.0295, Train AUC: 0.8820  test Loss: 1.0423, test AUC: 0.8443
# Epoch 107/200, Train Loss: 1.0289, Train AUC: 0.8947  test Loss: 1.0335, test AUC: 0.8497
# Epoch 108/200, Train Loss: 1.0502, Train AUC: 0.8855  test Loss: 1.0293, test AUC: 0.8476
# Epoch 109/200, Train Loss: 0.9316, Train AUC: 0.8956  test Loss: 1.0411, test AUC: 0.8505
# Epoch 110/200, Train Loss: 0.9744, Train AUC: 0.8877  test Loss: 1.0390, test AUC: 0.8489
# Epoch 111/200, Train Loss: 0.9982, Train AUC: 0.8920  test Loss: 1.0291, test AUC: 0.8545
# Epoch 112/200, Train Loss: 0.9557, Train AUC: 0.8994  test Loss: 1.0234, test AUC: 0.8564
# Epoch 113/200, Train Loss: 0.9587, Train AUC: 0.9075  test Loss: 1.0216, test AUC: 0.8574
# Epoch 114/200, Train Loss: 0.9594, Train AUC: 0.8911  test Loss: 1.0213, test AUC: 0.8582
# Epoch 115/200, Train Loss: 0.9898, Train AUC: 0.9076  test Loss: 1.0187, test AUC: 0.8515
# Epoch 116/200, Train Loss: 0.9858, Train AUC: 0.9102  test Loss: 1.0133, test AUC: 0.8637
# Epoch 117/200, Train Loss: 1.0188, Train AUC: 0.8935  test Loss: 1.0134, test AUC: 0.8580
# Epoch 118/200, Train Loss: 1.0143, Train AUC: 0.9064  test Loss: 1.0100, test AUC: 0.8556
# Epoch 119/200, Train Loss: 0.9707, Train AUC: 0.9098  test Loss: 1.0036, test AUC: 0.8625
# Epoch 120/200, Train Loss: 0.9916, Train AUC: 0.9076  test Loss: 0.9981, test AUC: 0.8640
# Epoch 121/200, Train Loss: 0.9277, Train AUC: 0.9178  test Loss: 0.9969, test AUC: 0.8619
# Epoch 122/200, Train Loss: 0.9402, Train AUC: 0.9203  test Loss: 1.0039, test AUC: 0.8642
# Epoch 123/200, Train Loss: 0.9587, Train AUC: 0.9072  test Loss: 0.9998, test AUC: 0.8675
# Epoch 124/200, Train Loss: 0.9958, Train AUC: 0.9168  test Loss: 0.9925, test AUC: 0.8673
# Epoch 125/200, Train Loss: 0.9099, Train AUC: 0.9207  test Loss: 0.9986, test AUC: 0.8663
# Epoch 126/200, Train Loss: 0.9600, Train AUC: 0.9126  test Loss: 0.9922, test AUC: 0.8707
# Epoch 127/200, Train Loss: 0.9790, Train AUC: 0.9097  test Loss: 0.9892, test AUC: 0.8711
# Epoch 128/200, Train Loss: 0.9760, Train AUC: 0.8990  test Loss: 0.9804, test AUC: 0.8698
# Epoch 129/200, Train Loss: 0.9670, Train AUC: 0.9141  test Loss: 0.9737, test AUC: 0.8737
# Epoch 130/200, Train Loss: 0.9121, Train AUC: 0.9123  test Loss: 0.9760, test AUC: 0.8730
# Epoch 131/200, Train Loss: 0.9647, Train AUC: 0.8953  test Loss: 0.9809, test AUC: 0.8718
# Epoch 132/200, Train Loss: 0.9394, Train AUC: 0.9214  test Loss: 0.9782, test AUC: 0.8702
# Epoch 133/200, Train Loss: 0.9056, Train AUC: 0.9168  test Loss: 0.9853, test AUC: 0.8707
# Epoch 134/200, Train Loss: 0.9240, Train AUC: 0.9174  test Loss: 0.9716, test AUC: 0.8757
# Epoch 135/200, Train Loss: 0.8817, Train AUC: 0.9227  test Loss: 0.9697, test AUC: 0.8773
# Epoch 136/200, Train Loss: 0.9009, Train AUC: 0.9194  test Loss: 0.9757, test AUC: 0.8739
# Epoch 137/200, Train Loss: 0.9504, Train AUC: 0.9128  test Loss: 0.9667, test AUC: 0.8754
# Epoch 138/200, Train Loss: 0.9600, Train AUC: 0.9200  test Loss: 0.9610, test AUC: 0.8750
# Epoch 139/200, Train Loss: 0.9209, Train AUC: 0.9274  test Loss: 0.9553, test AUC: 0.8749
# Epoch 140/200, Train Loss: 0.8715, Train AUC: 0.9153  test Loss: 0.9503, test AUC: 0.8755
# Epoch 141/200, Train Loss: 0.9373, Train AUC: 0.9241  test Loss: 0.9490, test AUC: 0.8768
# Epoch 142/200, Train Loss: 0.9299, Train AUC: 0.9329  test Loss: 0.9457, test AUC: 0.8775
# Epoch 143/200, Train Loss: 0.9224, Train AUC: 0.9249  test Loss: 0.9490, test AUC: 0.8707
# Epoch 144/200, Train Loss: 0.9220, Train AUC: 0.9290  test Loss: 0.9396, test AUC: 0.8772
# Epoch 145/200, Train Loss: 0.8778, Train AUC: 0.9271  test Loss: 0.9378, test AUC: 0.8795
# Epoch 146/200, Train Loss: 0.8805, Train AUC: 0.9205  test Loss: 0.9370, test AUC: 0.8797
# Epoch 147/200, Train Loss: 0.8542, Train AUC: 0.9315  test Loss: 0.9359, test AUC: 0.8823
# Epoch 148/200, Train Loss: 0.8840, Train AUC: 0.9189  test Loss: 0.9355, test AUC: 0.8815
# Epoch 149/200, Train Loss: 0.9307, Train AUC: 0.9159  test Loss: 0.9380, test AUC: 0.8849
# Epoch 150/200, Train Loss: 0.8547, Train AUC: 0.9313  test Loss: 0.9420, test AUC: 0.8779
# Epoch 151/200, Train Loss: 0.8980, Train AUC: 0.9312  test Loss: 0.9342, test AUC: 0.8794
# Epoch 152/200, Train Loss: 0.9053, Train AUC: 0.9281  test Loss: 0.9371, test AUC: 0.8839
# Epoch 153/200, Train Loss: 0.8100, Train AUC: 0.9401  test Loss: 0.9358, test AUC: 0.8821
# Epoch 154/200, Train Loss: 0.8381, Train AUC: 0.9343  test Loss: 0.9314, test AUC: 0.8820
# Epoch 155/200, Train Loss: 0.8726, Train AUC: 0.9338  test Loss: 0.9295, test AUC: 0.8832
# Epoch 156/200, Train Loss: 0.8228, Train AUC: 0.9341  test Loss: 0.9248, test AUC: 0.8831
# Epoch 157/200, Train Loss: 0.8664, Train AUC: 0.9361  test Loss: 0.9134, test AUC: 0.8846
# Epoch 158/200, Train Loss: 0.8805, Train AUC: 0.9389  test Loss: 0.9217, test AUC: 0.8845
# Epoch 159/200, Train Loss: 0.8576, Train AUC: 0.9344  test Loss: 0.9132, test AUC: 0.8834
# Epoch 160/200, Train Loss: 0.9193, Train AUC: 0.9327  test Loss: 0.9095, test AUC: 0.8823
# Epoch 161/200, Train Loss: 0.8028, Train AUC: 0.9406  test Loss: 0.9176, test AUC: 0.8843
# Epoch 162/200, Train Loss: 0.8392, Train AUC: 0.9358  test Loss: 0.9120, test AUC: 0.8853
# Epoch 163/200, Train Loss: 0.8289, Train AUC: 0.9381  test Loss: 0.9089, test AUC: 0.8833
# Epoch 164/200, Train Loss: 0.8399, Train AUC: 0.9337  test Loss: 0.9094, test AUC: 0.8829
# Epoch 165/200, Train Loss: 0.8298, Train AUC: 0.9383  test Loss: 0.9098, test AUC: 0.8888
# Epoch 166/200, Train Loss: 0.8152, Train AUC: 0.9295  test Loss: 0.9020, test AUC: 0.8872
# Epoch 167/200, Train Loss: 0.8217, Train AUC: 0.9409  test Loss: 0.9018, test AUC: 0.8866
# Epoch 168/200, Train Loss: 0.8725, Train AUC: 0.9329  test Loss: 0.9037, test AUC: 0.8854
# Epoch 169/200, Train Loss: 0.8400, Train AUC: 0.9296  test Loss: 0.8957, test AUC: 0.8860
# Epoch 170/200, Train Loss: 0.8493, Train AUC: 0.9340  test Loss: 0.8957, test AUC: 0.8872
# Epoch 171/200, Train Loss: 0.8462, Train AUC: 0.9461  test Loss: 0.8975, test AUC: 0.8815
# Epoch 172/200, Train Loss: 0.8744, Train AUC: 0.9314  test Loss: 0.8891, test AUC: 0.8840
# Epoch 173/200, Train Loss: 0.8416, Train AUC: 0.9361  test Loss: 0.8954, test AUC: 0.8858
# Epoch 174/200, Train Loss: 0.8137, Train AUC: 0.9328  test Loss: 0.8821, test AUC: 0.8872
# Epoch 175/200, Train Loss: 0.7857, Train AUC: 0.9330  test Loss: 0.8931, test AUC: 0.8865
# Epoch 176/200, Train Loss: 0.8351, Train AUC: 0.9286  test Loss: 0.8928, test AUC: 0.8851
# Epoch 177/200, Train Loss: 0.8650, Train AUC: 0.9406  test Loss: 0.8895, test AUC: 0.8838
# Epoch 178/200, Train Loss: 0.7475, Train AUC: 0.9530  test Loss: 0.8951, test AUC: 0.8863
# Epoch 179/200, Train Loss: 0.8653, Train AUC: 0.9341  test Loss: 0.8948, test AUC: 0.8844
# Epoch 180/200, Train Loss: 0.8356, Train AUC: 0.9396  test Loss: 0.8903, test AUC: 0.8856
# Epoch 181/200, Train Loss: 0.8353, Train AUC: 0.9504  test Loss: 0.8756, test AUC: 0.8860
# Epoch 182/200, Train Loss: 0.7569, Train AUC: 0.9284  test Loss: 0.8737, test AUC: 0.8906
# Epoch 183/200, Train Loss: 0.8761, Train AUC: 0.9380  test Loss: 0.8650, test AUC: 0.8899
# Epoch 184/200, Train Loss: 0.8099, Train AUC: 0.9437  test Loss: 0.8637, test AUC: 0.8872
# Epoch 185/200, Train Loss: 0.8384, Train AUC: 0.9417  test Loss: 0.8711, test AUC: 0.8881
# Epoch 186/200, Train Loss: 0.7957, Train AUC: 0.9393  test Loss: 0.8693, test AUC: 0.8889
# Epoch 187/200, Train Loss: 0.8505, Train AUC: 0.9396  test Loss: 0.8680, test AUC: 0.8875
# Epoch 188/200, Train Loss: 0.8399, Train AUC: 0.9428  test Loss: 0.8708, test AUC: 0.8874
# Epoch 189/200, Train Loss: 0.7647, Train AUC: 0.9392  test Loss: 0.8891, test AUC: 0.8921
# Epoch 190/200, Train Loss: 0.8452, Train AUC: 0.9491  test Loss: 0.8745, test AUC: 0.8872
# Epoch 191/200, Train Loss: 0.8677, Train AUC: 0.9433  test Loss: 0.8668, test AUC: 0.8900
# Epoch 192/200, Train Loss: 0.8575, Train AUC: 0.9355  test Loss: 0.8520, test AUC: 0.8921
# Epoch 193/200, Train Loss: 0.8432, Train AUC: 0.9452  test Loss: 0.8563, test AUC: 0.8923
# Epoch 194/200, Train Loss: 0.8336, Train AUC: 0.9515  test Loss: 0.8562, test AUC: 0.8900
# Epoch 195/200, Train Loss: 0.8319, Train AUC: 0.9439  test Loss: 0.8552, test AUC: 0.8893
# Epoch 196/200, Train Loss: 0.7710, Train AUC: 0.9474  test Loss: 0.8533, test AUC: 0.8897
# Epoch 197/200, Train Loss: 0.7374, Train AUC: 0.9496  test Loss: 0.8572, test AUC: 0.8920
# Epoch 198/200, Train Loss: 0.7744, Train AUC: 0.9541  test Loss: 0.8584, test AUC: 0.8916
# Epoch 199/200, Train Loss: 0.7393, Train AUC: 0.9586  test Loss: 0.8569, test AUC: 0.8905
# Epoch 200/200, Train Loss: 0.7625, Train AUC: 0.9574  test Loss: 0.8471, test AUC: 0.8931

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.6308
# Precision: 0.6431
# Recall:    0.5744
# F1 Score:  0.5727
# AUC-ROC:   0.9026

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("PPMI AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("PPMI Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
