# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,NeuralNet,PerceiverAttentionBlock,KGMultiModalPerceiver
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0

with open('NACC_normal.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'NACC_nii_no/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('NACC_ad.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NACC_nii_ad/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('NACC_mci.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'NACC_mci/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #713
print(count_no) #2116
print(count_mci) #879
# Out:
# 713
# 2116
# 879

# %%
# 基础替换字典 (请根据NACC的具体字符继续补充)
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0', 'ind': '3', 'ans': '4', 'no': '0', 'yes': '1', 'haw': '3'}

# EHR 模块 (53维): 人口学 (3-7) + 病史 (60-107)
ehr_cols = [3, 4, 5, 6, 7] + list(range(60, 108))

# BIO 模块 (43维): apoe (8) + 认知量表与问卷 (18-59)
bio_cols = [8] + list(range(18, 60))

# 统一且安全的预处理函数
def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        # 仅提取安全的特征列
        extracted_row = [row[idx] for idx in target_cols]
        # 字典映射替换
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                # 拦截 NaN，替换为 0.0
                if math.isnan(val):
                    val = 0.0
            except ValueError:
                # 无法转换的值替换为 0.0
                val = 0.0 
            numerical_row.append(val)
            
        processed_data.append(numerical_row)
    return np.array(processed_data)

# %%
# 1. 提取 BIO 数组 (真实的 47 维特征)
ad_bio_array = preprocess_data(data_ad, replace_dict, bio_cols)
normal_bio_array = preprocess_data(data_normal, replace_dict, bio_cols)
mci_bio_array = preprocess_data(data_mci, replace_dict, bio_cols)

# 2. 直接转换数据为 Tensor
ad_tensor = torch.from_numpy(ad_bio_array).float()
normal_tensor = torch.from_numpy(normal_bio_array).float()
mci_tensor = torch.from_numpy(mci_bio_array).float()

# 3. 打印结果检查维度
print('AD_tensor shape:', ad_tensor.shape)       
print('Normal_tensor shape:', normal_tensor.shape) 
print('MCI_tensor shape:', mci_tensor.shape)
# Out:
# AD_tensor shape: torch.Size([713, 43])
# Normal_tensor shape: torch.Size([2116, 43])
# MCI_tensor shape: torch.Size([879, 43])

# %%
# 1. 提取脱敏后的 EHR 数组 (真实的 59 维特征)
ad_ehr_data = preprocess_data(data_ad, replace_dict, ehr_cols)
normal_ehr_data = preprocess_data(data_normal, replace_dict, ehr_cols)
mci_ehr_data = preprocess_data(data_mci, replace_dict, ehr_cols)

# 2. 直接转换为 Tensor
ad_EHR = torch.from_numpy(ad_ehr_data).float()
normal_EHR = torch.from_numpy(normal_ehr_data).float()
mci_EHR = torch.from_numpy(mci_ehr_data).float()

# 3. 打印结果检查维度
print('ad.EHR--->', ad_EHR.shape)
print('normal.EHR--->', normal_EHR.shape)
print('mci.EHR--->', mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([713, 53])
# normal.EHR---> torch.Size([2116, 53])
# mci.EHR---> torch.Size([879, 53])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Using device:', device)
# Out:
# Using device: cuda

# %%
import torch
import gc
from torch.utils.data import DataLoader
from tqdm import tqdm  # 引入 tqdm 库用于显示进度

# 1. 显式清理缓存，防止之前的残留占用显存
torch.cuda.empty_cache()
gc.collect()

# 2. 实例化模型，将输出维度设为64，严格匹配 Transformer 的 img_dim=64
nii = CNN_3D(num_class=64)
nii = nii.to(device)
nii.eval() # 开启评估模式，冻结网络行为

def extract_mri_features(folder_path, batch_size=16):
    # 注意：这里将默认 batch_size 改为 4，防止 NACC 的 3D 图像导致 OOM
    dataset = NiiDataset(folder_path)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    all_outputs = []
    
    # 关闭梯度计算，节省显存并加快提取速度
    with torch.no_grad():
        # 使用 tqdm 包装 dataloader，实时打印当前文件夹的提取进度
        for batch_idx, batch_data in enumerate(tqdm(dataloader, desc="Extracting features")):
            batch_data = batch_data.to(device)
            output = nii(batch_data)
            # 提取后立即 detach 并转回 CPU，防止 GPU 显存堆积
            all_outputs.append(output.detach().cpu())
            
    # 每次提取完一个类别后，显式清理局部变量和显存
    del dataset, dataloader
    torch.cuda.empty_cache()
    gc.collect()
            
    return torch.cat(all_outputs, dim=0)

# NACC 图像数据路径
all_ad = 'NACC_nii_ad/'
all_normal = 'NACC_nii_no/'
all_mci = 'NACC_mci/'

# 3. 模块化调用提取特征
ad_output = extract_mri_features(all_ad, batch_size=4)
print('ad nii shape--->', ad_output.shape)

normal_output = extract_mri_features(all_normal, batch_size=4)
print('normal nii shape--->', normal_output.shape)

mci_output = extract_mri_features(all_mci, batch_size=4)
print('mci nii shape--->', mci_output.shape)
# Out:
# Extracting features: 100%|██████████| 179/179 [00:35<00:00,  5.04it/s]
# ad nii shape---> torch.Size([713, 64])
# Extracting features: 100%|██████████| 529/529 [01:13<00:00,  7.22it/s]
# normal nii shape---> torch.Size([2116, 64])
# Extracting features: 100%|██████████| 220/220 [00:29<00:00,  7.42it/s]
# mci nii shape---> torch.Size([879, 64])

# %%
import numpy as np
import torch
import pandas as pd
import json

# 保持你的路径配置不变
ENTITY_EMB_NPY = "NACC-DementiaHKG-Embeddings.npy"
ENTITY2ID_FILE = "NACC-DementiaHKG-Entity2ID.json"
PATIENT_QUERY_DICT = "NACC-DementiaHKG-Entities.json"

with open(ENTITY2ID_FILE, 'r', encoding='utf-8') as f:
    entity2id = json.load(f)

with open(PATIENT_QUERY_DICT, 'r', encoding='utf-8') as f:
    patient_entities = json.load(f)

emb = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
embed_dim = emb.shape[1] 
max_seq_len = 45 

def get_patient_embedding_seq(filename: str):
    filename = str(filename).strip()
    patient_data = patient_entities.get(filename, {})
    active_nodes = patient_data.get("input_nodes", [])
    
    vecs = []
    pad_masks = []
    
    # 构造固定长度为45的序列与对应的布尔掩码
    for i in range(max_seq_len):
        if i < len(active_nodes):
            node = active_nodes[i]
            if node != "[PAD]" and node in entity2id:
                vecs.append(emb[entity2id[node]])
                pad_masks.append(False) 
            else:
                vecs.append(torch.zeros(embed_dim))
                pad_masks.append(True) 
        else:
            vecs.append(torch.zeros(embed_dim))
            pad_masks.append(True)
            
    # 返回知识序列矩阵和用于PyTorch注意力的掩码
    return torch.stack(vecs), torch.tensor(pad_masks, dtype=torch.bool)

def process_and_verify_seq(df, cohort_name):
    seq_tensors = []
    mask_tensors = []
    valid_count = 0
    
    for _, r in df.iterrows():
        seq_tensor, mask_tensor = get_patient_embedding_seq(r['filename'])
        seq_tensors.append(seq_tensor)
        mask_tensors.append(mask_tensor)
        
        # 验证是否包含至少一个有效节点（掩码中存在False）
        if not torch.all(mask_tensor):
            valid_count += 1
            
    stacked_seq = torch.stack(seq_tensors)
    stacked_mask = torch.stack(mask_tensors)
    
    print(f"[{cohort_name}] 总样本数: {len(df)} | 成功注入KG先验序列的样本数: {valid_count}")
    return stacked_seq, stacked_mask

# 执行数据提取
print("开始提取完整知识序列与注意力掩码...")
ad_transe_seq, ad_transe_mask = process_and_verify_seq(pd.read_csv('NACC_ad.csv'), "AD")
mci_transe_seq, mci_transe_mask = process_and_verify_seq(pd.read_csv('NACC_mci.csv'), "MCI")
nc_transe_seq, nc_transe_mask = process_and_verify_seq(pd.read_csv('NACC_normal.csv'), "NC")

print("最终生成的知识序列 Shapes:", ad_transe_seq.shape, mci_transe_seq.shape, nc_transe_seq.shape)
print("最终生成的掩码张量 Shapes:", ad_transe_mask.shape, mci_transe_mask.shape, nc_transe_mask.shape)
# Out:
# 开始提取完整知识序列与注意力掩码...
# [AD] 总样本数: 713 | 成功注入KG先验序列的样本数: 709
# [MCI] 总样本数: 879 | 成功注入KG先验序列的样本数: 872
# [NC] 总样本数: 2116 | 成功注入KG先验序列的样本数: 1802
# 最终生成的知识序列 Shapes: torch.Size([713, 45, 128]) torch.Size([879, 45, 128]) torch.Size([2116, 45, 128])
# 最终生成的掩码张量 Shapes: torch.Size([713, 45]) torch.Size([879, 45]) torch.Size([2116, 45])

# %%
# 第一步：合并原有的多模态特征 (EHR + IMG + BIO)
features_ad = torch.cat([ad_EHR, ad_output.cpu(), ad_tensor], dim=1)
features_mci = torch.cat([mci_EHR, mci_output.cpu(), mci_tensor], dim=1)
features_normal = torch.cat([normal_EHR, normal_output.cpu(), normal_tensor], dim=1)

# 第二步：沿着批次维度(dim=0)纵向合并所有样本的特征
features = torch.cat([features_ad, features_mci, features_normal], dim=0).float()

# 第三步：纵向合并上一步提取的所有样本的知识序列矩阵
kg_seq = torch.cat([ad_transe_seq, mci_transe_seq, nc_transe_seq], dim=0).float()

# 第四步：纵向合并对应的知识掩码矩阵
kg_mask = torch.cat([ad_transe_mask, mci_transe_mask, nc_transe_mask], dim=0).bool()

# 第五步：生成类别标签
y_ad = torch.ones(len(features_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(features_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(features_normal)) * 0  # NC 类别标签为 0

# 分类任务的标签通常建议使用 long 类型
y = torch.cat([y_ad, y_mci, y_normal], dim=0).long() 

print("多模态特征 (features) 维度:", features.shape)
print("知识序列 (kg_seq) 维度:", kg_seq.shape)
print("注意力掩码 (kg_mask) 维度:", kg_mask.shape)
print("标签 (y) 维度:", y.shape)
# Out:
# 多模态特征 (features) 维度: torch.Size([3708, 160])
# 知识序列 (kg_seq) 维度: torch.Size([3708, 45, 128])
# 注意力掩码 (kg_mask) 维度: torch.Size([3708, 45])
# 标签 (y) 维度: torch.Size([3708])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.impute import SimpleImputer
import torch
# 1. 正常的划分数据集：同时切分特征(features), 图谱序列(kg_seq), 掩码(kg_mask) 和 标签(y)
# ★★★ 修复 NaN 报错的核心代码：防止全填充序列导致 Attention Softmax 除零崩溃 ★★★
# 找到那些掩码一整行全为 True 的样本（完全没有图谱节点的健康人）
all_padded_idx = kg_mask.all(dim=1)
# 强行把这些样本的第0个位置的掩码设为 False，使其能够去关注一个全零的 Padding 向量
kg_mask[all_padded_idx, 0] = False

X_train, X_test, seq_train, seq_test, mask_train, mask_test, y_train, y_test = train_test_split(
    features.detach().numpy(), 
    kg_seq.detach().numpy(), 
    kg_mask.detach().numpy(), 
    y.numpy(),
    test_size=0.20,
    stratify=y.numpy(),
    random_state=32
)


X_train, X_val, seq_train, seq_val, mask_train, mask_val, y_train, y_val = train_test_split(
    X_train, seq_train, mask_train, y_train,
    test_size=0.20,
    stratify=y_train,
    random_state=30
)

# ----------------- 缺失值填充与归一化模块 -----------------
# 2. 初始化填充器和标准化器
imputer = SimpleImputer(strategy='median')
scaler = StandardScaler()

# 3. 仅在训练集的“多模态特征(X)”上进行 fit_transform，严防数据泄露。图谱序列和掩码无需处理。
X_train = imputer.fit_transform(X_train)
X_train = scaler.fit_transform(X_train)

# 4. 在验证集和测试集上仅进行 transform
X_val = imputer.transform(X_val)
X_val = scaler.transform(X_val)

X_test = imputer.transform(X_test)
X_test = scaler.transform(X_test)
# ----------------------------------------------------

# 5. 转为 Tensor 并构建 DataLoader
X_train_tensor = torch.FloatTensor(X_train).to(device)
seq_train_tensor = torch.FloatTensor(seq_train).to(device)
mask_train_tensor = torch.BoolTensor(mask_train).to(device) # 注意掩码用 BoolTensor
y_train_tensor = torch.LongTensor(y_train).to(device)  

X_val_tensor = torch.FloatTensor(X_val).to(device)
seq_val_tensor = torch.FloatTensor(seq_val).to(device)
mask_val_tensor = torch.BoolTensor(mask_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
seq_test_tensor = torch.FloatTensor(seq_test).to(device)
mask_test_tensor = torch.BoolTensor(mask_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)

# 将 4 个张量打包进入 Dataset
train_dataset = TensorDataset(X_train_tensor, seq_train_tensor, mask_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, seq_val_tensor, mask_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, seq_test_tensor, mask_test_tensor, y_test_tensor)

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    # 接收新增的 mask 张量
    for inputs, transe_embed, mask, labels in loader:
        inputs = inputs.to(device)
        transe_embed = transe_embed.to(device)
        mask = mask.to(device)
        labels = labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        # 将 mask 传入模型
        outputs = model(inputs, transe_embed, mask)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        # 接收新增的 mask 张量
        for inputs, transe_embed, mask, labels in loader:
            inputs = inputs.to(device)
            transe_embed = transe_embed.to(device)
            mask = mask.to(device)
            labels = labels.to(device)
            labels = labels.long()
            
            # 将 mask 传入模型
            outputs = model(inputs, transe_embed, mask)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
embed_dim = 128
transe_embed_dim = 128
num_epochs = 200
batch_size = 32
learning_rate = 1e-5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Using device:', device)
weight_decay = 1e-3

# 初始化模型 
model = KGMultiModalPerceiver(
    ehr_dim=53, 
    img_dim=64, 
    bio_dim=43, 
    embed_dim=128,           # 映射后的统一特征维度
    latent_dim_low=32,       # 底层融合和图谱精炼的潜变量序列长度（对应你原先想设定的 num_latents）
    latent_dim_high=16,      # 高阶融合的潜变量序列长度（实现进一步的信息压缩）
    num_heads=4,             # 注意力头数
    transe_embed_dim=128     # KG 嵌入维度
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate,weight_decay=weight_decay)

train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"test Loss: {test_loss:.4f}, test AUC: {test_auc:.4f}")
# Out:
# Using device: cuda
# Epoch 1/200, Train Loss: 1.1390, Train AUC: 0.5217  test Loss: 1.0670, test AUC: 0.6898
# Epoch 2/200, Train Loss: 1.1014, Train AUC: 0.5692  test Loss: 1.0420, test AUC: 0.7563
# Epoch 3/200, Train Loss: 1.0493, Train AUC: 0.6293  test Loss: 0.9952, test AUC: 0.8009
# Epoch 4/200, Train Loss: 0.9823, Train AUC: 0.6954  test Loss: 0.8970, test AUC: 0.8162
# Epoch 5/200, Train Loss: 0.8968, Train AUC: 0.7578  test Loss: 0.7959, test AUC: 0.8446
# Epoch 6/200, Train Loss: 0.8243, Train AUC: 0.7940  test Loss: 0.7353, test AUC: 0.8409
# Epoch 7/200, Train Loss: 0.7716, Train AUC: 0.8274  test Loss: 0.6790, test AUC: 0.8591
# Epoch 8/200, Train Loss: 0.7329, Train AUC: 0.8393  test Loss: 0.6707, test AUC: 0.8772
# Epoch 9/200, Train Loss: 0.7074, Train AUC: 0.8437  test Loss: 0.6444, test AUC: 0.8774
# Epoch 10/200, Train Loss: 0.6736, Train AUC: 0.8667  test Loss: 0.6298, test AUC: 0.8733
# Epoch 11/200, Train Loss: 0.6687, Train AUC: 0.8642  test Loss: 0.6159, test AUC: 0.8745
# Epoch 12/200, Train Loss: 0.6499, Train AUC: 0.8720  test Loss: 0.5947, test AUC: 0.8820
# Epoch 13/200, Train Loss: 0.6495, Train AUC: 0.8750  test Loss: 0.5935, test AUC: 0.8764
# Epoch 14/200, Train Loss: 0.6314, Train AUC: 0.8772  test Loss: 0.5784, test AUC: 0.8852
# Epoch 15/200, Train Loss: 0.6249, Train AUC: 0.8820  test Loss: 0.5754, test AUC: 0.8921
# Epoch 16/200, Train Loss: 0.6191, Train AUC: 0.8818  test Loss: 0.5728, test AUC: 0.8924
# Epoch 17/200, Train Loss: 0.6123, Train AUC: 0.8840  test Loss: 0.5626, test AUC: 0.8912
# Epoch 18/200, Train Loss: 0.6063, Train AUC: 0.8831  test Loss: 0.5529, test AUC: 0.8931
# Epoch 19/200, Train Loss: 0.5940, Train AUC: 0.8895  test Loss: 0.5522, test AUC: 0.8898
# Epoch 20/200, Train Loss: 0.5810, Train AUC: 0.8928  test Loss: 0.5448, test AUC: 0.8949
# Epoch 21/200, Train Loss: 0.5831, Train AUC: 0.8930  test Loss: 0.5473, test AUC: 0.8921
# Epoch 22/200, Train Loss: 0.5807, Train AUC: 0.8893  test Loss: 0.5378, test AUC: 0.8905
# Epoch 23/200, Train Loss: 0.5783, Train AUC: 0.8945  test Loss: 0.5419, test AUC: 0.9045
# Epoch 24/200, Train Loss: 0.5637, Train AUC: 0.9007  test Loss: 0.5264, test AUC: 0.9026
# Epoch 25/200, Train Loss: 0.5540, Train AUC: 0.9014  test Loss: 0.5260, test AUC: 0.9012
# Epoch 26/200, Train Loss: 0.5568, Train AUC: 0.8991  test Loss: 0.5255, test AUC: 0.8962
# Epoch 27/200, Train Loss: 0.5435, Train AUC: 0.9032  test Loss: 0.5225, test AUC: 0.8939
# Epoch 28/200, Train Loss: 0.5489, Train AUC: 0.8998  test Loss: 0.5160, test AUC: 0.9083
# Epoch 29/200, Train Loss: 0.5409, Train AUC: 0.9044  test Loss: 0.5118, test AUC: 0.9058
# Epoch 30/200, Train Loss: 0.5558, Train AUC: 0.8985  test Loss: 0.5071, test AUC: 0.9100
# Epoch 31/200, Train Loss: 0.5536, Train AUC: 0.8987  test Loss: 0.5082, test AUC: 0.9116
# Epoch 32/200, Train Loss: 0.5356, Train AUC: 0.9052  test Loss: 0.5011, test AUC: 0.9092
# Epoch 33/200, Train Loss: 0.5264, Train AUC: 0.9078  test Loss: 0.5016, test AUC: 0.9007
# Epoch 34/200, Train Loss: 0.5320, Train AUC: 0.9036  test Loss: 0.4998, test AUC: 0.9079
# Epoch 35/200, Train Loss: 0.5347, Train AUC: 0.9070  test Loss: 0.4936, test AUC: 0.9111
# Epoch 36/200, Train Loss: 0.5197, Train AUC: 0.9095  test Loss: 0.4895, test AUC: 0.9103
# Epoch 37/200, Train Loss: 0.5330, Train AUC: 0.9036  test Loss: 0.4936, test AUC: 0.9049
# Epoch 38/200, Train Loss: 0.5210, Train AUC: 0.9083  test Loss: 0.4966, test AUC: 0.9000
# Epoch 39/200, Train Loss: 0.5093, Train AUC: 0.9114  test Loss: 0.4931, test AUC: 0.8969
# Epoch 40/200, Train Loss: 0.5149, Train AUC: 0.9062  test Loss: 0.4944, test AUC: 0.9014
# Epoch 41/200, Train Loss: 0.5172, Train AUC: 0.9086  test Loss: 0.4816, test AUC: 0.9109
# Epoch 42/200, Train Loss: 0.4939, Train AUC: 0.9155  test Loss: 0.4857, test AUC: 0.9094
# Epoch 43/200, Train Loss: 0.5085, Train AUC: 0.9104  test Loss: 0.4952, test AUC: 0.8956
# Epoch 44/200, Train Loss: 0.5043, Train AUC: 0.9127  test Loss: 0.4864, test AUC: 0.9118
# Epoch 45/200, Train Loss: 0.5195, Train AUC: 0.9111  test Loss: 0.4806, test AUC: 0.9081
# Epoch 46/200, Train Loss: 0.5072, Train AUC: 0.9101  test Loss: 0.4855, test AUC: 0.9036
# Epoch 47/200, Train Loss: 0.5130, Train AUC: 0.9118  test Loss: 0.4806, test AUC: 0.9021
# Epoch 48/200, Train Loss: 0.4923, Train AUC: 0.9166  test Loss: 0.4758, test AUC: 0.9093
# Epoch 49/200, Train Loss: 0.5037, Train AUC: 0.9111  test Loss: 0.4737, test AUC: 0.9140
# Epoch 50/200, Train Loss: 0.5069, Train AUC: 0.9118  test Loss: 0.4787, test AUC: 0.9059
# Epoch 51/200, Train Loss: 0.4967, Train AUC: 0.9141  test Loss: 0.4711, test AUC: 0.9120
# Epoch 52/200, Train Loss: 0.5008, Train AUC: 0.9159  test Loss: 0.4754, test AUC: 0.9099
# Epoch 53/200, Train Loss: 0.4757, Train AUC: 0.9199  test Loss: 0.4694, test AUC: 0.9120
# Epoch 54/200, Train Loss: 0.4980, Train AUC: 0.9135  test Loss: 0.4696, test AUC: 0.9117
# Epoch 55/200, Train Loss: 0.4890, Train AUC: 0.9154  test Loss: 0.4664, test AUC: 0.9128
# Epoch 56/200, Train Loss: 0.4766, Train AUC: 0.9181  test Loss: 0.4836, test AUC: 0.8976
# Epoch 57/200, Train Loss: 0.4970, Train AUC: 0.9132  test Loss: 0.4709, test AUC: 0.9117
# Epoch 58/200, Train Loss: 0.4830, Train AUC: 0.9199  test Loss: 0.4758, test AUC: 0.9024
# Epoch 59/200, Train Loss: 0.4974, Train AUC: 0.9175  test Loss: 0.4787, test AUC: 0.9156
# Epoch 60/200, Train Loss: 0.4750, Train AUC: 0.9211  test Loss: 0.4704, test AUC: 0.9069
# Epoch 61/200, Train Loss: 0.4796, Train AUC: 0.9188  test Loss: 0.4710, test AUC: 0.9056
# Epoch 62/200, Train Loss: 0.4769, Train AUC: 0.9205  test Loss: 0.4692, test AUC: 0.9113
# Epoch 63/200, Train Loss: 0.4751, Train AUC: 0.9217  test Loss: 0.4639, test AUC: 0.9129
# Epoch 64/200, Train Loss: 0.4800, Train AUC: 0.9181  test Loss: 0.4673, test AUC: 0.9066
# Epoch 65/200, Train Loss: 0.4646, Train AUC: 0.9263  test Loss: 0.4706, test AUC: 0.9147
# Epoch 66/200, Train Loss: 0.4724, Train AUC: 0.9246  test Loss: 0.4672, test AUC: 0.9097
# Epoch 67/200, Train Loss: 0.4771, Train AUC: 0.9168  test Loss: 0.4731, test AUC: 0.9047
# Epoch 68/200, Train Loss: 0.4770, Train AUC: 0.9197  test Loss: 0.4668, test AUC: 0.9105
# Epoch 69/200, Train Loss: 0.4788, Train AUC: 0.9163  test Loss: 0.4642, test AUC: 0.9070
# Epoch 70/200, Train Loss: 0.4632, Train AUC: 0.9261  test Loss: 0.4709, test AUC: 0.9048
# Epoch 71/200, Train Loss: 0.4860, Train AUC: 0.9167  test Loss: 0.4821, test AUC: 0.8942
# Epoch 72/200, Train Loss: 0.4641, Train AUC: 0.9214  test Loss: 0.4657, test AUC: 0.9091
# Epoch 73/200, Train Loss: 0.4803, Train AUC: 0.9204  test Loss: 0.4609, test AUC: 0.9133
# Epoch 74/200, Train Loss: 0.4707, Train AUC: 0.9222  test Loss: 0.4713, test AUC: 0.9056
# Epoch 75/200, Train Loss: 0.4558, Train AUC: 0.9254  test Loss: 0.4741, test AUC: 0.9007
# Epoch 76/200, Train Loss: 0.4604, Train AUC: 0.9244  test Loss: 0.4654, test AUC: 0.9054
# Epoch 77/200, Train Loss: 0.4578, Train AUC: 0.9244  test Loss: 0.4714, test AUC: 0.9025
# Epoch 78/200, Train Loss: 0.4581, Train AUC: 0.9229  test Loss: 0.4638, test AUC: 0.9073
# Epoch 79/200, Train Loss: 0.4734, Train AUC: 0.9198  test Loss: 0.4636, test AUC: 0.9126
# Epoch 80/200, Train Loss: 0.4646, Train AUC: 0.9232  test Loss: 0.4651, test AUC: 0.9104
# Epoch 81/200, Train Loss: 0.4629, Train AUC: 0.9233  test Loss: 0.4678, test AUC: 0.9048
# Epoch 82/200, Train Loss: 0.4521, Train AUC: 0.9244  test Loss: 0.4641, test AUC: 0.9084
# Epoch 83/200, Train Loss: 0.4570, Train AUC: 0.9243  test Loss: 0.4674, test AUC: 0.9045
# Epoch 84/200, Train Loss: 0.4580, Train AUC: 0.9275  test Loss: 0.4657, test AUC: 0.9060
# Epoch 85/200, Train Loss: 0.4397, Train AUC: 0.9314  test Loss: 0.4702, test AUC: 0.9027
# Epoch 86/200, Train Loss: 0.4510, Train AUC: 0.9253  test Loss: 0.4668, test AUC: 0.9052
# Epoch 87/200, Train Loss: 0.4457, Train AUC: 0.9311  test Loss: 0.4638, test AUC: 0.9139
# Epoch 88/200, Train Loss: 0.4409, Train AUC: 0.9295  test Loss: 0.4728, test AUC: 0.9023
# Epoch 89/200, Train Loss: 0.4458, Train AUC: 0.9276  test Loss: 0.4641, test AUC: 0.9048
# Epoch 90/200, Train Loss: 0.4339, Train AUC: 0.9325  test Loss: 0.4667, test AUC: 0.9048
# Epoch 91/200, Train Loss: 0.4392, Train AUC: 0.9308  test Loss: 0.4690, test AUC: 0.9020
# Epoch 92/200, Train Loss: 0.4623, Train AUC: 0.9242  test Loss: 0.4648, test AUC: 0.9112
# Epoch 93/200, Train Loss: 0.4449, Train AUC: 0.9267  test Loss: 0.4623, test AUC: 0.9097
# Epoch 94/200, Train Loss: 0.4450, Train AUC: 0.9294  test Loss: 0.4647, test AUC: 0.9108
# Epoch 95/200, Train Loss: 0.4417, Train AUC: 0.9287  test Loss: 0.4652, test AUC: 0.9128
# Epoch 96/200, Train Loss: 0.4635, Train AUC: 0.9247  test Loss: 0.4627, test AUC: 0.9055
# Epoch 97/200, Train Loss: 0.4554, Train AUC: 0.9279  test Loss: 0.4703, test AUC: 0.9006
# Epoch 98/200, Train Loss: 0.4531, Train AUC: 0.9257  test Loss: 0.4639, test AUC: 0.9058
# Epoch 99/200, Train Loss: 0.4404, Train AUC: 0.9298  test Loss: 0.4749, test AUC: 0.8965
# Epoch 100/200, Train Loss: 0.4340, Train AUC: 0.9313  test Loss: 0.4720, test AUC: 0.8999
# Epoch 101/200, Train Loss: 0.4509, Train AUC: 0.9269  test Loss: 0.4658, test AUC: 0.9060
# Epoch 102/200, Train Loss: 0.4313, Train AUC: 0.9340  test Loss: 0.4628, test AUC: 0.9113
# Epoch 103/200, Train Loss: 0.4416, Train AUC: 0.9272  test Loss: 0.4722, test AUC: 0.8995
# Epoch 104/200, Train Loss: 0.4439, Train AUC: 0.9268  test Loss: 0.4726, test AUC: 0.9056
# Epoch 105/200, Train Loss: 0.4417, Train AUC: 0.9314  test Loss: 0.4766, test AUC: 0.8985
# Epoch 106/200, Train Loss: 0.4327, Train AUC: 0.9321  test Loss: 0.4713, test AUC: 0.9034
# Epoch 107/200, Train Loss: 0.4312, Train AUC: 0.9334  test Loss: 0.4693, test AUC: 0.8997
# Epoch 108/200, Train Loss: 0.4384, Train AUC: 0.9297  test Loss: 0.4641, test AUC: 0.9044
# Epoch 109/200, Train Loss: 0.4237, Train AUC: 0.9328  test Loss: 0.4778, test AUC: 0.8973
# Epoch 110/200, Train Loss: 0.4369, Train AUC: 0.9291  test Loss: 0.4709, test AUC: 0.8993
# Epoch 111/200, Train Loss: 0.4205, Train AUC: 0.9357  test Loss: 0.4639, test AUC: 0.9051
# Epoch 112/200, Train Loss: 0.4115, Train AUC: 0.9374  test Loss: 0.4679, test AUC: 0.9037
# Epoch 113/200, Train Loss: 0.4289, Train AUC: 0.9322  test Loss: 0.4822, test AUC: 0.8946
# Epoch 114/200, Train Loss: 0.4387, Train AUC: 0.9286  test Loss: 0.4734, test AUC: 0.9013
# Epoch 115/200, Train Loss: 0.4407, Train AUC: 0.9315  test Loss: 0.4707, test AUC: 0.9040
# Epoch 116/200, Train Loss: 0.4301, Train AUC: 0.9315  test Loss: 0.4807, test AUC: 0.8944
# Epoch 117/200, Train Loss: 0.4215, Train AUC: 0.9353  test Loss: 0.4714, test AUC: 0.9021
# Epoch 118/200, Train Loss: 0.4121, Train AUC: 0.9380  test Loss: 0.4833, test AUC: 0.8947
# Epoch 119/200, Train Loss: 0.4210, Train AUC: 0.9373  test Loss: 0.4733, test AUC: 0.9000
# Epoch 120/200, Train Loss: 0.4223, Train AUC: 0.9363  test Loss: 0.4693, test AUC: 0.9053
# Epoch 121/200, Train Loss: 0.4300, Train AUC: 0.9358  test Loss: 0.4781, test AUC: 0.8974
# Epoch 122/200, Train Loss: 0.4036, Train AUC: 0.9424  test Loss: 0.4701, test AUC: 0.9059
# Epoch 123/200, Train Loss: 0.4107, Train AUC: 0.9381  test Loss: 0.4691, test AUC: 0.9019
# Epoch 124/200, Train Loss: 0.4244, Train AUC: 0.9326  test Loss: 0.4904, test AUC: 0.8908
# Epoch 125/200, Train Loss: 0.4521, Train AUC: 0.9344  test Loss: 0.4949, test AUC: 0.8916
# Epoch 126/200, Train Loss: 0.4264, Train AUC: 0.9342  test Loss: 0.4760, test AUC: 0.9000
# Epoch 127/200, Train Loss: 0.4200, Train AUC: 0.9344  test Loss: 0.4687, test AUC: 0.9008
# Epoch 128/200, Train Loss: 0.4058, Train AUC: 0.9407  test Loss: 0.4733, test AUC: 0.9022
# Epoch 129/200, Train Loss: 0.4186, Train AUC: 0.9357  test Loss: 0.4658, test AUC: 0.9075
# Epoch 130/200, Train Loss: 0.4217, Train AUC: 0.9379  test Loss: 0.4686, test AUC: 0.9052
# Epoch 131/200, Train Loss: 0.4244, Train AUC: 0.9363  test Loss: 0.4727, test AUC: 0.9041
# Epoch 132/200, Train Loss: 0.4154, Train AUC: 0.9363  test Loss: 0.4765, test AUC: 0.9024
# Epoch 133/200, Train Loss: 0.4073, Train AUC: 0.9406  test Loss: 0.4737, test AUC: 0.9013
# Epoch 134/200, Train Loss: 0.4205, Train AUC: 0.9374  test Loss: 0.4796, test AUC: 0.8986
# Epoch 135/200, Train Loss: 0.4217, Train AUC: 0.9332  test Loss: 0.4797, test AUC: 0.8977
# Epoch 136/200, Train Loss: 0.4103, Train AUC: 0.9372  test Loss: 0.4706, test AUC: 0.9043
# Epoch 137/200, Train Loss: 0.4270, Train AUC: 0.9330  test Loss: 0.4730, test AUC: 0.9035
# Epoch 138/200, Train Loss: 0.4077, Train AUC: 0.9408  test Loss: 0.4788, test AUC: 0.8987
# Epoch 139/200, Train Loss: 0.3984, Train AUC: 0.9411  test Loss: 0.4792, test AUC: 0.8966
# Epoch 140/200, Train Loss: 0.4082, Train AUC: 0.9387  test Loss: 0.4745, test AUC: 0.9014
# Epoch 141/200, Train Loss: 0.4005, Train AUC: 0.9420  test Loss: 0.4761, test AUC: 0.8970
# Epoch 142/200, Train Loss: 0.4122, Train AUC: 0.9370  test Loss: 0.4727, test AUC: 0.9021
# Epoch 143/200, Train Loss: 0.4451, Train AUC: 0.9303  test Loss: 0.4924, test AUC: 0.8899
# Epoch 144/200, Train Loss: 0.4049, Train AUC: 0.9429  test Loss: 0.4841, test AUC: 0.8970
# Epoch 145/200, Train Loss: 0.4042, Train AUC: 0.9432  test Loss: 0.4876, test AUC: 0.8939
# Epoch 146/200, Train Loss: 0.4037, Train AUC: 0.9391  test Loss: 0.4788, test AUC: 0.9001
# Epoch 147/200, Train Loss: 0.4050, Train AUC: 0.9416  test Loss: 0.4830, test AUC: 0.8961
# Epoch 148/200, Train Loss: 0.4083, Train AUC: 0.9403  test Loss: 0.4851, test AUC: 0.8970
# Epoch 149/200, Train Loss: 0.3985, Train AUC: 0.9420  test Loss: 0.4832, test AUC: 0.9010
# Epoch 150/200, Train Loss: 0.4141, Train AUC: 0.9387  test Loss: 0.4804, test AUC: 0.9030
# Epoch 151/200, Train Loss: 0.3978, Train AUC: 0.9416  test Loss: 0.4804, test AUC: 0.8989
# Epoch 152/200, Train Loss: 0.4020, Train AUC: 0.9389  test Loss: 0.4918, test AUC: 0.8913
# Epoch 153/200, Train Loss: 0.4035, Train AUC: 0.9427  test Loss: 0.4822, test AUC: 0.8963
# Epoch 154/200, Train Loss: 0.4005, Train AUC: 0.9421  test Loss: 0.4989, test AUC: 0.8919
# Epoch 155/200, Train Loss: 0.3971, Train AUC: 0.9408  test Loss: 0.4832, test AUC: 0.8965
# Epoch 156/200, Train Loss: 0.3830, Train AUC: 0.9463  test Loss: 0.4849, test AUC: 0.8973
# Epoch 157/200, Train Loss: 0.4013, Train AUC: 0.9393  test Loss: 0.4892, test AUC: 0.8930
# Epoch 158/200, Train Loss: 0.3850, Train AUC: 0.9447  test Loss: 0.4889, test AUC: 0.8997
# Epoch 159/200, Train Loss: 0.3758, Train AUC: 0.9479  test Loss: 0.4920, test AUC: 0.8927
# Epoch 160/200, Train Loss: 0.3904, Train AUC: 0.9443  test Loss: 0.4934, test AUC: 0.8904
# Epoch 161/200, Train Loss: 0.3898, Train AUC: 0.9428  test Loss: 0.4822, test AUC: 0.8953
# Epoch 162/200, Train Loss: 0.3759, Train AUC: 0.9496  test Loss: 0.5047, test AUC: 0.8870
# Epoch 163/200, Train Loss: 0.4078, Train AUC: 0.9388  test Loss: 0.4869, test AUC: 0.9066
# Epoch 164/200, Train Loss: 0.3870, Train AUC: 0.9442  test Loss: 0.4857, test AUC: 0.9002
# Epoch 165/200, Train Loss: 0.3827, Train AUC: 0.9474  test Loss: 0.4961, test AUC: 0.8916
# Epoch 166/200, Train Loss: 0.3889, Train AUC: 0.9442  test Loss: 0.4815, test AUC: 0.9004
# Epoch 167/200, Train Loss: 0.3747, Train AUC: 0.9482  test Loss: 0.4863, test AUC: 0.8949
# Epoch 168/200, Train Loss: 0.3856, Train AUC: 0.9461  test Loss: 0.4921, test AUC: 0.8964
# Epoch 169/200, Train Loss: 0.3829, Train AUC: 0.9466  test Loss: 0.4994, test AUC: 0.8909
# Epoch 170/200, Train Loss: 0.3961, Train AUC: 0.9416  test Loss: 0.4934, test AUC: 0.8932
# Epoch 171/200, Train Loss: 0.3931, Train AUC: 0.9437  test Loss: 0.4889, test AUC: 0.8915
# Epoch 172/200, Train Loss: 0.4034, Train AUC: 0.9458  test Loss: 0.4812, test AUC: 0.9008
# Epoch 173/200, Train Loss: 0.3802, Train AUC: 0.9455  test Loss: 0.5028, test AUC: 0.8872
# Epoch 174/200, Train Loss: 0.3827, Train AUC: 0.9470  test Loss: 0.5074, test AUC: 0.8830
# Epoch 175/200, Train Loss: 0.3895, Train AUC: 0.9440  test Loss: 0.4851, test AUC: 0.8949
# Epoch 176/200, Train Loss: 0.3864, Train AUC: 0.9472  test Loss: 0.4857, test AUC: 0.8981
# Epoch 177/200, Train Loss: 0.3833, Train AUC: 0.9489  test Loss: 0.4913, test AUC: 0.8980
# Epoch 178/200, Train Loss: 0.3783, Train AUC: 0.9469  test Loss: 0.4975, test AUC: 0.8882
# Epoch 179/200, Train Loss: 0.3807, Train AUC: 0.9474  test Loss: 0.4803, test AUC: 0.8991
# Epoch 180/200, Train Loss: 0.4126, Train AUC: 0.9425  test Loss: 0.4843, test AUC: 0.8966
# Epoch 181/200, Train Loss: 0.3727, Train AUC: 0.9482  test Loss: 0.4819, test AUC: 0.8984
# Epoch 182/200, Train Loss: 0.3668, Train AUC: 0.9503  test Loss: 0.5058, test AUC: 0.8867
# Epoch 183/200, Train Loss: 0.3837, Train AUC: 0.9457  test Loss: 0.5041, test AUC: 0.8889
# Epoch 184/200, Train Loss: 0.3669, Train AUC: 0.9500  test Loss: 0.4945, test AUC: 0.8907
# Epoch 185/200, Train Loss: 0.3853, Train AUC: 0.9453  test Loss: 0.4876, test AUC: 0.9000
# Epoch 186/200, Train Loss: 0.3758, Train AUC: 0.9468  test Loss: 0.4962, test AUC: 0.8921
# Epoch 187/200, Train Loss: 0.3850, Train AUC: 0.9480  test Loss: 0.4968, test AUC: 0.8935
# Epoch 188/200, Train Loss: 0.3807, Train AUC: 0.9480  test Loss: 0.4941, test AUC: 0.8960
# Epoch 189/200, Train Loss: 0.3643, Train AUC: 0.9506  test Loss: 0.4963, test AUC: 0.8913
# Epoch 190/200, Train Loss: 0.3647, Train AUC: 0.9496  test Loss: 0.4912, test AUC: 0.8944
# Epoch 191/200, Train Loss: 0.3813, Train AUC: 0.9455  test Loss: 0.4982, test AUC: 0.8906
# Epoch 192/200, Train Loss: 0.3754, Train AUC: 0.9488  test Loss: 0.4884, test AUC: 0.8947
# Epoch 193/200, Train Loss: 0.3639, Train AUC: 0.9505  test Loss: 0.5111, test AUC: 0.8852
# Epoch 194/200, Train Loss: 0.3643, Train AUC: 0.9528  test Loss: 0.5158, test AUC: 0.8869
# Epoch 195/200, Train Loss: 0.3737, Train AUC: 0.9476  test Loss: 0.4943, test AUC: 0.8880
# Epoch 196/200, Train Loss: 0.3622, Train AUC: 0.9516  test Loss: 0.4863, test AUC: 0.9007
# Epoch 197/200, Train Loss: 0.3728, Train AUC: 0.9475  test Loss: 0.4871, test AUC: 0.8995
# Epoch 198/200, Train Loss: 0.3730, Train AUC: 0.9469  test Loss: 0.5026, test AUC: 0.8875
# Epoch 199/200, Train Loss: 0.3604, Train AUC: 0.9523  test Loss: 0.4913, test AUC: 0.8955
# Epoch 200/200, Train Loss: 0.3694, Train AUC: 0.9507  test Loss: 0.5047, test AUC: 0.8921

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    # 接收新增的 mask 张量
    for inputs, transe_embed, mask, labels in val_loader:
        inputs = inputs.to(device)
        transe_embed = transe_embed.to(device)
        mask = mask.to(device)
        labels = labels.to(device)
        
        # 将 mask 传入模型
        outputs = model(inputs, transe_embed, mask)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.7778
# Recall:    0.7134
# F1 Score:  0.7164
# Precision: 0.7239
# AUC-ROC:   0.9151

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("NACC AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("NACC Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
import torch
from thop import profile

# 实例化影像提取模型
model_cnn = CNN_3D(num_class=64)

# 构建符合 NiiDataset 输出维度的虚拟输入
dummy_input_img = torch.randn(1, 1, 64, 64, 64)

# 使用 thop 计算指标
flops_cnn, params_cnn = profile(model_cnn, inputs=(dummy_input_img, ))

print("3D-CNN 参数量: %.2f M" % (params_cnn / 1e6))
print("3D-CNN 算力损耗 (FLOPs): %.2f G" % (flops_cnn / 1e9))
# Out:
# [INFO] Register count_convNd() for <class 'torch.nn.modules.conv.Conv3d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.activation.ReLU'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.pooling.MaxPool3d'>.
# [INFO] Register zero_ops() for <class 'torch.nn.modules.container.Sequential'>.
# [INFO] Register count_linear() for <class 'torch.nn.modules.linear.Linear'>.
# 3D-CNN 参数量: 8.41 M
# 3D-CNN 算力损耗 (FLOPs): 0.57 G

# %%
import torch
from thop import profile

# 1. 影像提取模块 (3D-CNN) 测算
model_cnn = CNN_3D(num_class=64).to(device)
dummy_input_img = torch.randn(1, 1, 64, 64, 64).to(device)
# verbose=False 用于关闭 thop 默认的逐层打印输出
flops_cnn, params_cnn = profile(model_cnn, inputs=(dummy_input_img, ), verbose=False)

# 2. 下游多模态分类模块 (Transformer) 测算
# 根据真实数据维度进行实例化
model_transformer = KGMultiModalPerceiver(
    ehr_dim=53, 
    img_dim=64, 
    bio_dim=43, 
    embed_dim=128, 
    num_heads=4, 
    transe_embed_dim=128
).to(device)

# 构建符合数据特征的虚拟输入
dummy_x = torch.randn(1, 160).to(device)
dummy_kg_seq = torch.randn(1, 45, 128).to(device)
dummy_kg_mask = torch.zeros(1, 45, dtype=torch.bool).to(device)

flops_trans, params_trans = profile(model_transformer, inputs=(dummy_x, dummy_kg_seq, dummy_kg_mask), verbose=False)

# 3. 打印统计结果
print("=" * 40)
print("【影像特征提取模块 (3D-CNN)】")
print(f"参数量: {params_cnn / 1e6:.4f} M")
print(f"算力损耗 (FLOPs): {flops_cnn / 1e9:.4f} G")
print("-" * 40)

print("【下游多模态分类模块 (KGMultiModalPerceiver)】")
print(f"参数量: {params_trans / 1e6:.4f} M")
print(f"算力损耗 (FLOPs): {flops_trans / 1e9:.4f} G")
print("-" * 40)

print("【总计】")
print(f"总参数量: {(params_cnn + params_trans) / 1e6:.4f} M")
print(f"总算力损耗: {(flops_cnn + flops_trans) / 1e9:.4f} G")
print("=" * 40)
