# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,KGMultiModalPerceiver,PerceiverAttentionBlock
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('NC.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'NC/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'AD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('MCI.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'MCI/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #44
print(count_no) #247
print(count_mci) #106
# Out:
# 72
# 358
# 86

# %%
# 基础替换字典
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','no':'0','yes':'1','ans':'2','haw':'3','ind':'4','bl':'1'}

# 隔离诊断标签的列索引提取规则
# EHR (2维): age(3), gender(4)
ehr_cols = [3, 4] 
# BIO (5维): apoe(5), mmse(18), cdr(19), lm_imm(20), lm_del(21)
bio_cols = [5, 18, 19, 20, 21]

# 统一且安全的预处理函数
def preprocess_data(data, replace_dict, target_cols):
    processed_data = []
    for row in data:
        # 仅提取安全的特征列
        extracted_row = [row[idx] for idx in target_cols]
        # 字典映射替换
        extracted_row = [replace_dict.get(item, item) for item in extracted_row]
        
        numerical_row = []
        for item in extracted_row:
            try:
                val = float(item)
                # 拦截 NaN，保留为 np.nan 供后续专门的 Imputer 处理
                if math.isnan(val):
                    val = np.nan
            except ValueError:
                val = np.nan 
            numerical_row.append(val)
            
        processed_data.append(numerical_row)
    return np.array(processed_data)

# 加权算值函数 
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
# 1. 提取 BIO 数组 (5 维特征)
ad_array = preprocess_data(data_ad, replace_dict, bio_cols)
normal_array = preprocess_data(data_normal, replace_dict, bio_cols)
mci_array = preprocess_data(data_mci, replace_dict, bio_cols)

# 2. 直接转换数据为 Tensor (无需外部线性层)
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()

# 3. 打印结果 (预期输出类似: torch.Size([72, 5]))
print('AD_tensor shape:', ad_tensor.shape)      
print('Normal_tensor shape:', normal_tensor.shape) 
print('MCI_tensor shape:', mci_tensor.shape)
# Out:
# AD_tensor shape: torch.Size([72, 5])
# Normal_tensor shape: torch.Size([358, 5])
# MCI_tensor shape: torch.Size([86, 5])

# %%
# 1. 提取脱敏后的 EHR 数组 (内部已通过 replace_dict 转换为数值)
ad_data = preprocess_data(data_ad, replace_dict, ehr_cols)
normal_data = preprocess_data(data_normal, replace_dict, ehr_cols)
mci_data = preprocess_data(data_mci, replace_dict, ehr_cols)

# 2. 直接转换为 Tensor (无需外部线性层)
ad_EHR = torch.from_numpy(ad_data).float()
normal_EHR = torch.from_numpy(normal_data).float()
mci_EHR = torch.from_numpy(mci_data).float()

# 3. 打印结果 (预期输出类似: torch.Size([72, 2]))
print('ad.EHR--->', ad_EHR.shape)
print('normal.EHR--->', normal_EHR.shape)
print('mci.EHR--->', mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([72, 2])
# normal.EHR---> torch.Size([358, 2])
# mci.EHR---> torch.Size([86, 2])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import os
import torch
from torch.utils.data import DataLoader

def get_nii_file_list(folder_path):
    return [os.path.join(folder_path, f) for f in os.listdir(folder_path)
            if f.endswith('.nii') or f.endswith('.nii.gz')]

# 1. 实例化模型，将输出维度设为64，严格匹配 Transformer
nii = CNN_3D(num_class=64)
nii = nii.to(device)
nii.eval() # 开启评估模式

def extract_mri_features(folder_path, batch_size=16):
    # 保留 AIBL 获取文件列表的逻辑
    nii_files = get_nii_file_list(folder_path)
    dataset = NiiDataset(nii_files)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    all_outputs = []
    
    # 2. 关闭梯度计算
    with torch.no_grad():
        for batch_idx, batch_data in enumerate(dataloader):
            batch_data = batch_data.to(device)
            output = nii(batch_data)
            # 提取后立即转回 CPU
            all_outputs.append(output.cpu())
            
    return torch.cat(all_outputs, dim=0)

# 3. 模块化调用，保留原始文件夹名称
ad_output = extract_mri_features('AD')
print('ad nii shape--->', ad_output.shape)

normal_output = extract_mri_features('NC')
print('normal nii shape--->', normal_output.shape)

mci_output = extract_mri_features('MCI')
print('mci nii shape--->', mci_output.shape)
# Out:
# ad nii shape---> torch.Size([72, 64])
# normal nii shape---> torch.Size([358, 64])
# mci nii shape---> torch.Size([86, 64])

# %%
import numpy as np
import torch
import pandas as pd
import json

# 1. 替换为AIBL数据集对应的图谱特征文件
ENTITY_EMB_NPY = "AIBL-DementiaHKG-Embeddings.npy"
ENTITY2ID_FILE = "AIBL-DementiaHKG-Entity2ID.json"
PATIENT_QUERY_DICT = "AIBL-DementiaHKG-Entities.json"

with open(ENTITY2ID_FILE, 'r', encoding='utf-8') as f:
    entity2id = json.load(f)

with open(PATIENT_QUERY_DICT, 'r', encoding='utf-8') as f:
    patient_entities = json.load(f)

emb = torch.from_numpy(np.load(ENTITY_EMB_NPY)).float()
embed_dim = emb.shape[1] 

# 2. 核心修改：将序列长度下调至16，适配AIBL的数据维度
max_seq_len = 16 

def get_patient_embedding_seq(filename: str):
    filename = str(filename).strip()
    patient_data = patient_entities.get(filename, {})
    active_nodes = patient_data.get("input_nodes", [])
    
    vecs = []
    pad_masks = []
    
    # 构造固定长度为16的序列与对应的布尔掩码
    for i in range(max_seq_len):
        if i < len(active_nodes):
            node = active_nodes[i]
            if node != "[PAD]" and node in entity2id:
                vecs.append(emb[entity2id[node]])
                pad_masks.append(False)  # 保持你正确的逻辑：False代表有效节点
            else:
                vecs.append(torch.zeros(embed_dim))
                pad_masks.append(True)   # True代表PAD，让注意力机制忽略
        else:
            vecs.append(torch.zeros(embed_dim))
            pad_masks.append(True)
            
    # 返回知识序列矩阵和用于PyTorch注意力的掩码
    return torch.stack(vecs), torch.tensor(pad_masks, dtype=torch.bool)

def process_and_verify_seq(df, cohort_name):
    seq_tensors = []
    mask_tensors = []
    valid_count = 0
    
    for _, r in df.iterrows():
        seq_tensor, mask_tensor = get_patient_embedding_seq(r['filename'])
        seq_tensors.append(seq_tensor)
        mask_tensors.append(mask_tensor)
        
        # 验证是否包含至少一个有效节点（掩码中存在False）
        if not torch.all(mask_tensor):
            valid_count += 1
            
    stacked_seq = torch.stack(seq_tensors)
    stacked_mask = torch.stack(mask_tensors)
    
    print(f"[{cohort_name}] 总样本数: {len(df)} | 成功注入KG先验序列的样本数: {valid_count}")
    return stacked_seq, stacked_mask

# ==========================================
# 3. 沿用ADNI的三个独立表格提取方式
# ==========================================
print("开始提取AIBL完整知识序列与注意力掩码...")
ad_transe_seq, ad_transe_mask = process_and_verify_seq(pd.read_csv('AD.csv'), "AD")
mci_transe_seq, mci_transe_mask = process_and_verify_seq(pd.read_csv('mci.csv'), "MCI")
normal_transe_seq, normal_transe_mask = process_and_verify_seq(pd.read_csv('NC.csv'), "NC")

print("-" * 50)
print("最终生成的知识序列 Shapes:", ad_transe_seq.shape, mci_transe_seq.shape, normal_transe_seq.shape)
print("最终生成的掩码张量 Shapes:", ad_transe_mask.shape, mci_transe_mask.shape, normal_transe_mask.shape)
# Out:
# 开始提取AIBL完整知识序列与注意力掩码...
# [AD] 总样本数: 72 | 成功注入KG先验序列的样本数: 72
# [MCI] 总样本数: 86 | 成功注入KG先验序列的样本数: 86
# [NC] 总样本数: 358 | 成功注入KG先验序列的样本数: 358
# --------------------------------------------------
# 最终生成的知识序列 Shapes: torch.Size([72, 16, 128]) torch.Size([86, 16, 128]) torch.Size([358, 16, 128])
# 最终生成的掩码张量 Shapes: torch.Size([72, 16]) torch.Size([86, 16]) torch.Size([358, 16])

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import numpy as np

# ==========================================
# 1. 组合基础多模态特征 (EHR + IMG + BIO)
# 严格匹配你的变量名：ad_EHR, ad_output, ad_tensor 等
# ==========================================
X_ad = torch.cat([ad_EHR, ad_output, ad_tensor], dim=1)
X_mci = torch.cat([mci_EHR, mci_output, mci_tensor], dim=1)
X_normal = torch.cat([normal_EHR, normal_output, normal_tensor], dim=1)

y_ad = torch.ones(len(X_ad)) * 2
y_mci = torch.ones(len(X_mci)) * 1
y_normal = torch.ones(len(X_normal)) * 0

# ==========================================
# 2. 沿着 batch 维度合并所有数据
# ==========================================
X_all = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y_all = torch.cat([y_ad, y_mci, y_normal], dim=0).long()

# 合并提取好的三维知识序列和二维掩码 (使用你代码中的 normal_transe_seq)
kg_seq_all = torch.cat([ad_transe_seq, mci_transe_seq, normal_transe_seq], dim=0).float()
kg_mask_all = torch.cat([ad_transe_mask, mci_transe_mask, normal_transe_mask], dim=0).bool()

# ==========================================
# 3. 使用索引(Index)进行一致性数据集切分
# ==========================================
indices = np.arange(len(y_all))
idx_train, idx_test, y_train, y_test = train_test_split(
    indices, y_all.numpy(), test_size=0.20, stratify=y_all.numpy(), random_state=32
)
idx_train, idx_val, y_train, y_val = train_test_split(
    idx_train, y_train, test_size=0.20, stratify=y_train, random_state=30
)

# ==========================================
# 4. 根据划分好的索引，生成并分发对应的 Tensor 到 GPU
# ==========================================
X_train_t = X_all[idx_train].to(device)
seq_train_t = kg_seq_all[idx_train].to(device)
mask_train_t = kg_mask_all[idx_train].to(device)
y_train_t = torch.tensor(y_train, dtype=torch.long).to(device)

X_val_t = X_all[idx_val].to(device)
seq_val_t = kg_seq_all[idx_val].to(device)
mask_val_t = kg_mask_all[idx_val].to(device)
y_val_t = torch.tensor(y_val, dtype=torch.long).to(device)

X_test_t = X_all[idx_test].to(device)
seq_test_t = kg_seq_all[idx_test].to(device)
mask_test_t = kg_mask_all[idx_test].to(device)
y_test_t = torch.tensor(y_test, dtype=torch.long).to(device)

# ==========================================
# 5. 封装 DataLoader (包含4个元素：X, seq, mask, y)
# ==========================================
train_dataset = TensorDataset(X_train_t, seq_train_t, mask_train_t, y_train_t)
val_dataset = TensorDataset(X_val_t, seq_val_t, mask_val_t, y_val_t)
test_dataset = TensorDataset(X_test_t, seq_test_t, mask_test_t, y_test_t)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

print("数据准备完毕！Train:", len(train_dataset), "Val:", len(val_dataset), "Test:", len(test_dataset))
# Out:
# 数据准备完毕！Train: 329 Val: 83 Test: 104

# %%
from sklearn.metrics import roc_auc_score, f1_score, recall_score, precision_score
import numpy as np

def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs, all_labels, all_preds = [], [], []
    
    # ★ 修改点：解包出4个变量
    for inputs, kg_seq, kg_mask, labels in loader:
        optimizer.zero_grad()
        
        # ★ 修改点：传入 seq 和 mask
        outputs = model(inputs, kg_seq, kg_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs, all_labels, all_preds = [], [], []
    
    with torch.no_grad():
        for inputs, kg_seq, kg_mask, labels in loader:
            outputs = model(inputs, kg_seq, kg_mask)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
import torch.optim as optim
import torch.nn as nn

# AIBL 数据集的具体参数
ehr_dim = 2
img_dim = 64
bio_dim = 5
max_seq_len = 16

num_epochs = 200
learning_rate = 1e-5
weight_decay = 1e-3

# ★ 修改点：实例化新的AIBL专属Perceiver陪跑模型
model = KGMultiModalPerceiver(
    ehr_dim=ehr_dim, 
    img_dim=img_dim, 
    bio_dim=bio_dim, 
    embed_dim=128,            
    latent_dim_low=16,          # Perceiver底层潜变量维度
    latent_dim_high=8,          # Perceiver高层潜变量维度
    num_heads=4,                # 注意力头数
    transe_embed_dim=128, 
    max_seq_len=max_seq_len
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

train_losses, train_aucs, train_f1s, train_recalls, train_precisions = [], [], [], [], []
test_losses, test_aucs, test_f1s, test_recalls, test_precisions = [], [], [], [], []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"Test Loss: {test_loss:.4f}, Test AUC: {test_auc:.4f}")
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 1/200, Train Loss: 1.0925, Train AUC: 0.4618  Test Loss: 1.0864, Test AUC: 0.4747
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 2/200, Train Loss: 1.0750, Train AUC: 0.4650  Test Loss: 1.0971, Test AUC: 0.4407
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 3/200, Train Loss: 1.0700, Train AUC: 0.4535  Test Loss: 1.0991, Test AUC: 0.4974
# Epoch 4/200, Train Loss: 1.0473, Train AUC: 0.5108  Test Loss: 1.0993, Test AUC: 0.5598
# Epoch 5/200, Train Loss: 1.0437, Train AUC: 0.5069  Test Loss: 1.0890, Test AUC: 0.5902
# Epoch 6/200, Train Loss: 1.0563, Train AUC: 0.4499  Test Loss: 1.0738, Test AUC: 0.6254
# Epoch 7/200, Train Loss: 1.0311, Train AUC: 0.5020  Test Loss: 1.0572, Test AUC: 0.6243
# Epoch 8/200, Train Loss: 0.9989, Train AUC: 0.5280  Test Loss: 1.0581, Test AUC: 0.6408
# Epoch 9/200, Train Loss: 1.0300, Train AUC: 0.5018  Test Loss: 1.0639, Test AUC: 0.6191
# Epoch 10/200, Train Loss: 1.0100, Train AUC: 0.5253  Test Loss: 1.0625, Test AUC: 0.6579
# Epoch 11/200, Train Loss: 1.0076, Train AUC: 0.5382  Test Loss: 1.0442, Test AUC: 0.6928
# Epoch 12/200, Train Loss: 0.9968, Train AUC: 0.5707  Test Loss: 1.0427, Test AUC: 0.6817
# Epoch 13/200, Train Loss: 0.9868, Train AUC: 0.5585  Test Loss: 1.0360, Test AUC: 0.7082
# Epoch 14/200, Train Loss: 0.9652, Train AUC: 0.5917  Test Loss: 1.0351, Test AUC: 0.7152
# Epoch 15/200, Train Loss: 0.9624, Train AUC: 0.5746  Test Loss: 1.0328, Test AUC: 0.7408
# Epoch 16/200, Train Loss: 1.0180, Train AUC: 0.4879  Test Loss: 1.0180, Test AUC: 0.7244
# Epoch 17/200, Train Loss: 0.9591, Train AUC: 0.5979  Test Loss: 0.9980, Test AUC: 0.7588
# Epoch 18/200, Train Loss: 0.9474, Train AUC: 0.6084  Test Loss: 0.9899, Test AUC: 0.7605
# Epoch 19/200, Train Loss: 0.9552, Train AUC: 0.5899  Test Loss: 0.9991, Test AUC: 0.7705
# Epoch 20/200, Train Loss: 0.9823, Train AUC: 0.5437  Test Loss: 0.9896, Test AUC: 0.7814
# Epoch 21/200, Train Loss: 0.9345, Train AUC: 0.6138  Test Loss: 0.9783, Test AUC: 0.7855
# Epoch 22/200, Train Loss: 0.9332, Train AUC: 0.6287  Test Loss: 0.9589, Test AUC: 0.8012
# Epoch 23/200, Train Loss: 0.9182, Train AUC: 0.6447  Test Loss: 0.9615, Test AUC: 0.7806
# Epoch 24/200, Train Loss: 0.8973, Train AUC: 0.6925  Test Loss: 0.9611, Test AUC: 0.7984
# Epoch 25/200, Train Loss: 0.8520, Train AUC: 0.7304  Test Loss: 0.9456, Test AUC: 0.8070
# Epoch 26/200, Train Loss: 0.8770, Train AUC: 0.7290  Test Loss: 0.9435, Test AUC: 0.8176
# Epoch 27/200, Train Loss: 0.8640, Train AUC: 0.6976  Test Loss: 0.9390, Test AUC: 0.8268
# Epoch 28/200, Train Loss: 0.8347, Train AUC: 0.7318  Test Loss: 0.9170, Test AUC: 0.8336
# Epoch 29/200, Train Loss: 0.8478, Train AUC: 0.7062  Test Loss: 0.8965, Test AUC: 0.8224
# Epoch 30/200, Train Loss: 0.8083, Train AUC: 0.7618  Test Loss: 0.8702, Test AUC: 0.8371
# Epoch 31/200, Train Loss: 0.7976, Train AUC: 0.7608  Test Loss: 0.8420, Test AUC: 0.8443
# Epoch 32/200, Train Loss: 0.7972, Train AUC: 0.7524  Test Loss: 0.8359, Test AUC: 0.8535
# Epoch 33/200, Train Loss: 0.7794, Train AUC: 0.7596  Test Loss: 0.8113, Test AUC: 0.8488
# Epoch 34/200, Train Loss: 0.7712, Train AUC: 0.7817  Test Loss: 0.8089, Test AUC: 0.8529
# Epoch 35/200, Train Loss: 0.7526, Train AUC: 0.8030  Test Loss: 0.7914, Test AUC: 0.8471
# Epoch 36/200, Train Loss: 0.7382, Train AUC: 0.7941  Test Loss: 0.7750, Test AUC: 0.8453
# Epoch 37/200, Train Loss: 0.7505, Train AUC: 0.7789  Test Loss: 0.7648, Test AUC: 0.8526
# Epoch 38/200, Train Loss: 0.7213, Train AUC: 0.8069  Test Loss: 0.7556, Test AUC: 0.8578
# Epoch 39/200, Train Loss: 0.7454, Train AUC: 0.7730  Test Loss: 0.7436, Test AUC: 0.8707
# Epoch 40/200, Train Loss: 0.6813, Train AUC: 0.8524  Test Loss: 0.7281, Test AUC: 0.8732
# Epoch 41/200, Train Loss: 0.6798, Train AUC: 0.8168  Test Loss: 0.7165, Test AUC: 0.8733
# Epoch 42/200, Train Loss: 0.6714, Train AUC: 0.8413  Test Loss: 0.6885, Test AUC: 0.8812
# Epoch 43/200, Train Loss: 0.6828, Train AUC: 0.8320  Test Loss: 0.6708, Test AUC: 0.8793
# Epoch 44/200, Train Loss: 0.6443, Train AUC: 0.8576  Test Loss: 0.6937, Test AUC: 0.8848
# Epoch 45/200, Train Loss: 0.6633, Train AUC: 0.8376  Test Loss: 0.6688, Test AUC: 0.8769
# Epoch 46/200, Train Loss: 0.6536, Train AUC: 0.8295  Test Loss: 0.6688, Test AUC: 0.8797
# Epoch 47/200, Train Loss: 0.6045, Train AUC: 0.8812  Test Loss: 0.6458, Test AUC: 0.8786
# Epoch 48/200, Train Loss: 0.6363, Train AUC: 0.8499  Test Loss: 0.6400, Test AUC: 0.8799
# Epoch 49/200, Train Loss: 0.6252, Train AUC: 0.8460  Test Loss: 0.6446, Test AUC: 0.8813
# Epoch 50/200, Train Loss: 0.6199, Train AUC: 0.8393  Test Loss: 0.6519, Test AUC: 0.8845
# Epoch 51/200, Train Loss: 0.6225, Train AUC: 0.8738  Test Loss: 0.6242, Test AUC: 0.8805
# Epoch 52/200, Train Loss: 0.5985, Train AUC: 0.8713  Test Loss: 0.6151, Test AUC: 0.8785
# Epoch 53/200, Train Loss: 0.6148, Train AUC: 0.8469  Test Loss: 0.5950, Test AUC: 0.8725
# Epoch 54/200, Train Loss: 0.5942, Train AUC: 0.8582  Test Loss: 0.6081, Test AUC: 0.8774
# Epoch 55/200, Train Loss: 0.6105, Train AUC: 0.8546  Test Loss: 0.5814, Test AUC: 0.8816
# Epoch 56/200, Train Loss: 0.5944, Train AUC: 0.8551  Test Loss: 0.5715, Test AUC: 0.8810
# Epoch 57/200, Train Loss: 0.5858, Train AUC: 0.8797  Test Loss: 0.5715, Test AUC: 0.8879
# Epoch 58/200, Train Loss: 0.5773, Train AUC: 0.8597  Test Loss: 0.5673, Test AUC: 0.8829
# Epoch 59/200, Train Loss: 0.6015, Train AUC: 0.8768  Test Loss: 0.5713, Test AUC: 0.8910
# Epoch 60/200, Train Loss: 0.5978, Train AUC: 0.8500  Test Loss: 0.5766, Test AUC: 0.8912
# Epoch 61/200, Train Loss: 0.5612, Train AUC: 0.8595  Test Loss: 0.5730, Test AUC: 0.8892
# Epoch 62/200, Train Loss: 0.5678, Train AUC: 0.8803  Test Loss: 0.5566, Test AUC: 0.8799
# Epoch 63/200, Train Loss: 0.5663, Train AUC: 0.8673  Test Loss: 0.5447, Test AUC: 0.8880
# Epoch 64/200, Train Loss: 0.5826, Train AUC: 0.8564  Test Loss: 0.5350, Test AUC: 0.8848
# Epoch 65/200, Train Loss: 0.5536, Train AUC: 0.8681  Test Loss: 0.5301, Test AUC: 0.8829
# Epoch 66/200, Train Loss: 0.5986, Train AUC: 0.8521  Test Loss: 0.5459, Test AUC: 0.8914
# Epoch 67/200, Train Loss: 0.5981, Train AUC: 0.8397  Test Loss: 0.5363, Test AUC: 0.8847
# Epoch 68/200, Train Loss: 0.5624, Train AUC: 0.8768  Test Loss: 0.5206, Test AUC: 0.8813
# Epoch 69/200, Train Loss: 0.5444, Train AUC: 0.8896  Test Loss: 0.5138, Test AUC: 0.8762
# Epoch 70/200, Train Loss: 0.5421, Train AUC: 0.8720  Test Loss: 0.5152, Test AUC: 0.8855
# Epoch 71/200, Train Loss: 0.5210, Train AUC: 0.8938  Test Loss: 0.5129, Test AUC: 0.8875
# Epoch 72/200, Train Loss: 0.5280, Train AUC: 0.8781  Test Loss: 0.5043, Test AUC: 0.8882
# Epoch 73/200, Train Loss: 0.5655, Train AUC: 0.8476  Test Loss: 0.5045, Test AUC: 0.8913
# Epoch 74/200, Train Loss: 0.5563, Train AUC: 0.8785  Test Loss: 0.5134, Test AUC: 0.8939
# Epoch 75/200, Train Loss: 0.5307, Train AUC: 0.8783  Test Loss: 0.5175, Test AUC: 0.8943
# Epoch 76/200, Train Loss: 0.5458, Train AUC: 0.8763  Test Loss: 0.5035, Test AUC: 0.8916
# Epoch 77/200, Train Loss: 0.5536, Train AUC: 0.8718  Test Loss: 0.5117, Test AUC: 0.8977
# Epoch 78/200, Train Loss: 0.4824, Train AUC: 0.9085  Test Loss: 0.5116, Test AUC: 0.8975
# Epoch 79/200, Train Loss: 0.5687, Train AUC: 0.8850  Test Loss: 0.5190, Test AUC: 0.8980
# Epoch 80/200, Train Loss: 0.5041, Train AUC: 0.8906  Test Loss: 0.5104, Test AUC: 0.8929
# Epoch 81/200, Train Loss: 0.5195, Train AUC: 0.8806  Test Loss: 0.5107, Test AUC: 0.8955
# Epoch 82/200, Train Loss: 0.4929, Train AUC: 0.9019  Test Loss: 0.4976, Test AUC: 0.8913
# Epoch 83/200, Train Loss: 0.5884, Train AUC: 0.8757  Test Loss: 0.4964, Test AUC: 0.8948
# Epoch 84/200, Train Loss: 0.5584, Train AUC: 0.8759  Test Loss: 0.4944, Test AUC: 0.8841
# Epoch 85/200, Train Loss: 0.5329, Train AUC: 0.8615  Test Loss: 0.5009, Test AUC: 0.8896
# Epoch 86/200, Train Loss: 0.5068, Train AUC: 0.8948  Test Loss: 0.5029, Test AUC: 0.8953
# Epoch 87/200, Train Loss: 0.5091, Train AUC: 0.8884  Test Loss: 0.5019, Test AUC: 0.8922
# Epoch 88/200, Train Loss: 0.4845, Train AUC: 0.9017  Test Loss: 0.4946, Test AUC: 0.8861
# Epoch 89/200, Train Loss: 0.5409, Train AUC: 0.8886  Test Loss: 0.4973, Test AUC: 0.8945
# Epoch 90/200, Train Loss: 0.5113, Train AUC: 0.8887  Test Loss: 0.5041, Test AUC: 0.8949
# Epoch 91/200, Train Loss: 0.5362, Train AUC: 0.8801  Test Loss: 0.4961, Test AUC: 0.8897
# Epoch 92/200, Train Loss: 0.4746, Train AUC: 0.9016  Test Loss: 0.4973, Test AUC: 0.8967
# Epoch 93/200, Train Loss: 0.4999, Train AUC: 0.8972  Test Loss: 0.4815, Test AUC: 0.8957
# Epoch 94/200, Train Loss: 0.4925, Train AUC: 0.8797  Test Loss: 0.4905, Test AUC: 0.8897
# Epoch 95/200, Train Loss: 0.4870, Train AUC: 0.8871  Test Loss: 0.4890, Test AUC: 0.8934
# Epoch 96/200, Train Loss: 0.5108, Train AUC: 0.8876  Test Loss: 0.4902, Test AUC: 0.8980
# Epoch 97/200, Train Loss: 0.4901, Train AUC: 0.8968  Test Loss: 0.4943, Test AUC: 0.8962
# Epoch 98/200, Train Loss: 0.4899, Train AUC: 0.8819  Test Loss: 0.4788, Test AUC: 0.8919
# Epoch 99/200, Train Loss: 0.5290, Train AUC: 0.8819  Test Loss: 0.4759, Test AUC: 0.8921
# Epoch 100/200, Train Loss: 0.4792, Train AUC: 0.8900  Test Loss: 0.4823, Test AUC: 0.8961
# Epoch 101/200, Train Loss: 0.4823, Train AUC: 0.8800  Test Loss: 0.4737, Test AUC: 0.8864
# Epoch 102/200, Train Loss: 0.5064, Train AUC: 0.8960  Test Loss: 0.4719, Test AUC: 0.8892
# Epoch 103/200, Train Loss: 0.4974, Train AUC: 0.8889  Test Loss: 0.4565, Test AUC: 0.8895
# Epoch 104/200, Train Loss: 0.4518, Train AUC: 0.9118  Test Loss: 0.4692, Test AUC: 0.8889
# Epoch 105/200, Train Loss: 0.4765, Train AUC: 0.9059  Test Loss: 0.4790, Test AUC: 0.8887
# Epoch 106/200, Train Loss: 0.5131, Train AUC: 0.8870  Test Loss: 0.4737, Test AUC: 0.8875
# Epoch 107/200, Train Loss: 0.4976, Train AUC: 0.8780  Test Loss: 0.4666, Test AUC: 0.8879
# Epoch 108/200, Train Loss: 0.4615, Train AUC: 0.8962  Test Loss: 0.4746, Test AUC: 0.8953
# Epoch 109/200, Train Loss: 0.4440, Train AUC: 0.9088  Test Loss: 0.4745, Test AUC: 0.8943
# Epoch 110/200, Train Loss: 0.4894, Train AUC: 0.8876  Test Loss: 0.4649, Test AUC: 0.8930
# Epoch 111/200, Train Loss: 0.4691, Train AUC: 0.9057  Test Loss: 0.4597, Test AUC: 0.8956
# Epoch 112/200, Train Loss: 0.4887, Train AUC: 0.8928  Test Loss: 0.4602, Test AUC: 0.8964
# Epoch 113/200, Train Loss: 0.4588, Train AUC: 0.9169  Test Loss: 0.4684, Test AUC: 0.8945
# Epoch 114/200, Train Loss: 0.5271, Train AUC: 0.8751  Test Loss: 0.4639, Test AUC: 0.8904
# Epoch 115/200, Train Loss: 0.4742, Train AUC: 0.8991  Test Loss: 0.4645, Test AUC: 0.8963
# Epoch 116/200, Train Loss: 0.4373, Train AUC: 0.9076  Test Loss: 0.4638, Test AUC: 0.8992
# Epoch 117/200, Train Loss: 0.4776, Train AUC: 0.8949  Test Loss: 0.4686, Test AUC: 0.8986
# Epoch 118/200, Train Loss: 0.4947, Train AUC: 0.8863  Test Loss: 0.4657, Test AUC: 0.8929
# Epoch 119/200, Train Loss: 0.4866, Train AUC: 0.8908  Test Loss: 0.4599, Test AUC: 0.8962
# Epoch 120/200, Train Loss: 0.4860, Train AUC: 0.8858  Test Loss: 0.4502, Test AUC: 0.8902
# Epoch 121/200, Train Loss: 0.4624, Train AUC: 0.9034  Test Loss: 0.4552, Test AUC: 0.8936
# Epoch 122/200, Train Loss: 0.4548, Train AUC: 0.9055  Test Loss: 0.4576, Test AUC: 0.8880
# Epoch 123/200, Train Loss: 0.5135, Train AUC: 0.8874  Test Loss: 0.4661, Test AUC: 0.8965
# Epoch 124/200, Train Loss: 0.4697, Train AUC: 0.9015  Test Loss: 0.4574, Test AUC: 0.8898
# Epoch 125/200, Train Loss: 0.4755, Train AUC: 0.8867  Test Loss: 0.4591, Test AUC: 0.8911
# Epoch 126/200, Train Loss: 0.4722, Train AUC: 0.9073  Test Loss: 0.4460, Test AUC: 0.8933
# Epoch 127/200, Train Loss: 0.4430, Train AUC: 0.9037  Test Loss: 0.4604, Test AUC: 0.8941
# Epoch 128/200, Train Loss: 0.4562, Train AUC: 0.9036  Test Loss: 0.4576, Test AUC: 0.8852
# Epoch 129/200, Train Loss: 0.4726, Train AUC: 0.8845  Test Loss: 0.4602, Test AUC: 0.8929
# Epoch 130/200, Train Loss: 0.4443, Train AUC: 0.9069  Test Loss: 0.4621, Test AUC: 0.8915
# Epoch 131/200, Train Loss: 0.4361, Train AUC: 0.9065  Test Loss: 0.4747, Test AUC: 0.8938
# Epoch 132/200, Train Loss: 0.4468, Train AUC: 0.9065  Test Loss: 0.4715, Test AUC: 0.8914
# Epoch 133/200, Train Loss: 0.4588, Train AUC: 0.8909  Test Loss: 0.4739, Test AUC: 0.8954
# Epoch 134/200, Train Loss: 0.4523, Train AUC: 0.9077  Test Loss: 0.4612, Test AUC: 0.8917
# Epoch 135/200, Train Loss: 0.4322, Train AUC: 0.9121  Test Loss: 0.4619, Test AUC: 0.8941
# Epoch 136/200, Train Loss: 0.4300, Train AUC: 0.9037  Test Loss: 0.4605, Test AUC: 0.8911
# Epoch 137/200, Train Loss: 0.4573, Train AUC: 0.9034  Test Loss: 0.4568, Test AUC: 0.8941
# Epoch 138/200, Train Loss: 0.4404, Train AUC: 0.8903  Test Loss: 0.4537, Test AUC: 0.8904
# Epoch 139/200, Train Loss: 0.4592, Train AUC: 0.8831  Test Loss: 0.4515, Test AUC: 0.8926
# Epoch 140/200, Train Loss: 0.4188, Train AUC: 0.9159  Test Loss: 0.4495, Test AUC: 0.8925
# Epoch 141/200, Train Loss: 0.4683, Train AUC: 0.9063  Test Loss: 0.4405, Test AUC: 0.8835
# Epoch 142/200, Train Loss: 0.4764, Train AUC: 0.9015  Test Loss: 0.4362, Test AUC: 0.8926
# Epoch 143/200, Train Loss: 0.4392, Train AUC: 0.9046  Test Loss: 0.4375, Test AUC: 0.8955
# Epoch 144/200, Train Loss: 0.4659, Train AUC: 0.9009  Test Loss: 0.4381, Test AUC: 0.8940
# Epoch 145/200, Train Loss: 0.4440, Train AUC: 0.9143  Test Loss: 0.4403, Test AUC: 0.8954
# Epoch 146/200, Train Loss: 0.4180, Train AUC: 0.9135  Test Loss: 0.4437, Test AUC: 0.8927
# Epoch 147/200, Train Loss: 0.4288, Train AUC: 0.9107  Test Loss: 0.4410, Test AUC: 0.8904
# Epoch 148/200, Train Loss: 0.4640, Train AUC: 0.8934  Test Loss: 0.4384, Test AUC: 0.8928
# Epoch 149/200, Train Loss: 0.4481, Train AUC: 0.9006  Test Loss: 0.4420, Test AUC: 0.8908
# Epoch 150/200, Train Loss: 0.4336, Train AUC: 0.9088  Test Loss: 0.4649, Test AUC: 0.8938
# Epoch 151/200, Train Loss: 0.4526, Train AUC: 0.8945  Test Loss: 0.4547, Test AUC: 0.8915
# Epoch 152/200, Train Loss: 0.4395, Train AUC: 0.9045  Test Loss: 0.4417, Test AUC: 0.8918
# Epoch 153/200, Train Loss: 0.4457, Train AUC: 0.9046  Test Loss: 0.4435, Test AUC: 0.8899
# Epoch 154/200, Train Loss: 0.4564, Train AUC: 0.8910  Test Loss: 0.4502, Test AUC: 0.8947
# Epoch 155/200, Train Loss: 0.4223, Train AUC: 0.9178  Test Loss: 0.4395, Test AUC: 0.8924
# Epoch 156/200, Train Loss: 0.4293, Train AUC: 0.8987  Test Loss: 0.4452, Test AUC: 0.8914
# Epoch 157/200, Train Loss: 0.4459, Train AUC: 0.8943  Test Loss: 0.4332, Test AUC: 0.8959
# Epoch 158/200, Train Loss: 0.4351, Train AUC: 0.9088  Test Loss: 0.4375, Test AUC: 0.8844
# Epoch 159/200, Train Loss: 0.4783, Train AUC: 0.9047  Test Loss: 0.4350, Test AUC: 0.8922
# Epoch 160/200, Train Loss: 0.4575, Train AUC: 0.9168  Test Loss: 0.4257, Test AUC: 0.8934
# Epoch 161/200, Train Loss: 0.4368, Train AUC: 0.8927  Test Loss: 0.4323, Test AUC: 0.8919
# Epoch 162/200, Train Loss: 0.4546, Train AUC: 0.9024  Test Loss: 0.4295, Test AUC: 0.8933
# Epoch 163/200, Train Loss: 0.4863, Train AUC: 0.8798  Test Loss: 0.4340, Test AUC: 0.8960
# Epoch 164/200, Train Loss: 0.4320, Train AUC: 0.9116  Test Loss: 0.4294, Test AUC: 0.8949
# Epoch 165/200, Train Loss: 0.4604, Train AUC: 0.8898  Test Loss: 0.4362, Test AUC: 0.8933
# Epoch 166/200, Train Loss: 0.4602, Train AUC: 0.9001  Test Loss: 0.4462, Test AUC: 0.8930
# Epoch 167/200, Train Loss: 0.3896, Train AUC: 0.9244  Test Loss: 0.4373, Test AUC: 0.8911
# Epoch 168/200, Train Loss: 0.4284, Train AUC: 0.9078  Test Loss: 0.4298, Test AUC: 0.8931
# Epoch 169/200, Train Loss: 0.4338, Train AUC: 0.9044  Test Loss: 0.4319, Test AUC: 0.8919
# Epoch 170/200, Train Loss: 0.4192, Train AUC: 0.9141  Test Loss: 0.4353, Test AUC: 0.8925
# Epoch 171/200, Train Loss: 0.4852, Train AUC: 0.8956  Test Loss: 0.4223, Test AUC: 0.8904
# Epoch 172/200, Train Loss: 0.4611, Train AUC: 0.9181  Test Loss: 0.4294, Test AUC: 0.8768
# Epoch 173/200, Train Loss: 0.4233, Train AUC: 0.8991  Test Loss: 0.4369, Test AUC: 0.8888
# Epoch 174/200, Train Loss: 0.4780, Train AUC: 0.8977  Test Loss: 0.4270, Test AUC: 0.8899
# Epoch 175/200, Train Loss: 0.4149, Train AUC: 0.9260  Test Loss: 0.4261, Test AUC: 0.8874
# Epoch 176/200, Train Loss: 0.4118, Train AUC: 0.9107  Test Loss: 0.4290, Test AUC: 0.8877
# Epoch 177/200, Train Loss: 0.4382, Train AUC: 0.9075  Test Loss: 0.4407, Test AUC: 0.8892
# Epoch 178/200, Train Loss: 0.4166, Train AUC: 0.9117  Test Loss: 0.4404, Test AUC: 0.8875
# Epoch 179/200, Train Loss: 0.4049, Train AUC: 0.9179  Test Loss: 0.4412, Test AUC: 0.8886
# Epoch 180/200, Train Loss: 0.4020, Train AUC: 0.9197  Test Loss: 0.4341, Test AUC: 0.8886
# Epoch 181/200, Train Loss: 0.4087, Train AUC: 0.9144  Test Loss: 0.4293, Test AUC: 0.8914
# Epoch 182/200, Train Loss: 0.3967, Train AUC: 0.9307  Test Loss: 0.4252, Test AUC: 0.8888
# Epoch 183/200, Train Loss: 0.4297, Train AUC: 0.9074  Test Loss: 0.4292, Test AUC: 0.8951
# Epoch 184/200, Train Loss: 0.4648, Train AUC: 0.9167  Test Loss: 0.4308, Test AUC: 0.8913
# Epoch 185/200, Train Loss: 0.3797, Train AUC: 0.9248  Test Loss: 0.4273, Test AUC: 0.8897
# Epoch 186/200, Train Loss: 0.4141, Train AUC: 0.9146  Test Loss: 0.4299, Test AUC: 0.8891
# Epoch 187/200, Train Loss: 0.4570, Train AUC: 0.8929  Test Loss: 0.4227, Test AUC: 0.8911
# Epoch 188/200, Train Loss: 0.4182, Train AUC: 0.9027  Test Loss: 0.4219, Test AUC: 0.8809
# Epoch 189/200, Train Loss: 0.4122, Train AUC: 0.9269  Test Loss: 0.4286, Test AUC: 0.8860
# Epoch 190/200, Train Loss: 0.4597, Train AUC: 0.8926  Test Loss: 0.4333, Test AUC: 0.8753
# Epoch 191/200, Train Loss: 0.4041, Train AUC: 0.9219  Test Loss: 0.4372, Test AUC: 0.8744
# Epoch 192/200, Train Loss: 0.4365, Train AUC: 0.9077  Test Loss: 0.4318, Test AUC: 0.8879
# Epoch 193/200, Train Loss: 0.4614, Train AUC: 0.8972  Test Loss: 0.4157, Test AUC: 0.8775
# Epoch 194/200, Train Loss: 0.4073, Train AUC: 0.9172  Test Loss: 0.4192, Test AUC: 0.8838
# Epoch 195/200, Train Loss: 0.4140, Train AUC: 0.9177  Test Loss: 0.4216, Test AUC: 0.8755
# Epoch 196/200, Train Loss: 0.4098, Train AUC: 0.9296  Test Loss: 0.4183, Test AUC: 0.8882
# Epoch 197/200, Train Loss: 0.4103, Train AUC: 0.9177  Test Loss: 0.4265, Test AUC: 0.8840
# Epoch 198/200, Train Loss: 0.3876, Train AUC: 0.9265  Test Loss: 0.4276, Test AUC: 0.8843
# Epoch 199/200, Train Loss: 0.3965, Train AUC: 0.9317  Test Loss: 0.4315, Test AUC: 0.8879
# Epoch 200/200, Train Loss: 0.3967, Train AUC: 0.9222  Test Loss: 0.4249, Test AUC: 0.8895

# %%
from sklearn.metrics import accuracy_score

model.eval()
all_probs = []
all_labels = []

with torch.no_grad():
    for inputs, kg_seq, kg_mask, labels in val_loader:
        # 已经在 DataLoader 初始化时 to(device) 了，但写上以防万一
        inputs, kg_seq, kg_mask = inputs.to(device), kg_seq.to(device), kg_mask.to(device)
        
        outputs = model(inputs, kg_seq, kg_mask)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.8072
# Recall:    0.6602
# F1 Score:  0.6465
# Precision: 0.6515
# AUC-ROC:   0.8733

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("AIBL AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("AIBL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
from torchinfo import summary
import torch

model = model.to(device)

# ★ 修改点1：总特征维度 = 2 (EHR) + 64 (img) + 5 (bio) = 71
dummy_x = torch.randn(32, 71).to(device)

# ★ 修改点2：AIBL的序列长度 max_seq_len 为 16
dummy_seq = torch.randn(32, 16, 128).to(device)
dummy_mask = torch.zeros(32, 16, dtype=torch.bool).to(device)

model_stats = summary(
    model, 
    input_data=(dummy_x, dummy_seq, dummy_mask), 
    col_names=["input_size", "output_size", "num_params", "trainable"],
    verbose=1
)

print(model_stats)
# Out:
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# KGMultiModalPerceiver                    [32, 71]                  [32, 3]                   --                        True
# ├─Sequential: 1-1                        [32, 2]                   [32, 128]                 --                        True
# │    └─Linear: 2-1                       [32, 2]                   [32, 16]                  48                        True
# │    └─BatchNorm1d: 2-2                  [32, 16]                  [32, 16]                  32                        True
# │    └─ReLU: 2-3                         [32, 16]                  [32, 16]                  --                        --
# │    └─Linear: 2-4                       [32, 16]                  [32, 128]                 2,176                     True
# │    └─BatchNorm1d: 2-5                  [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-6                         [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-2                        [32, 64]                  [32, 128]                 --                        True
# │    └─Linear: 2-7                       [32, 64]                  [32, 128]                 8,320                     True
# │    └─BatchNorm1d: 2-8                  [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-9                         [32, 128]                 [32, 128]                 --                        --
# │    └─Dropout: 2-10                     [32, 128]                 [32, 128]                 --                        --
# │    └─Linear: 2-11                      [32, 128]                 [32, 128]                 16,512                    True
# │    └─BatchNorm1d: 2-12                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-13                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-3                        [32, 5]                   [32, 128]                 --                        True
# │    └─Linear: 2-14                      [32, 5]                   [32, 16]                  96                        True
# │    └─BatchNorm1d: 2-15                 [32, 16]                  [32, 16]                  32                        True
# │    └─ReLU: 2-16                        [32, 16]                  [32, 16]                  --                        --
# │    └─Dropout: 2-17                     [32, 16]                  [32, 16]                  --                        --
# │    └─Linear: 2-18                      [32, 16]                  [32, 128]                 2,176                     True
# │    └─BatchNorm1d: 2-19                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-20                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-4                        [32, 16, 128]             [32, 16, 128]             --                        True
# │    └─Linear: 2-21                      [32, 16, 128]             [32, 16, 128]             16,512                    True
# │    └─ReLU: 2-22                        [32, 16, 128]             [32, 16, 128]             --                        --
# │    └─Dropout: 2-23                     [32, 16, 128]             [32, 16, 128]             --                        --
# │    └─Linear: 2-24                      [32, 16, 128]             [32, 16, 128]             16,512                    True
# ├─PerceiverAttentionBlock: 1-5           [32, 16, 128]             [32, 16, 128]             2,048                     True
# │    └─MultiheadAttention: 2-25          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-26                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─MultiheadAttention: 2-27          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-28                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─Sequential: 2-29                  [32, 16, 128]             [32, 16, 128]             --                        True
# │    │    └─Linear: 3-1                  [32, 16, 128]             [32, 16, 512]             66,048                    True
# │    │    └─GELU: 3-2                    [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Dropout: 3-3                 [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Linear: 3-4                  [32, 16, 512]             [32, 16, 128]             65,664                    True
# │    └─LayerNorm: 2-30                   [32, 16, 128]             [32, 16, 128]             256                       True
# ├─Embedding: 1-6                         --                        [128]                     512                       True
# ├─Embedding: 1-7                         --                        [128]                     (recursive)               True
# ├─Embedding: 1-8                         --                        [128]                     (recursive)               True
# ├─Embedding: 1-9                         --                        [128]                     (recursive)               True
# ├─PerceiverAttentionBlock: 1-10          [32, 18, 128]             [32, 16, 128]             2,048                     True
# │    └─MultiheadAttention: 2-31          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-32                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─MultiheadAttention: 2-33          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-34                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─Sequential: 2-35                  [32, 16, 128]             [32, 16, 128]             --                        True
# │    │    └─Linear: 3-5                  [32, 16, 128]             [32, 16, 512]             66,048                    True
# │    │    └─GELU: 3-6                    [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Dropout: 3-7                 [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Linear: 3-8                  [32, 16, 512]             [32, 16, 128]             65,664                    True
# │    └─LayerNorm: 2-36                   [32, 16, 128]             [32, 16, 128]             256                       True
# ├─PerceiverAttentionBlock: 1-11          [32, 17, 128]             [32, 8, 128]              1,024                     True
# │    └─MultiheadAttention: 2-37          --                        [32, 8, 128]              66,048                    True
# │    └─LayerNorm: 2-38                   [32, 8, 128]              [32, 8, 128]              256                       True
# │    └─MultiheadAttention: 2-39          --                        [32, 8, 128]              66,048                    True
# │    └─LayerNorm: 2-40                   [32, 8, 128]              [32, 8, 128]              256                       True
# │    └─Sequential: 2-41                  [32, 8, 128]              [32, 8, 128]              --                        True
# │    │    └─Linear: 3-9                  [32, 8, 128]              [32, 8, 512]              66,048                    True
# │    │    └─GELU: 3-10                   [32, 8, 512]              [32, 8, 512]              --                        --
# │    │    └─Dropout: 3-11                [32, 8, 512]              [32, 8, 512]              --                        --
# │    │    └─Linear: 3-12                 [32, 8, 512]              [32, 8, 128]              65,664                    True
# │    └─LayerNorm: 2-42                   [32, 8, 128]              [32, 8, 128]              256                       True
# ├─Sequential: 1-12                       [32, 8, 128]              [32, 8, 1]                --                        True
# │    └─Linear: 2-43                      [32, 8, 128]              [32, 8, 1]                129                       True
# │    └─Softmax: 2-44                     [32, 8, 1]                [32, 8, 1]                --                        --
# ├─Sequential: 1-13                       [32, 128]                 [32, 3]                   --                        True
# │    └─Linear: 2-45                      [32, 128]                 [32, 128]                 16,512                    True
# │    └─BatchNorm1d: 2-46                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-47                        [32, 128]                 [32, 128]                 --                        --
# │    └─Dropout: 2-48                     [32, 128]                 [32, 128]                 --                        --
# │    └─Linear: 2-49                      [32, 128]                 [32, 3]                   387                       True
# ============================================================================================================================================
# Total params: 880,084
# Trainable params: 880,084
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 15.56
# ============================================================================================================================================
# Input size (MB): 0.27
# Forward/backward pass size (MB): 11.89
# Params size (MB): 1.91
# Estimated Total Size (MB): 14.07
# ============================================================================================================================================
# ============================================================================================================================================
# Layer (type:depth-idx)                   Input Shape               Output Shape              Param #                   Trainable
# ============================================================================================================================================
# KGMultiModalPerceiver                    [32, 71]                  [32, 3]                   --                        True
# ├─Sequential: 1-1                        [32, 2]                   [32, 128]                 --                        True
# │    └─Linear: 2-1                       [32, 2]                   [32, 16]                  48                        True
# │    └─BatchNorm1d: 2-2                  [32, 16]                  [32, 16]                  32                        True
# │    └─ReLU: 2-3                         [32, 16]                  [32, 16]                  --                        --
# │    └─Linear: 2-4                       [32, 16]                  [32, 128]                 2,176                     True
# │    └─BatchNorm1d: 2-5                  [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-6                         [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-2                        [32, 64]                  [32, 128]                 --                        True
# │    └─Linear: 2-7                       [32, 64]                  [32, 128]                 8,320                     True
# │    └─BatchNorm1d: 2-8                  [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-9                         [32, 128]                 [32, 128]                 --                        --
# │    └─Dropout: 2-10                     [32, 128]                 [32, 128]                 --                        --
# │    └─Linear: 2-11                      [32, 128]                 [32, 128]                 16,512                    True
# │    └─BatchNorm1d: 2-12                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-13                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-3                        [32, 5]                   [32, 128]                 --                        True
# │    └─Linear: 2-14                      [32, 5]                   [32, 16]                  96                        True
# │    └─BatchNorm1d: 2-15                 [32, 16]                  [32, 16]                  32                        True
# │    └─ReLU: 2-16                        [32, 16]                  [32, 16]                  --                        --
# │    └─Dropout: 2-17                     [32, 16]                  [32, 16]                  --                        --
# │    └─Linear: 2-18                      [32, 16]                  [32, 128]                 2,176                     True
# │    └─BatchNorm1d: 2-19                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-20                        [32, 128]                 [32, 128]                 --                        --
# ├─Sequential: 1-4                        [32, 16, 128]             [32, 16, 128]             --                        True
# │    └─Linear: 2-21                      [32, 16, 128]             [32, 16, 128]             16,512                    True
# │    └─ReLU: 2-22                        [32, 16, 128]             [32, 16, 128]             --                        --
# │    └─Dropout: 2-23                     [32, 16, 128]             [32, 16, 128]             --                        --
# │    └─Linear: 2-24                      [32, 16, 128]             [32, 16, 128]             16,512                    True
# ├─PerceiverAttentionBlock: 1-5           [32, 16, 128]             [32, 16, 128]             2,048                     True
# │    └─MultiheadAttention: 2-25          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-26                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─MultiheadAttention: 2-27          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-28                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─Sequential: 2-29                  [32, 16, 128]             [32, 16, 128]             --                        True
# │    │    └─Linear: 3-1                  [32, 16, 128]             [32, 16, 512]             66,048                    True
# │    │    └─GELU: 3-2                    [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Dropout: 3-3                 [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Linear: 3-4                  [32, 16, 512]             [32, 16, 128]             65,664                    True
# │    └─LayerNorm: 2-30                   [32, 16, 128]             [32, 16, 128]             256                       True
# ├─Embedding: 1-6                         --                        [128]                     512                       True
# ├─Embedding: 1-7                         --                        [128]                     (recursive)               True
# ├─Embedding: 1-8                         --                        [128]                     (recursive)               True
# ├─Embedding: 1-9                         --                        [128]                     (recursive)               True
# ├─PerceiverAttentionBlock: 1-10          [32, 18, 128]             [32, 16, 128]             2,048                     True
# │    └─MultiheadAttention: 2-31          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-32                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─MultiheadAttention: 2-33          --                        [32, 16, 128]             66,048                    True
# │    └─LayerNorm: 2-34                   [32, 16, 128]             [32, 16, 128]             256                       True
# │    └─Sequential: 2-35                  [32, 16, 128]             [32, 16, 128]             --                        True
# │    │    └─Linear: 3-5                  [32, 16, 128]             [32, 16, 512]             66,048                    True
# │    │    └─GELU: 3-6                    [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Dropout: 3-7                 [32, 16, 512]             [32, 16, 512]             --                        --
# │    │    └─Linear: 3-8                  [32, 16, 512]             [32, 16, 128]             65,664                    True
# │    └─LayerNorm: 2-36                   [32, 16, 128]             [32, 16, 128]             256                       True
# ├─PerceiverAttentionBlock: 1-11          [32, 17, 128]             [32, 8, 128]              1,024                     True
# │    └─MultiheadAttention: 2-37          --                        [32, 8, 128]              66,048                    True
# │    └─LayerNorm: 2-38                   [32, 8, 128]              [32, 8, 128]              256                       True
# │    └─MultiheadAttention: 2-39          --                        [32, 8, 128]              66,048                    True
# │    └─LayerNorm: 2-40                   [32, 8, 128]              [32, 8, 128]              256                       True
# │    └─Sequential: 2-41                  [32, 8, 128]              [32, 8, 128]              --                        True
# │    │    └─Linear: 3-9                  [32, 8, 128]              [32, 8, 512]              66,048                    True
# │    │    └─GELU: 3-10                   [32, 8, 512]              [32, 8, 512]              --                        --
# │    │    └─Dropout: 3-11                [32, 8, 512]              [32, 8, 512]              --                        --
# │    │    └─Linear: 3-12                 [32, 8, 512]              [32, 8, 128]              65,664                    True
# │    └─LayerNorm: 2-42                   [32, 8, 128]              [32, 8, 128]              256                       True
# ├─Sequential: 1-12                       [32, 8, 128]              [32, 8, 1]                --                        True
# │    └─Linear: 2-43                      [32, 8, 128]              [32, 8, 1]                129                       True
# │    └─Softmax: 2-44                     [32, 8, 1]                [32, 8, 1]                --                        --
# ├─Sequential: 1-13                       [32, 128]                 [32, 3]                   --                        True
# │    └─Linear: 2-45                      [32, 128]                 [32, 128]                 16,512                    True
# │    └─BatchNorm1d: 2-46                 [32, 128]                 [32, 128]                 256                       True
# │    └─ReLU: 2-47                        [32, 128]                 [32, 128]                 --                        --
# │    └─Dropout: 2-48                     [32, 128]                 [32, 128]                 --                        --
# │    └─Linear: 2-49                      [32, 128]                 [32, 3]                   387                       True
# ============================================================================================================================================
# Total params: 880,084
# Trainable params: 880,084
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 15.56
# ============================================================================================================================================
# Input size (MB): 0.27
# Forward/backward pass size (MB): 11.89
# Params size (MB): 1.91
# Estimated Total Size (MB): 14.07
# ============================================================================================================================================
