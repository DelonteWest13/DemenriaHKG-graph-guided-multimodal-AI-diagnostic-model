# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,TransEModel,KGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('NC.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'NC/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'AD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('MCI.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'MCI/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #44
print(count_no) #247
print(count_mci) #106
# Out:
# 72
# 358
# 86

# %%
ad_arrays=[]
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','no':'0','yes':'1','ans':'2','haw':'3','ind':'4','bl':'1'}
for i in data_ad:
    j= i[14:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    ad_array = np.array(num_list)
    ad_arrays.append(ad_array)
ad_array = np.vstack(ad_arrays)

normal_arrays=[]
for i in data_normal:
    j= i[14:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    normal_array = np.array(num_list)
    normal_arrays.append(normal_array)
normal_array = np.vstack(normal_arrays)

mci_arrays=[]
for i in data_mci:
    j= i[14:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    mci_array = np.array(num_list)
    mci_arrays.append(mci_array)
mci_array = np.vstack(mci_arrays)

# %%
#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()
normal_labels = torch.zeros(normal_tensor.shape[0], dtype=torch.long)
mci_labels = torch.ones(mci_tensor.shape[0], dtype=torch.long)
ad_labels = torch.full((ad_tensor.shape[0],), 2, dtype=torch.long)

X = torch.cat([ad_tensor, normal_tensor, mci_tensor], dim=0)
y = torch.cat([ad_labels, normal_labels, mci_labels], dim=0)

dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
model = NeuralNet(embedding=9)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
for epoch in range(50):
    for inputs, labels in dataloader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
with torch.no_grad():
    ad_tensor = model(ad_tensor)
    normal_tensor = model(normal_tensor)
    mci_tensor = model(mci_tensor)
    
ad_tensor = weighted_sum(ad_tensor)
mci_tensor = weighted_sum(mci_tensor)
normal_tensor = weighted_sum(normal_tensor)

print('AD_tensor shape:', ad_tensor.shape)
print('Normal_tensor shape:', normal_tensor.shape)
print('MCI_tensor shape:', mci_tensor.shape)
# Out:
# AD_tensor shape: torch.Size([72, 1])
# Normal_tensor shape: torch.Size([358, 1])
# MCI_tensor shape: torch.Size([86, 1])

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        row = [replace_dict.get(item, item) for item in row]
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[3:18])
    return np.array(processed_data)

# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict)
normal_data = preprocess_data(data_normal, replace_dict)
mci_data = preprocess_data(data_mci, replace_dict)

categorical_indices = [2, 3, 4, 5]  # gender, education, hispanic, race, apoe
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(15, 8)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(8, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([72, 1])
# normal.EHR---> torch.Size([358, 1])
# mci.EHR---> torch.Size([86, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 先导入模型定义（你cell1里已import）
nii = CNN_3D(num_class=1)    # 输出维度根据你的网络结构和任务来设
nii = nii.to(device)

def get_nii_file_list(folder_path):
    import os
    return [os.path.join(folder_path, f) for f in os.listdir(folder_path)
            if f.endswith('.nii') or f.endswith('.nii.gz')]

# 加在Cell12前，假设你的CNN_3D模型叫 nii，且device设置好了
# --- AD ---
ad_nii_files = get_nii_file_list('AD')
dataset = NiiDataset(ad_nii_files)
dataloader = DataLoader(dataset, batch_size=16, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output.cpu())
ad_output = torch.cat(all_outputs, dim=0)

# --- NC ---
normal_nii_files = get_nii_file_list('NC')
dataset = NiiDataset(normal_nii_files)
dataloader = DataLoader(dataset, batch_size=16, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output.cpu())
normal_output = torch.cat(all_outputs, dim=0)

# --- MCI ---
mci_nii_files = get_nii_file_list('MCI')
dataset = NiiDataset(mci_nii_files)
dataloader = DataLoader(dataset, batch_size=16, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output.cpu())
mci_output = torch.cat(all_outputs, dim=0)

print('ad_output shape:', ad_output.shape)
print('normal_output shape:', normal_output.shape)
print('mci_output shape:', mci_output.shape)
# Out:
# ad_output shape: torch.Size([72, 1])
# normal_output shape: torch.Size([358, 1])
# mci_output shape: torch.Size([86, 1])

# %%
# 获取EHR主键顺序（假设 row[1] 是nii文件名，不带扩展名）
ad_ehr_keys = [os.path.splitext(row[1])[0] for row in data_ad]
mci_ehr_keys = [os.path.splitext(row[1])[0] for row in data_mci]
normal_ehr_keys = [os.path.splitext(row[1])[0] for row in data_normal]

# NII文件主键到索引
ad_nii_files = get_nii_file_list('AD')
ad_nii_key2idx = {os.path.splitext(os.path.basename(f))[0]: i for i, f in enumerate(ad_nii_files)}
mci_nii_files = get_nii_file_list('MCI')
mci_nii_key2idx = {os.path.splitext(os.path.basename(f))[0]: i for i, f in enumerate(mci_nii_files)}
normal_nii_files = get_nii_file_list('NC')
normal_nii_key2idx = {os.path.splitext(os.path.basename(f))[0]: i for i, f in enumerate(normal_nii_files)}

# 对齐NII输出，只保留EHR有的部分（顺序与EHR一致）
ad_nii_indices = [ad_nii_key2idx[k] for k in ad_ehr_keys if k in ad_nii_key2idx]
ad_output_aligned = ad_output[ad_nii_indices]

mci_nii_indices = [mci_nii_key2idx[k] for k in mci_ehr_keys if k in mci_nii_key2idx]
mci_output_aligned = mci_output[mci_nii_indices]

normal_nii_indices = [normal_nii_key2idx[k] for k in normal_ehr_keys if k in normal_nii_key2idx]
normal_output_aligned = normal_output[normal_nii_indices]

# 检查对齐后shape
print('ad_EHR:', ad_EHR.shape, 'ad_output_aligned:', ad_output_aligned.shape)
print('mci_EHR:', mci_EHR.shape, 'mci_output_aligned:', mci_output_aligned.shape)
print('normal_EHR:', normal_EHR.shape, 'normal_output_aligned:', normal_output_aligned.shape)
# Out:
# ad_EHR: torch.Size([72, 1]) ad_output_aligned: torch.Size([72, 1])
# mci_EHR: torch.Size([86, 1]) mci_output_aligned: torch.Size([86, 1])
# normal_EHR: torch.Size([358, 1]) normal_output_aligned: torch.Size([358, 1])

# %%
import os

def get_nii_file_list(folder_path):
    return [os.path.join(folder_path, f) for f in os.listdir(folder_path)
            if f.endswith('.nii') or f.endswith('.nii.gz')]

batch_size = 16

# AD
ad_nii_files = get_nii_file_list('AD')
dataset = NiiDataset(ad_nii_files)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)
print('ad nii shape--->', ad_output.shape)

# NC
normal_nii_files = get_nii_file_list('NC')
dataset = NiiDataset(normal_nii_files)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)
print('normal nii shape--->', normal_output.shape)

# MCI
mci_nii_files = get_nii_file_list('MCI')
dataset = NiiDataset(mci_nii_files)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)
print('mci nii shape--->', mci_output.shape)
# Out:
# ad nii shape---> torch.Size([72, 1])
# normal nii shape---> torch.Size([358, 1])
# mci nii shape---> torch.Size([86, 1])

# %%
import json
import os
import pandas as pd
import numpy as np
import torch

# --- 1. 读取数据 (保持你原有的逻辑) ---
ad_df = pd.read_csv('AD.csv')
mci_df = pd.read_csv('MCI.csv')
normal_df = pd.read_csv('NC.csv')

# --- 2. 加载字典和 Embedding (保持你原有的逻辑) ---
entity2id_path = 'aibl_kg_entity2id.json' 
if not os.path.exists(entity2id_path):
    print(f"Error: {entity2id_path} not found!")
    # 模拟数据用于调试
    entity2id = {"Patient:123": 0, "Patient:456": 1} 
else:
    with open(entity2id_path, 'r', encoding='utf-8') as f:
        entity2id = json.load(f)

embed_path = 'aibl_kg_embeddings.npy'
if not os.path.exists(embed_path):
    # 模拟数据用于调试
    kg_embeddings = torch.randn(len(entity2id), 128)
else:
    distmult_matrix = np.load(embed_path)
    kg_embeddings = torch.from_numpy(distmult_matrix).float()

# ==========================================
# ★★★ 诊断代码开始 (Diagnostic Block) ★★★
# ==========================================
print("\n" + "="*30)
print("       开始诊断 NC 匹配失败原因       ")
print("="*30)

# 1. 查看 NC.csv 里的 filename 到底长什么样
print("\n[1] NC.csv 前 3 行 filename 数据:")
print(normal_df['filename'].head(3).tolist())

# 2. 查看 KG 里的 Key 到底长什么样 (打印前 5 个包含 'Patient' 的 key)
print("\n[2] KG 中的 Key 示例 (前 5 个):")
sample_keys = [k for k in list(entity2id.keys()) if "Patient" in k][:5]
print(sample_keys)

# 3. 模拟一次匹配过程，看看具体差异
sample_nc = str(normal_df['filename'].iloc[0]).strip()
constructed_key = f"Patient:{sample_nc}"
print(f"\n[3] 尝试匹配 NC 的第一个病人:")
print(f"   CSV中的原文件名: '{sample_nc}'")
print(f"   构建出的 Key   : '{constructed_key}'")

if constructed_key in entity2id:
    print(f"   ---> 结果: 匹配成功 (In KG)")
else:
    print(f"   ---> 结果: 匹配失败 (Not in KG)")
    # 尝试智能搜索：在 KG 里找找看有没有类似的
    # 比如：去掉 .nii 后缀试试？
    name_no_ext = sample_nc.replace('.nii', '').replace('.gz', '')
    guess_key = f"Patient:{name_no_ext}"
    if guess_key in entity2id:
        print(f"   [!] 发现潜在匹配: KG 中存在 '{guess_key}'，看来你需要去掉文件后缀！")
    else:
        # 看看是不是 CSV 文件名本身就是 ID 的一部分
        partial_matches = [k for k in sample_keys if name_no_ext in k]
        if partial_matches:
            print(f"   [!] KG 中类似的 Key: {partial_matches}")
        else:
            print(f"   [!] 在 KG 样本中完全找不到类似 ID。")

print("="*30 + "\n")

# ==========================================
# ★★★ 修复后的函数 (Robust Version) ★★★
# ==========================================

def get_distmult_embeddings_robust(df, entity2id, embeddings_tensor, label_name):
    embeddings_list = []
    found_count = 0
    dim = embeddings_tensor.shape[1]
    
    # 获取所有 KG 的 key 集合，用于快速查找 (如果 key 很长，这步会耗内存，但在 Jupyter 里通常没事)
    # kg_keys_set = set(entity2id.keys()) 
    
    for index, row in df.iterrows():
        fname = str(row['filename']).strip()
        
        # --- 尝试 1: 直接拼接 (针对 AD/MCI 可能有效) ---
        kg_key = f"Patient:{fname}"
        
        # --- 尝试 2: 去掉 .nii 或 .nii.gz 后缀 (针对 NC 可能有效) ---
        # 很多时候 CSV 里带后缀，但 KG ID 是纯编号
        fname_clean = fname.replace('.nii.gz', '').replace('.nii', '')
        kg_key_clean = f"Patient:{fname_clean}"
        
        idx = -1
        
        if kg_key in entity2id:
            idx = entity2id[kg_key]
        elif kg_key_clean in entity2id:
            idx = entity2id[kg_key_clean]
        
        if idx != -1:
            emb = embeddings_tensor[idx]
            embeddings_list.append(emb)
            found_count += 1
        else:
            # 没找到，填 0
            embeddings_list.append(torch.zeros(dim)) 

    print(f"Processing {label_name}...")
    print(f"  - Matched {found_count} / {len(df)} patients in KG.")
    return torch.stack(embeddings_list)

# 使用修复后的函数重新运行
ad_kg = get_distmult_embeddings_robust(ad_df, entity2id, kg_embeddings, "AD")
mci_kg = get_distmult_embeddings_robust(mci_df, entity2id, kg_embeddings, "MCI")
normal_kg = get_distmult_embeddings_robust(normal_df, entity2id, kg_embeddings, "NC") # 这里应该不再是 0 了

print(f"AD KG shape: {ad_kg.shape}")
print(f"MCI KG shape: {mci_kg.shape}")
print(f"NC KG shape: {normal_kg.shape}")
# Out:
# ==============================
#        开始诊断 NC 匹配失败原因
# ==============================
#
# [1] NC.csv 前 3 行 filename 数据:
# ['AIBL_1467_MR_MPRAGE_ADNI_confirmed__br_raw_20141107112943194_24_S236160_I451428.nii', 'AIBL_551_MR_MPRAGE_ADNI_confirmed__br_raw_20100514133422478_54_S84920_I173695.nii', 'AIBL_796_MR_MPRAGE_ADNI_confirmed__br_raw_20100330105154047_68_S82553_I169861.nii']
#
# [2] KG 中的 Key 示例 (前 5 个):
# ['Patient:AIBL_1000_MR_MPRAGE_ADNI_confirmed__br_raw_20090107130517522_1_S61337_I132872.nii', 'Patient:AIBL_1001_MR_MPRAGE_ADNI_confirmed__br_raw_20090107131125301_1_S61338_I132873.nii', 'Patient:AIBL_100_MR_MPRAGE_ADNI_confirmed__br_raw_20090114132851679_1_S61721_I133615.nii', 'Patient:AIBL_1013_MR_MPRAGE_ADNI_confirmed__br_raw_20100518160535474_24_S85107_I173974.nii', 'Patient:AIBL_1020_MR_MPRAGE_ADNI_confirmed__br_raw_20141127100940270_106_S237660_I455196.nii']
#
# [3] 尝试匹配 NC 的第一个病人:
#    CSV中的原文件名: 'AIBL_1467_MR_MPRAGE_ADNI_confirmed__br_raw_20141107112943194_24_S236160_I451428.nii'
#    构建出的 Key   : 'Patient:AIBL_1467_MR_MPRAGE_ADNI_confirmed__br_raw_20141107112943194_24_S236160_I451428.nii'
#    ---> 结果: 匹配成功 (In KG)
# ==============================
#
# Processing AD...
#   - Matched 72 / 72 patients in KG.
# Processing MCI...
#   - Matched 86 / 86 patients in KG.
# Processing NC...
#   - Matched 358 / 358 patients in KG.
# AD KG shape: torch.Size([72, 128])
# MCI KG shape: torch.Size([86, 128])
# NC KG shape: torch.Size([358, 128])

# %%
# ===============================================
# Cell 16 - 引入消融实验配置与 DataLoader 构建
# ===============================================
kg_embed_dim = 128 # 对应你 DistMult 设置的 128

# ================= 消融实验配置 =================
# 0: ALL (全模态/Baseline)
# 1: 消去 EHR 特征 (临床文本/表格特征)
# 2: 消去 MRI 影像特征 (NII)
# 3: 消去 Tensor 特征 (神经网络加权特征)
# 4: 消去 KG 知识图谱特征
ABLATION_MODE = 4  # 修改此处以切换不同实验 (0, 1, 2, 3, 4)
# ===============================================

print(f"当前消融实验模式代码: {ABLATION_MODE}")

def mask_tensor(tensor, mode_code):
    """如果当前模式代码匹配，则返回全0张量，实现特征消融"""
    if ABLATION_MODE == mode_code:
        return torch.zeros_like(tensor)
    return tensor

# 使用 mask_tensor 重新拼接各类别特征
X_ad = torch.cat([
    mask_tensor(ad_EHR, 1), 
    mask_tensor(ad_output_aligned.cpu(), 2), 
    mask_tensor(ad_tensor, 3), 
    mask_tensor(ad_kg, 4)
], dim=1)

X_mci = torch.cat([
    mask_tensor(mci_EHR, 1), 
    mask_tensor(mci_output_aligned.cpu(), 2), 
    mask_tensor(mci_tensor, 3), 
    mask_tensor(mci_kg, 4)
], dim=1)

X_normal = torch.cat([
    mask_tensor(normal_EHR, 1), 
    mask_tensor(normal_output_aligned.cpu(), 2), 
    mask_tensor(normal_tensor, 3), 
    mask_tensor(normal_kg, 4)
], dim=1)

# 验证特征拼接与消融情况 (基于AIBL的维度: EHR, MRI, Tensor各占第0,1,2列)
def check_modality_status(tensor, class_name):
    ehr  = tensor[:, 0]
    mri  = tensor[:, 1]
    tens = tensor[:, 2]
    kg   = tensor[:, 3:]
    print(f"\n--- {class_name} 特征拼接情况验证 ---")
    print(f"EHR特征 非零占比: {torch.count_nonzero(ehr)/ehr.numel():.1%}, 均值: {ehr.mean():.4f}")
    print(f"MRI特征 非零占比: {torch.count_nonzero(mri)/mri.numel():.1%}, 均值: {mri.mean():.4f}")
    print(f"Tensor特征 非零占比: {torch.count_nonzero(tens)/tens.numel():.1%}, 均值: {tens.mean():.4f}")
    print(f"KG特征 非零占比: {torch.count_nonzero(kg)/kg.numel():.1%}, 均值: {kg.mean():.4f}")

# 打印AD类别的消融状态供核对
check_modality_status(X_ad, "AD")

# 构建标签
y_ad = torch.ones(len(X_ad)) * 2
y_mci = torch.ones(len(X_mci)) * 1
y_normal = torch.ones(len(X_normal)) * 0

X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()

# 分离特征和KG嵌入
features = X[:, :-kg_embed_dim]      
kg_embeddings_data = X[:, -kg_embed_dim:]  

# 切分数据集 (严格保留你原有的 stratify 和 random_state 逻辑)
X_train, X_test, y_train, y_test, kg_train, kg_test = train_test_split(
    features.detach().cpu().numpy(), y.numpy(), kg_embeddings_data.detach().cpu().numpy(),
    test_size=0.20, stratify=y.numpy(), random_state=32
)
X_train, X_val, y_train, y_val, kg_train, kg_val = train_test_split(
    X_train, y_train, kg_train,
    test_size=0.20, stratify=y_train, random_state=30
)

# 转 Tensor 并放入设备
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)
kg_train_tensor = torch.FloatTensor(kg_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
kg_val_tensor = torch.FloatTensor(kg_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
kg_test_tensor = torch.FloatTensor(kg_test).to(device)

# 封装 DataLoader
train_dataset = TensorDataset(X_train_tensor, kg_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, kg_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, kg_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

print("\nDataLoaders ready:", len(train_loader), len(val_loader), len(test_loader))
# Out:
# 当前消融实验模式代码: 4
#
# --- AD 特征拼接情况验证 ---
# EHR特征 非零占比: 100.0%, 均值: 21.0170
# MRI特征 非零占比: 100.0%, 均值: 2.7531
# Tensor特征 非零占比: 100.0%, 均值: 1.1058
# KG特征 非零占比: 0.0%, 均值: 0.0000
#
# DataLoaders ready: 11 3 4

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
# Cell 18 - Modified
embed_dim = 32
transe_embed_dim = 128 # 这里其实是 DistMult dim，但名字为了兼容 model1 没改
num_epochs = 200
learning_rate = 1e-5
weight_decay = 1e-3

# --- 删除掉了原本在这里的 TransEModel 初始化和 load_state_dict ---
# 因为 Embedding 已经作为数据输入了，不需要模型来生成

# 初始化主模型
model = KGMultiModalTransformer(embed_dim=embed_dim, transe_embed_dim=transe_embed_dim).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)


train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"test Loss: {test_loss:.4f}, test AUC: {test_auc:.4f}")
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/200, Train Loss: 1.0871, Train AUC: 0.7833  test Loss: 1.1347, test AUC: 0.8425
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 2/200, Train Loss: 1.0748, Train AUC: 0.8090  test Loss: 1.1259, test AUC: 0.8535
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/200, Train Loss: 1.0460, Train AUC: 0.8441  test Loss: 1.1177, test AUC: 0.8546
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 4/200, Train Loss: 1.0218, Train AUC: 0.8745  test Loss: 1.1053, test AUC: 0.8640
# Epoch 5/200, Train Loss: 1.0139, Train AUC: 0.8619  test Loss: 1.0796, test AUC: 0.8816
# Epoch 6/200, Train Loss: 1.0158, Train AUC: 0.8527  test Loss: 1.0459, test AUC: 0.8944
# Epoch 7/200, Train Loss: 1.0036, Train AUC: 0.8710  test Loss: 1.0209, test AUC: 0.9030
# Epoch 8/200, Train Loss: 0.9995, Train AUC: 0.8917  test Loss: 0.9913, test AUC: 0.9097
# Epoch 9/200, Train Loss: 0.9619, Train AUC: 0.9124  test Loss: 0.9714, test AUC: 0.9119
# Epoch 10/200, Train Loss: 0.9511, Train AUC: 0.9163  test Loss: 0.9579, test AUC: 0.9135
# Epoch 11/200, Train Loss: 0.9514, Train AUC: 0.9243  test Loss: 0.9588, test AUC: 0.9169
# Epoch 12/200, Train Loss: 0.9362, Train AUC: 0.9081  test Loss: 0.9375, test AUC: 0.9187
# Epoch 13/200, Train Loss: 0.9152, Train AUC: 0.9221  test Loss: 0.9153, test AUC: 0.9198
# Epoch 14/200, Train Loss: 0.9229, Train AUC: 0.9193  test Loss: 0.9104, test AUC: 0.9254
# Epoch 15/200, Train Loss: 0.8939, Train AUC: 0.9303  test Loss: 0.9076, test AUC: 0.9283
# Epoch 16/200, Train Loss: 0.8955, Train AUC: 0.9300  test Loss: 0.8769, test AUC: 0.9294
# Epoch 17/200, Train Loss: 0.8778, Train AUC: 0.9459  test Loss: 0.8806, test AUC: 0.9345
# Epoch 18/200, Train Loss: 0.8977, Train AUC: 0.9308  test Loss: 0.8741, test AUC: 0.9418
# Epoch 19/200, Train Loss: 0.8698, Train AUC: 0.9451  test Loss: 0.8643, test AUC: 0.9404
# Epoch 20/200, Train Loss: 0.8648, Train AUC: 0.9430  test Loss: 0.8537, test AUC: 0.9443
# Epoch 21/200, Train Loss: 0.8596, Train AUC: 0.9499  test Loss: 0.8377, test AUC: 0.9435
# Epoch 22/200, Train Loss: 0.8590, Train AUC: 0.9512  test Loss: 0.8269, test AUC: 0.9423
# Epoch 23/200, Train Loss: 0.8498, Train AUC: 0.9474  test Loss: 0.8159, test AUC: 0.9444
# Epoch 24/200, Train Loss: 0.8203, Train AUC: 0.9551  test Loss: 0.7988, test AUC: 0.9459
# Epoch 25/200, Train Loss: 0.8147, Train AUC: 0.9559  test Loss: 0.7883, test AUC: 0.9470
# Epoch 26/200, Train Loss: 0.7990, Train AUC: 0.9587  test Loss: 0.7799, test AUC: 0.9456
# Epoch 27/200, Train Loss: 0.7954, Train AUC: 0.9632  test Loss: 0.7733, test AUC: 0.9461
# Epoch 28/200, Train Loss: 0.7971, Train AUC: 0.9555  test Loss: 0.7600, test AUC: 0.9472
# Epoch 29/200, Train Loss: 0.7753, Train AUC: 0.9641  test Loss: 0.7610, test AUC: 0.9495
# Epoch 30/200, Train Loss: 0.7817, Train AUC: 0.9562  test Loss: 0.7610, test AUC: 0.9565
# Epoch 31/200, Train Loss: 0.7818, Train AUC: 0.9580  test Loss: 0.7641, test AUC: 0.9618
# Epoch 32/200, Train Loss: 0.7650, Train AUC: 0.9628  test Loss: 0.7620, test AUC: 0.9656
# Epoch 33/200, Train Loss: 0.7727, Train AUC: 0.9692  test Loss: 0.7527, test AUC: 0.9652
# Epoch 34/200, Train Loss: 0.7428, Train AUC: 0.9658  test Loss: 0.7463, test AUC: 0.9615
# Epoch 35/200, Train Loss: 0.7605, Train AUC: 0.9563  test Loss: 0.7505, test AUC: 0.9619
# Epoch 36/200, Train Loss: 0.7702, Train AUC: 0.9660  test Loss: 0.7518, test AUC: 0.9663
# Epoch 37/200, Train Loss: 0.7490, Train AUC: 0.9673  test Loss: 0.7692, test AUC: 0.9678
# Epoch 38/200, Train Loss: 0.7782, Train AUC: 0.9611  test Loss: 0.7667, test AUC: 0.9686
# Epoch 39/200, Train Loss: 0.7382, Train AUC: 0.9668  test Loss: 0.7482, test AUC: 0.9687
# Epoch 40/200, Train Loss: 0.7155, Train AUC: 0.9718  test Loss: 0.7356, test AUC: 0.9695
# Epoch 41/200, Train Loss: 0.7527, Train AUC: 0.9686  test Loss: 0.7341, test AUC: 0.9698
# Epoch 42/200, Train Loss: 0.7161, Train AUC: 0.9679  test Loss: 0.7214, test AUC: 0.9701
# Epoch 43/200, Train Loss: 0.6956, Train AUC: 0.9744  test Loss: 0.7125, test AUC: 0.9700
# Epoch 44/200, Train Loss: 0.7415, Train AUC: 0.9666  test Loss: 0.7128, test AUC: 0.9709
# Epoch 45/200, Train Loss: 0.7074, Train AUC: 0.9703  test Loss: 0.7212, test AUC: 0.9700
# Epoch 46/200, Train Loss: 0.7058, Train AUC: 0.9761  test Loss: 0.7235, test AUC: 0.9724
# Epoch 47/200, Train Loss: 0.6749, Train AUC: 0.9801  test Loss: 0.7102, test AUC: 0.9708
# Epoch 48/200, Train Loss: 0.6840, Train AUC: 0.9766  test Loss: 0.6935, test AUC: 0.9722
# Epoch 49/200, Train Loss: 0.6685, Train AUC: 0.9788  test Loss: 0.6839, test AUC: 0.9713
# Epoch 50/200, Train Loss: 0.6891, Train AUC: 0.9710  test Loss: 0.6874, test AUC: 0.9734
# Epoch 51/200, Train Loss: 0.6868, Train AUC: 0.9705  test Loss: 0.6864, test AUC: 0.9735
# Epoch 52/200, Train Loss: 0.6645, Train AUC: 0.9722  test Loss: 0.6626, test AUC: 0.9712
# Epoch 53/200, Train Loss: 0.6625, Train AUC: 0.9785  test Loss: 0.6457, test AUC: 0.9714
# Epoch 54/200, Train Loss: 0.6572, Train AUC: 0.9786  test Loss: 0.6378, test AUC: 0.9726
# Epoch 55/200, Train Loss: 0.6474, Train AUC: 0.9782  test Loss: 0.6538, test AUC: 0.9726
# Epoch 56/200, Train Loss: 0.6721, Train AUC: 0.9666  test Loss: 0.6539, test AUC: 0.9727
# Epoch 57/200, Train Loss: 0.6716, Train AUC: 0.9753  test Loss: 0.6402, test AUC: 0.9742
# Epoch 58/200, Train Loss: 0.6619, Train AUC: 0.9771  test Loss: 0.6457, test AUC: 0.9740
# Epoch 59/200, Train Loss: 0.6418, Train AUC: 0.9766  test Loss: 0.6429, test AUC: 0.9724
# Epoch 60/200, Train Loss: 0.6356, Train AUC: 0.9756  test Loss: 0.6330, test AUC: 0.9716
# Epoch 61/200, Train Loss: 0.6819, Train AUC: 0.9712  test Loss: 0.6428, test AUC: 0.9740
# Epoch 62/200, Train Loss: 0.6402, Train AUC: 0.9781  test Loss: 0.6311, test AUC: 0.9739
# Epoch 63/200, Train Loss: 0.6290, Train AUC: 0.9789  test Loss: 0.6238, test AUC: 0.9730
# Epoch 64/200, Train Loss: 0.6330, Train AUC: 0.9845  test Loss: 0.6204, test AUC: 0.9730
# Epoch 65/200, Train Loss: 0.6276, Train AUC: 0.9803  test Loss: 0.6085, test AUC: 0.9735
# Epoch 66/200, Train Loss: 0.6239, Train AUC: 0.9755  test Loss: 0.5793, test AUC: 0.9725
# Epoch 67/200, Train Loss: 0.6328, Train AUC: 0.9775  test Loss: 0.5931, test AUC: 0.9738
# Epoch 68/200, Train Loss: 0.6407, Train AUC: 0.9664  test Loss: 0.5964, test AUC: 0.9726
# Epoch 69/200, Train Loss: 0.6165, Train AUC: 0.9739  test Loss: 0.5940, test AUC: 0.9724
# Epoch 70/200, Train Loss: 0.6256, Train AUC: 0.9734  test Loss: 0.6126, test AUC: 0.9742
# Epoch 71/200, Train Loss: 0.6156, Train AUC: 0.9798  test Loss: 0.6072, test AUC: 0.9745
# Epoch 72/200, Train Loss: 0.6388, Train AUC: 0.9776  test Loss: 0.6135, test AUC: 0.9758
# Epoch 73/200, Train Loss: 0.6078, Train AUC: 0.9838  test Loss: 0.6221, test AUC: 0.9752
# Epoch 74/200, Train Loss: 0.6100, Train AUC: 0.9797  test Loss: 0.5976, test AUC: 0.9739
# Epoch 75/200, Train Loss: 0.6146, Train AUC: 0.9785  test Loss: 0.6032, test AUC: 0.9739
# Epoch 76/200, Train Loss: 0.6087, Train AUC: 0.9834  test Loss: 0.5983, test AUC: 0.9737
# Epoch 77/200, Train Loss: 0.5930, Train AUC: 0.9817  test Loss: 0.5872, test AUC: 0.9728
# Epoch 78/200, Train Loss: 0.5944, Train AUC: 0.9836  test Loss: 0.5887, test AUC: 0.9724
# Epoch 79/200, Train Loss: 0.5948, Train AUC: 0.9801  test Loss: 0.5800, test AUC: 0.9735
# Epoch 80/200, Train Loss: 0.6072, Train AUC: 0.9744  test Loss: 0.5766, test AUC: 0.9758
# Epoch 81/200, Train Loss: 0.5757, Train AUC: 0.9825  test Loss: 0.5818, test AUC: 0.9758
# Epoch 82/200, Train Loss: 0.5926, Train AUC: 0.9768  test Loss: 0.5755, test AUC: 0.9750
# Epoch 83/200, Train Loss: 0.5925, Train AUC: 0.9779  test Loss: 0.5771, test AUC: 0.9738
# Epoch 84/200, Train Loss: 0.5953, Train AUC: 0.9752  test Loss: 0.5651, test AUC: 0.9739
# Epoch 85/200, Train Loss: 0.5852, Train AUC: 0.9799  test Loss: 0.5731, test AUC: 0.9731
# Epoch 86/200, Train Loss: 0.6006, Train AUC: 0.9732  test Loss: 0.5733, test AUC: 0.9729
# Epoch 87/200, Train Loss: 0.5900, Train AUC: 0.9754  test Loss: 0.5722, test AUC: 0.9747
# Epoch 88/200, Train Loss: 0.5901, Train AUC: 0.9759  test Loss: 0.5580, test AUC: 0.9748
# Epoch 89/200, Train Loss: 0.5670, Train AUC: 0.9818  test Loss: 0.5388, test AUC: 0.9758
# Epoch 90/200, Train Loss: 0.5696, Train AUC: 0.9804  test Loss: 0.5434, test AUC: 0.9756
# Epoch 91/200, Train Loss: 0.5798, Train AUC: 0.9776  test Loss: 0.5598, test AUC: 0.9752
# Epoch 92/200, Train Loss: 0.5805, Train AUC: 0.9778  test Loss: 0.5623, test AUC: 0.9751
# Epoch 93/200, Train Loss: 0.5734, Train AUC: 0.9795  test Loss: 0.5512, test AUC: 0.9759
# Epoch 94/200, Train Loss: 0.5951, Train AUC: 0.9798  test Loss: 0.5558, test AUC: 0.9765
# Epoch 95/200, Train Loss: 0.5621, Train AUC: 0.9823  test Loss: 0.5549, test AUC: 0.9755
# Epoch 96/200, Train Loss: 0.5615, Train AUC: 0.9811  test Loss: 0.5452, test AUC: 0.9729
# Epoch 97/200, Train Loss: 0.5822, Train AUC: 0.9780  test Loss: 0.5452, test AUC: 0.9764
# Epoch 98/200, Train Loss: 0.5890, Train AUC: 0.9762  test Loss: 0.5541, test AUC: 0.9761
# Epoch 99/200, Train Loss: 0.5446, Train AUC: 0.9821  test Loss: 0.5301, test AUC: 0.9763
# Epoch 100/200, Train Loss: 0.5426, Train AUC: 0.9805  test Loss: 0.5184, test AUC: 0.9719
# Epoch 101/200, Train Loss: 0.5365, Train AUC: 0.9801  test Loss: 0.5111, test AUC: 0.9739
# Epoch 102/200, Train Loss: 0.5884, Train AUC: 0.9742  test Loss: 0.5298, test AUC: 0.9763
# Epoch 103/200, Train Loss: 0.5488, Train AUC: 0.9788  test Loss: 0.5228, test AUC: 0.9748
# Epoch 104/200, Train Loss: 0.5479, Train AUC: 0.9715  test Loss: 0.5148, test AUC: 0.9725
# Epoch 105/200, Train Loss: 0.5319, Train AUC: 0.9811  test Loss: 0.5251, test AUC: 0.9747
# Epoch 106/200, Train Loss: 0.5294, Train AUC: 0.9772  test Loss: 0.5146, test AUC: 0.9735
# Epoch 107/200, Train Loss: 0.5571, Train AUC: 0.9756  test Loss: 0.5192, test AUC: 0.9760
# Epoch 108/200, Train Loss: 0.5443, Train AUC: 0.9804  test Loss: 0.5140, test AUC: 0.9760
# Epoch 109/200, Train Loss: 0.5357, Train AUC: 0.9762  test Loss: 0.5050, test AUC: 0.9755
# Epoch 110/200, Train Loss: 0.5358, Train AUC: 0.9794  test Loss: 0.5190, test AUC: 0.9742
# Epoch 111/200, Train Loss: 0.5188, Train AUC: 0.9802  test Loss: 0.5056, test AUC: 0.9761
# Epoch 112/200, Train Loss: 0.5190, Train AUC: 0.9810  test Loss: 0.5154, test AUC: 0.9760
# Epoch 113/200, Train Loss: 0.5181, Train AUC: 0.9782  test Loss: 0.5112, test AUC: 0.9728
# Epoch 114/200, Train Loss: 0.5295, Train AUC: 0.9826  test Loss: 0.4953, test AUC: 0.9760
# Epoch 115/200, Train Loss: 0.5195, Train AUC: 0.9805  test Loss: 0.4914, test AUC: 0.9735
# Epoch 116/200, Train Loss: 0.5220, Train AUC: 0.9817  test Loss: 0.4984, test AUC: 0.9722
# Epoch 117/200, Train Loss: 0.5055, Train AUC: 0.9834  test Loss: 0.4991, test AUC: 0.9749
# Epoch 118/200, Train Loss: 0.5166, Train AUC: 0.9773  test Loss: 0.4991, test AUC: 0.9748
# Epoch 119/200, Train Loss: 0.4998, Train AUC: 0.9824  test Loss: 0.4950, test AUC: 0.9756
# Epoch 120/200, Train Loss: 0.5217, Train AUC: 0.9789  test Loss: 0.4962, test AUC: 0.9760
# Epoch 121/200, Train Loss: 0.5295, Train AUC: 0.9752  test Loss: 0.4767, test AUC: 0.9761
# Epoch 122/200, Train Loss: 0.5249, Train AUC: 0.9814  test Loss: 0.4954, test AUC: 0.9758
# Epoch 123/200, Train Loss: 0.5191, Train AUC: 0.9802  test Loss: 0.4964, test AUC: 0.9763
# Epoch 124/200, Train Loss: 0.5428, Train AUC: 0.9737  test Loss: 0.4907, test AUC: 0.9764
# Epoch 125/200, Train Loss: 0.5395, Train AUC: 0.9736  test Loss: 0.4766, test AUC: 0.9761
# Epoch 126/200, Train Loss: 0.4935, Train AUC: 0.9768  test Loss: 0.4736, test AUC: 0.9722
# Epoch 127/200, Train Loss: 0.5337, Train AUC: 0.9798  test Loss: 0.4949, test AUC: 0.9761
# Epoch 128/200, Train Loss: 0.4922, Train AUC: 0.9807  test Loss: 0.4907, test AUC: 0.9723
# Epoch 129/200, Train Loss: 0.4936, Train AUC: 0.9801  test Loss: 0.4764, test AUC: 0.9725
# Epoch 130/200, Train Loss: 0.4825, Train AUC: 0.9835  test Loss: 0.4625, test AUC: 0.9739
# Epoch 131/200, Train Loss: 0.4974, Train AUC: 0.9802  test Loss: 0.4712, test AUC: 0.9765
# Epoch 132/200, Train Loss: 0.5086, Train AUC: 0.9811  test Loss: 0.4687, test AUC: 0.9764
# Epoch 133/200, Train Loss: 0.4828, Train AUC: 0.9847  test Loss: 0.4516, test AUC: 0.9723
# Epoch 134/200, Train Loss: 0.4898, Train AUC: 0.9780  test Loss: 0.4439, test AUC: 0.9723
# Epoch 135/200, Train Loss: 0.5222, Train AUC: 0.9797  test Loss: 0.4558, test AUC: 0.9756
# Epoch 136/200, Train Loss: 0.5057, Train AUC: 0.9751  test Loss: 0.4606, test AUC: 0.9761
# Epoch 137/200, Train Loss: 0.4815, Train AUC: 0.9813  test Loss: 0.4686, test AUC: 0.9764
# Epoch 138/200, Train Loss: 0.4911, Train AUC: 0.9825  test Loss: 0.4611, test AUC: 0.9764
# Epoch 139/200, Train Loss: 0.4872, Train AUC: 0.9779  test Loss: 0.4383, test AUC: 0.9726
# Epoch 140/200, Train Loss: 0.4740, Train AUC: 0.9819  test Loss: 0.4785, test AUC: 0.9731
# Epoch 141/200, Train Loss: 0.4669, Train AUC: 0.9796  test Loss: 0.4646, test AUC: 0.9727
# Epoch 142/200, Train Loss: 0.4785, Train AUC: 0.9841  test Loss: 0.4660, test AUC: 0.9726
# Epoch 143/200, Train Loss: 0.4703, Train AUC: 0.9811  test Loss: 0.4501, test AUC: 0.9717
# Epoch 144/200, Train Loss: 0.4631, Train AUC: 0.9813  test Loss: 0.4471, test AUC: 0.9723
# Epoch 145/200, Train Loss: 0.4659, Train AUC: 0.9834  test Loss: 0.4376, test AUC: 0.9723
# Epoch 146/200, Train Loss: 0.4878, Train AUC: 0.9822  test Loss: 0.4396, test AUC: 0.9726
# Epoch 147/200, Train Loss: 0.4525, Train AUC: 0.9836  test Loss: 0.4438, test AUC: 0.9725
# Epoch 148/200, Train Loss: 0.4633, Train AUC: 0.9804  test Loss: 0.4428, test AUC: 0.9727
# Epoch 149/200, Train Loss: 0.4647, Train AUC: 0.9783  test Loss: 0.4323, test AUC: 0.9727
# Epoch 150/200, Train Loss: 0.4789, Train AUC: 0.9809  test Loss: 0.4425, test AUC: 0.9727
# Epoch 151/200, Train Loss: 0.4613, Train AUC: 0.9811  test Loss: 0.4463, test AUC: 0.9727
# Epoch 152/200, Train Loss: 0.4924, Train AUC: 0.9691  test Loss: 0.4393, test AUC: 0.9727
# Epoch 153/200, Train Loss: 0.4676, Train AUC: 0.9767  test Loss: 0.4336, test AUC: 0.9717
# Epoch 154/200, Train Loss: 0.4803, Train AUC: 0.9814  test Loss: 0.4351, test AUC: 0.9725
# Epoch 155/200, Train Loss: 0.4495, Train AUC: 0.9808  test Loss: 0.4188, test AUC: 0.9725
# Epoch 156/200, Train Loss: 0.4490, Train AUC: 0.9828  test Loss: 0.4308, test AUC: 0.9765
# Epoch 157/200, Train Loss: 0.4497, Train AUC: 0.9792  test Loss: 0.4176, test AUC: 0.9743
# Epoch 158/200, Train Loss: 0.4965, Train AUC: 0.9816  test Loss: 0.4446, test AUC: 0.9749
# Epoch 159/200, Train Loss: 0.4452, Train AUC: 0.9808  test Loss: 0.4318, test AUC: 0.9726
# Epoch 160/200, Train Loss: 0.4550, Train AUC: 0.9774  test Loss: 0.4268, test AUC: 0.9725
# Epoch 161/200, Train Loss: 0.4698, Train AUC: 0.9738  test Loss: 0.4225, test AUC: 0.9725
# Epoch 162/200, Train Loss: 0.4701, Train AUC: 0.9796  test Loss: 0.4459, test AUC: 0.9754
# Epoch 163/200, Train Loss: 0.4600, Train AUC: 0.9812  test Loss: 0.4437, test AUC: 0.9752
# Epoch 164/200, Train Loss: 0.4412, Train AUC: 0.9822  test Loss: 0.4398, test AUC: 0.9735
# Epoch 165/200, Train Loss: 0.4537, Train AUC: 0.9836  test Loss: 0.4283, test AUC: 0.9727
# Epoch 166/200, Train Loss: 0.4544, Train AUC: 0.9829  test Loss: 0.4164, test AUC: 0.9733
# Epoch 167/200, Train Loss: 0.4475, Train AUC: 0.9831  test Loss: 0.4107, test AUC: 0.9735
# Epoch 168/200, Train Loss: 0.4510, Train AUC: 0.9754  test Loss: 0.4002, test AUC: 0.9726
# Epoch 169/200, Train Loss: 0.4381, Train AUC: 0.9830  test Loss: 0.4036, test AUC: 0.9733
# Epoch 170/200, Train Loss: 0.4286, Train AUC: 0.9843  test Loss: 0.4121, test AUC: 0.9734
# Epoch 171/200, Train Loss: 0.4240, Train AUC: 0.9841  test Loss: 0.4259, test AUC: 0.9726
# Epoch 172/200, Train Loss: 0.4184, Train AUC: 0.9856  test Loss: 0.4230, test AUC: 0.9725
# Epoch 173/200, Train Loss: 0.4147, Train AUC: 0.9829  test Loss: 0.3996, test AUC: 0.9725
# Epoch 174/200, Train Loss: 0.4334, Train AUC: 0.9822  test Loss: 0.4163, test AUC: 0.9729
# Epoch 175/200, Train Loss: 0.4643, Train AUC: 0.9793  test Loss: 0.4297, test AUC: 0.9729
# Epoch 176/200, Train Loss: 0.4160, Train AUC: 0.9825  test Loss: 0.4053, test AUC: 0.9726
# Epoch 177/200, Train Loss: 0.4389, Train AUC: 0.9827  test Loss: 0.4114, test AUC: 0.9726
# Epoch 178/200, Train Loss: 0.4233, Train AUC: 0.9831  test Loss: 0.4178, test AUC: 0.9727
# Epoch 179/200, Train Loss: 0.4119, Train AUC: 0.9819  test Loss: 0.4108, test AUC: 0.9712
# Epoch 180/200, Train Loss: 0.4302, Train AUC: 0.9805  test Loss: 0.4103, test AUC: 0.9716
# Epoch 181/200, Train Loss: 0.4153, Train AUC: 0.9852  test Loss: 0.4092, test AUC: 0.9696
# Epoch 182/200, Train Loss: 0.4167, Train AUC: 0.9829  test Loss: 0.3961, test AUC: 0.9721
# Epoch 183/200, Train Loss: 0.4098, Train AUC: 0.9855  test Loss: 0.4000, test AUC: 0.9701
# Epoch 184/200, Train Loss: 0.4436, Train AUC: 0.9826  test Loss: 0.4171, test AUC: 0.9729
# Epoch 185/200, Train Loss: 0.4292, Train AUC: 0.9804  test Loss: 0.4213, test AUC: 0.9729
# Epoch 186/200, Train Loss: 0.4272, Train AUC: 0.9836  test Loss: 0.4125, test AUC: 0.9725
# Epoch 187/200, Train Loss: 0.4137, Train AUC: 0.9836  test Loss: 0.4008, test AUC: 0.9723
# Epoch 188/200, Train Loss: 0.4022, Train AUC: 0.9838  test Loss: 0.3907, test AUC: 0.9723
# Epoch 189/200, Train Loss: 0.4231, Train AUC: 0.9783  test Loss: 0.3870, test AUC: 0.9722
# Epoch 190/200, Train Loss: 0.3879, Train AUC: 0.9865  test Loss: 0.3758, test AUC: 0.9722
# Epoch 191/200, Train Loss: 0.4361, Train AUC: 0.9762  test Loss: 0.3867, test AUC: 0.9722
# Epoch 192/200, Train Loss: 0.4229, Train AUC: 0.9790  test Loss: 0.3880, test AUC: 0.9725
# Epoch 193/200, Train Loss: 0.3947, Train AUC: 0.9819  test Loss: 0.3988, test AUC: 0.9727
# Epoch 194/200, Train Loss: 0.4015, Train AUC: 0.9846  test Loss: 0.3912, test AUC: 0.9727
# Epoch 195/200, Train Loss: 0.4199, Train AUC: 0.9786  test Loss: 0.3683, test AUC: 0.9718
# Epoch 196/200, Train Loss: 0.4062, Train AUC: 0.9837  test Loss: 0.3644, test AUC: 0.9726
# Epoch 197/200, Train Loss: 0.4103, Train AUC: 0.9781  test Loss: 0.3799, test AUC: 0.9726
# Epoch 198/200, Train Loss: 0.4206, Train AUC: 0.9847  test Loss: 0.3921, test AUC: 0.9735
# Epoch 199/200, Train Loss: 0.4235, Train AUC: 0.9824  test Loss: 0.4023, test AUC: 0.9734
# Epoch 200/200, Train Loss: 0.4016, Train AUC: 0.9818  test Loss: 0.4013, test AUC: 0.9725

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.8795
# Recall:    0.8883
# F1 Score:  0.8661
# Precision: 0.8519
# AUC-ROC:   0.9596

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("AIBL AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("AIBL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
