# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,MultiModalTransformer,NeuralNet,TransEModel,KGMultiModalTransformer
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import pandas as pd

# %%
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('NC.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'NC/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'AD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('MCI.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'MCI/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #44
print(count_no) #247
print(count_mci) #106
# Out:
# 72
# 358
# 86

# %%
ad_arrays=[]
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','no':'0','yes':'1','ans':'2','haw':'3','ind':'4','bl':'1'}
for i in data_ad:
    j= i[14:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    ad_array = np.array(num_list)
    ad_arrays.append(ad_array)
ad_array = np.vstack(ad_arrays)

# %%
normal_arrays=[]
for i in data_normal:
    j= i[14:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    normal_array = np.array(num_list)
    normal_arrays.append(normal_array)
normal_array = np.vstack(normal_arrays)

# %%
mci_arrays=[]
for i in data_mci:
    j= i[14:]
    j= [replace_dict.get(item, item) for item in j]
    num_list = [float(num) for num in j]
    mci_array = np.array(num_list)
    mci_arrays.append(mci_array)
mci_array = np.vstack(mci_arrays)

# %%
#加权算值
def weighted_sum(tensor):
    weights = [0.2, 0.3, 0.5]
    weight_tensor = torch.tensor(weights, dtype=tensor.dtype, device=tensor.device)
    weighted_sum_result = torch.sum(tensor * weight_tensor, dim=1, keepdim=True)
    return weighted_sum_result

# %%
ad_tensor = torch.from_numpy(ad_array).float()
normal_tensor = torch.from_numpy(normal_array).float()
mci_tensor = torch.from_numpy(mci_array).float()
normal_labels = torch.zeros(normal_tensor.shape[0], dtype=torch.long)
mci_labels = torch.ones(mci_tensor.shape[0], dtype=torch.long)
ad_labels = torch.full((ad_tensor.shape[0],), 2, dtype=torch.long)

X = torch.cat([ad_tensor, normal_tensor, mci_tensor], dim=0)
y = torch.cat([ad_labels, normal_labels, mci_labels], dim=0)

dataset = TensorDataset(X, y)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)
model = NeuralNet(embedding=9)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
for epoch in range(50):
    for inputs, labels in dataloader:
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
with torch.no_grad():
    ad_tensor = model(ad_tensor)
    normal_tensor = model(normal_tensor)
    mci_tensor = model(mci_tensor)
    
ad_tensor = weighted_sum(ad_tensor)
mci_tensor = weighted_sum(mci_tensor)
normal_tensor = weighted_sum(normal_tensor)

print('AD_tensor shape:', ad_tensor.shape)
print('Normal_tensor shape:', normal_tensor.shape)
print('MCI_tensor shape:', mci_tensor.shape)
# Out:
# AD_tensor shape: torch.Size([72, 1])
# Normal_tensor shape: torch.Size([358, 1])
# MCI_tensor shape: torch.Size([86, 1])

# %%
# 数据处理函数
def preprocess_data(data, replace_dict):
    processed_data = []
    for row in data:
        row = [replace_dict.get(item, item) for item in row]
        row = [float(item) if item.replace('.', '', 1).isdigit() else item for item in row]
        processed_data.append(row[3:18])
    return np.array(processed_data)

# %%
# 编码类别型变量
def encode_categorical(data, categorical_indices):
    encoded_data = data.copy()
    for idx in categorical_indices:
        le = LabelEncoder()
        encoded_data[:, idx] = le.fit_transform(encoded_data[:, idx])
    return encoded_data.astype(float)

# %%
ad_data = preprocess_data(data_ad, replace_dict)
normal_data = preprocess_data(data_normal, replace_dict)
mci_data = preprocess_data(data_mci, replace_dict)

categorical_indices = [2, 3, 4, 5]  # gender, education, hispanic, race, apoe
ad_EHR = encode_categorical(ad_data, categorical_indices)
normal_EHR = encode_categorical(normal_data, categorical_indices)
mci_EHR = encode_categorical(mci_data, categorical_indices)

ad_EHR = torch.from_numpy(ad_EHR).float()
normal_EHR = torch.from_numpy(normal_EHR).float()
mci_EHR = torch.from_numpy(mci_EHR).float()

linear_layer = nn.Linear(15, 8)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

linear_layer = nn.Linear(8, 1)
normal_EHR = linear_layer(normal_EHR)
ad_EHR = linear_layer(ad_EHR)
mci_EHR = linear_layer(mci_EHR)

print('ad.EHR--->',ad_EHR.shape)
print('normal.EHR--->',normal_EHR.shape)
print('mci.EHR--->',mci_EHR.shape)
# Out:
# ad.EHR---> torch.Size([72, 1])
# normal.EHR---> torch.Size([358, 1])
# mci.EHR---> torch.Size([86, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 先导入模型定义（你cell1里已import）
nii = CNN_3D(num_class=1)    # 输出维度根据你的网络结构和任务来设
nii = nii.to(device)

def get_nii_file_list(folder_path):
    import os
    return [os.path.join(folder_path, f) for f in os.listdir(folder_path)
            if f.endswith('.nii') or f.endswith('.nii.gz')]

# 加在Cell12前，假设你的CNN_3D模型叫 nii，且device设置好了
# --- AD ---
ad_nii_files = get_nii_file_list('AD')
dataset = NiiDataset(ad_nii_files)
dataloader = DataLoader(dataset, batch_size=16, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output.cpu())
ad_output = torch.cat(all_outputs, dim=0)

# --- NC ---
normal_nii_files = get_nii_file_list('NC')
dataset = NiiDataset(normal_nii_files)
dataloader = DataLoader(dataset, batch_size=16, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output.cpu())
normal_output = torch.cat(all_outputs, dim=0)

# --- MCI ---
mci_nii_files = get_nii_file_list('MCI')
dataset = NiiDataset(mci_nii_files)
dataloader = DataLoader(dataset, batch_size=16, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output.cpu())
mci_output = torch.cat(all_outputs, dim=0)

print('ad_output shape:', ad_output.shape)
print('normal_output shape:', normal_output.shape)
print('mci_output shape:', mci_output.shape)
# Out:
# ad_output shape: torch.Size([72, 1])
# normal_output shape: torch.Size([358, 1])
# mci_output shape: torch.Size([86, 1])

# %%
# 获取EHR主键顺序（假设 row[1] 是nii文件名，不带扩展名）
ad_ehr_keys = [os.path.splitext(row[1])[0] for row in data_ad]
mci_ehr_keys = [os.path.splitext(row[1])[0] for row in data_mci]
normal_ehr_keys = [os.path.splitext(row[1])[0] for row in data_normal]

# NII文件主键到索引
ad_nii_files = get_nii_file_list('AD')
ad_nii_key2idx = {os.path.splitext(os.path.basename(f))[0]: i for i, f in enumerate(ad_nii_files)}
mci_nii_files = get_nii_file_list('MCI')
mci_nii_key2idx = {os.path.splitext(os.path.basename(f))[0]: i for i, f in enumerate(mci_nii_files)}
normal_nii_files = get_nii_file_list('NC')
normal_nii_key2idx = {os.path.splitext(os.path.basename(f))[0]: i for i, f in enumerate(normal_nii_files)}

# 对齐NII输出，只保留EHR有的部分（顺序与EHR一致）
ad_nii_indices = [ad_nii_key2idx[k] for k in ad_ehr_keys if k in ad_nii_key2idx]
ad_output_aligned = ad_output[ad_nii_indices]

mci_nii_indices = [mci_nii_key2idx[k] for k in mci_ehr_keys if k in mci_nii_key2idx]
mci_output_aligned = mci_output[mci_nii_indices]

normal_nii_indices = [normal_nii_key2idx[k] for k in normal_ehr_keys if k in normal_nii_key2idx]
normal_output_aligned = normal_output[normal_nii_indices]

# 检查对齐后shape
print('ad_EHR:', ad_EHR.shape, 'ad_output_aligned:', ad_output_aligned.shape)
print('mci_EHR:', mci_EHR.shape, 'mci_output_aligned:', mci_output_aligned.shape)
print('normal_EHR:', normal_EHR.shape, 'normal_output_aligned:', normal_output_aligned.shape)
# Out:
# ad_EHR: torch.Size([72, 1]) ad_output_aligned: torch.Size([72, 1])
# mci_EHR: torch.Size([86, 1]) mci_output_aligned: torch.Size([86, 1])
# normal_EHR: torch.Size([358, 1]) normal_output_aligned: torch.Size([358, 1])

# %%
import os

def get_nii_file_list(folder_path):
    return [os.path.join(folder_path, f) for f in os.listdir(folder_path)
            if f.endswith('.nii') or f.endswith('.nii.gz')]

batch_size = 16

# AD
ad_nii_files = get_nii_file_list('AD')
dataset = NiiDataset(ad_nii_files)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
ad_output = torch.cat(all_outputs, dim=0)
print('ad nii shape--->', ad_output.shape)

# NC
normal_nii_files = get_nii_file_list('NC')
dataset = NiiDataset(normal_nii_files)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
normal_output = torch.cat(all_outputs, dim=0)
print('normal nii shape--->', normal_output.shape)

# MCI
mci_nii_files = get_nii_file_list('MCI')
dataset = NiiDataset(mci_nii_files)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
all_outputs = []
for batch_idx, batch_data in enumerate(dataloader):
    batch_data = batch_data.to(device)
    output = nii(batch_data)
    all_outputs.append(output)
mci_output = torch.cat(all_outputs, dim=0)
print('mci nii shape--->', mci_output.shape)
# Out:
# ad nii shape---> torch.Size([72, 1])
# normal nii shape---> torch.Size([358, 1])
# mci nii shape---> torch.Size([86, 1])

# %%
# --- 先读取这三个 CSV 文件，否则没有 ad_df 等变量 ---
ad_df = pd.read_csv('AD.csv')
mci_df = pd.read_csv('MCI.csv')
normal_df = pd.read_csv('NC.csv')

# 1. 加载 PyKEEN 训练好的映射和向量
# 确保文件名和你训练脚本输出的一致
entity2id = {}
# 如果报错文件不存在，请检查文件名是否带有 _fixed 后缀
with open('entity2id_distmult_AIBL_fixed.txt', 'r', encoding='utf-8') as f:
    for line in f:
        entity, idx = line.strip().split('\t')
        entity2id[entity] = int(idx)

# 加载保存的 numpy 矩阵
distmult_matrix = np.load('entity_embeddings_distmult_AIBL_fixed.npy')
# 转为 tensor，方便后续操作 (num_entities, 32)
kg_embeddings = torch.from_numpy(distmult_matrix).float()

def get_distmult_embeddings(df, entity2id, embeddings_tensor):
    embeddings_list = []
    
    for index, row in df.iterrows():
        # 获取文件名 
        # 假设 CSV 里有一列叫 'filename' (根据你之前的代码逻辑)
        # 如果报错 KeyError: 'filename'，请把下面这行改为 fname = str(row.iloc[1]).strip()
        fname = str(row['filename']).strip() 
        
        if fname in entity2id:
            idx = entity2id[fname]
            emb = embeddings_tensor[idx] # 直接查表
            embeddings_list.append(emb)
        else:
            # 如果没找到，用全0填充 (为了保持batch对齐，不能跳过)
            # print(f"Warning: {fname} not in KG.")
            embeddings_list.append(torch.zeros(32)) 

    return torch.stack(embeddings_list)

# 获取嵌入向量 (维度应为 [Batch, 32])
ad_kg = get_distmult_embeddings(ad_df, entity2id, kg_embeddings)
mci_kg = get_distmult_embeddings(mci_df, entity2id, kg_embeddings)
normal_kg = get_distmult_embeddings(normal_df, entity2id, kg_embeddings)

print(f"AD KG shape: {ad_kg.shape}")
print(f"MCI KG shape: {mci_kg.shape}")
print(f"NC KG shape: {normal_kg.shape}")
# Out:
# AD KG shape: torch.Size([72, 32])
# MCI KG shape: torch.Size([86, 32])
# NC KG shape: torch.Size([358, 32])

# %%
# Cell 16 - Modified
kg_embed_dim = 32 # 对应你 DistMult 设置的 32

# 注意：这里把 ad_transe 换成了 ad_kg
X_ad = torch.cat([ad_EHR, ad_output_aligned.cpu(), ad_tensor, ad_kg], dim=1)
X_mci = torch.cat([mci_EHR, mci_output_aligned.cpu(), mci_tensor, mci_kg], dim=1)
X_normal = torch.cat([normal_EHR, normal_output_aligned.cpu(), normal_tensor, normal_kg], dim=1)

# 下面的代码基本不用动，只要确保分割时取对了维度
y_ad = torch.ones(len(X_ad)) * 2
y_mci = torch.ones(len(X_mci)) * 1
y_normal = torch.ones(len(X_normal)) * 0

X = torch.cat([X_ad, X_mci, X_normal], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal], dim=0).float()

# 分离特征和KG嵌入
features = X[:, :-kg_embed_dim]      
kg_embeddings_data = X[:, -kg_embed_dim:]  

# 切分数据集 (把 transe_embeddings 换成 kg_embeddings_data)
X_train, X_test, y_train, y_test, kg_train, kg_test = train_test_split(
    features.detach().numpy(), y.numpy(), kg_embeddings_data.detach().numpy(),
    test_size=0.20, stratify=y.numpy(), random_state=32
)
X_train, X_val, y_train, y_val, kg_train, kg_val = train_test_split(
    X_train, y_train, kg_train,
    test_size=0.20, stratify=y_train, random_state=30
)

# 转 Tensor
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.LongTensor(y_train).to(device)
kg_train_tensor = torch.FloatTensor(kg_train).to(device) # DistMult 向量

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.LongTensor(y_val).to(device)
kg_val_tensor = torch.FloatTensor(kg_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.LongTensor(y_test).to(device)
kg_test_tensor = torch.FloatTensor(kg_test).to(device)

# 封装 DataLoader
train_dataset = TensorDataset(X_train_tensor, kg_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, kg_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, kg_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)
test_loader = DataLoader(test_dataset, batch_size=32)

# %%
def train_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, transe_embed, labels in loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs, transe_embed)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()

        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)

    # Convert lists to numpy arrays for easier manipulation
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')

    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

def validate_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for inputs, transe_embed, labels in loader:
            inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
            labels = labels.long()
            
            outputs = model(inputs, transe_embed)
            loss = criterion(outputs, labels)
            
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    
    all_probs = np.array(all_probs)
    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)

    # 计算指标
    val_auc = roc_auc_score(all_labels, all_probs, multi_class='ovo')
    val_f1 = f1_score(all_labels, all_preds, average='macro')
    val_recall = recall_score(all_labels, all_preds, average='macro')
    val_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, val_auc, val_f1, val_recall, val_precision

# %%
# Cell 18 - Modified
embed_dim = 32
transe_embed_dim = 32 # 这里其实是 DistMult dim，但名字为了兼容 model1 没改
num_epochs = 200
learning_rate = 1e-5
weight_decay = 1e-3

# --- 删除掉了原本在这里的 TransEModel 初始化和 load_state_dict ---
# 因为 Embedding 已经作为数据输入了，不需要模型来生成

# 初始化主模型
model = KGMultiModalTransformer(embed_dim=embed_dim, transe_embed_dim=transe_embed_dim).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)


train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []

for epoch in range(num_epochs):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion, device)
    test_loss, test_auc, test_f1, test_recall, test_precision = validate_epoch(model, test_loader, criterion, device)
    
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    print(f"Epoch {epoch + 1}/{num_epochs}, "
          f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}  "   
          f"test Loss: {test_loss:.4f}, test AUC: {test_auc:.4f}")
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/200, Train Loss: 1.2094, Train AUC: 0.4581  test Loss: 1.1562, test AUC: 0.5065
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 2/200, Train Loss: 1.1874, Train AUC: 0.4858  test Loss: 1.1544, test AUC: 0.5515
# D:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 3/200, Train Loss: 1.1781, Train AUC: 0.4904  test Loss: 1.1501, test AUC: 0.5811
# Epoch 4/200, Train Loss: 1.1517, Train AUC: 0.5336  test Loss: 1.1431, test AUC: 0.5982
# Epoch 5/200, Train Loss: 1.1981, Train AUC: 0.5217  test Loss: 1.1352, test AUC: 0.6156
# Epoch 6/200, Train Loss: 1.1455, Train AUC: 0.5500  test Loss: 1.1249, test AUC: 0.6225
# Epoch 7/200, Train Loss: 1.1668, Train AUC: 0.5515  test Loss: 1.1146, test AUC: 0.6446
# Epoch 8/200, Train Loss: 1.1191, Train AUC: 0.5940  test Loss: 1.1074, test AUC: 0.6575
# Epoch 9/200, Train Loss: 1.1300, Train AUC: 0.5862  test Loss: 1.0935, test AUC: 0.6727
# Epoch 10/200, Train Loss: 1.1278, Train AUC: 0.5777  test Loss: 1.0862, test AUC: 0.6831
# Epoch 11/200, Train Loss: 1.0850, Train AUC: 0.6495  test Loss: 1.0769, test AUC: 0.6964
# Epoch 12/200, Train Loss: 1.0928, Train AUC: 0.6482  test Loss: 1.0660, test AUC: 0.7113
# Epoch 13/200, Train Loss: 1.1013, Train AUC: 0.6516  test Loss: 1.0564, test AUC: 0.7232
# Epoch 14/200, Train Loss: 1.0786, Train AUC: 0.6568  test Loss: 1.0446, test AUC: 0.7278
# Epoch 15/200, Train Loss: 1.0501, Train AUC: 0.7158  test Loss: 1.0327, test AUC: 0.7387
# Epoch 16/200, Train Loss: 1.0587, Train AUC: 0.7173  test Loss: 1.0260, test AUC: 0.7435
# Epoch 17/200, Train Loss: 1.0282, Train AUC: 0.7416  test Loss: 1.0092, test AUC: 0.7588
# Epoch 18/200, Train Loss: 1.0241, Train AUC: 0.7300  test Loss: 0.9930, test AUC: 0.7611
# Epoch 19/200, Train Loss: 1.0143, Train AUC: 0.7382  test Loss: 0.9856, test AUC: 0.7738
# Epoch 20/200, Train Loss: 1.0386, Train AUC: 0.7368  test Loss: 0.9813, test AUC: 0.7829
# Epoch 21/200, Train Loss: 0.9756, Train AUC: 0.7898  test Loss: 0.9673, test AUC: 0.7832
# Epoch 22/200, Train Loss: 1.0004, Train AUC: 0.7659  test Loss: 0.9584, test AUC: 0.7882
# Epoch 23/200, Train Loss: 0.9759, Train AUC: 0.7952  test Loss: 0.9400, test AUC: 0.7943
# Epoch 24/200, Train Loss: 0.9649, Train AUC: 0.8049  test Loss: 0.9278, test AUC: 0.8018
# Epoch 25/200, Train Loss: 0.9409, Train AUC: 0.8145  test Loss: 0.9073, test AUC: 0.8025
# Epoch 26/200, Train Loss: 0.9431, Train AUC: 0.8239  test Loss: 0.9056, test AUC: 0.8082
# Epoch 27/200, Train Loss: 0.9344, Train AUC: 0.8301  test Loss: 0.8940, test AUC: 0.8118
# Epoch 28/200, Train Loss: 0.9327, Train AUC: 0.8345  test Loss: 0.8776, test AUC: 0.8175
# Epoch 29/200, Train Loss: 0.9107, Train AUC: 0.8543  test Loss: 0.8685, test AUC: 0.8246
# Epoch 30/200, Train Loss: 0.9206, Train AUC: 0.8458  test Loss: 0.8645, test AUC: 0.8258
# Epoch 31/200, Train Loss: 0.9076, Train AUC: 0.8721  test Loss: 0.8590, test AUC: 0.8355
# Epoch 32/200, Train Loss: 0.8899, Train AUC: 0.8605  test Loss: 0.8450, test AUC: 0.8384
# Epoch 33/200, Train Loss: 0.8814, Train AUC: 0.8571  test Loss: 0.8356, test AUC: 0.8415
# Epoch 34/200, Train Loss: 0.8446, Train AUC: 0.8938  test Loss: 0.8270, test AUC: 0.8422
# Epoch 35/200, Train Loss: 0.8666, Train AUC: 0.8679  test Loss: 0.8245, test AUC: 0.8484
# Epoch 36/200, Train Loss: 0.8330, Train AUC: 0.9125  test Loss: 0.8181, test AUC: 0.8475
# Epoch 37/200, Train Loss: 0.8418, Train AUC: 0.8874  test Loss: 0.7893, test AUC: 0.8488
# Epoch 38/200, Train Loss: 0.8334, Train AUC: 0.8881  test Loss: 0.7838, test AUC: 0.8538
# Epoch 39/200, Train Loss: 0.8281, Train AUC: 0.8961  test Loss: 0.7896, test AUC: 0.8603
# Epoch 40/200, Train Loss: 0.7958, Train AUC: 0.9043  test Loss: 0.7659, test AUC: 0.8583
# Epoch 41/200, Train Loss: 0.8149, Train AUC: 0.9067  test Loss: 0.7646, test AUC: 0.8576
# Epoch 42/200, Train Loss: 0.8009, Train AUC: 0.9105  test Loss: 0.7486, test AUC: 0.8611
# Epoch 43/200, Train Loss: 0.7738, Train AUC: 0.9270  test Loss: 0.7441, test AUC: 0.8635
# Epoch 44/200, Train Loss: 0.7781, Train AUC: 0.9127  test Loss: 0.7422, test AUC: 0.8691
# Epoch 45/200, Train Loss: 0.7654, Train AUC: 0.9264  test Loss: 0.7343, test AUC: 0.8703
# Epoch 46/200, Train Loss: 0.7684, Train AUC: 0.9215  test Loss: 0.7306, test AUC: 0.8719
# Epoch 47/200, Train Loss: 0.7761, Train AUC: 0.9125  test Loss: 0.7164, test AUC: 0.8765
# Epoch 48/200, Train Loss: 0.7364, Train AUC: 0.9243  test Loss: 0.7088, test AUC: 0.8777
# Epoch 49/200, Train Loss: 0.7387, Train AUC: 0.9358  test Loss: 0.7050, test AUC: 0.8811
# Epoch 50/200, Train Loss: 0.7322, Train AUC: 0.9253  test Loss: 0.7005, test AUC: 0.8837
# Epoch 51/200, Train Loss: 0.7431, Train AUC: 0.9421  test Loss: 0.7038, test AUC: 0.8947
# Epoch 52/200, Train Loss: 0.7430, Train AUC: 0.9310  test Loss: 0.6945, test AUC: 0.8956
# Epoch 53/200, Train Loss: 0.7110, Train AUC: 0.9364  test Loss: 0.6657, test AUC: 0.8878
# Epoch 54/200, Train Loss: 0.7028, Train AUC: 0.9448  test Loss: 0.6702, test AUC: 0.8969
# Epoch 55/200, Train Loss: 0.7215, Train AUC: 0.9407  test Loss: 0.6704, test AUC: 0.9036
# Epoch 56/200, Train Loss: 0.6920, Train AUC: 0.9460  test Loss: 0.6637, test AUC: 0.9033
# Epoch 57/200, Train Loss: 0.6830, Train AUC: 0.9503  test Loss: 0.6492, test AUC: 0.8981
# Epoch 58/200, Train Loss: 0.6882, Train AUC: 0.9440  test Loss: 0.6501, test AUC: 0.9071
# Epoch 59/200, Train Loss: 0.6924, Train AUC: 0.9519  test Loss: 0.6549, test AUC: 0.9150
# Epoch 60/200, Train Loss: 0.6927, Train AUC: 0.9454  test Loss: 0.6239, test AUC: 0.9103
# Epoch 61/200, Train Loss: 0.6933, Train AUC: 0.9555  test Loss: 0.6378, test AUC: 0.9198
# Epoch 62/200, Train Loss: 0.6678, Train AUC: 0.9571  test Loss: 0.6220, test AUC: 0.9154
# Epoch 63/200, Train Loss: 0.6593, Train AUC: 0.9539  test Loss: 0.6253, test AUC: 0.9224
# Epoch 64/200, Train Loss: 0.6442, Train AUC: 0.9579  test Loss: 0.6123, test AUC: 0.9215
# Epoch 65/200, Train Loss: 0.6557, Train AUC: 0.9498  test Loss: 0.6039, test AUC: 0.9221
# Epoch 66/200, Train Loss: 0.6606, Train AUC: 0.9602  test Loss: 0.6087, test AUC: 0.9287
# Epoch 67/200, Train Loss: 0.6437, Train AUC: 0.9494  test Loss: 0.6060, test AUC: 0.9258
# Epoch 68/200, Train Loss: 0.6458, Train AUC: 0.9602  test Loss: 0.6072, test AUC: 0.9337
# Epoch 69/200, Train Loss: 0.6399, Train AUC: 0.9533  test Loss: 0.6066, test AUC: 0.9378
# Epoch 70/200, Train Loss: 0.6240, Train AUC: 0.9520  test Loss: 0.5680, test AUC: 0.9291
# Epoch 71/200, Train Loss: 0.6250, Train AUC: 0.9616  test Loss: 0.5756, test AUC: 0.9315
# Epoch 72/200, Train Loss: 0.6246, Train AUC: 0.9671  test Loss: 0.5865, test AUC: 0.9387
# Epoch 73/200, Train Loss: 0.6131, Train AUC: 0.9689  test Loss: 0.5825, test AUC: 0.9399
# Epoch 74/200, Train Loss: 0.6127, Train AUC: 0.9675  test Loss: 0.5685, test AUC: 0.9375
# Epoch 75/200, Train Loss: 0.6229, Train AUC: 0.9598  test Loss: 0.5656, test AUC: 0.9385
# Epoch 76/200, Train Loss: 0.5924, Train AUC: 0.9720  test Loss: 0.5789, test AUC: 0.9445
# Epoch 77/200, Train Loss: 0.6054, Train AUC: 0.9618  test Loss: 0.5535, test AUC: 0.9436
# Epoch 78/200, Train Loss: 0.6315, Train AUC: 0.9647  test Loss: 0.5730, test AUC: 0.9508
# Epoch 79/200, Train Loss: 0.5940, Train AUC: 0.9681  test Loss: 0.5465, test AUC: 0.9444
# Epoch 80/200, Train Loss: 0.5854, Train AUC: 0.9674  test Loss: 0.5508, test AUC: 0.9455
# Epoch 81/200, Train Loss: 0.5971, Train AUC: 0.9694  test Loss: 0.5499, test AUC: 0.9458
# Epoch 82/200, Train Loss: 0.5834, Train AUC: 0.9738  test Loss: 0.5473, test AUC: 0.9515
# Epoch 83/200, Train Loss: 0.5886, Train AUC: 0.9631  test Loss: 0.5514, test AUC: 0.9509
# Epoch 84/200, Train Loss: 0.5678, Train AUC: 0.9782  test Loss: 0.5317, test AUC: 0.9479
# Epoch 85/200, Train Loss: 0.5730, Train AUC: 0.9699  test Loss: 0.5352, test AUC: 0.9512
# Epoch 86/200, Train Loss: 0.5636, Train AUC: 0.9797  test Loss: 0.5395, test AUC: 0.9539
# Epoch 87/200, Train Loss: 0.5566, Train AUC: 0.9732  test Loss: 0.5305, test AUC: 0.9530
# Epoch 88/200, Train Loss: 0.5680, Train AUC: 0.9733  test Loss: 0.5348, test AUC: 0.9550
# Epoch 89/200, Train Loss: 0.5452, Train AUC: 0.9784  test Loss: 0.5276, test AUC: 0.9542
# Epoch 90/200, Train Loss: 0.5712, Train AUC: 0.9709  test Loss: 0.5345, test AUC: 0.9570
# Epoch 91/200, Train Loss: 0.5589, Train AUC: 0.9712  test Loss: 0.5150, test AUC: 0.9552
# Epoch 92/200, Train Loss: 0.5566, Train AUC: 0.9740  test Loss: 0.5261, test AUC: 0.9571
# Epoch 93/200, Train Loss: 0.5633, Train AUC: 0.9731  test Loss: 0.5130, test AUC: 0.9561
# Epoch 94/200, Train Loss: 0.5378, Train AUC: 0.9772  test Loss: 0.5077, test AUC: 0.9565
# Epoch 95/200, Train Loss: 0.5302, Train AUC: 0.9800  test Loss: 0.5028, test AUC: 0.9548
# Epoch 96/200, Train Loss: 0.5650, Train AUC: 0.9727  test Loss: 0.5170, test AUC: 0.9595
# Epoch 97/200, Train Loss: 0.5399, Train AUC: 0.9738  test Loss: 0.5057, test AUC: 0.9579
# Epoch 98/200, Train Loss: 0.5319, Train AUC: 0.9778  test Loss: 0.4901, test AUC: 0.9560
# Epoch 99/200, Train Loss: 0.5277, Train AUC: 0.9794  test Loss: 0.4943, test AUC: 0.9582
# Epoch 100/200, Train Loss: 0.5214, Train AUC: 0.9774  test Loss: 0.5039, test AUC: 0.9607
# Epoch 101/200, Train Loss: 0.5532, Train AUC: 0.9660  test Loss: 0.5108, test AUC: 0.9628
# Epoch 102/200, Train Loss: 0.5409, Train AUC: 0.9732  test Loss: 0.4997, test AUC: 0.9616
# Epoch 103/200, Train Loss: 0.5296, Train AUC: 0.9748  test Loss: 0.4990, test AUC: 0.9617
# Epoch 104/200, Train Loss: 0.5462, Train AUC: 0.9814  test Loss: 0.5043, test AUC: 0.9633
# Epoch 105/200, Train Loss: 0.4939, Train AUC: 0.9850  test Loss: 0.5023, test AUC: 0.9635
# Epoch 106/200, Train Loss: 0.5264, Train AUC: 0.9735  test Loss: 0.4877, test AUC: 0.9622
# Epoch 107/200, Train Loss: 0.4996, Train AUC: 0.9791  test Loss: 0.4850, test AUC: 0.9620
# Epoch 108/200, Train Loss: 0.5375, Train AUC: 0.9733  test Loss: 0.4927, test AUC: 0.9650
# Epoch 109/200, Train Loss: 0.5270, Train AUC: 0.9784  test Loss: 0.4862, test AUC: 0.9653
# Epoch 110/200, Train Loss: 0.5200, Train AUC: 0.9735  test Loss: 0.4765, test AUC: 0.9639
# Epoch 111/200, Train Loss: 0.5150, Train AUC: 0.9720  test Loss: 0.4750, test AUC: 0.9626
# Epoch 112/200, Train Loss: 0.5772, Train AUC: 0.9644  test Loss: 0.4779, test AUC: 0.9658
# Epoch 113/200, Train Loss: 0.5018, Train AUC: 0.9824  test Loss: 0.4690, test AUC: 0.9649
# Epoch 114/200, Train Loss: 0.4865, Train AUC: 0.9852  test Loss: 0.4706, test AUC: 0.9649
# Epoch 115/200, Train Loss: 0.4921, Train AUC: 0.9830  test Loss: 0.4661, test AUC: 0.9648
# Epoch 116/200, Train Loss: 0.4930, Train AUC: 0.9814  test Loss: 0.4603, test AUC: 0.9631
# Epoch 117/200, Train Loss: 0.5001, Train AUC: 0.9792  test Loss: 0.4602, test AUC: 0.9649
# Epoch 118/200, Train Loss: 0.4891, Train AUC: 0.9814  test Loss: 0.4660, test AUC: 0.9652
# Epoch 119/200, Train Loss: 0.4802, Train AUC: 0.9825  test Loss: 0.4599, test AUC: 0.9644
# Epoch 120/200, Train Loss: 0.4969, Train AUC: 0.9829  test Loss: 0.4661, test AUC: 0.9666
# Epoch 121/200, Train Loss: 0.5021, Train AUC: 0.9781  test Loss: 0.4442, test AUC: 0.9638
# Epoch 122/200, Train Loss: 0.4882, Train AUC: 0.9853  test Loss: 0.4602, test AUC: 0.9665
# Epoch 123/200, Train Loss: 0.5013, Train AUC: 0.9764  test Loss: 0.4491, test AUC: 0.9653
# Epoch 124/200, Train Loss: 0.5327, Train AUC: 0.9739  test Loss: 0.4602, test AUC: 0.9696
# Epoch 125/200, Train Loss: 0.4987, Train AUC: 0.9806  test Loss: 0.4636, test AUC: 0.9685
# Epoch 126/200, Train Loss: 0.4969, Train AUC: 0.9801  test Loss: 0.4567, test AUC: 0.9678
# Epoch 127/200, Train Loss: 0.4731, Train AUC: 0.9829  test Loss: 0.4554, test AUC: 0.9696
# Epoch 128/200, Train Loss: 0.4633, Train AUC: 0.9862  test Loss: 0.4582, test AUC: 0.9709
# Epoch 129/200, Train Loss: 0.5148, Train AUC: 0.9792  test Loss: 0.4599, test AUC: 0.9709
# Epoch 130/200, Train Loss: 0.5125, Train AUC: 0.9750  test Loss: 0.4418, test AUC: 0.9713
# Epoch 131/200, Train Loss: 0.4837, Train AUC: 0.9821  test Loss: 0.4461, test AUC: 0.9708
# Epoch 132/200, Train Loss: 0.4771, Train AUC: 0.9749  test Loss: 0.4376, test AUC: 0.9661
# Epoch 133/200, Train Loss: 0.4728, Train AUC: 0.9836  test Loss: 0.4421, test AUC: 0.9702
# Epoch 134/200, Train Loss: 0.4554, Train AUC: 0.9836  test Loss: 0.4365, test AUC: 0.9699
# Epoch 135/200, Train Loss: 0.4620, Train AUC: 0.9846  test Loss: 0.4356, test AUC: 0.9700
# Epoch 136/200, Train Loss: 0.4656, Train AUC: 0.9850  test Loss: 0.4415, test AUC: 0.9709
# Epoch 137/200, Train Loss: 0.4512, Train AUC: 0.9812  test Loss: 0.4408, test AUC: 0.9705
# Epoch 138/200, Train Loss: 0.4647, Train AUC: 0.9773  test Loss: 0.4340, test AUC: 0.9695
# Epoch 139/200, Train Loss: 0.4662, Train AUC: 0.9796  test Loss: 0.4311, test AUC: 0.9703
# Epoch 140/200, Train Loss: 0.4484, Train AUC: 0.9842  test Loss: 0.4334, test AUC: 0.9703
# Epoch 141/200, Train Loss: 0.4969, Train AUC: 0.9833  test Loss: 0.4323, test AUC: 0.9704
# Epoch 142/200, Train Loss: 0.4763, Train AUC: 0.9789  test Loss: 0.4267, test AUC: 0.9717
# Epoch 143/200, Train Loss: 0.4825, Train AUC: 0.9860  test Loss: 0.4380, test AUC: 0.9727
# Epoch 144/200, Train Loss: 0.4347, Train AUC: 0.9834  test Loss: 0.4385, test AUC: 0.9735
# Epoch 145/200, Train Loss: 0.4566, Train AUC: 0.9835  test Loss: 0.4162, test AUC: 0.9709
# Epoch 146/200, Train Loss: 0.4529, Train AUC: 0.9805  test Loss: 0.4248, test AUC: 0.9721
# Epoch 147/200, Train Loss: 0.4506, Train AUC: 0.9857  test Loss: 0.4297, test AUC: 0.9721
# Epoch 148/200, Train Loss: 0.4715, Train AUC: 0.9771  test Loss: 0.4213, test AUC: 0.9719
# Epoch 149/200, Train Loss: 0.4316, Train AUC: 0.9848  test Loss: 0.4070, test AUC: 0.9708
# Epoch 150/200, Train Loss: 0.4416, Train AUC: 0.9833  test Loss: 0.4069, test AUC: 0.9722
# Epoch 151/200, Train Loss: 0.4443, Train AUC: 0.9834  test Loss: 0.4207, test AUC: 0.9724
# Epoch 152/200, Train Loss: 0.4514, Train AUC: 0.9794  test Loss: 0.4061, test AUC: 0.9708
# Epoch 153/200, Train Loss: 0.4289, Train AUC: 0.9844  test Loss: 0.4150, test AUC: 0.9719
# Epoch 154/200, Train Loss: 0.4414, Train AUC: 0.9806  test Loss: 0.3974, test AUC: 0.9709
# Epoch 155/200, Train Loss: 0.4361, Train AUC: 0.9827  test Loss: 0.3966, test AUC: 0.9695
# Epoch 156/200, Train Loss: 0.4255, Train AUC: 0.9865  test Loss: 0.4057, test AUC: 0.9714
# Epoch 157/200, Train Loss: 0.4393, Train AUC: 0.9837  test Loss: 0.4006, test AUC: 0.9721
# Epoch 158/200, Train Loss: 0.4346, Train AUC: 0.9858  test Loss: 0.4122, test AUC: 0.9737
# Epoch 159/200, Train Loss: 0.4939, Train AUC: 0.9793  test Loss: 0.4156, test AUC: 0.9734
# Epoch 160/200, Train Loss: 0.4365, Train AUC: 0.9786  test Loss: 0.4116, test AUC: 0.9730
# Epoch 161/200, Train Loss: 0.4231, Train AUC: 0.9867  test Loss: 0.4103, test AUC: 0.9735
# Epoch 162/200, Train Loss: 0.4136, Train AUC: 0.9827  test Loss: 0.4086, test AUC: 0.9734
# Epoch 163/200, Train Loss: 0.4245, Train AUC: 0.9872  test Loss: 0.4086, test AUC: 0.9726
# Epoch 164/200, Train Loss: 0.4239, Train AUC: 0.9836  test Loss: 0.4005, test AUC: 0.9735
# Epoch 165/200, Train Loss: 0.4418, Train AUC: 0.9831  test Loss: 0.4054, test AUC: 0.9739
# Epoch 166/200, Train Loss: 0.4357, Train AUC: 0.9822  test Loss: 0.4008, test AUC: 0.9738
# Epoch 167/200, Train Loss: 0.4196, Train AUC: 0.9893  test Loss: 0.3928, test AUC: 0.9738
# Epoch 168/200, Train Loss: 0.4215, Train AUC: 0.9825  test Loss: 0.3783, test AUC: 0.9720
# Epoch 169/200, Train Loss: 0.4321, Train AUC: 0.9844  test Loss: 0.3926, test AUC: 0.9738
# Epoch 170/200, Train Loss: 0.4436, Train AUC: 0.9819  test Loss: 0.3960, test AUC: 0.9739
# Epoch 171/200, Train Loss: 0.4162, Train AUC: 0.9851  test Loss: 0.3985, test AUC: 0.9731
# Epoch 172/200, Train Loss: 0.4157, Train AUC: 0.9835  test Loss: 0.3881, test AUC: 0.9734
# Epoch 173/200, Train Loss: 0.4122, Train AUC: 0.9868  test Loss: 0.3982, test AUC: 0.9741
# Epoch 174/200, Train Loss: 0.3955, Train AUC: 0.9884  test Loss: 0.3847, test AUC: 0.9733
# Epoch 175/200, Train Loss: 0.4293, Train AUC: 0.9824  test Loss: 0.3705, test AUC: 0.9728
# Epoch 176/200, Train Loss: 0.4023, Train AUC: 0.9869  test Loss: 0.3801, test AUC: 0.9728
# Epoch 177/200, Train Loss: 0.3980, Train AUC: 0.9863  test Loss: 0.3794, test AUC: 0.9738
# Epoch 178/200, Train Loss: 0.4152, Train AUC: 0.9846  test Loss: 0.3836, test AUC: 0.9747
# Epoch 179/200, Train Loss: 0.4094, Train AUC: 0.9869  test Loss: 0.3800, test AUC: 0.9749
# Epoch 180/200, Train Loss: 0.4057, Train AUC: 0.9859  test Loss: 0.3807, test AUC: 0.9746
# Epoch 181/200, Train Loss: 0.4364, Train AUC: 0.9804  test Loss: 0.3831, test AUC: 0.9747
# Epoch 182/200, Train Loss: 0.4022, Train AUC: 0.9863  test Loss: 0.3794, test AUC: 0.9747
# Epoch 183/200, Train Loss: 0.3891, Train AUC: 0.9869  test Loss: 0.3792, test AUC: 0.9749
# Epoch 184/200, Train Loss: 0.4280, Train AUC: 0.9854  test Loss: 0.3805, test AUC: 0.9755
# Epoch 185/200, Train Loss: 0.3911, Train AUC: 0.9897  test Loss: 0.3780, test AUC: 0.9751
# Epoch 186/200, Train Loss: 0.4072, Train AUC: 0.9855  test Loss: 0.3794, test AUC: 0.9750
# Epoch 187/200, Train Loss: 0.4042, Train AUC: 0.9850  test Loss: 0.3727, test AUC: 0.9747
# Epoch 188/200, Train Loss: 0.3987, Train AUC: 0.9869  test Loss: 0.3721, test AUC: 0.9750
# Epoch 189/200, Train Loss: 0.3780, Train AUC: 0.9900  test Loss: 0.3740, test AUC: 0.9749
# Epoch 190/200, Train Loss: 0.3974, Train AUC: 0.9826  test Loss: 0.3817, test AUC: 0.9750
# Epoch 191/200, Train Loss: 0.3799, Train AUC: 0.9854  test Loss: 0.3680, test AUC: 0.9750
# Epoch 192/200, Train Loss: 0.4473, Train AUC: 0.9806  test Loss: 0.3805, test AUC: 0.9768
# Epoch 193/200, Train Loss: 0.3766, Train AUC: 0.9894  test Loss: 0.3603, test AUC: 0.9751
# Epoch 194/200, Train Loss: 0.3980, Train AUC: 0.9846  test Loss: 0.3759, test AUC: 0.9764
# Epoch 195/200, Train Loss: 0.4273, Train AUC: 0.9870  test Loss: 0.3721, test AUC: 0.9771
# Epoch 196/200, Train Loss: 0.3708, Train AUC: 0.9909  test Loss: 0.3690, test AUC: 0.9759
# Epoch 197/200, Train Loss: 0.3866, Train AUC: 0.9882  test Loss: 0.3647, test AUC: 0.9764
# Epoch 198/200, Train Loss: 0.3782, Train AUC: 0.9882  test Loss: 0.3598, test AUC: 0.9761
# Epoch 199/200, Train Loss: 0.4000, Train AUC: 0.9872  test Loss: 0.3678, test AUC: 0.9767
# Epoch 200/200, Train Loss: 0.4347, Train AUC: 0.9848  test Loss: 0.3745, test AUC: 0.9780

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, transe_embed, labels in val_loader:
        inputs, transe_embed, labels = inputs.to(device), transe_embed.to(device), labels.to(device)
        outputs = model(inputs, transe_embed)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())

preds = np.argmax(all_probs, axis=1)
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro')
recall = recall_score(all_labels, preds, average='macro')
f1 = f1_score(all_labels, preds, average='macro')
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

print("\n=== Final Validation Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"AUC-ROC:   {auc:.4f}")
# Out:
# === Final Validation Metrics ===
# Accuracy:  0.8916
# Recall:    0.8941
# F1 Score:  0.8767
# Precision: 0.8642
# AUC-ROC:   0.9647

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("AIBL AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("AIBL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()
