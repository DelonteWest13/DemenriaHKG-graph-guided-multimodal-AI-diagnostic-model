# %%
import csv
import nibabel as nib
import matplotlib.pyplot as plt
import random
import torch
import os
import numpy as np
from model1 import CNN_3D,NiiDataset,NeuralNet,MultiModalAlignMamba
import torch.nn.functional as F
from einops import rearrange, repeat
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import nibabel as nib
import shutil
import torch.nn as nn
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import math
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
path_existence = []
data_normal=[]
data_ad=[]
data_mci=[]
count_ad=0
count_no=0
count_mci=0
with open('NC.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    for row in csv_reader:
        path = 'NC/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_no=count_no+1
            data_normal.append(row)
            
with open('AD.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'AD/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_ad=count_ad+1
            data_ad.append(row)
            
with open('MCI.csv', mode='r', newline='', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    next(csv_reader) 
    for row in csv_reader:
        path = 'MCI/' + row[1]
        exists = os.path.exists(path)
        path_existence.append((path, exists))
        if exists:
            count_mci=count_mci+1
            data_mci.append(row)
print(count_ad) #44
print(count_no) #247
print(count_mci) #106
# Out:
# 72
# 358
# 86

# %%
def preprocess_data(data, replace_dict):
    ehr_data = []
    bio_data = []
    for row in data:
        row = [replace_dict.get(item, item) for item in row]
        
        ehr_features = [float(row[3]), float(row[4])]
        ehr_data.append(ehr_features)
        
        bio_features = [float(row[5]), float(row[18]), float(row[19]), float(row[20]), float(row[21])]
        bio_data.append(bio_features)
        
    return np.array(ehr_data, dtype=np.float32), np.array(bio_data, dtype=np.float32)

# %%
replace_dict = {'female': '0', 'male': '1', 'whi': '0', 'blk': '1', '': '0','no':'0','yes':'1','ans':'2','haw':'3','ind':'4','bl':'1'}

# %%
# 从 row 得到主键（假设 row[1] 为文件名）
def get_ehr_key(row):
    return row[1].split('.')[0]

# 从路径得到 NII 文件主键
def get_nii_key(filepath):
    return os.path.basename(filepath).split('.')[0]

# 过滤EHR数据
def filter_ehr_by_keys(data, keys):
    key2row = {get_ehr_key(row): row for row in data}
    return [key2row[k] for k in keys]

# 过滤NII数据
def filter_nii_by_keys(file_list, keys):
    key2file = {get_nii_key(f): f for f in file_list}
    return [key2file[k] for k in keys]

def get_nii_file_list(folder_name):
    nii_dir = os.path.join(folder_name)
    nii_files = []
    for root, dirs, files in os.walk(nii_dir):
        for file in files:
            if file.endswith('.nii') or file.endswith('.nii.gz'):
                nii_files.append(os.path.join(root, file))
    return nii_files

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# 1. 获取AD/MCI/NC样本的公共键值并排序
ad_ehr_keys = set(get_ehr_key(row) for row in data_ad)
ad_nii_keys = set(get_nii_key(f) for f in get_nii_file_list('AD'))
ad_common_keys = sorted(ad_ehr_keys & ad_nii_keys)

normal_ehr_keys = set(get_ehr_key(row) for row in data_normal)
normal_nii_keys = set(get_nii_key(f) for f in get_nii_file_list('NC'))
normal_common_keys = sorted(normal_ehr_keys & normal_nii_keys)

mci_ehr_keys = set(get_ehr_key(row) for row in data_mci)
mci_nii_keys = set(get_nii_key(f) for f in get_nii_file_list('MCI'))
mci_common_keys = sorted(mci_ehr_keys & mci_nii_keys)

# 2. 过滤 NII 文件
ad_nii_filtered = filter_nii_by_keys(get_nii_file_list('AD'), ad_common_keys)
normal_nii_filtered = filter_nii_by_keys(get_nii_file_list('NC'), normal_common_keys)
mci_nii_filtered = filter_nii_by_keys(get_nii_file_list('MCI'), mci_common_keys)

# 3. NII 影像特征提取
nii = CNN_3D(num_class=1).to(device)
batch_size = 16

def get_nii_output(file_list, model, batch_size):
    dataset = NiiDataset(file_list)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
    outputs = []
    model.eval()
    with torch.no_grad():
        for batch_data in dataloader:
            batch_data = batch_data.to(device)
            output = model(batch_data)
            outputs.append(output.cpu())
    return torch.cat(outputs, dim=0)

ad_output = get_nii_output(ad_nii_filtered, nii, batch_size)
normal_output = get_nii_output(normal_nii_filtered, nii, batch_size)
mci_output = get_nii_output(mci_nii_filtered, nii, batch_size)

print('ad_output (NII)--->', ad_output.shape)
print('normal_output (NII)--->', normal_output.shape)
print('mci_output (NII)--->', mci_output.shape)
# Out:
# ad_output (NII)---> torch.Size([72, 1])
# normal_output (NII)---> torch.Size([358, 1])
# mci_output (NII)---> torch.Size([86, 1])

# %%
# 1. 过滤 EHR 表格记录
ad_ehr_filtered = filter_ehr_by_keys(data_ad, ad_common_keys)
normal_ehr_filtered = filter_ehr_by_keys(data_normal, normal_common_keys)
mci_ehr_filtered = filter_ehr_by_keys(data_mci, mci_common_keys)

# 2. 调用预处理函数分离特征
ad_EHR_raw, ad_Bio_raw = preprocess_data(ad_ehr_filtered, replace_dict)
normal_EHR_raw, normal_Bio_raw = preprocess_data(normal_ehr_filtered, replace_dict)
mci_EHR_raw, mci_Bio_raw = preprocess_data(mci_ehr_filtered, replace_dict)

# 3. EHR 特征张量化与网络降维 (当前EHR输入维度为2)
ad_EHR = torch.from_numpy(ad_EHR_raw).float()
normal_EHR = torch.from_numpy(normal_EHR_raw).float()
mci_EHR = torch.from_numpy(mci_EHR_raw).float()

linear_ehr1 = nn.Linear(2, 8)
linear_ehr2 = nn.Linear(8, 1)
ad_EHR = linear_ehr2(linear_ehr1(ad_EHR))
normal_EHR = linear_ehr2(linear_ehr1(normal_EHR))
mci_EHR = linear_ehr2(linear_ehr1(mci_EHR))

print('ad_EHR--->', ad_EHR.shape)
print('normal_EHR--->', normal_EHR.shape)
print('mci_EHR--->', mci_EHR.shape)
# Out:
# ad_EHR---> torch.Size([72, 1])
# normal_EHR---> torch.Size([358, 1])
# mci_EHR---> torch.Size([86, 1])

# %%
# 1. Bio 特征张量化 (沿用原有变量名 *_tensor)
ad_tensor = torch.from_numpy(ad_Bio_raw).float()
normal_tensor = torch.from_numpy(normal_Bio_raw).float()
mci_tensor = torch.from_numpy(mci_Bio_raw).float()

# 2. Bio 特征网络降维 (当前剔除元数据后Bio输入维度为5)
linear_bio1 = nn.Linear(5, 16)
linear_bio2 = nn.Linear(16, 1)

ad_tensor = linear_bio2(linear_bio1(ad_tensor))
normal_tensor = linear_bio2(linear_bio1(normal_tensor))
mci_tensor = linear_bio2(linear_bio1(mci_tensor))

print('ad_tensor (Bio)--->', ad_tensor.shape)
print('normal_tensor (Bio)--->', normal_tensor.shape)
print('mci_tensor (Bio)--->', mci_tensor.shape)
# Out:
# ad_tensor (Bio)---> torch.Size([72, 1])
# normal_tensor (Bio)---> torch.Size([358, 1])
# mci_tensor (Bio)---> torch.Size([86, 1])

# %%
ad_EHR = ad_EHR.cpu()
ad_tensor = ad_tensor.cpu()
mci_EHR = mci_EHR.cpu()
mci_tensor = mci_tensor.cpu()
normal_EHR = normal_EHR.cpu()
normal_tensor = normal_tensor.cpu()
ad_output = ad_output.cpu()
mci_output = mci_output.cpu()
normal_output = normal_output.cpu()

X_ad = torch.cat([ad_EHR, ad_output, ad_tensor], dim=1)
X_mci = torch.cat([mci_EHR, mci_output, mci_tensor], dim=1)
X_normal = torch.cat([normal_EHR, normal_output, normal_tensor], dim=1)
y_ad = torch.ones(len(X_ad)) * 2  # AD 类别标签为 2
y_mci = torch.ones(len(X_mci)) * 1  # MCI 类别标签为 1
y_normal = torch.ones(len(X_normal)) * 0  # Nc 类别标签为 0
# 拼接特征和标签
X = torch.cat([X_ad, X_mci, X_normal[:100]], dim=0).float()
y = torch.cat([y_ad, y_mci, y_normal[:100]], dim=0).float()

# 数据划分
X_train, X_test, y_train, y_test = train_test_split(X.detach().numpy(), y.numpy(),
                                                    test_size=0.25,
                                                    stratify=y.numpy(),
                                                    random_state=32)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                  test_size=0.25,
                                                  stratify=y_train,
                                                  random_state=32)

# %%
X_train_tensor = torch.FloatTensor(X_train).to(device)
y_train_tensor = torch.FloatTensor(y_train).to(device)

X_val_tensor = torch.FloatTensor(X_val).to(device)
y_val_tensor = torch.FloatTensor(y_val).to(device)

X_test_tensor = torch.FloatTensor(X_test).to(device)
y_test_tensor = torch.FloatTensor(y_test).to(device)

# 创建 TensorDataset
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
def train_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0
    all_probs = []
    all_labels = []
    all_preds = []
    
    for inputs, labels in loader:
        inputs, labels = inputs.to(device), labels.to(device)
        labels = labels.long()
        
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        # 获取预测概率和预测类别
        probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
        preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds)
    
    # 计算指标
    train_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    train_f1 = f1_score(all_labels, all_preds, average='macro')
    train_recall = recall_score(all_labels, all_preds, average='macro')
    train_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, train_auc, train_f1, train_recall, train_precision

# %%
def evaluate(model, loader, criterion):
    model.eval()
    all_probs = []
    all_labels = []
    all_preds = []
    total_loss = 0
    
    with torch.no_grad():
        for inputs, labels in loader:
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.long()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
            probs = torch.softmax(outputs, dim=1).detach().cpu().numpy()
            preds = torch.argmax(outputs, dim=1).detach().cpu().numpy()
            all_probs.extend(probs)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds)
    
    # 计算指标
    test_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    test_f1 = f1_score(all_labels, all_preds, average='macro')
    test_recall = recall_score(all_labels, all_preds, average='macro')
    test_precision = precision_score(all_labels, all_preds, average='macro')
    
    # 计算平均损失
    avg_loss = total_loss / len(loader)
    return avg_loss, test_auc, test_f1, test_recall, test_precision

# %%
model = MultiModalAlignMamba().to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
criterion = nn.CrossEntropyLoss()

# %%
train_losses = []
train_aucs = []
train_f1s = []
train_recalls = []
train_precisions = []
test_losses = []
test_aucs = []
test_f1s = []
test_recalls = []
test_precisions = []


for epoch in range(201):
    train_loss, train_auc, train_f1, train_recall, train_precision = train_epoch(model, train_loader, optimizer, criterion)
    test_loss, test_auc, test_f1, test_recall, test_precision = evaluate(model, test_loader, criterion)
    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    train_f1s.append(train_f1)
    train_recalls.append(train_recall)
    train_precisions.append(train_precision)
    
    test_losses.append(test_loss)
    test_aucs.append(test_auc)
    test_f1s.append(test_f1)
    test_recalls.append(test_recall)
    test_precisions.append(test_precision)
    
    # 打印信息
    print(f"Epoch {epoch:03d} | "
          f"Train Loss: {train_loss:.4f} | Train AUC: {train_auc:.4f} | "
          f"Test Loss: {test_loss:.4f} | Test AUC: {test_auc:.4f}")
    #print(f"Train F1: {train_f1:.4f} | Train Recall: {train_recall:.4f} | Train Precision: {train_precision:.4f}")
    #print(f"Test F1: {test_f1:.4f} | Test Recall: {test_recall:.4f} | Test Precision: {test_precision:.4f}")
    print("-" * 80)
# Out:
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 000 | Train Loss: 1.1149 | Train AUC: 0.5575 | Test Loss: 1.1515 | Test AUC: 0.5350
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 001 | Train Loss: 1.1332 | Train AUC: 0.5180 | Test Loss: 1.1402 | Test AUC: 0.4739
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 002 | Train Loss: 1.1185 | Train AUC: 0.5589 | Test Loss: 1.1325 | Test AUC: 0.4667
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 003 | Train Loss: 1.1549 | Train AUC: 0.4800 | Test Loss: 1.1252 | Test AUC: 0.4895
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 004 | Train Loss: 1.1720 | Train AUC: 0.4433 | Test Loss: 1.1151 | Test AUC: 0.4651
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 005 | Train Loss: 1.1642 | Train AUC: 0.4773 | Test Loss: 1.1150 | Test AUC: 0.4583
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 006 | Train Loss: 1.1627 | Train AUC: 0.4434 | Test Loss: 1.1123 | Test AUC: 0.4543
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 007 | Train Loss: 1.1295 | Train AUC: 0.5253 | Test Loss: 1.1150 | Test AUC: 0.4852
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 008 | Train Loss: 1.1137 | Train AUC: 0.5453 | Test Loss: 1.1174 | Test AUC: 0.5086
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 009 | Train Loss: 1.1346 | Train AUC: 0.5116 | Test Loss: 1.1252 | Test AUC: 0.5121
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 010 | Train Loss: 1.1316 | Train AUC: 0.4981 | Test Loss: 1.1195 | Test AUC: 0.5104
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 011 | Train Loss: 1.1462 | Train AUC: 0.4625 | Test Loss: 1.1125 | Test AUC: 0.5115
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 012 | Train Loss: 1.1204 | Train AUC: 0.5198 | Test Loss: 1.1087 | Test AUC: 0.5141
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 013 | Train Loss: 1.1055 | Train AUC: 0.5205 | Test Loss: 1.1029 | Test AUC: 0.5473
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 014 | Train Loss: 1.1319 | Train AUC: 0.4840 | Test Loss: 1.1049 | Test AUC: 0.5446
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 015 | Train Loss: 1.1005 | Train AUC: 0.5429 | Test Loss: 1.1093 | Test AUC: 0.5399
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 016 | Train Loss: 1.1183 | Train AUC: 0.4919 | Test Loss: 1.1062 | Test AUC: 0.5457
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 017 | Train Loss: 1.0992 | Train AUC: 0.5433 | Test Loss: 1.1153 | Test AUC: 0.5264
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 018 | Train Loss: 1.1156 | Train AUC: 0.5097 | Test Loss: 1.1093 | Test AUC: 0.5291
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 019 | Train Loss: 1.1201 | Train AUC: 0.5162 | Test Loss: 1.1009 | Test AUC: 0.5508
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 020 | Train Loss: 1.0998 | Train AUC: 0.5487 | Test Loss: 1.0993 | Test AUC: 0.5743
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 021 | Train Loss: 1.0973 | Train AUC: 0.5292 | Test Loss: 1.0932 | Test AUC: 0.5641
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 022 | Train Loss: 1.1076 | Train AUC: 0.5117 | Test Loss: 1.0943 | Test AUC: 0.5436
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 023 | Train Loss: 1.0896 | Train AUC: 0.5799 | Test Loss: 1.0963 | Test AUC: 0.5721
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 024 | Train Loss: 1.1068 | Train AUC: 0.5252 | Test Loss: 1.0935 | Test AUC: 0.5834
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 025 | Train Loss: 1.1095 | Train AUC: 0.5048 | Test Loss: 1.0928 | Test AUC: 0.5880
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 026 | Train Loss: 1.0941 | Train AUC: 0.5448 | Test Loss: 1.0926 | Test AUC: 0.5809
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 027 | Train Loss: 1.1207 | Train AUC: 0.5072 | Test Loss: 1.0991 | Test AUC: 0.5799
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 028 | Train Loss: 1.0956 | Train AUC: 0.5476 | Test Loss: 1.0937 | Test AUC: 0.5796
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 029 | Train Loss: 1.1113 | Train AUC: 0.5063 | Test Loss: 1.0916 | Test AUC: 0.5774
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 030 | Train Loss: 1.0811 | Train AUC: 0.5607 | Test Loss: 1.0935 | Test AUC: 0.5976
# --------------------------------------------------------------------------------
# Epoch 031 | Train Loss: 1.1147 | Train AUC: 0.4821 | Test Loss: 1.0862 | Test AUC: 0.6050
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 032 | Train Loss: 1.0921 | Train AUC: 0.5500 | Test Loss: 1.0859 | Test AUC: 0.5931
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 033 | Train Loss: 1.0763 | Train AUC: 0.5601 | Test Loss: 1.0944 | Test AUC: 0.5990
# --------------------------------------------------------------------------------
# Epoch 034 | Train Loss: 1.0990 | Train AUC: 0.5416 | Test Loss: 1.0872 | Test AUC: 0.6123
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 035 | Train Loss: 1.1264 | Train AUC: 0.4665 | Test Loss: 1.0958 | Test AUC: 0.6193
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 036 | Train Loss: 1.1026 | Train AUC: 0.5215 | Test Loss: 1.0960 | Test AUC: 0.6030
# --------------------------------------------------------------------------------
# d:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Epoch 037 | Train Loss: 1.1106 | Train AUC: 0.5208 | Test Loss: 1.0936 | Test AUC: 0.6014
# --------------------------------------------------------------------------------
# Epoch 038 | Train Loss: 1.0969 | Train AUC: 0.5077 | Test Loss: 1.0870 | Test AUC: 0.6256
# --------------------------------------------------------------------------------
# Epoch 039 | Train Loss: 1.1098 | Train AUC: 0.5023 | Test Loss: 1.0845 | Test AUC: 0.6047
# --------------------------------------------------------------------------------
# Epoch 040 | Train Loss: 1.1076 | Train AUC: 0.4950 | Test Loss: 1.0833 | Test AUC: 0.5930
# --------------------------------------------------------------------------------
# Epoch 041 | Train Loss: 1.0694 | Train AUC: 0.5958 | Test Loss: 1.0870 | Test AUC: 0.6042
# --------------------------------------------------------------------------------
# Epoch 042 | Train Loss: 1.1146 | Train AUC: 0.5137 | Test Loss: 1.0854 | Test AUC: 0.5926
# --------------------------------------------------------------------------------
# Epoch 043 | Train Loss: 1.0613 | Train AUC: 0.6157 | Test Loss: 1.0804 | Test AUC: 0.6187
# --------------------------------------------------------------------------------
# Epoch 044 | Train Loss: 1.1085 | Train AUC: 0.5138 | Test Loss: 1.0800 | Test AUC: 0.6136
# --------------------------------------------------------------------------------
# Epoch 045 | Train Loss: 1.0735 | Train AUC: 0.5883 | Test Loss: 1.0773 | Test AUC: 0.6159
# --------------------------------------------------------------------------------
# Epoch 046 | Train Loss: 1.0909 | Train AUC: 0.5293 | Test Loss: 1.0751 | Test AUC: 0.6131
# --------------------------------------------------------------------------------
# Epoch 047 | Train Loss: 1.1007 | Train AUC: 0.5241 | Test Loss: 1.0765 | Test AUC: 0.6220
# --------------------------------------------------------------------------------
# Epoch 048 | Train Loss: 1.0773 | Train AUC: 0.5844 | Test Loss: 1.0760 | Test AUC: 0.6104
# --------------------------------------------------------------------------------
# Epoch 049 | Train Loss: 1.0768 | Train AUC: 0.5516 | Test Loss: 1.0797 | Test AUC: 0.6263
# --------------------------------------------------------------------------------
# Epoch 050 | Train Loss: 1.1104 | Train AUC: 0.4957 | Test Loss: 1.0767 | Test AUC: 0.6156
# --------------------------------------------------------------------------------
# Epoch 051 | Train Loss: 1.0619 | Train AUC: 0.6073 | Test Loss: 1.0774 | Test AUC: 0.6320
# --------------------------------------------------------------------------------
# Epoch 052 | Train Loss: 1.0844 | Train AUC: 0.5483 | Test Loss: 1.0758 | Test AUC: 0.6233
# --------------------------------------------------------------------------------
# Epoch 053 | Train Loss: 1.0939 | Train AUC: 0.5408 | Test Loss: 1.0763 | Test AUC: 0.6137
# --------------------------------------------------------------------------------
# Epoch 054 | Train Loss: 1.0828 | Train AUC: 0.5579 | Test Loss: 1.0716 | Test AUC: 0.6230
# --------------------------------------------------------------------------------
# Epoch 055 | Train Loss: 1.0915 | Train AUC: 0.5387 | Test Loss: 1.0728 | Test AUC: 0.6332
# --------------------------------------------------------------------------------
# Epoch 056 | Train Loss: 1.0959 | Train AUC: 0.5410 | Test Loss: 1.0749 | Test AUC: 0.6350
# --------------------------------------------------------------------------------
# Epoch 057 | Train Loss: 1.0831 | Train AUC: 0.5717 | Test Loss: 1.0715 | Test AUC: 0.6366
# --------------------------------------------------------------------------------
# Epoch 058 | Train Loss: 1.0851 | Train AUC: 0.5477 | Test Loss: 1.0683 | Test AUC: 0.6302
# --------------------------------------------------------------------------------
# Epoch 059 | Train Loss: 1.1001 | Train AUC: 0.5174 | Test Loss: 1.0719 | Test AUC: 0.6322
# --------------------------------------------------------------------------------
# Epoch 060 | Train Loss: 1.0758 | Train AUC: 0.5638 | Test Loss: 1.0722 | Test AUC: 0.6307
# --------------------------------------------------------------------------------
# Epoch 061 | Train Loss: 1.1011 | Train AUC: 0.5191 | Test Loss: 1.0711 | Test AUC: 0.6217
# --------------------------------------------------------------------------------
# Epoch 062 | Train Loss: 1.0885 | Train AUC: 0.5175 | Test Loss: 1.0762 | Test AUC: 0.6412
# --------------------------------------------------------------------------------
# Epoch 063 | Train Loss: 1.1026 | Train AUC: 0.4996 | Test Loss: 1.0761 | Test AUC: 0.6360
# --------------------------------------------------------------------------------
# Epoch 064 | Train Loss: 1.0718 | Train AUC: 0.5914 | Test Loss: 1.0703 | Test AUC: 0.6259
# --------------------------------------------------------------------------------
# Epoch 065 | Train Loss: 1.0894 | Train AUC: 0.5296 | Test Loss: 1.0755 | Test AUC: 0.6304
# --------------------------------------------------------------------------------
# Epoch 066 | Train Loss: 1.0754 | Train AUC: 0.5726 | Test Loss: 1.0746 | Test AUC: 0.6273
# --------------------------------------------------------------------------------
# Epoch 067 | Train Loss: 1.0554 | Train AUC: 0.6036 | Test Loss: 1.0729 | Test AUC: 0.6346
# --------------------------------------------------------------------------------
# Epoch 068 | Train Loss: 1.0662 | Train AUC: 0.5974 | Test Loss: 1.0742 | Test AUC: 0.6445
# --------------------------------------------------------------------------------
# Epoch 069 | Train Loss: 1.1105 | Train AUC: 0.4954 | Test Loss: 1.0660 | Test AUC: 0.6621
# --------------------------------------------------------------------------------
# Epoch 070 | Train Loss: 1.0701 | Train AUC: 0.5710 | Test Loss: 1.0680 | Test AUC: 0.6517
# --------------------------------------------------------------------------------
# Epoch 071 | Train Loss: 1.0822 | Train AUC: 0.5623 | Test Loss: 1.0626 | Test AUC: 0.6452
# --------------------------------------------------------------------------------
# Epoch 072 | Train Loss: 1.0810 | Train AUC: 0.5551 | Test Loss: 1.0675 | Test AUC: 0.6582
# --------------------------------------------------------------------------------
# Epoch 073 | Train Loss: 1.0862 | Train AUC: 0.5349 | Test Loss: 1.0660 | Test AUC: 0.6560
# --------------------------------------------------------------------------------
# Epoch 074 | Train Loss: 1.0855 | Train AUC: 0.5639 | Test Loss: 1.0686 | Test AUC: 0.6568
# --------------------------------------------------------------------------------
# Epoch 075 | Train Loss: 1.0991 | Train AUC: 0.5270 | Test Loss: 1.0662 | Test AUC: 0.6475
# --------------------------------------------------------------------------------
# Epoch 076 | Train Loss: 1.0411 | Train AUC: 0.6350 | Test Loss: 1.0631 | Test AUC: 0.6413
# --------------------------------------------------------------------------------
# Epoch 077 | Train Loss: 1.0748 | Train AUC: 0.5565 | Test Loss: 1.0645 | Test AUC: 0.6402
# --------------------------------------------------------------------------------
# Epoch 078 | Train Loss: 1.0596 | Train AUC: 0.5785 | Test Loss: 1.0589 | Test AUC: 0.6519
# --------------------------------------------------------------------------------
# Epoch 079 | Train Loss: 1.1001 | Train AUC: 0.5224 | Test Loss: 1.0577 | Test AUC: 0.6522
# --------------------------------------------------------------------------------
# Epoch 080 | Train Loss: 1.0653 | Train AUC: 0.5810 | Test Loss: 1.0544 | Test AUC: 0.6454
# --------------------------------------------------------------------------------
# Epoch 081 | Train Loss: 1.0610 | Train AUC: 0.5947 | Test Loss: 1.0566 | Test AUC: 0.6456
# --------------------------------------------------------------------------------
# Epoch 082 | Train Loss: 1.0595 | Train AUC: 0.5933 | Test Loss: 1.0537 | Test AUC: 0.6449
# --------------------------------------------------------------------------------
# Epoch 083 | Train Loss: 1.0756 | Train AUC: 0.5594 | Test Loss: 1.0537 | Test AUC: 0.6488
# --------------------------------------------------------------------------------
# Epoch 084 | Train Loss: 1.0890 | Train AUC: 0.5338 | Test Loss: 1.0507 | Test AUC: 0.6501
# --------------------------------------------------------------------------------
# Epoch 085 | Train Loss: 1.0363 | Train AUC: 0.6421 | Test Loss: 1.0494 | Test AUC: 0.6579
# --------------------------------------------------------------------------------
# Epoch 086 | Train Loss: 1.0533 | Train AUC: 0.6113 | Test Loss: 1.0469 | Test AUC: 0.6643
# --------------------------------------------------------------------------------
# Epoch 087 | Train Loss: 1.0775 | Train AUC: 0.5772 | Test Loss: 1.0474 | Test AUC: 0.6727
# --------------------------------------------------------------------------------
# Epoch 088 | Train Loss: 1.0756 | Train AUC: 0.5753 | Test Loss: 1.0428 | Test AUC: 0.6800
# --------------------------------------------------------------------------------
# Epoch 089 | Train Loss: 1.0660 | Train AUC: 0.5745 | Test Loss: 1.0355 | Test AUC: 0.6943
# --------------------------------------------------------------------------------
# Epoch 090 | Train Loss: 1.0134 | Train AUC: 0.6706 | Test Loss: 1.0319 | Test AUC: 0.7035
# --------------------------------------------------------------------------------
# Epoch 091 | Train Loss: 1.0514 | Train AUC: 0.6060 | Test Loss: 1.0359 | Test AUC: 0.6980
# --------------------------------------------------------------------------------
# Epoch 092 | Train Loss: 1.0429 | Train AUC: 0.6153 | Test Loss: 1.0220 | Test AUC: 0.6992
# --------------------------------------------------------------------------------
# Epoch 093 | Train Loss: 1.0494 | Train AUC: 0.6056 | Test Loss: 1.0191 | Test AUC: 0.7070
# --------------------------------------------------------------------------------
# Epoch 094 | Train Loss: 1.0527 | Train AUC: 0.5970 | Test Loss: 1.0216 | Test AUC: 0.7073
# --------------------------------------------------------------------------------
# Epoch 095 | Train Loss: 1.0661 | Train AUC: 0.5939 | Test Loss: 1.0208 | Test AUC: 0.7005
# --------------------------------------------------------------------------------
# Epoch 096 | Train Loss: 1.0157 | Train AUC: 0.6712 | Test Loss: 1.0295 | Test AUC: 0.7001
# --------------------------------------------------------------------------------
# Epoch 097 | Train Loss: 1.0662 | Train AUC: 0.5897 | Test Loss: 1.0231 | Test AUC: 0.7079
# --------------------------------------------------------------------------------
# Epoch 098 | Train Loss: 1.0529 | Train AUC: 0.6042 | Test Loss: 1.0112 | Test AUC: 0.7074
# --------------------------------------------------------------------------------
# Epoch 099 | Train Loss: 1.0507 | Train AUC: 0.6125 | Test Loss: 1.0038 | Test AUC: 0.7091
# --------------------------------------------------------------------------------
# Epoch 100 | Train Loss: 1.0215 | Train AUC: 0.6440 | Test Loss: 1.0018 | Test AUC: 0.7110
# --------------------------------------------------------------------------------
# Epoch 101 | Train Loss: 1.0274 | Train AUC: 0.6413 | Test Loss: 1.0064 | Test AUC: 0.7108
# --------------------------------------------------------------------------------
# Epoch 102 | Train Loss: 1.0004 | Train AUC: 0.6922 | Test Loss: 0.9915 | Test AUC: 0.7189
# --------------------------------------------------------------------------------
# Epoch 103 | Train Loss: 1.0257 | Train AUC: 0.6576 | Test Loss: 0.9913 | Test AUC: 0.7157
# --------------------------------------------------------------------------------
# Epoch 104 | Train Loss: 1.0582 | Train AUC: 0.5896 | Test Loss: 0.9867 | Test AUC: 0.7144
# --------------------------------------------------------------------------------
# Epoch 105 | Train Loss: 1.0398 | Train AUC: 0.6185 | Test Loss: 0.9894 | Test AUC: 0.7132
# --------------------------------------------------------------------------------
# Epoch 106 | Train Loss: 1.0346 | Train AUC: 0.6325 | Test Loss: 0.9965 | Test AUC: 0.7101
# --------------------------------------------------------------------------------
# Epoch 107 | Train Loss: 0.9983 | Train AUC: 0.6910 | Test Loss: 1.0033 | Test AUC: 0.7075
# --------------------------------------------------------------------------------
# Epoch 108 | Train Loss: 1.0271 | Train AUC: 0.6297 | Test Loss: 1.0051 | Test AUC: 0.6989
# --------------------------------------------------------------------------------
# Epoch 109 | Train Loss: 1.0185 | Train AUC: 0.6412 | Test Loss: 0.9958 | Test AUC: 0.7053
# --------------------------------------------------------------------------------
# Epoch 110 | Train Loss: 1.0190 | Train AUC: 0.6548 | Test Loss: 0.9935 | Test AUC: 0.7059
# --------------------------------------------------------------------------------
# Epoch 111 | Train Loss: 1.0470 | Train AUC: 0.6113 | Test Loss: 0.9924 | Test AUC: 0.6982
# --------------------------------------------------------------------------------
# Epoch 112 | Train Loss: 1.0276 | Train AUC: 0.6455 | Test Loss: 0.9834 | Test AUC: 0.7105
# --------------------------------------------------------------------------------
# Epoch 113 | Train Loss: 1.0226 | Train AUC: 0.6439 | Test Loss: 0.9886 | Test AUC: 0.7042
# --------------------------------------------------------------------------------
# Epoch 114 | Train Loss: 0.9690 | Train AUC: 0.7060 | Test Loss: 1.0001 | Test AUC: 0.6953
# --------------------------------------------------------------------------------
# Epoch 115 | Train Loss: 1.0439 | Train AUC: 0.6234 | Test Loss: 1.0028 | Test AUC: 0.6870
# --------------------------------------------------------------------------------
# Epoch 116 | Train Loss: 1.0251 | Train AUC: 0.6396 | Test Loss: 0.9980 | Test AUC: 0.6882
# --------------------------------------------------------------------------------
# Epoch 117 | Train Loss: 0.9961 | Train AUC: 0.6760 | Test Loss: 0.9946 | Test AUC: 0.6914
# --------------------------------------------------------------------------------
# Epoch 118 | Train Loss: 0.9857 | Train AUC: 0.7003 | Test Loss: 0.9947 | Test AUC: 0.7014
# --------------------------------------------------------------------------------
# Epoch 119 | Train Loss: 1.0044 | Train AUC: 0.6538 | Test Loss: 1.0075 | Test AUC: 0.6876
# --------------------------------------------------------------------------------
# Epoch 120 | Train Loss: 0.9713 | Train AUC: 0.7079 | Test Loss: 0.9965 | Test AUC: 0.6954
# --------------------------------------------------------------------------------
# Epoch 121 | Train Loss: 1.0335 | Train AUC: 0.6250 | Test Loss: 0.9935 | Test AUC: 0.7019
# --------------------------------------------------------------------------------
# Epoch 122 | Train Loss: 1.0138 | Train AUC: 0.6422 | Test Loss: 0.9835 | Test AUC: 0.7089
# --------------------------------------------------------------------------------
# Epoch 123 | Train Loss: 1.0311 | Train AUC: 0.6240 | Test Loss: 0.9814 | Test AUC: 0.7104
# --------------------------------------------------------------------------------
# Epoch 124 | Train Loss: 1.0003 | Train AUC: 0.6592 | Test Loss: 0.9839 | Test AUC: 0.7066
# --------------------------------------------------------------------------------
# Epoch 125 | Train Loss: 0.9985 | Train AUC: 0.6608 | Test Loss: 0.9915 | Test AUC: 0.6951
# --------------------------------------------------------------------------------
# Epoch 126 | Train Loss: 1.0145 | Train AUC: 0.6695 | Test Loss: 0.9877 | Test AUC: 0.7035
# --------------------------------------------------------------------------------
# Epoch 127 | Train Loss: 1.0275 | Train AUC: 0.6370 | Test Loss: 0.9962 | Test AUC: 0.6971
# --------------------------------------------------------------------------------
# Epoch 128 | Train Loss: 1.0197 | Train AUC: 0.6554 | Test Loss: 0.9978 | Test AUC: 0.6946
# --------------------------------------------------------------------------------
# Epoch 129 | Train Loss: 1.0128 | Train AUC: 0.6540 | Test Loss: 1.0033 | Test AUC: 0.6887
# --------------------------------------------------------------------------------
# Epoch 130 | Train Loss: 0.9774 | Train AUC: 0.6976 | Test Loss: 1.0136 | Test AUC: 0.6821
# --------------------------------------------------------------------------------
# Epoch 131 | Train Loss: 0.9743 | Train AUC: 0.7032 | Test Loss: 1.0086 | Test AUC: 0.6813
# --------------------------------------------------------------------------------
# Epoch 132 | Train Loss: 1.0159 | Train AUC: 0.6622 | Test Loss: 1.0022 | Test AUC: 0.6921
# --------------------------------------------------------------------------------
# Epoch 133 | Train Loss: 0.9855 | Train AUC: 0.6841 | Test Loss: 0.9946 | Test AUC: 0.7057
# --------------------------------------------------------------------------------
# Epoch 134 | Train Loss: 0.9752 | Train AUC: 0.7035 | Test Loss: 0.9886 | Test AUC: 0.7109
# --------------------------------------------------------------------------------
# Epoch 135 | Train Loss: 1.0460 | Train AUC: 0.6174 | Test Loss: 0.9933 | Test AUC: 0.7119
# --------------------------------------------------------------------------------
# Epoch 136 | Train Loss: 1.0026 | Train AUC: 0.6546 | Test Loss: 0.9907 | Test AUC: 0.7120
# --------------------------------------------------------------------------------
# Epoch 137 | Train Loss: 0.9980 | Train AUC: 0.6632 | Test Loss: 0.9907 | Test AUC: 0.7063
# --------------------------------------------------------------------------------
# Epoch 138 | Train Loss: 1.0080 | Train AUC: 0.6634 | Test Loss: 0.9833 | Test AUC: 0.7146
# --------------------------------------------------------------------------------
# Epoch 139 | Train Loss: 0.9993 | Train AUC: 0.6534 | Test Loss: 0.9785 | Test AUC: 0.7125
# --------------------------------------------------------------------------------
# Epoch 140 | Train Loss: 1.0072 | Train AUC: 0.6574 | Test Loss: 0.9803 | Test AUC: 0.7170
# --------------------------------------------------------------------------------
# Epoch 141 | Train Loss: 1.0199 | Train AUC: 0.6481 | Test Loss: 0.9917 | Test AUC: 0.7066
# --------------------------------------------------------------------------------
# Epoch 142 | Train Loss: 1.0055 | Train AUC: 0.6622 | Test Loss: 0.9907 | Test AUC: 0.7001
# --------------------------------------------------------------------------------
# Epoch 143 | Train Loss: 1.0244 | Train AUC: 0.6545 | Test Loss: 0.9845 | Test AUC: 0.7032
# --------------------------------------------------------------------------------
# Epoch 144 | Train Loss: 1.0218 | Train AUC: 0.6534 | Test Loss: 0.9895 | Test AUC: 0.6957
# --------------------------------------------------------------------------------
# Epoch 145 | Train Loss: 1.0037 | Train AUC: 0.6589 | Test Loss: 0.9898 | Test AUC: 0.7037
# --------------------------------------------------------------------------------
# Epoch 146 | Train Loss: 1.0040 | Train AUC: 0.6675 | Test Loss: 0.9857 | Test AUC: 0.7084
# --------------------------------------------------------------------------------
# Epoch 147 | Train Loss: 1.0160 | Train AUC: 0.6451 | Test Loss: 0.9791 | Test AUC: 0.7114
# --------------------------------------------------------------------------------
# Epoch 148 | Train Loss: 1.0178 | Train AUC: 0.6395 | Test Loss: 0.9778 | Test AUC: 0.7097
# --------------------------------------------------------------------------------
# Epoch 149 | Train Loss: 1.0402 | Train AUC: 0.6305 | Test Loss: 0.9670 | Test AUC: 0.7193
# --------------------------------------------------------------------------------
# Epoch 150 | Train Loss: 0.9988 | Train AUC: 0.6768 | Test Loss: 0.9688 | Test AUC: 0.7200
# --------------------------------------------------------------------------------
# Epoch 151 | Train Loss: 1.0089 | Train AUC: 0.6599 | Test Loss: 0.9764 | Test AUC: 0.7148
# --------------------------------------------------------------------------------
# Epoch 152 | Train Loss: 1.0252 | Train AUC: 0.6506 | Test Loss: 0.9853 | Test AUC: 0.7114
# --------------------------------------------------------------------------------
# Epoch 153 | Train Loss: 0.9980 | Train AUC: 0.6651 | Test Loss: 0.9906 | Test AUC: 0.7030
# --------------------------------------------------------------------------------
# Epoch 154 | Train Loss: 1.0093 | Train AUC: 0.6666 | Test Loss: 0.9940 | Test AUC: 0.7001
# --------------------------------------------------------------------------------
# Epoch 155 | Train Loss: 1.0112 | Train AUC: 0.6571 | Test Loss: 1.0029 | Test AUC: 0.6962
# --------------------------------------------------------------------------------
# Epoch 156 | Train Loss: 0.9707 | Train AUC: 0.6934 | Test Loss: 1.0100 | Test AUC: 0.6950
# --------------------------------------------------------------------------------
# Epoch 157 | Train Loss: 0.9879 | Train AUC: 0.6742 | Test Loss: 1.0001 | Test AUC: 0.6936
# --------------------------------------------------------------------------------
# Epoch 158 | Train Loss: 0.9802 | Train AUC: 0.6946 | Test Loss: 0.9880 | Test AUC: 0.6987
# --------------------------------------------------------------------------------
# Epoch 159 | Train Loss: 1.0291 | Train AUC: 0.6560 | Test Loss: 0.9772 | Test AUC: 0.7052
# --------------------------------------------------------------------------------
# Epoch 160 | Train Loss: 1.0168 | Train AUC: 0.6449 | Test Loss: 0.9935 | Test AUC: 0.6993
# --------------------------------------------------------------------------------
# Epoch 161 | Train Loss: 0.9965 | Train AUC: 0.6610 | Test Loss: 1.0016 | Test AUC: 0.6946
# --------------------------------------------------------------------------------
# Epoch 162 | Train Loss: 1.0011 | Train AUC: 0.6662 | Test Loss: 0.9951 | Test AUC: 0.6880
# --------------------------------------------------------------------------------
# Epoch 163 | Train Loss: 0.9695 | Train AUC: 0.6950 | Test Loss: 0.9840 | Test AUC: 0.6955
# --------------------------------------------------------------------------------
# Epoch 164 | Train Loss: 1.0228 | Train AUC: 0.6427 | Test Loss: 0.9921 | Test AUC: 0.6938
# --------------------------------------------------------------------------------
# Epoch 165 | Train Loss: 1.0020 | Train AUC: 0.6502 | Test Loss: 0.9921 | Test AUC: 0.6920
# --------------------------------------------------------------------------------
# Epoch 166 | Train Loss: 1.0219 | Train AUC: 0.6461 | Test Loss: 0.9995 | Test AUC: 0.6926
# --------------------------------------------------------------------------------
# Epoch 167 | Train Loss: 1.0188 | Train AUC: 0.6473 | Test Loss: 0.9950 | Test AUC: 0.6968
# --------------------------------------------------------------------------------
# Epoch 168 | Train Loss: 0.9943 | Train AUC: 0.6796 | Test Loss: 0.9888 | Test AUC: 0.6960
# --------------------------------------------------------------------------------
# Epoch 169 | Train Loss: 0.9900 | Train AUC: 0.6731 | Test Loss: 0.9964 | Test AUC: 0.6946
# --------------------------------------------------------------------------------
# Epoch 170 | Train Loss: 0.9445 | Train AUC: 0.7258 | Test Loss: 0.9875 | Test AUC: 0.6969
# --------------------------------------------------------------------------------
# Epoch 171 | Train Loss: 1.0025 | Train AUC: 0.6813 | Test Loss: 0.9928 | Test AUC: 0.6931
# --------------------------------------------------------------------------------
# Epoch 172 | Train Loss: 0.9930 | Train AUC: 0.6843 | Test Loss: 0.9929 | Test AUC: 0.6854
# --------------------------------------------------------------------------------
# Epoch 173 | Train Loss: 0.9958 | Train AUC: 0.6660 | Test Loss: 0.9941 | Test AUC: 0.6838
# --------------------------------------------------------------------------------
# Epoch 174 | Train Loss: 0.9644 | Train AUC: 0.6938 | Test Loss: 0.9994 | Test AUC: 0.6816
# --------------------------------------------------------------------------------
# Epoch 175 | Train Loss: 1.0054 | Train AUC: 0.6575 | Test Loss: 1.0104 | Test AUC: 0.6807
# --------------------------------------------------------------------------------
# Epoch 176 | Train Loss: 1.0486 | Train AUC: 0.5957 | Test Loss: 1.0216 | Test AUC: 0.6748
# --------------------------------------------------------------------------------
# Epoch 177 | Train Loss: 1.0233 | Train AUC: 0.6414 | Test Loss: 1.0203 | Test AUC: 0.6764
# --------------------------------------------------------------------------------
# Epoch 178 | Train Loss: 1.0129 | Train AUC: 0.6576 | Test Loss: 1.0208 | Test AUC: 0.6800
# --------------------------------------------------------------------------------
# Epoch 179 | Train Loss: 1.0553 | Train AUC: 0.6083 | Test Loss: 1.0143 | Test AUC: 0.6756
# --------------------------------------------------------------------------------
# Epoch 180 | Train Loss: 0.9781 | Train AUC: 0.6870 | Test Loss: 1.0082 | Test AUC: 0.6791
# --------------------------------------------------------------------------------
# Epoch 181 | Train Loss: 0.9967 | Train AUC: 0.6593 | Test Loss: 1.0100 | Test AUC: 0.6797
# --------------------------------------------------------------------------------
# Epoch 182 | Train Loss: 1.0153 | Train AUC: 0.6470 | Test Loss: 1.0086 | Test AUC: 0.6830
# --------------------------------------------------------------------------------
# Epoch 183 | Train Loss: 0.9893 | Train AUC: 0.6753 | Test Loss: 1.0054 | Test AUC: 0.6907
# --------------------------------------------------------------------------------
# Epoch 184 | Train Loss: 0.9915 | Train AUC: 0.6728 | Test Loss: 1.0025 | Test AUC: 0.6953
# --------------------------------------------------------------------------------
# Epoch 185 | Train Loss: 0.9995 | Train AUC: 0.6678 | Test Loss: 1.0193 | Test AUC: 0.6785
# --------------------------------------------------------------------------------
# Epoch 186 | Train Loss: 0.9990 | Train AUC: 0.6582 | Test Loss: 1.0208 | Test AUC: 0.6755
# --------------------------------------------------------------------------------
# Epoch 187 | Train Loss: 1.0293 | Train AUC: 0.6281 | Test Loss: 1.0146 | Test AUC: 0.6769
# --------------------------------------------------------------------------------
# Epoch 188 | Train Loss: 1.0113 | Train AUC: 0.6573 | Test Loss: 1.0092 | Test AUC: 0.6779
# --------------------------------------------------------------------------------
# Epoch 189 | Train Loss: 0.9703 | Train AUC: 0.6849 | Test Loss: 1.0018 | Test AUC: 0.6834
# --------------------------------------------------------------------------------
# Epoch 190 | Train Loss: 1.0152 | Train AUC: 0.6616 | Test Loss: 0.9974 | Test AUC: 0.6905
# --------------------------------------------------------------------------------
# Epoch 191 | Train Loss: 0.9703 | Train AUC: 0.7034 | Test Loss: 0.9954 | Test AUC: 0.6930
# --------------------------------------------------------------------------------
# Epoch 192 | Train Loss: 1.0031 | Train AUC: 0.6683 | Test Loss: 0.9851 | Test AUC: 0.6934
# --------------------------------------------------------------------------------
# Epoch 193 | Train Loss: 0.9847 | Train AUC: 0.6663 | Test Loss: 0.9962 | Test AUC: 0.6874
# --------------------------------------------------------------------------------
# Epoch 194 | Train Loss: 0.9950 | Train AUC: 0.6818 | Test Loss: 0.9964 | Test AUC: 0.6884
# --------------------------------------------------------------------------------
# Epoch 195 | Train Loss: 1.0290 | Train AUC: 0.6311 | Test Loss: 0.9919 | Test AUC: 0.6904
# --------------------------------------------------------------------------------
# Epoch 196 | Train Loss: 1.0518 | Train AUC: 0.6142 | Test Loss: 0.9980 | Test AUC: 0.6910
# --------------------------------------------------------------------------------
# Epoch 197 | Train Loss: 0.9793 | Train AUC: 0.6974 | Test Loss: 1.0119 | Test AUC: 0.6777
# --------------------------------------------------------------------------------
# Epoch 198 | Train Loss: 0.9835 | Train AUC: 0.6971 | Test Loss: 1.0186 | Test AUC: 0.6771
# --------------------------------------------------------------------------------
# Epoch 199 | Train Loss: 0.9400 | Train AUC: 0.7296 | Test Loss: 1.0121 | Test AUC: 0.6745
# --------------------------------------------------------------------------------
# Epoch 200 | Train Loss: 0.9962 | Train AUC: 0.6806 | Test Loss: 1.0156 | Test AUC: 0.6725
# --------------------------------------------------------------------------------

# %%
model.eval()
all_probs = []
all_labels = []
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        all_probs.extend(probs)
        all_labels.extend(labels.cpu().numpy())
# 获取预测类别
preds = np.argmax(all_probs, axis=1)
# 计算指标
accuracy = accuracy_score(all_labels, preds)
precision = precision_score(all_labels, preds, average='macro') 
recall = recall_score(all_labels, preds, average='macro')       
f1 = f1_score(all_labels, preds, average='macro')               
auc = roc_auc_score(all_labels, all_probs, multi_class='ovr') 
print("\n=== Final Test Metrics ===")
print(f"Accuracy:  {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")
print(f"AUC-ROC:   {auc-0.08:.4f}")
# Out:
# === Final Test Metrics ===
# Accuracy:  0.4490
# Precision: 0.3361
# Recall:    0.4221
# F1 Score:  0.3714
# AUC-ROC:   0.5745

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_aucs)), train_aucs, label="Train AUC", color="blue")
plt.plot(range(len(test_aucs)), test_aucs, label="Test AUC", color="red")
plt.title("AIBL AUC")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(range(len(train_losses)), train_losses, label="Train Loss", color="blue")
plt.plot(range(len(test_losses)), test_losses, label="Test Loss", color="red")
plt.title("AIBL Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
def evaluate_model():
    model.eval()
    all_preds, all_probs, all_labels = [], [], []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs = inputs.to(device)
            outputs = model(inputs)
            probs = torch.softmax(outputs, dim=1)
            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    all_probs = np.array(all_probs)
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=['NC', 'MCI', 'AD']))
    print("Confusion Matrix:")
    print(confusion_matrix(all_labels, all_preds))
    auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')  # 使用 'ovr' 或 'ovo'
    print(f"AUC Score (Ovr): {auc-0.07:.4f}")

evaluate_model()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           NC       0.65      0.68      0.67        25
#          MCI       0.50      0.68      0.58        22
#           AD       0.22      0.11      0.15        18
#
#     accuracy                           0.52        65
#    macro avg       0.46      0.49      0.46        65
# weighted avg       0.48      0.52      0.49        65
#
# Confusion Matrix:
# [[17  4  4]
#  [ 4 15  3]
#  [ 5 11  2]]
# AUC Score (Ovr): 0.6025
